# %% [markdown]
# # Version description
# - PCA & FS splitting between stock & market feats
# - Full Run

# %%
# import libraries
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
from os.path import isfile, isdir, join
import numpy as np
import pandas as pd
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
import re
from IPython.display import display
from zipfile import ZipFile
import pickle
import unicodedata
import pytz
from joblib import Parallel, delayed
import shutil
import difflib
import random
import math
from shutil import copyfile
import itertools
import time
from tqdm import tqdm
import collections
from collections import deque
import gc

from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer
from sklearn.metrics import ndcg_score, accuracy_score, mean_squared_error

import lightgbm as lgbm
import optuna
from optuna import Trial, visualization

import matplotlib as mpl
from matplotlib import pyplot as plt

import jpx_tokyo_market_prediction

from utility_script import *
# from utility_script_jpx import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
'''
Notebook Parameters
'''
# basic
SEED = 0
JPX_PATH = '../input/jpx-tokyo-stock-exchange-prediction'

# data sacling
SCALER = StandardScaler()
SCALE_DAILY = False

# feature composition
DROP_MARKET_FEATS = False

# PCA
RUN_PCA = True
PCA_SPLIT = True
N_COMP = 0.9

# target definition
RANK_ASCENDING = False # set this to False if model prediction is same direction of Target
TARGET_POW = 0

# data split
N_FOLD = 5
TRN_SIZE = 240
VAL_SIZE = 60
TRN_VAL_GAP = 14
SPLIT_METHOD = 'trn_val_split_late_val'

# model fixed params
DEVICE_TYPE = 'CPU'
EVAL_METRIC = f'binary_logloss'
LGBM_VAR_PARAMS = dict(
    max_depth = 32,
    num_leaves = 32,
    learning_rate = 0.01,
    min_child_weight = 0.1,
    min_child_samples = 1,
    subsample = 0.65,
    subsample_freq = 1,
    colsample_bytree = 0.6,
    reg_alpha = 1.5,
    reg_lambda = 1.5,
    max_bin = 255,
)
LGBM_FIXED_PARAMS = dict(
    boosting_type = 'gbdt',
    objective = 'binary',
    n_estimators = 5000,
    n_jobs = -1,
    random_state = SEED,
    device_type = DEVICE_TYPE,
)

# feature importance
RUN_IMP = True
N_SHUFFLE = 12
N_FEATS_IMP_TEST = 10
N_ESTIMATORS_IMP = 50
EARLY_STOPPING_ROUNDS_IMP = 9999
FEAT_GROUPS = None # fixed output if not running IMP

# forward selection
RUN_FS = True
FS_SPLIT = {'n_stock_feats': 20, 'n_market_feats': 10}
SELECTED_STOCK_FEATS = None
N_ESTIMATORS_FS = 5000
EARLY_STOPPING_ROUNDS_FS = 20
N_FEATS_FS = None # top N features considered for FS based on importance
N_FEATS_FINAL = None # top N features if skipping FS based on importance
SELECTED_FEATS = ''.split(', ') # fixed features if skipping both IMP and FS

# hyperparameters tuning
RUN_HP = True
N_ESTIMATORS_HP = 5000
EARLY_STOPPING_ROUNDS_HP = 30
HP_OPT_HRS = 4
BEST_PARAMS = None

# re-fit
N_ESTIMATORS_REFIT = 5000
EARLY_STOPPING_ROUNDS_REFIT = 30

# %% [markdown]
# # Data preprocessing

# %%
'''
Train-Val split where validation periods are right after train period
'''
def trn_val_split_even_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).head(VAL_SIZE)
        else:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).loc[lambda x: x.notnull()]
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data


'''
Train-Val split where validation periods are farthest in future
'''
def trn_val_split_late_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    val_dates_list = full_dates.tail(VAL_SIZE * N_FOLD).values.reshape(N_FOLD, -1)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = val_dates_list[i]
        else:
            dates_val = np.concatenate(val_dates_list[i:])
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data

# %%
'''
Function to scale the features
'''
def jpx_data_scaling(full_data, scaler, daily):
    feats = time_features + stock_features
    
    if daily==False:
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[feats])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[feats] = scaler.transform(data_trn[feats]).astype(np.float32)
            data_val[feats] = scaler.transform(data_val[feats]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
            
    elif daily==True:
        # scale stock features for each day
        def transform_data(df, scaler, feats):
            df[feats] = scaler.fit_transform(df[feats]).astype(np.float32)
            return df
        full_data = full_data.groupby(['fold','trn_val','Date']).apply(lambda df: transform_data(df, scaler, stock_features))
        # then scale time features across days
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[time_features])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[time_features] = scaler.transform(data_trn[time_features]).astype(np.float32)
            data_val[time_features] = scaler.transform(data_val[time_features]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
        
    return data_scaled

# %%
'''
PCA Compression
'''
def pca_compress(full_data):
    
    if PCA_SPLIT==False:
        # fit with one fold of traiing data
        pca = PCA(n_components=N_COMP, random_state=SEED)
        pca.fit(full_data.loc[lambda x: (x.fold==0) & (x.trn_val=='trn'), all_features])
        save_pkl(pca, 'pca')
        log(f'PCA shape of components: {pca.components_.shape}')
        
        # tranform the full dataset
        cols = [f'pc{x}' for x in range(pca.components_.shape[0])]
        compressed_data = []
        for fold in range(N_FOLD):
            for trn_val in ['trn','val']:
                X = pd.DataFrame(pca.transform(full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), all_features]), columns=cols)
                header = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), [c for c in full_data.columns if c not in all_features]].reset_index(drop=True)
                new_df = pd.concat([header, X], axis=1)
                compressed_data.append(new_df)
        compressed_data = pd.concat(compressed_data, axis=0).reset_index(drop=True)
        col_def = {'all_features': cols,
                   'stock_features': None,
                   'time_features': None}
        
    elif PCA_SPLIT==True:
        # fit with one fold of traiing data
        stock_feats = [c for c in all_features if c not in time_features]
        market_feats = [c for c in all_features if c in time_features]
        pca_stock = PCA(n_components=N_COMP, random_state=SEED)
        pca_market = PCA(n_components=N_COMP, random_state=SEED)
        pca_stock.fit(full_data.loc[lambda x: (x.fold==0) & (x.trn_val=='trn'), stock_feats])
        pca_market.fit(full_data.loc[lambda x: (x.fold==0) & (x.trn_val=='trn'), market_feats])
        save_pkl(pca_stock, 'pca_stock')
        save_pkl(pca_market, 'pca_market')
        log(f'Stock PCA shape of components: {pca_stock.components_.shape}')
        log(f'Market PCA shape of components: {pca_market.components_.shape}')
    
        # tranform the full dataset
        cols_stock = [f'pc_stock{x}' for x in range(pca_stock.components_.shape[0])]
        cols_market = [f'pc_market{x}' for x in range(pca_market.components_.shape[0])]
        compressed_data = []
        for fold in range(N_FOLD):
            for trn_val in ['trn','val']:
                X_stock = pd.DataFrame(pca_stock.transform(full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), stock_feats]), columns=cols_stock)
                X_market = pd.DataFrame(pca_market.transform(full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), market_feats]), columns=cols_market)
                header = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), [c for c in full_data.columns if c not in all_features]].reset_index(drop=True)
                new_df = pd.concat([header, X_stock, X_market], axis=1)
                compressed_data.append(new_df)
        compressed_data = pd.concat(compressed_data, axis=0).reset_index(drop=True)
        col_def = {'all_features': cols_stock + cols_market,
                   'stock_features': cols_stock,
                   'time_features': cols_market}
    return compressed_data, col_def

# %% [markdown]
# # Model Training Functions

# %%
'''
Function to get sub-columns from table for model fitting
'''
def get_dataset(df, selected_feats, trn_val):
    if trn_val=='val':
        df = df.groupby('Date').sample(frac=1.0, random_state=SEED)
    df = df.reset_index(drop=True)
    grp = df.groupby('Date').size().tolist()
    qid = df['Date']
    X = df[selected_feats]
    y = df['target_train']
    target = df['Target']
    header = df[id_cols]
    return X, y, grp, qid, header, target

'''
Function to predict scores within groups
'''
def pred_score(model, X):
    return pd.Series(model.predict_proba(X)[:,1])

'''
Function to predict rankings within groups
'''
def pred_rank(model, X, qid):
    X_ = X.assign(Date=qid)
    rnk = []
    for date in X_.Date.unique():
        rnk += pd.Series(model.predict_proba(X_.loc[lambda x: x.Date==date].drop('Date',axis=1))[:,1]).rank(method='first').tolist()
    return pd.Series(rnk)

'''
Function to transform model output to rank prediction table
'''
def get_pred_df(header, pred_model, y_true_train, y_true, rank_ascending):
    df_pred = pd.concat([header[['RowId','Date','SecuritiesCode']].assign(Date=lambda x: x.Date.dt.strftime('%Y-%m-%d'), SecuritiesCode=lambda x: x.SecuritiesCode.astype(int)).reset_index(drop=True),
                        pd.Series(pred_model).rename('pred_model').reset_index(drop=True),
                        y_true_train.reset_index(drop=True),
                        y_true.reset_index(drop=True)
                        ], axis=1)
    df_pred['Rank'] = df_pred.groupby('Date').pred_model.rank(method='first', ascending=rank_ascending).astype(int) - 1
    return df_pred

'''
Official function to calculate Sharpe Ratio given a prediction
'''
def _calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def my_calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return pd.DataFrame({'long':[purchase],'short':[short],'net':[purchase - short]})

def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    buf = df.groupby('Date').apply(_calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio

# %%
'''
Training function
'''
def train_model(fold, params, mode):
    # unpack model params
    selected_feats = params['selected_feats']
    lgbm_var_params = params['lgbm_var_params']
    lgbm_fixed_params = params['lgbm_fixed_params']
    lgbm_fixed_params['n_estimators'] = params['n_estimators']
    early_stopping_rounds = params['early_stopping_rounds']
    
    # define dataset
    data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
    data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
    X_trn, y_trn, grp_trn, qid_trn, header_trn, target_trn = get_dataset(data_trn, selected_feats, 'trn')
    X_val, y_val, grp_val, qid_val, header_val, target_val = get_dataset(data_val, selected_feats, 'val')
    # model fit
    model = lgbm.LGBMClassifier(**lgbm_fixed_params, **lgbm_var_params)
    model.fit(
        X = X_trn,
        y = y_trn,
        eval_set = [(X_val, y_val)],
        eval_names = ['Validation'],
        verbose = False,
        eval_metric = EVAL_METRIC,
        early_stopping_rounds = early_stopping_rounds
    )

    # output
    if mode == 'val_score_only':
        output = model.best_score_['Validation'][EVAL_METRIC] # this score is for minimization problem
        
    if mode == 'val_sharpe_only':
        pred_val = pred_score(model, X_val)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        output = sharpe_val * -1 # this score is for minimization problem
        
    if mode == 'feat_imp':
        model.set_params(importance_type='gain')
        imp_gain = model.feature_importances_
        model.set_params(importance_type='split')
        imp_split = model.feature_importances_
        output = pd.concat([
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_gain}).assign(imp_type='gain', imp=lambda x: x.imp.rank()),
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_split}).assign(imp_type='split', imp=lambda x: x.imp.rank())
        ], axis=0).assign(fold=fold)
    
    if mode == 'normal':
        # save model
        save_pkl(model, f"model{fold}")
        # number of distinct predicted values
        n_uniq_trn = pd.concat([pred_score(model, X_trn).rename('score'), header_trn], axis=1).groupby('Date').score.nunique().mean()
        n_uniq_val = pd.concat([pred_score(model, X_val).rename('score'), header_val], axis=1).groupby('Date').score.nunique().mean()
        # prediction
        pred_trn = pred_score(model, X_trn)
        pred_val = pred_score(model, X_val)
        # prediction df
        df_pred_trn = get_pred_df(header_trn, pred_trn, y_trn, target_trn, RANK_ASCENDING)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        # sharpe
        sharpe_trn = calc_spread_return_sharpe(df_pred_trn)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        # output dict
        output = dict(
            fold = fold,
            params = params,
            best_iteration_ = model.best_iteration_,
            best_score_ = model.best_score_['Validation'][EVAL_METRIC],
            sharpe = {'trn': sharpe_trn, 'val': sharpe_val},
            ann_sharpe = {'trn': sharpe_trn * np.sqrt(240), 'val': sharpe_val * np.sqrt(240)},
            evals_result_ = model.evals_result_['Validation'][EVAL_METRIC],
            feat_imp = pd.DataFrame(list(zip(model.feature_name_, model.feature_importances_)), columns=['feat','imp']),
            df_pred_val = df_pred_val,
            n_uniq_trn = n_uniq_trn,
            n_uniq_val = n_uniq_val,
        )
    return output

# %% [markdown]
# # Feature Importance

# %%
def run_feature_importance():
    # random sampling of features
    all_feats = all_features.copy()
    feat_groups = []
    for i in range(N_SHUFFLE):
        random.shuffle(all_feats)
        n_groups = math.floor(len(all_feats)/N_FEATS_IMP_TEST)
        feat_groups += np.array(all_feats[:N_FEATS_IMP_TEST*n_groups]).reshape(-1,N_FEATS_IMP_TEST).tolist()
    log(f'Total number of run: {len(feat_groups)}')
    
    # calculate feature importance
    df_imp = []
    for i, group in enumerate(feat_groups):
        for fold in range(N_FOLD):
            params = {'selected_feats': group, 
                      'lgbm_var_params': LGBM_VAR_PARAMS,
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_IMP,
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_IMP}
            df_imp.append(train_model(fold, params, 'feat_imp'))
        log(f'Completed running feature group {i}') if i%10==0 else None
    df_imp = pd.concat(df_imp)
    df_imp_agg = df_imp.groupby('feat').imp.mean().sort_values(ascending=False).reset_index()
    df_imp_agg.to_csv('df_imp_agg.csv', index=False)
    display(df_imp_agg.head(10))

    # plotting feature importance
    df_imp_agg.sort_values('imp', ascending=True).set_index('feat').plot.barh(figsize=(20, 20))
    return df_imp_agg

# %% [markdown]
# # Forward Selection

# %%
'''
Forward Selection function
'''
def forward_selection(base_feats, feat_groups, name):
    if base_feats==None:
        base_feats = []
    hist = []
    while len(feat_groups) > 0:
        scores = []
        for feats in feat_groups:
            # calculate CV score
            params = {'selected_feats': base_feats + feats, 
                      'lgbm_var_params': LGBM_VAR_PARAMS, 
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_FS, 
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_FS}
            mean_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
            scores.append(mean_score)
            hist.append((mean_score,
                         len(base_feats + feats),
                         ', '.join(base_feats + feats)
                         ))
            log(f'Score: {mean_score}; Num features: {len(base_feats + feats)}; Features: {", ".join(base_feats + feats)}')
        # add the new feature (group) which gives minimum score
        base_feats += feat_groups[np.argmin(scores)]
        # remove the added feature (group) from remaining candidate pool
        del feat_groups[np.argmin(scores)]
    hist = pd.DataFrame(hist, columns=['score','len_feats','total_feats'])
    hist.to_csv(f'fs_hist_{name}.csv', index=False)
    return hist

# %% [markdown]
# # Hyperparameter Tuning

# %%
'''
Hyperparameter Optimization function
'''
def Objective(trial):
    lgbm_var_params = dict(
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True),
        num_leaves = trial.suggest_int('num_leaves', 16, 64, log=True),
        learning_rate = trial.suggest_float("learning_rate", 0.005, 0.2),
        min_child_weight = trial.suggest_float("min_child_weight", 1e-3, 4, log=True),
        subsample = trial.suggest_float("subsample", 0.5, 1),
        subsample_freq = trial.suggest_categorical("subsample_freq", [1,2,4,6,8]),
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1),
        reg_alpha = trial.suggest_float("reg_alpha", 1e-2, 16, log=True),
        reg_lambda = trial.suggest_float("reg_lambda", 1e-2, 16, log=True),
        max_bin = trial.suggest_int('max_bin', 50, 500),
    )
    
    # pack all params
    params = {'selected_feats': selected_feats, 
              'lgbm_var_params': lgbm_var_params, 
              'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
              'n_estimators': N_ESTIMATORS_HP, 
              'early_stopping_rounds': EARLY_STOPPING_ROUNDS_HP}
    # return average CV score
    cv_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
    return cv_score


def optimize_hp():
    # run optimization
    study = optuna.create_study(direction="minimize", study_name='LGBM optimization')
    study.optimize(Objective, timeout=HP_OPT_HRS*60*60)
    
    # save results
    best_params = study.best_params
    best_score = study.best_value
    log(best_params)
    log(f'Best score is {best_score}')
    trials = study.trials_dataframe()
    trials.to_csv(f'trials.csv', index=False)
    save_pkl(best_params, f'best_params')
    save_pkl(study, f'study')
    
    # visualise relationship between parameter and CV score
    for c in trials.columns:
        if c[:7]=='params_':
            new_plot()
            trials.plot.scatter(c, 'value')
            plt.grid()
            plt.title(c)
            plt.show()
    return best_params

# %% [markdown]
# # Signal Analysis

# %%
def analyze_signal(outputs):
    df = pd.concat([x['df_pred_val'] for x in outputs])
    df.Date = pd.to_datetime(df.Date)
    df['rank_pred'] = df.groupby('Date').pred_model.rank(method='first',ascending=False)
    df['rank_true'] = df.groupby('Date').target_train.rank(method='first',ascending=True)

    # distribution of model prediction
    new_plot()
    df.pred_model.hist(bins=100)
    plt.grid()
    plt.title('Distribution of model prediction')

    # percentage in correct region
    new_plot()
    n = 200
    top = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true>=2000-n) & (x.rank_pred>=2000-n)].shape[0]).divide(n)
    bottom = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true<=n) & (x.rank_pred<=n)].shape[0]).divide(n)
    top.rolling(20).mean().plot(label='top')
    bottom.rolling(20).mean().plot(label='bottom')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('% in correct region')
    log(f'Average % in top 200: {top.mean()}')
    log(f'Average % in bottom 200: {bottom.mean()}')

    # portfolio return analysis
    ret = df.groupby('Date').apply(my_calc_spread_return_per_day, 200, 2)
    ret = ret.reset_index().set_index('Date') \
        .assign(short = lambda x: -1 * x.short)

    # cumulative returns
    new_plot()
    ret.long.cumsum().plot(label='long')
    ret.short.cumsum().plot(label='short')
    ret.net.cumsum().plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Cumulative Returns')
    log(f'Mean long returns: {ret.long.mean()}')
    log(f'Mean short returns: {ret.short.mean()}')
    log(f'Mean net returns: {ret.net.mean()}')

    # rolling sharpes
    new_plot()
    ret.long.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='long')
    ret.short.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='short')
    ret.net.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Rolling Sharpes')
    log(f'Sharpe of long: {ret.long.mean() / ret.long.std()}')
    log(f'Sharpe of short: {ret.short.mean() / ret.short.std()}')
    log(f'Sharpe of net: {ret.net.mean() / ret.net.std()}')

# %% [markdown]
# # Execution

# %%
# %%time
'''
Preprocessing
'''
# load features
path = '../input/jpx-feature-engineering/features'
features = pd.concat([pd.concat(load_pkl(f'{path}/{filename}')) for filename in os.listdir(path)]).sort_values('RowId').reset_index(drop=True)

# train-val split
if SPLIT_METHOD == 'trn_val_split_late_val':
    full_data = trn_val_split_late_val(features, val_to_end=False)
elif SPLIT_METHOD == 'trn_val_split_even_val':
    full_data = trn_val_split_even_val(features, val_to_end=False)
display(full_data.groupby(['fold','trn_val']).agg({'Date':['min','max','nunique']}))

# add targets
targets = pd.concat([pd.read_csv(f'{JPX_PATH}/{folder}/stock_prices.csv', parse_dates=['Date']) for folder in ['train_files', 'supplemental_files']]) \
    .loc[:,['RowId','Target']] \
    .loc[lambda x: x.Target.notnull()] \
    .drop_duplicates() \
    .reset_index(drop=True)
full_data = full_data.merge(targets, how='inner', on='RowId')

# remove irregular data
full_data = full_data.loc[lambda x: x.volatility_1w!=0].reset_index(drop=True)

# derive training target
full_data['target_train'] = full_data.groupby(['fold','trn_val','Date']).Target.apply(lambda s: (s >= s.quantile(0.5)).astype(int))

# release memory
del features
gc.collect()

# define column types
id_cols = ['RowId','Date','SecuritiesCode','fold','trn_val']
all_features = [c for c in list(full_data) if c not in id_cols and c not in ['target_train','Target']]
cat_features = ['AdjustmentFactor','first_div']
time_features = [c for c in all_features if '_mkt' in c] + \
                [c for c in all_features if c[:4]=='sec_'] + \
                [c for c in all_features if c[-4:] in ['_sin','_cos']]
stock_features = [c for c in all_features if c not in cat_features + time_features]

# scaling
full_data = jpx_data_scaling(full_data=full_data, scaler=SCALER, daily=SCALE_DAILY)

# drop market features
if DROP_MARKET_FEATS:
    full_data = full_data.drop(time_features, axis=1)
    all_features = [c for c in all_features if c not in time_features]

# PCA compression
if RUN_PCA:
    full_data, col_def = pca_compress(full_data)
    all_features = col_def['all_features']
    stock_features = col_def['stock_features']
    time_features = col_def['time_features']
# Out:
#                    Date
#                     min        max nunique
# fold trn_val
# 0    trn     2019-01-16 2020-01-14     240
#      val     2021-03-05 2021-06-02      60
# 1    trn     2019-07-23 2020-07-16     240
#      val     2021-06-03 2021-08-30      60
# 2    trn     2020-01-30 2021-01-22     240
#      val     2021-08-31 2021-11-26      60
# 3    trn     2020-08-06 2021-07-29     240
#      val     2021-11-29 2022-02-25      60
# 4    trn     2021-02-10 2022-02-02     240
#      val     2022-02-28 2022-05-27      60
# [2022-06-20 21:27:50] Stock PCA shape of components: (30, 59)
# [2022-06-20 21:27:50] Market PCA shape of components: (13, 26)
# CPU times: user 52.3 s, sys: 12.7 s, total: 1min 5s
# Wall time: 59.1 s

# %%
# %%time
'''
Feature importance
'''
if RUN_IMP:
    df_imp_agg = run_feature_importance()
# Out:
# [2022-06-20 21:28:03] Total number of run: 48
# [2022-06-20 21:28:15] Completed running feature group 0
# [2022-06-20 21:30:07] Completed running feature group 10
# [2022-06-20 21:32:00] Completed running feature group 20
# [2022-06-20 21:33:55] Completed running feature group 30
# [2022-06-20 21:35:49] Completed running feature group 40
#           feat       imp
# 0   pc_market3  8.870833
# 1  pc_market11  8.729167
# 2   pc_market2  8.600000
# 3   pc_market5  8.525000
# 4  pc_market10  8.509091
# 5  pc_market12  8.477273
# 6   pc_market4  8.391667
# 7   pc_market9  8.345455
# 8   pc_market7  8.231818
# 9   pc_market8  8.190000
# CPU times: user 27min 19s, sys: 4.14 s, total: 27min 23s
# Wall time: 9min 6s

# %%
# %%time
'''
Forward Selection
'''
if RUN_FS:
    
    # normal run
    if FS_SPLIT == None:
        feat_groups = [[x] for x in df_imp_agg.head(N_FEATS_FS).feat]
        fs_hist = forward_selection(base_feats=None, feat_groups=feat_groups, name='')
    
    # FS with splitting stock & market features
    elif FS_SPLIT != None:
        # running both stock & market feats
        if SELECTED_STOCK_FEATS == None:
            # FS for stock features
            feat_groups = [[x] for x in df_imp_agg.loc[lambda x: ~x.feat.isin(time_features)].head(FS_SPLIT['n_stock_feats']).feat]
            fs_hist_stock = forward_selection(base_feats=None, feat_groups=feat_groups, name='stock')
            base_feats = fs_hist_stock.sort_values('score', ascending=True).total_feats.iloc[0].split(', ')
        
        # fixed stock feats and run market feats
        else:
            base_feats = SELECTED_STOCK_FEATS.copy()
        # FS for market features
        feat_groups = [[x] for x in df_imp_agg.loc[lambda x: x.feat.isin(time_features)].head(FS_SPLIT['n_market_feats']).feat]
        fs_hist = forward_selection(base_feats=base_feats, feat_groups=feat_groups, name='market')
        
    # output selected features
    display(fs_hist.sort_values('score', ascending=True).head(1))
    selected_feats = fs_hist.sort_values('score', ascending=True).total_feats.iloc[0].split(', ')

else:
    # if not running both IMP and FS, output pre-set selected_feats
    if not RUN_IMP:
        selected_feats = SELECTED_FEATS
    # if ran IMP but not FS, output first N important features where N is pre-set
    elif RUN_IMP:
        selected_feats = [x[0] for x in feat_groups][:N_FEATS_FINAL]
# Out:
# [2022-06-20 21:37:44] Score: -0.1667578235957982; Num features: 1; Features: pc_stock14
# [2022-06-20 21:38:23] Score: -0.15310299060357924; Num features: 1; Features: pc_stock16
# [2022-06-20 21:38:54] Score: -0.11874963357128143; Num features: 1; Features: pc_stock21
# [2022-06-20 21:39:27] Score: -0.1085254411205302; Num features: 1; Features: pc_stock20
# [2022-06-20 21:39:43] Score: 0.01891423769633229; Num features: 1; Features: pc_stock2
# [2022-06-20 21:39:58] Score: 0.08488562613637086; Num features: 1; Features: pc_stock3
# [2022-06-20 21:40:12] Score: 0.0034605177442931026; Num features: 1; Features: pc_stock5
# [2022-06-20 21:40:31] Score: -0.023296557781621173; Num features: 1; Features: pc_stock22
# [2022-06-20 21:40:49] Score: -0.08122321292852099; Num features: 1; Features: pc_stock8
# [2022-06-20 21:41:10] Score: 0.0009321953128281702; Num features: 1; Features: pc_stock7
# [2022-06-20 21:41:24] Score: -0.02434527951558344; Num features: 1; Features: pc_stock11
# [2022-06-20 21:41:43] Score: -0.07076720596861945; Num features: 1; Features: pc_stock19
# [2022-06-20 21:41:58] Score: -0.026754681110995986; Num features: 1; Features: pc_stock6
# [2022-06-20 21:42:09] Score: 0.017936580367397682; Num features: 1; Features: pc_stock1
# [2022-06-20 21:42:33] Score: -0.15924168258305127; Num features: 1; Features: pc_stock18
# [2022-06-20 21:42:48] Score: 0.024188732103469026; Num features: 1; Features: pc_stock4
# [2022-06-20 21:43:00] Score: 0.038606239161017325; Num features: 1; Features: pc_stock12
# [2022-06-20 21:43:15] Score: -0.0593555960770097; Num features: 1; Features: pc_stock27
# [2022-06-20 21:43:30] Score: -0.05851105831245744; Num features: 1; Features: pc_stock24
# [2022-06-20 21:43:47] Score: -0.016658546680117136; Num features: 1; Features: pc_stock13
# [2022-06-20 21:44:29] Score: -0.1656590284585834; Num features: 2; Features: pc_stock14, pc_stock16
# [2022-06-20 21:45:10] Score: -0.08822918630657012; Num features: 2; Features: pc_stock14, pc_stock21
# [2022-06-20 21:45:50] Score: -0.11261439365875048; Num features: 2; Features: pc_stock14, pc_stock20
# [2022-06-20 21:46:35] Score: -0.09197264260519207; Num features: 2; Features: pc_stock14, pc_stock2
# [2022-06-20 21:47:19] Score: -0.049025639942616286; Num features: 2; Features: pc_stock14, pc_stock3
# [2022-06-20 21:48:06] Score: -0.11592492658093785; Num features: 2; Features: pc_stock14, pc_stock5
# [2022-06-20 21:48:51] Score: -0.13069993351425777; Num features: 2; Features: pc_stock14, pc_stock22
# [2022-06-20 21:49:37] Score: -0.11671254318968667; Num features: 2; Features: pc_stock14, pc_stock8
# [2022-06-20 21:50:26] Score: -0.09593791240799773; Num features: 2; Features: pc_stock14, pc_stock7
# [2022-06-20 21:51:12] Score: -0.14740405705678838; Num features: 2; Features: pc_stock14, pc_stock11
# [2022-06-20 21:51:53] Score: -0.07577987550581702; Num features: 2; Features: pc_stock14, pc_stock19
# [2022-06-20 21:52:41] Score: -0.10641734360701396; Num features: 2; Features: pc_stock14, pc_stock6
# [2022-06-20 21:53:27] Score: -0.056892674550197676; Num features: 2; Features: pc_stock14, pc_stock1
# [2022-06-20 21:54:16] Score: -0.18041245411400564; Num features: 2; Features: pc_stock14, pc_stock18
# [2022-06-20 21:55:01] Score: -0.07577345921126777; Num features: 2; Features: pc_stock14, pc_stock4
# [2022-06-20 21:55:45] Score: -0.059812753610721005; Num features: 2; Features: pc_stock14, pc_stock12
# [2022-06-20 21:56:28] Score: -0.11695899943825894; Num features: 2; Features: pc_stock14, pc_stock27
# [2022-06-20 21:57:12] Score: -0.12048042305643343; Num features: 2; Features: pc_stock14, pc_stock24
# [2022-06-20 21:57:59] Score: -0.1185262241615094; Num features: 2; Features: pc_stock14, pc_stock13
# [2022-06-20 21:58:40] Score: -0.14976055797626187; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock16
# [2022-06-20 21:59:21] Score: -0.10908087067148509; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock21
# [2022-06-20 22:00:01] Score: -0.10822875596893425; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock20
# [2022-06-20 22:00:38] Score: -0.12802999733614964; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock2
# [2022-06-20 22:01:14] Score: -0.09524356145831006; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock3
# [2022-06-20 22:01:52] Score: -0.11042090402141205; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock5
# [2022-06-20 22:02:29] Score: -0.09234871716019762; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock22
# [2022-06-20 22:03:07] Score: -0.11045742995235944; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock8
# [2022-06-20 22:03:47] Score: -0.11579194804365485; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock7
# [2022-06-20 22:04:22] Score: -0.13169424678994346; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock11
# [2022-06-20 22:04:57] Score: -0.13766711574783225; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock19
# [2022-06-20 22:05:37] Score: -0.12709975044190847; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock6
# [2022-06-20 22:06:15] Score: -0.11751668860127915; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock1
# [2022-06-20 22:06:50] Score: -0.1175637196157127; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock4
# [2022-06-20 22:07:24] Score: -0.0794160667000809; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock12
# [2022-06-20 22:07:59] Score: -0.12905657974321194; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock27
# [2022-06-20 22:08:38] Score: -0.14145491877769273; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock24
# [2022-06-20 22:09:17] Score: -0.14777956637817957; Num features: 3; Features: pc_stock14, pc_stock18, pc_stock13
# [2022-06-20 22:10:00] Score: -0.08599104856958796; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock21
# [2022-06-20 22:10:41] Score: -0.10456105228647543; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock20
# [2022-06-20 22:11:29] Score: -0.10830319936160819; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock2
# [2022-06-20 22:12:14] Score: -0.0895424031040707; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock3
# [2022-06-20 22:13:01] Score: -0.10006176507247708; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock5
# [2022-06-20 22:13:46] Score: -0.10112703849665175; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock22
# [2022-06-20 22:14:31] Score: -0.08982298145474715; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock8
# [2022-06-20 22:15:21] Score: -0.1013111042139226; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock7
# [2022-06-20 22:16:10] Score: -0.1367443000315511; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock11
# [2022-06-20 22:16:50] Score: -0.098220941125478; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock19
# [2022-06-20 22:17:37] Score: -0.09931948552866611; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock6
# [2022-06-20 22:18:22] Score: -0.08445020052313101; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock1
# [2022-06-20 22:19:10] Score: -0.07807660453702467; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock4
# [2022-06-20 22:19:54] Score: -0.0639914765576323; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock12
# [2022-06-20 22:20:36] Score: -0.1298387228875994; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock27
# [2022-06-20 22:21:24] Score: -0.11774866138333344; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock24
# [2022-06-20 22:22:09] Score: -0.1452036722781396; Num features: 4; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13
# [2022-06-20 22:22:51] Score: -0.1203213902968597; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock21
# [2022-06-20 22:23:33] Score: -0.13599843724562896; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock20
# [2022-06-20 22:24:19] Score: -0.1385137229447655; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock2
# [2022-06-20 22:25:03] Score: -0.1077603874718485; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock3
# [2022-06-20 22:25:50] Score: -0.13476032964456364; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock5
# [2022-06-20 22:26:31] Score: -0.13186924066247346; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock22
# [2022-06-20 22:27:17] Score: -0.14203263851325354; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock8
# [2022-06-20 22:28:05] Score: -0.11691572087327917; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock7
# [2022-06-20 22:28:52] Score: -0.18025684009214238; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11
# [2022-06-20 22:29:35] Score: -0.14560309462130389; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock19
# [2022-06-20 22:30:21] Score: -0.13908683555842083; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock6
# [2022-06-20 22:31:07] Score: -0.127786041812691; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock1
# [2022-06-20 22:31:51] Score: -0.13749597004742622; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock4
# [2022-06-20 22:32:35] Score: -0.14115702654877788; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock12
# [2022-06-20 22:33:17] Score: -0.1582622988720538; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock27
# [2022-06-20 22:34:00] Score: -0.1328585174081477; Num features: 5; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock24
# [2022-06-20 22:34:42] Score: -0.13147506689803518; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock21
# [2022-06-20 22:35:23] Score: -0.1405979368995605; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock20
# [2022-06-20 22:36:07] Score: -0.14519398799507116; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock2
# [2022-06-20 22:36:50] Score: -0.10361348442872793; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock3
# [2022-06-20 22:37:33] Score: -0.12925924779680514; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock5
# [2022-06-20 22:38:12] Score: -0.15835042507188074; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock22
# [2022-06-20 22:38:55] Score: -0.14670642047299384; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock8
# [2022-06-20 22:39:45] Score: -0.13740369418654064; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock7
# [2022-06-20 22:40:26] Score: -0.1594905767878154; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock19
# [2022-06-20 22:41:11] Score: -0.1660241392294898; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock6
# [2022-06-20 22:41:55] Score: -0.14748985562456945; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock1
# [2022-06-20 22:42:36] Score: -0.14946984715213563; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock4
# [2022-06-20 22:43:20] Score: -0.14596437302296028; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock12
# [2022-06-20 22:43:59] Score: -0.18272410002508474; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27
# [2022-06-20 22:44:43] Score: -0.1559441385996047; Num features: 6; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock24
# [2022-06-20 22:45:22] Score: -0.13785662613267924; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock21
# [2022-06-20 22:46:05] Score: -0.1454514774714005; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock20
# [2022-06-20 22:46:47] Score: -0.1643312819237152; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock2
# [2022-06-20 22:47:30] Score: -0.11976283394840692; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock3
# [2022-06-20 22:48:15] Score: -0.1371084361719272; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock5
# [2022-06-20 22:48:58] Score: -0.15730050282284677; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock22
# [2022-06-20 22:49:40] Score: -0.12847765794080052; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock8
# [2022-06-20 22:50:23] Score: -0.14491287722287888; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock7
# [2022-06-20 22:51:04] Score: -0.15348753528786524; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock19
# [2022-06-20 22:51:49] Score: -0.17345536262429845; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6
# [2022-06-20 22:52:30] Score: -0.1272858114497289; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock1
# [2022-06-20 22:53:13] Score: -0.15143103976844155; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock4
# [2022-06-20 22:53:57] Score: -0.1288836137141864; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock12
# [2022-06-20 22:54:43] Score: -0.1550801174812857; Num features: 7; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock24
# [2022-06-20 22:55:28] Score: -0.14935439453231636; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock21
# [2022-06-20 22:56:14] Score: -0.17631424058439582; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock20
# [2022-06-20 22:56:59] Score: -0.18413773382929524; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2
# [2022-06-20 22:57:42] Score: -0.09454538246124851; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock3
# [2022-06-20 22:58:33] Score: -0.15603493705690327; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock5
# [2022-06-20 22:59:19] Score: -0.14567283088109717; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock22
# [2022-06-20 23:00:06] Score: -0.13436534488393884; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock8
# [2022-06-20 23:00:51] Score: -0.16867430732238836; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock7
# [2022-06-20 23:01:39] Score: -0.17230065719290713; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock19
# [2022-06-20 23:02:26] Score: -0.1300037873988881; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock1
# [2022-06-20 23:03:13] Score: -0.17207551005026206; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock4
# [2022-06-20 23:04:03] Score: -0.14365452680912227; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock12
# [2022-06-20 23:04:51] Score: -0.15429479782726982; Num features: 8; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock24
# [2022-06-20 23:05:38] Score: -0.1496871483126533; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock21
# [2022-06-20 23:06:26] Score: -0.16709281934843173; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock20
# [2022-06-20 23:07:16] Score: -0.12120557106775312; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock3
# [2022-06-20 23:08:05] Score: -0.1438221435506053; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock5
# [2022-06-20 23:08:52] Score: -0.13444389382010874; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock22
# [2022-06-20 23:09:41] Score: -0.1576761535029179; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock8
# [2022-06-20 23:10:36] Score: -0.15706623163330674; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock7
# [2022-06-20 23:11:23] Score: -0.1626387532747422; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock19
# [2022-06-20 23:12:12] Score: -0.1309438943676875; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock1
# [2022-06-20 23:13:03] Score: -0.19028182335377197; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4
# [2022-06-20 23:13:52] Score: -0.14769580688643855; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock12
# [2022-06-20 23:14:42] Score: -0.16155921897648753; Num features: 9; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock24
# [2022-06-20 23:15:29] Score: -0.13763487823068082; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock21
# [2022-06-20 23:16:18] Score: -0.16513318146165873; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20
# [2022-06-20 23:17:08] Score: -0.11939099866029637; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock3
# [2022-06-20 23:17:57] Score: -0.14957837134982696; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock5
# [2022-06-20 23:18:47] Score: -0.1334152032975147; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock22
# [2022-06-20 23:19:36] Score: -0.1531754544812799; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock8
# [2022-06-20 23:20:25] Score: -0.15965001705660384; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock7
# [2022-06-20 23:21:16] Score: -0.16018237384725958; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock19
# [2022-06-20 23:22:09] Score: -0.15285499288357363; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock1
# [2022-06-20 23:23:01] Score: -0.16215469212743167; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock12
# [2022-06-20 23:23:50] Score: -0.14709364190072247; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock24
# [2022-06-20 23:24:36] Score: -0.13545657777840053; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock21
# [2022-06-20 23:25:23] Score: -0.13668060226197773; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock3
# [2022-06-20 23:26:12] Score: -0.16564977598166986; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock5
# [2022-06-20 23:27:00] Score: -0.15355083857278878; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock22
# [2022-06-20 23:27:46] Score: -0.14236261184858354; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock8
# [2022-06-20 23:28:36] Score: -0.15847557877173626; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock7
# [2022-06-20 23:29:23] Score: -0.17634356170149185; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19
# [2022-06-20 23:30:09] Score: -0.14473423330572538; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock1
# [2022-06-20 23:30:55] Score: -0.15717948007138655; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock12
# [2022-06-20 23:31:41] Score: -0.13409881074591926; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock24
# [2022-06-20 23:32:28] Score: -0.1325614084079846; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock21
# [2022-06-20 23:33:15] Score: -0.12933587181663359; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock3
# [2022-06-20 23:34:03] Score: -0.14513873993489215; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5
# [2022-06-20 23:34:52] Score: -0.1416121560635138; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock22
# [2022-06-20 23:35:40] Score: -0.1399586444477369; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock8
# [2022-06-20 23:36:29] Score: -0.14247615765338978; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock7
# [2022-06-20 23:37:18] Score: -0.11405749669285195; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock1
# [2022-06-20 23:38:09] Score: -0.14267633490390214; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock12
# [2022-06-20 23:38:58] Score: -0.13998760623512696; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock24
# [2022-06-20 23:39:49] Score: -0.1346444757127998; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock21
# [2022-06-20 23:40:37] Score: -0.10535307115758694; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock3
# [2022-06-20 23:41:27] Score: -0.1265573834958163; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock22
# [2022-06-20 23:42:14] Score: -0.12426881978632513; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock8
# [2022-06-20 23:43:04] Score: -0.1464325501374568; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7
# [2022-06-20 23:43:51] Score: -0.13570459902867213; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock1
# [2022-06-20 23:44:38] Score: -0.12953855346148532; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock12
# [2022-06-20 23:45:25] Score: -0.13511303158677407; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock24
# [2022-06-20 23:46:18] Score: -0.13454530856223587; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock21
# [2022-06-20 23:47:08] Score: -0.11731149302756205; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock3
# [2022-06-20 23:47:57] Score: -0.13641994731790907; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock22
# [2022-06-20 23:48:47] Score: -0.12450457632776904; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock8
# [2022-06-20 23:49:42] Score: -0.15162802053175126; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1
# [2022-06-20 23:50:33] Score: -0.13493772211836325; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock12
# [2022-06-20 23:51:24] Score: -0.13728444807119886; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock24
# [2022-06-20 23:52:20] Score: -0.13872446227377297; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21
# [2022-06-20 23:53:13] Score: -0.10910795169224444; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock3
# [2022-06-20 23:54:01] Score: -0.11556546147061295; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock22
# [2022-06-20 23:54:57] Score: -0.10867339395828353; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock8
# [2022-06-20 23:55:52] Score: -0.12954061873503064; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock12
# [2022-06-20 23:56:46] Score: -0.12175859926577288; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock24
# [2022-06-20 23:57:44] Score: -0.12827913524105872; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3
# [2022-06-20 23:58:39] Score: -0.11092740285923734; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock22
# [2022-06-20 23:59:31] Score: -0.11050902937763951; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock8
# [2022-06-21 00:00:22] Score: -0.12571363824150966; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock12
# [2022-06-21 00:01:14] Score: -0.11500087738718831; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock24
# [2022-06-21 00:02:10] Score: -0.11701747837151293; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock22
# [2022-06-21 00:03:07] Score: -0.10441467925935881; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock8
# [2022-06-21 00:04:09] Score: -0.12023855150884244; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12
# [2022-06-21 00:05:04] Score: -0.10883958050800915; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock24
# [2022-06-21 00:06:02] Score: -0.09971588194330674; Num features: 18; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12, pc_stock22
# [2022-06-21 00:07:00] Score: -0.09530581720734983; Num features: 18; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12, pc_stock8
# [2022-06-21 00:07:56] Score: -0.09428664015718197; Num features: 18; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12, pc_stock24
# [2022-06-21 00:08:50] Score: -0.08420092671381481; Num features: 19; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12, pc_stock22, pc_stock8
# [2022-06-21 00:09:46] Score: -0.09867276269756795; Num features: 19; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12, pc_stock22, pc_stock24
# [2022-06-21 00:10:39] Score: -0.09139927630512655; Num features: 20; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_stock20, pc_stock19, pc_stock5, pc_stock7, pc_stock1, pc_stock21, pc_stock3, pc_stock12, pc_stock22, pc_stock24, pc_stock8
# [2022-06-21 00:11:19] Score: -0.15020482446693323; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market3
# [2022-06-21 00:11:48] Score: -0.11840486593545214; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market11
# [2022-06-21 00:12:32] Score: -0.18858920501603899; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2
# [2022-06-21 00:13:05] Score: -0.08212840060724311; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market5
# [2022-06-21 00:13:44] Score: -0.1575399640673117; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market10
# [2022-06-21 00:14:17] Score: -0.0835118677975859; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market12
# [2022-06-21 00:14:47] Score: -0.11714333998620767; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market4
# [2022-06-21 00:15:22] Score: -0.12991669175372894; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market9
# [2022-06-21 00:15:49] Score: -0.11639937203416835; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market7
# [2022-06-21 00:16:16] Score: -0.11215049196801927; Num features: 10; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market8
# [2022-06-21 00:17:00] Score: -0.20379165858296333; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market3
# [2022-06-21 00:17:32] Score: -0.1431873955269009; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market11
# [2022-06-21 00:18:08] Score: -0.13498446785700044; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market5
# [2022-06-21 00:18:41] Score: -0.20586814638435888; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10
# [2022-06-21 00:19:20] Score: -0.1339774048589821; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market12
# [2022-06-21 00:19:48] Score: -0.17257814905627794; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market4
# [2022-06-21 00:20:20] Score: -0.14367480336068536; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market9
# [2022-06-21 00:20:53] Score: -0.1714781719574417; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market7
# [2022-06-21 00:21:26] Score: -0.15013719499203387; Num features: 11; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market8
# [2022-06-21 00:22:15] Score: -0.20629255446010547; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3
# [2022-06-21 00:22:45] Score: -0.1433235929646843; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market11
# [2022-06-21 00:23:16] Score: -0.14457197728085674; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market5
# [2022-06-21 00:23:50] Score: -0.12681161513037542; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market12
# [2022-06-21 00:24:23] Score: -0.16294345098156002; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market4
# [2022-06-21 00:24:56] Score: -0.13759684398868932; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market9
# [2022-06-21 00:25:34] Score: -0.168700112282456; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market7
# [2022-06-21 00:26:14] Score: -0.1531195445948198; Num features: 12; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market8
# [2022-06-21 00:26:49] Score: -0.16425424209876965; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market11
# [2022-06-21 00:27:24] Score: -0.13496352871719633; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market5
# [2022-06-21 00:28:02] Score: -0.13470275865170528; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market12
# [2022-06-21 00:28:33] Score: -0.16673526647432327; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market4
# [2022-06-21 00:29:09] Score: -0.14341305359578968; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market9
# [2022-06-21 00:29:44] Score: -0.2058530530515726; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7
# [2022-06-21 00:30:26] Score: -0.19122969328378336; Num features: 13; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market8
# [2022-06-21 00:30:58] Score: -0.1753231949942984; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11
# [2022-06-21 00:31:25] Score: -0.1503061378828322; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market5
# [2022-06-21 00:32:01] Score: -0.13941339608961958; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market12
# [2022-06-21 00:32:30] Score: -0.15503360949174178; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market4
# [2022-06-21 00:33:08] Score: -0.1730720332859398; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market9
# [2022-06-21 00:33:46] Score: -0.17036031697814097; Num features: 14; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market8
# [2022-06-21 00:34:22] Score: -0.15325769796983668; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market5
# [2022-06-21 00:34:52] Score: -0.12079697248641733; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market12
# [2022-06-21 00:35:25] Score: -0.16793757420038857; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market4
# [2022-06-21 00:35:58] Score: -0.1495975833715421; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market9
# [2022-06-21 00:36:33] Score: -0.18134909198665466; Num features: 15; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8
# [2022-06-21 00:37:06] Score: -0.11832451560656265; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market5
# [2022-06-21 00:37:40] Score: -0.10772294338049893; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market12
# [2022-06-21 00:38:16] Score: -0.15773916802500756; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4
# [2022-06-21 00:38:48] Score: -0.1539411966804514; Num features: 16; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market9
# [2022-06-21 00:39:20] Score: -0.1440439953505115; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4, pc_market5
# [2022-06-21 00:39:53] Score: -0.12676111950897437; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4, pc_market12
# [2022-06-21 00:40:26] Score: -0.12145258675092148; Num features: 17; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4, pc_market9
# [2022-06-21 00:40:54] Score: -0.13872352896627257; Num features: 18; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4, pc_market5, pc_market12
# [2022-06-21 00:41:22] Score: -0.15026864033373333; Num features: 18; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4, pc_market5, pc_market9
# [2022-06-21 00:41:52] Score: -0.18173116630121453; Num features: 19; Features: pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3, pc_market7, pc_market11, pc_market8, pc_market4, pc_market5, pc_market9, pc_market12
#        score  len_feats  \
# 19 -0.206293         12
#
#                                                                                                                                      total_feats
# 19  pc_stock14, pc_stock18, pc_stock16, pc_stock13, pc_stock11, pc_stock27, pc_stock6, pc_stock2, pc_stock4, pc_market2, pc_market10, pc_market3
# CPU times: user 10h 30min 5s, sys: 1min 47s, total: 10h 31min 53s
# Wall time: 3h 4min 42s

# %%
# %%time
'''
Hyperparameter tuning
'''
if RUN_HP:
    # run optimization
    best_params = optimize_hp()
    
else:
    # if not running HP, use pre-set best parameters
    best_params = BEST_PARAMS
# Out:
# [I 2022-06-20 16:41:52,859] A new study created in memory with name: LGBM optimization
# [I 2022-06-20 16:42:09,409] Trial 0 finished with value: -0.14841964314047495 and parameters: {'max_depth': 18, 'num_leaves': 60, 'learning_rate': 0.12282933898117034, 'min_child_weight': 1.4793740386626766, 'subsample': 0.9906203176798829, 'subsample_freq': 2, 'colsample_bytree': 0.5374546338969612, 'reg_alpha': 0.3606059319610534, 'reg_lambda': 2.0208147929228124, 'max_bin': 225}. Best is trial 0 with value: -0.14841964314047495.
# [I 2022-06-20 16:42:26,767] Trial 1 finished with value: -0.1349942787435885 and parameters: {'max_depth': 10, 'num_leaves': 16, 'learning_rate': 0.05721681980394035, 'min_child_weight': 2.199504112350797, 'subsample': 0.6029414536412107, 'subsample_freq': 4, 'colsample_bytree': 0.6639413391098934, 'reg_alpha': 0.011070660792271045, 'reg_lambda': 0.852099730415403, 'max_bin': 319}. Best is trial 0 with value: -0.14841964314047495.
# [I 2022-06-20 16:42:44,299] Trial 2 finished with value: -0.14320160244474783 and parameters: {'max_depth': 18, 'num_leaves': 21, 'learning_rate': 0.05403585231743423, 'min_child_weight': 2.847647553293827, 'subsample': 0.5805443629465188, 'subsample_freq': 6, 'colsample_bytree': 0.7644660804144633, 'reg_alpha': 0.03571245393625366, 'reg_lambda': 6.1231763455339685, 'max_bin': 250}. Best is trial 0 with value: -0.14841964314047495.
# [I 2022-06-20 16:42:59,818] Trial 3 finished with value: -0.17787001964370439 and parameters: {'max_depth': 27, 'num_leaves': 46, 'learning_rate': 0.13261624715289894, 'min_child_weight': 0.45967520481011914, 'subsample': 0.7910527959995808, 'subsample_freq': 1, 'colsample_bytree': 0.8137414205939121, 'reg_alpha': 0.1087263346273336, 'reg_lambda': 3.265597689705022, 'max_bin': 362}. Best is trial 3 with value: -0.17787001964370439.
# [I 2022-06-20 16:43:14,738] Trial 4 finished with value: -0.1728008404654957 and parameters: {'max_depth': 30, 'num_leaves': 61, 'learning_rate': 0.08051671803629112, 'min_child_weight': 0.018815262340798798, 'subsample': 0.7992769145008553, 'subsample_freq': 1, 'colsample_bytree': 0.7113981751074101, 'reg_alpha': 0.4068956787263517, 'reg_lambda': 0.03319536158037743, 'max_bin': 96}. Best is trial 3 with value: -0.17787001964370439.
# [I 2022-06-20 16:43:32,178] Trial 5 finished with value: -0.19215371996528685 and parameters: {'max_depth': 21, 'num_leaves': 31, 'learning_rate': 0.12305083048071247, 'min_child_weight': 0.028322630397761058, 'subsample': 0.5566035897385905, 'subsample_freq': 6, 'colsample_bytree': 0.555959977997346, 'reg_alpha': 15.582788828324025, 'reg_lambda': 0.04923930142760236, 'max_bin': 392}. Best is trial 5 with value: -0.19215371996528685.
# [I 2022-06-20 16:43:48,226] Trial 6 finished with value: -0.16868821816086413 and parameters: {'max_depth': 6, 'num_leaves': 26, 'learning_rate': 0.12813260649973454, 'min_child_weight': 0.6225739411225109, 'subsample': 0.8666919897071128, 'subsample_freq': 8, 'colsample_bytree': 0.7460005987841098, 'reg_alpha': 1.3850817692985187, 'reg_lambda': 6.4322162061488, 'max_bin': 221}. Best is trial 5 with value: -0.19215371996528685.
# [I 2022-06-20 16:44:02,226] Trial 7 finished with value: -0.15901281841500653 and parameters: {'max_depth': 14, 'num_leaves': 45, 'learning_rate': 0.16950051945062247, 'min_child_weight': 0.0018745248342936112, 'subsample': 0.5829256906672837, 'subsample_freq': 1, 'colsample_bytree': 0.7021922726710406, 'reg_alpha': 0.1793067946859712, 'reg_lambda': 1.6939757484911036, 'max_bin': 493}. Best is trial 5 with value: -0.19215371996528685.
# [I 2022-06-20 16:44:17,022] Trial 8 finished with value: -0.13500561466701047 and parameters: {'max_depth': 2, 'num_leaves': 29, 'learning_rate': 0.15685187217479227, 'min_child_weight': 1.5154500224823235, 'subsample': 0.5884754194753264, 'subsample_freq': 6, 'colsample_bytree': 0.6933647765582549, 'reg_alpha': 0.5446152369203413, 'reg_lambda': 6.91955239029896, 'max_bin': 383}. Best is trial 5 with value: -0.19215371996528685.
# [I 2022-06-20 16:44:41,429] Trial 9 finished with value: -0.11657981973412582 and parameters: {'max_depth': 2, 'num_leaves': 50, 'learning_rate': 0.05058537155671015, 'min_child_weight': 2.1556789232713123, 'subsample': 0.8363213768089588, 'subsample_freq': 6, 'colsample_bytree': 0.5048448685691792, 'reg_alpha': 0.34591310051747987, 'reg_lambda': 0.0886128643361462, 'max_bin': 156}. Best is trial 5 with value: -0.19215371996528685.
# [I 2022-06-20 16:44:56,805] Trial 10 finished with value: -0.1924358214012727 and parameters: {'max_depth': 6, 'num_leaves': 36, 'learning_rate': 0.1917190775514765, 'min_child_weight': 0.039620244747418494, 'subsample': 0.6996403297589485, 'subsample_freq': 4, 'colsample_bytree': 0.9990646337375582, 'reg_alpha': 7.6293075043218455, 'reg_lambda': 0.011550014930437481, 'max_bin': 473}. Best is trial 10 with value: -0.1924358214012727.
# [I 2022-06-20 16:45:12,807] Trial 11 finished with value: -0.22662111839713545 and parameters: {'max_depth': 5, 'num_leaves': 33, 'learning_rate': 0.1919936473647909, 'min_child_weight': 0.03760216893917707, 'subsample': 0.5005559603577686, 'subsample_freq': 4, 'colsample_bytree': 0.9769631966532891, 'reg_alpha': 15.6862576041561, 'reg_lambda': 0.017727194721427097, 'max_bin': 471}. Best is trial 11 with value: -0.22662111839713545.
# [I 2022-06-20 16:45:28,166] Trial 12 finished with value: -0.23395018161302192 and parameters: {'max_depth': 5, 'num_leaves': 38, 'learning_rate': 0.19858394125153422, 'min_child_weight': 0.11974420280273816, 'subsample': 0.6838409466556433, 'subsample_freq': 4, 'colsample_bytree': 0.9897721645162543, 'reg_alpha': 15.26051129882993, 'reg_lambda': 0.01028450555134356, 'max_bin': 499}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:45:43,683] Trial 13 finished with value: -0.1979154163176861 and parameters: {'max_depth': 4, 'num_leaves': 37, 'learning_rate': 0.19172803308413494, 'min_child_weight': 0.13317876226190684, 'subsample': 0.6765852612107831, 'subsample_freq': 4, 'colsample_bytree': 0.9819947042503988, 'reg_alpha': 3.880074686659502, 'reg_lambda': 0.010003541240317479, 'max_bin': 443}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:46:09,827] Trial 14 finished with value: -0.17514023473537255 and parameters: {'max_depth': 4, 'num_leaves': 22, 'learning_rate': 0.022872788990677892, 'min_child_weight': 0.005736304606790701, 'subsample': 0.508464931359633, 'subsample_freq': 4, 'colsample_bytree': 0.9006941669887685, 'reg_alpha': 2.6716097022241634, 'reg_lambda': 0.20893352826713493, 'max_bin': 432}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:46:26,432] Trial 15 finished with value: -0.19165309021838545 and parameters: {'max_depth': 3, 'num_leaves': 38, 'learning_rate': 0.1635236498671625, 'min_child_weight': 0.13232562210611526, 'subsample': 0.6733184059015513, 'subsample_freq': 4, 'colsample_bytree': 0.9049077181836309, 'reg_alpha': 15.928962798067113, 'reg_lambda': 0.026980163836011855, 'max_bin': 495}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:46:40,468] Trial 16 finished with value: -0.14736577262877187 and parameters: {'max_depth': 9, 'num_leaves': 26, 'learning_rate': 0.19835454911063233, 'min_child_weight': 0.012369578334275684, 'subsample': 0.5046487854161622, 'subsample_freq': 8, 'colsample_bytree': 0.9072509372233715, 'reg_alpha': 5.172571736531942, 'reg_lambda': 0.12456157495740043, 'max_bin': 311}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:46:57,230] Trial 17 finished with value: -0.17248245254682795 and parameters: {'max_depth': 4, 'num_leaves': 38, 'learning_rate': 0.151524135511836, 'min_child_weight': 0.09219481636174087, 'subsample': 0.9008910435511942, 'subsample_freq': 2, 'colsample_bytree': 0.850557657866515, 'reg_alpha': 1.3700254379731125, 'reg_lambda': 0.4450042317799949, 'max_bin': 423}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:47:13,892] Trial 18 finished with value: -0.16477983889859696 and parameters: {'max_depth': 8, 'num_leaves': 51, 'learning_rate': 0.17866927316152637, 'min_child_weight': 0.31785179897930227, 'subsample': 0.7284206490491838, 'subsample_freq': 4, 'colsample_bytree': 0.9476944067187023, 'reg_alpha': 9.136038541301536, 'reg_lambda': 0.019743161034861425, 'max_bin': 350}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:47:27,737] Trial 19 finished with value: -0.08337774149851049 and parameters: {'max_depth': 3, 'num_leaves': 33, 'learning_rate': 0.09517327839329413, 'min_child_weight': 0.00781151020486941, 'subsample': 0.6402130161593889, 'subsample_freq': 4, 'colsample_bytree': 0.8390709294291708, 'reg_alpha': 1.3028940375526348, 'reg_lambda': 0.07229262462649179, 'max_bin': 53}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:47:45,001] Trial 20 finished with value: -0.20802559091221764 and parameters: {'max_depth': 5, 'num_leaves': 43, 'learning_rate': 0.14257090978918943, 'min_child_weight': 0.0024824187194763827, 'subsample': 0.7548230462374264, 'subsample_freq': 4, 'colsample_bytree': 0.9390577772376318, 'reg_alpha': 2.5195495314750005, 'reg_lambda': 0.19725080700190206, 'max_bin': 448}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:48:01,323] Trial 21 finished with value: -0.1956699074962774 and parameters: {'max_depth': 5, 'num_leaves': 42, 'learning_rate': 0.1780046725907084, 'min_child_weight': 0.003085047919596335, 'subsample': 0.7553404350893976, 'subsample_freq': 4, 'colsample_bytree': 0.9442041245317125, 'reg_alpha': 2.7227874725940566, 'reg_lambda': 0.22124476185023, 'max_bin': 453}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:48:19,336] Trial 22 finished with value: -0.199833679025156 and parameters: {'max_depth': 3, 'num_leaves': 54, 'learning_rate': 0.14330351599400906, 'min_child_weight': 0.0014102527277520718, 'subsample': 0.9420667588867341, 'subsample_freq': 4, 'colsample_bytree': 0.9569568160464873, 'reg_alpha': 6.312902178431067, 'reg_lambda': 0.018792725048427533, 'max_bin': 499}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:48:38,431] Trial 23 finished with value: -0.18339000352741489 and parameters: {'max_depth': 5, 'num_leaves': 41, 'learning_rate': 0.10345064502704708, 'min_child_weight': 0.059648456453239136, 'subsample': 0.7596529983192046, 'subsample_freq': 4, 'colsample_bytree': 0.9999296296339197, 'reg_alpha': 10.08048190712091, 'reg_lambda': 15.22163400397854, 'max_bin': 415}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:48:52,632] Trial 24 finished with value: -0.20020614148940158 and parameters: {'max_depth': 11, 'num_leaves': 32, 'learning_rate': 0.17979483778638725, 'min_child_weight': 0.2544356592576265, 'subsample': 0.6326934680911168, 'subsample_freq': 8, 'colsample_bytree': 0.877620263940842, 'reg_alpha': 2.2006434637776637, 'reg_lambda': 0.04206036783135067, 'max_bin': 458}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:49:09,634] Trial 25 finished with value: -0.1922826218255899 and parameters: {'max_depth': 7, 'num_leaves': 29, 'learning_rate': 0.19916005994981445, 'min_child_weight': 0.0038525234468179954, 'subsample': 0.8149224057074854, 'subsample_freq': 2, 'colsample_bytree': 0.9478833790241443, 'reg_alpha': 14.678553351415259, 'reg_lambda': 0.6220177124356379, 'max_bin': 407}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:49:26,052] Trial 26 finished with value: -0.19975907728083384 and parameters: {'max_depth': 6, 'num_leaves': 44, 'learning_rate': 0.14133742641225713, 'min_child_weight': 0.01619142110821445, 'subsample': 0.7201524893348811, 'subsample_freq': 4, 'colsample_bytree': 0.7952056629626476, 'reg_alpha': 3.5916033286278206, 'reg_lambda': 0.17756833409883066, 'max_bin': 312}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:49:42,704] Trial 27 finished with value: -0.1791393678907212 and parameters: {'max_depth': 5, 'num_leaves': 26, 'learning_rate': 0.10561878452432627, 'min_child_weight': 0.043988370881764924, 'subsample': 0.5450221505409227, 'subsample_freq': 4, 'colsample_bytree': 0.9187922395927823, 'reg_alpha': 0.7336255714854228, 'reg_lambda': 0.018907020838477916, 'max_bin': 465}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:49:58,069] Trial 28 finished with value: -0.2188275068280891 and parameters: {'max_depth': 13, 'num_leaves': 34, 'learning_rate': 0.16798165318269126, 'min_child_weight': 0.7574427101376172, 'subsample': 0.6587927550574694, 'subsample_freq': 4, 'colsample_bytree': 0.8712868816711277, 'reg_alpha': 5.9177917416791495, 'reg_lambda': 0.06070074839419082, 'max_bin': 351}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:50:13,695] Trial 29 finished with value: -0.18845074432028336 and parameters: {'max_depth': 13, 'num_leaves': 34, 'learning_rate': 0.17167755263198467, 'min_child_weight': 0.8644365292341794, 'subsample': 0.6552585936454468, 'subsample_freq': 2, 'colsample_bytree': 0.8719253147284136, 'reg_alpha': 5.133030629242612, 'reg_lambda': 0.06482928051733094, 'max_bin': 275}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:50:28,913] Trial 30 finished with value: -0.16396067842162834 and parameters: {'max_depth': 17, 'num_leaves': 23, 'learning_rate': 0.1864988607040226, 'min_child_weight': 0.24843921418538958, 'subsample': 0.9774310116933045, 'subsample_freq': 4, 'colsample_bytree': 0.6107366839547967, 'reg_alpha': 9.412872573911539, 'reg_lambda': 0.013042596311141607, 'max_bin': 196}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:50:45,043] Trial 31 finished with value: -0.17638644576531182 and parameters: {'max_depth': 8, 'num_leaves': 40, 'learning_rate': 0.15355470020021386, 'min_child_weight': 0.881673455851115, 'subsample': 0.7048660313478102, 'subsample_freq': 4, 'colsample_bytree': 0.9657144142986903, 'reg_alpha': 9.78228844808332, 'reg_lambda': 0.12076365347354401, 'max_bin': 344}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:51:00,439] Trial 32 finished with value: -0.1862611861378158 and parameters: {'max_depth': 11, 'num_leaves': 29, 'learning_rate': 0.1651423100446174, 'min_child_weight': 0.1447973218297769, 'subsample': 0.7721847081745598, 'subsample_freq': 4, 'colsample_bytree': 0.9354720501299435, 'reg_alpha': 5.076894840481558, 'reg_lambda': 0.030395290391050905, 'max_bin': 376}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:51:16,145] Trial 33 finished with value: -0.19736066193032356 and parameters: {'max_depth': 4, 'num_leaves': 18, 'learning_rate': 0.18201357090298997, 'min_child_weight': 3.768325547552899, 'subsample': 0.6112431652287564, 'subsample_freq': 4, 'colsample_bytree': 0.8699317576804007, 'reg_alpha': 1.9143591958266708, 'reg_lambda': 0.3087488886685288, 'max_bin': 474}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:51:31,062] Trial 34 finished with value: -0.16997934546022114 and parameters: {'max_depth': 7, 'num_leaves': 35, 'learning_rate': 0.13814839140262752, 'min_child_weight': 0.010246487094884297, 'subsample': 0.5377348994636257, 'subsample_freq': 4, 'colsample_bytree': 0.9764046677988875, 'reg_alpha': 0.010788789118958603, 'reg_lambda': 0.047758907273459474, 'max_bin': 422}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:51:46,327] Trial 35 finished with value: -0.19450519851499867 and parameters: {'max_depth': 5, 'num_leaves': 48, 'learning_rate': 0.11634530502466633, 'min_child_weight': 0.0010592745094609758, 'subsample': 0.6232132206447937, 'subsample_freq': 1, 'colsample_bytree': 0.7831516227611588, 'reg_alpha': 3.836847233087576, 'reg_lambda': 0.018309669627369272, 'max_bin': 328}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:52:01,571] Trial 36 finished with value: -0.1980206743763268 and parameters: {'max_depth': 21, 'num_leaves': 57, 'learning_rate': 0.1586677103266954, 'min_child_weight': 0.026634505123023983, 'subsample': 0.7305945494184847, 'subsample_freq': 4, 'colsample_bytree': 0.8273770707318461, 'reg_alpha': 0.07389827020653422, 'reg_lambda': 1.3877545729013978, 'max_bin': 396}. Best is trial 12 with value: -0.23395018161302192.
# [I 2022-06-20 16:52:17,809] Trial 37 finished with value: -0.2401233092960447 and parameters: {'max_depth': 9, 'num_leaves': 64, 'learning_rate': 0.17170743467499178, 'min_child_weight': 0.4435548845455675, 'subsample': 0.6776605574527427, 'subsample_freq': 8, 'colsample_bytree': 0.9266684843816703, 'reg_alpha': 12.692112158081176, 'reg_lambda': 0.10697246965540133, 'max_bin': 284}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:52:32,410] Trial 38 finished with value: -0.20059821477172263 and parameters: {'max_depth': 14, 'num_leaves': 63, 'learning_rate': 0.1728906560862516, 'min_child_weight': 0.5794394222802064, 'subsample': 0.6791441214424551, 'subsample_freq': 8, 'colsample_bytree': 0.883717623479595, 'reg_alpha': 0.02489693619579347, 'reg_lambda': 0.032782904214906955, 'max_bin': 283}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:52:46,727] Trial 39 finished with value: -0.1957496150819254 and parameters: {'max_depth': 9, 'num_leaves': 19, 'learning_rate': 0.19661037037829635, 'min_child_weight': 0.39172873606620634, 'subsample': 0.572301382291676, 'subsample_freq': 8, 'colsample_bytree': 0.7514272450453543, 'reg_alpha': 12.794679965758297, 'reg_lambda': 0.06076980454787728, 'max_bin': 245}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:53:03,772] Trial 40 finished with value: -0.17278299566563365 and parameters: {'max_depth': 16, 'num_leaves': 24, 'learning_rate': 0.08050066661924099, 'min_child_weight': 1.006222068355974, 'subsample': 0.5985904222413304, 'subsample_freq': 8, 'colsample_bytree': 0.9232364511185952, 'reg_alpha': 7.442442070818502, 'reg_lambda': 0.09172352073016053, 'max_bin': 178}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:53:18,548] Trial 41 finished with value: -0.17857725538457367 and parameters: {'max_depth': 11, 'num_leaves': 31, 'learning_rate': 0.14897457366200365, 'min_child_weight': 0.20514244831084524, 'subsample': 0.7920777891978215, 'subsample_freq': 1, 'colsample_bytree': 0.9714388986415319, 'reg_alpha': 11.320479191122534, 'reg_lambda': 0.14040220085323046, 'max_bin': 294}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:53:34,785] Trial 42 finished with value: -0.2221435570434766 and parameters: {'max_depth': 6, 'num_leaves': 55, 'learning_rate': 0.1869693859206484, 'min_child_weight': 0.4708736230399466, 'subsample': 0.8434474076152172, 'subsample_freq': 6, 'colsample_bytree': 0.9965716462936249, 'reg_alpha': 6.80285665680099, 'reg_lambda': 0.025321809883751236, 'max_bin': 370}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:53:51,748] Trial 43 finished with value: -0.17650644178953473 and parameters: {'max_depth': 6, 'num_leaves': 58, 'learning_rate': 0.18653058474414957, 'min_child_weight': 0.08322191274153745, 'subsample': 0.85910047358594, 'subsample_freq': 6, 'colsample_bytree': 0.9915493315143219, 'reg_alpha': 6.948817937988305, 'reg_lambda': 0.024193633620728672, 'max_bin': 371}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:54:08,998] Trial 44 finished with value: -0.19619013623137566 and parameters: {'max_depth': 8, 'num_leaves': 54, 'learning_rate': 0.1887038657896242, 'min_child_weight': 1.4951983960295967, 'subsample': 0.9020913100568392, 'subsample_freq': 6, 'colsample_bytree': 0.9587905734187275, 'reg_alpha': 15.70191988434539, 'reg_lambda': 0.044213075014702986, 'max_bin': 345}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:54:24,665] Trial 45 finished with value: -0.18595377087732165 and parameters: {'max_depth': 12, 'num_leaves': 63, 'learning_rate': 0.1676917648973084, 'min_child_weight': 0.46328998080745915, 'subsample': 0.6574109213793083, 'subsample_freq': 6, 'colsample_bytree': 0.9783824137430042, 'reg_alpha': 6.268908945080343, 'reg_lambda': 0.013083553278542165, 'max_bin': 245}. Best is trial 37 with value: -0.2401233092960447.
# [I 2022-06-20 16:54:40,856] Trial 46 finished with value: -0.24966558449429593 and parameters: {'max_depth': 9, 'num_leaves': 47, 'learning_rate': 0.1739161324910146, 'min_child_weight': 2.269023417595106, 'subsample': 0.6956060249381771, 'subsample_freq': 6, 'colsample_bytree': 0.9228006518345832, 'reg_alpha': 11.134485703610098, 'reg_lambda': 0.015138209300965075, 'max_bin': 268}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:54:57,722] Trial 47 finished with value: -0.19128136237498122 and parameters: {'max_depth': 6, 'num_leaves': 47, 'learning_rate': 0.19911586372949952, 'min_child_weight': 2.0047096572806384, 'subsample': 0.8249855559642706, 'subsample_freq': 6, 'colsample_bytree': 0.9206054596120645, 'reg_alpha': 11.995636762908939, 'reg_lambda': 0.010098981981889446, 'max_bin': 223}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:55:35,108] Trial 48 finished with value: -0.21276320367189294 and parameters: {'max_depth': 9, 'num_leaves': 52, 'learning_rate': 0.011047935227560757, 'min_child_weight': 2.9587486226735455, 'subsample': 0.7004075273810717, 'subsample_freq': 6, 'colsample_bytree': 0.9995095236086726, 'reg_alpha': 0.1859789389664302, 'reg_lambda': 0.015700216364755618, 'max_bin': 155}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:55:51,120] Trial 49 finished with value: -0.20003746394192534 and parameters: {'max_depth': 7, 'num_leaves': 59, 'learning_rate': 0.19156218237594902, 'min_child_weight': 0.0282979044483221, 'subsample': 0.8528754511553616, 'subsample_freq': 6, 'colsample_bytree': 0.6668737477179684, 'reg_alpha': 3.75577224033536, 'reg_lambda': 0.02581454674253396, 'max_bin': 267}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:56:08,789] Trial 50 finished with value: -0.13009613169136913 and parameters: {'max_depth': 10, 'num_leaves': 49, 'learning_rate': 0.130152495343976, 'min_child_weight': 0.16199694918511814, 'subsample': 0.8813415472024143, 'subsample_freq': 6, 'colsample_bytree': 0.580392866447193, 'reg_alpha': 8.722971551122107, 'reg_lambda': 0.014209658267320473, 'max_bin': 479}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:56:23,478] Trial 51 finished with value: -0.22093397934878295 and parameters: {'max_depth': 21, 'num_leaves': 37, 'learning_rate': 0.17317720911923956, 'min_child_weight': 1.1599868776070426, 'subsample': 0.684939165045919, 'subsample_freq': 8, 'colsample_bytree': 0.89885104846539, 'reg_alpha': 11.937456343505424, 'reg_lambda': 0.03327650687127452, 'max_bin': 300}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:56:39,598] Trial 52 finished with value: -0.21158986629733545 and parameters: {'max_depth': 28, 'num_leaves': 39, 'learning_rate': 0.1777554751142379, 'min_child_weight': 1.247454603846485, 'subsample': 0.6839578603670461, 'subsample_freq': 8, 'colsample_bytree': 0.8926942237396847, 'reg_alpha': 12.45339109814394, 'reg_lambda': 0.039833235928589956, 'max_bin': 299}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:56:54,543] Trial 53 finished with value: -0.16095532632891651 and parameters: {'max_depth': 23, 'num_leaves': 56, 'learning_rate': 0.18364806769838982, 'min_child_weight': 1.9740168937961422, 'subsample': 0.7727742050947302, 'subsample_freq': 8, 'colsample_bytree': 0.9198440489918229, 'reg_alpha': 8.14791400986325, 'reg_lambda': 0.021580258275168632, 'max_bin': 264}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:57:11,078] Trial 54 finished with value: -0.16988973966332252 and parameters: {'max_depth': 25, 'num_leaves': 45, 'learning_rate': 0.1607713038192009, 'min_child_weight': 0.502707202524172, 'subsample': 0.710236960841773, 'subsample_freq': 8, 'colsample_bytree': 0.9658806713368032, 'reg_alpha': 14.759237972810038, 'reg_lambda': 0.010110106561113856, 'max_bin': 327}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:57:26,974] Trial 55 finished with value: -0.20193639074012654 and parameters: {'max_depth': 3, 'num_leaves': 36, 'learning_rate': 0.17553607445090377, 'min_child_weight': 0.3640341741846991, 'subsample': 0.5261262748935538, 'subsample_freq': 8, 'colsample_bytree': 0.8542150961553302, 'reg_alpha': 4.748283428696684, 'reg_lambda': 0.03197743993640028, 'max_bin': 203}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:57:43,959] Trial 56 finished with value: -0.2173758529474948 and parameters: {'max_depth': 32, 'num_leaves': 61, 'learning_rate': 0.19054093394514354, 'min_child_weight': 0.08614041492800478, 'subsample': 0.7345925989569871, 'subsample_freq': 6, 'colsample_bytree': 0.9012350572476953, 'reg_alpha': 11.5302958623618, 'reg_lambda': 0.014967291681563692, 'max_bin': 254}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:58:08,189] Trial 57 finished with value: -0.16641586189405114 and parameters: {'max_depth': 20, 'num_leaves': 53, 'learning_rate': 0.04456102137628781, 'min_child_weight': 1.2614958083886008, 'subsample': 0.6386015096064193, 'subsample_freq': 2, 'colsample_bytree': 0.9361226945085602, 'reg_alpha': 15.667181065761287, 'reg_lambda': 0.025186594095999708, 'max_bin': 434}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:58:23,972] Trial 58 finished with value: -0.2078174099739359 and parameters: {'max_depth': 4, 'num_leaves': 41, 'learning_rate': 0.15045417190365037, 'min_child_weight': 0.052774795162671466, 'subsample': 0.6881162954639475, 'subsample_freq': 1, 'colsample_bytree': 0.9878470885764377, 'reg_alpha': 7.457615740108654, 'reg_lambda': 0.01743403413635882, 'max_bin': 291}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:58:38,046] Trial 59 finished with value: -0.17298485434374453 and parameters: {'max_depth': 8, 'num_leaves': 31, 'learning_rate': 0.1940328629807173, 'min_child_weight': 2.6197379706584267, 'subsample': 0.5615939819846251, 'subsample_freq': 8, 'colsample_bytree': 0.9542201662010312, 'reg_alpha': 0.8495920518204163, 'reg_lambda': 0.03690451449142412, 'max_bin': 486}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:58:53,980] Trial 60 finished with value: -0.14839589167672057 and parameters: {'max_depth': 6, 'num_leaves': 37, 'learning_rate': 0.1716112139219472, 'min_child_weight': 0.6154079028225999, 'subsample': 0.7443120704013063, 'subsample_freq': 6, 'colsample_bytree': 0.8123313237511435, 'reg_alpha': 3.1217587518068517, 'reg_lambda': 0.09851794955596344, 'max_bin': 397}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:59:08,692] Trial 61 finished with value: -0.15090748704775966 and parameters: {'max_depth': 15, 'num_leaves': 34, 'learning_rate': 0.162337349059466, 'min_child_weight': 0.8076122588133609, 'subsample': 0.6583545923350146, 'subsample_freq': 8, 'colsample_bytree': 0.8606985375188434, 'reg_alpha': 6.047508176938811, 'reg_lambda': 0.05628924983497479, 'max_bin': 364}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:59:25,131] Trial 62 finished with value: -0.2036151975375744 and parameters: {'max_depth': 7, 'num_leaves': 39, 'learning_rate': 0.184786044627302, 'min_child_weight': 0.6980533499645992, 'subsample': 0.6650358840638895, 'subsample_freq': 4, 'colsample_bytree': 0.9334119841134083, 'reg_alpha': 10.036899010446776, 'reg_lambda': 0.08406471780323764, 'max_bin': 310}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:59:40,223] Trial 63 finished with value: -0.15819786438434252 and parameters: {'max_depth': 10, 'num_leaves': 33, 'learning_rate': 0.16667079715606953, 'min_child_weight': 0.2806601565943996, 'subsample': 0.7150699780135181, 'subsample_freq': 6, 'colsample_bytree': 0.9097043863800485, 'reg_alpha': 4.633395026613367, 'reg_lambda': 0.022216168080459307, 'max_bin': 335}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 16:59:55,395] Trial 64 finished with value: -0.1705242837327017 and parameters: {'max_depth': 19, 'num_leaves': 29, 'learning_rate': 0.1780296241473169, 'min_child_weight': 1.1164704407344201, 'subsample': 0.6154047119055659, 'subsample_freq': 2, 'colsample_bytree': 0.8870820431306751, 'reg_alpha': 6.257201679782921, 'reg_lambda': 3.934986991108451, 'max_bin': 357}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:00:11,438] Trial 65 finished with value: -0.20310494421805414 and parameters: {'max_depth': 13, 'num_leaves': 50, 'learning_rate': 0.19938145451198144, 'min_child_weight': 1.7445105335767692, 'subsample': 0.6938864215092914, 'subsample_freq': 4, 'colsample_bytree': 0.9771441526066585, 'reg_alpha': 1.8716813337845422, 'reg_lambda': 0.012544072136006433, 'max_bin': 235}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:00:27,046] Trial 66 finished with value: -0.17793478831660045 and parameters: {'max_depth': 9, 'num_leaves': 28, 'learning_rate': 0.1549954160641665, 'min_child_weight': 3.8527505184341706, 'subsample': 0.5883876332950948, 'subsample_freq': 4, 'colsample_bytree': 0.9507093639088973, 'reg_alpha': 8.702360218620472, 'reg_lambda': 0.056845920788305325, 'max_bin': 304}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:00:44,232] Trial 67 finished with value: -0.22187102465386435 and parameters: {'max_depth': 5, 'num_leaves': 43, 'learning_rate': 0.17182166650220715, 'min_child_weight': 0.10853910318969776, 'subsample': 0.638979760006193, 'subsample_freq': 8, 'colsample_bytree': 0.9322534740276397, 'reg_alpha': 12.808058883808357, 'reg_lambda': 0.27824426727053153, 'max_bin': 464}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:01:00,104] Trial 68 finished with value: -0.19518235446260046 and parameters: {'max_depth': 4, 'num_leaves': 43, 'learning_rate': 0.18405853605171282, 'min_child_weight': 0.10938943068765436, 'subsample': 0.6462885897615476, 'subsample_freq': 8, 'colsample_bytree': 0.9869948435796297, 'reg_alpha': 11.885655078701774, 'reg_lambda': 0.30822294309805226, 'max_bin': 443}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:01:19,770] Trial 69 finished with value: -0.19928952646214063 and parameters: {'max_depth': 5, 'num_leaves': 46, 'learning_rate': 0.12088428941972372, 'min_child_weight': 0.195857197417114, 'subsample': 0.7744806383606376, 'subsample_freq': 8, 'colsample_bytree': 0.932521948887457, 'reg_alpha': 13.399209306426402, 'reg_lambda': 0.8470293232041658, 'max_bin': 484}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:01:35,192] Trial 70 finished with value: -0.22134037385898697 and parameters: {'max_depth': 4, 'num_leaves': 42, 'learning_rate': 0.19218956769387463, 'min_child_weight': 0.03734158257657895, 'subsample': 0.6284286121374726, 'subsample_freq': 8, 'colsample_bytree': 0.9616053328448652, 'reg_alpha': 10.104063025600988, 'reg_lambda': 0.6710847386708416, 'max_bin': 464}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:01:51,310] Trial 71 finished with value: -0.22916693029306945 and parameters: {'max_depth': 4, 'num_leaves': 43, 'learning_rate': 0.1916626562662783, 'min_child_weight': 0.03887904878093999, 'subsample': 0.6286593595655198, 'subsample_freq': 8, 'colsample_bytree': 0.9622564608310331, 'reg_alpha': 9.42436025222624, 'reg_lambda': 0.5688600488615265, 'max_bin': 455}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:02:05,541] Trial 72 finished with value: -0.16935271058881116 and parameters: {'max_depth': 3, 'num_leaves': 42, 'learning_rate': 0.19131741320554074, 'min_child_weight': 0.03735034637087445, 'subsample': 0.604148774665793, 'subsample_freq': 8, 'colsample_bytree': 0.7254383082378021, 'reg_alpha': 9.584236774899834, 'reg_lambda': 0.7368997150085772, 'max_bin': 464}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:02:20,736] Trial 73 finished with value: -0.17808829050843517 and parameters: {'max_depth': 5, 'num_leaves': 44, 'learning_rate': 0.19503067163578167, 'min_child_weight': 0.01742487443574764, 'subsample': 0.6256997548984481, 'subsample_freq': 8, 'colsample_bytree': 0.9640800702891169, 'reg_alpha': 7.810210252372615, 'reg_lambda': 0.5592235570818335, 'max_bin': 452}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:02:37,214] Trial 74 finished with value: -0.1779776867835176 and parameters: {'max_depth': 6, 'num_leaves': 55, 'learning_rate': 0.17917659666212488, 'min_child_weight': 0.0615701351002135, 'subsample': 0.6719548400249241, 'subsample_freq': 8, 'colsample_bytree': 0.9495153536516484, 'reg_alpha': 15.75421474484616, 'reg_lambda': 1.1880203807346736, 'max_bin': 497}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:02:53,594] Trial 75 finished with value: -0.206877275379667 and parameters: {'max_depth': 4, 'num_leaves': 48, 'learning_rate': 0.18441678641514678, 'min_child_weight': 0.03574400794124998, 'subsample': 0.5762427723042506, 'subsample_freq': 8, 'colsample_bytree': 0.9984469219769982, 'reg_alpha': 10.229638343846496, 'reg_lambda': 0.36956635930578136, 'max_bin': 434}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:03:08,283] Trial 76 finished with value: -0.17736321581841946 and parameters: {'max_depth': 5, 'num_leaves': 40, 'learning_rate': 0.1900779017627627, 'min_child_weight': 0.07356386530559147, 'subsample': 0.6356250416682684, 'subsample_freq': 1, 'colsample_bytree': 0.9740156202857864, 'reg_alpha': 0.3396663005655728, 'reg_lambda': 0.5380993097113524, 'max_bin': 466}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:03:23,988] Trial 77 finished with value: -0.15648611226582726 and parameters: {'max_depth': 6, 'num_leaves': 46, 'learning_rate': 0.19377143242201172, 'min_child_weight': 0.024461004302787213, 'subsample': 0.5152615624693865, 'subsample_freq': 8, 'colsample_bytree': 0.9115296611053794, 'reg_alpha': 4.827358700613738, 'reg_lambda': 1.1261280924587767, 'max_bin': 409}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:03:39,662] Trial 78 finished with value: -0.18157018784651702 and parameters: {'max_depth': 3, 'num_leaves': 51, 'learning_rate': 0.1812644167690645, 'min_child_weight': 0.10848393003164883, 'subsample': 0.6489194888668508, 'subsample_freq': 6, 'colsample_bytree': 0.9442779674046903, 'reg_alpha': 7.238766294924823, 'reg_lambda': 0.43158997334282684, 'max_bin': 444}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:03:59,838] Trial 79 finished with value: -0.20595872962860362 and parameters: {'max_depth': 4, 'num_leaves': 42, 'learning_rate': 0.0702101479743189, 'min_child_weight': 0.053242156119151784, 'subsample': 0.6178367560357689, 'subsample_freq': 8, 'colsample_bytree': 0.9830378962426851, 'reg_alpha': 13.175495204140633, 'reg_lambda': 2.388046086184106, 'max_bin': 473}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:04:16,598] Trial 80 finished with value: -0.17240928603305464 and parameters: {'max_depth': 8, 'num_leaves': 60, 'learning_rate': 0.17361341454108647, 'min_child_weight': 0.022162115494107786, 'subsample': 0.5966682107308235, 'subsample_freq': 2, 'colsample_bytree': 0.9625678916491595, 'reg_alpha': 9.919398195993358, 'reg_lambda': 0.15633855333830016, 'max_bin': 388}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:04:33,287] Trial 81 finished with value: -0.2239147712726663 and parameters: {'max_depth': 7, 'num_leaves': 35, 'learning_rate': 0.17055864176215532, 'min_child_weight': 0.047111856900962215, 'subsample': 0.6718695677453553, 'subsample_freq': 8, 'colsample_bytree': 0.9249195571525491, 'reg_alpha': 11.486674950733049, 'reg_lambda': 0.27541667773824446, 'max_bin': 498}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:04:50,228] Trial 82 finished with value: -0.21343037261217096 and parameters: {'max_depth': 7, 'num_leaves': 64, 'learning_rate': 0.18813501403793775, 'min_child_weight': 0.04804986983954358, 'subsample': 0.6724125784673479, 'subsample_freq': 8, 'colsample_bytree': 0.932307066386843, 'reg_alpha': 15.997229916596337, 'reg_lambda': 0.3383395417053287, 'max_bin': 498}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:05:06,323] Trial 83 finished with value: -0.2052948424118007 and parameters: {'max_depth': 9, 'num_leaves': 38, 'learning_rate': 0.16564756324973776, 'min_child_weight': 0.01404776306756485, 'subsample': 0.72111983986341, 'subsample_freq': 8, 'colsample_bytree': 0.9238937637392112, 'reg_alpha': 8.524602205919575, 'reg_lambda': 0.18815767513634793, 'max_bin': 487}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:05:21,584] Trial 84 finished with value: -0.22777937879811422 and parameters: {'max_depth': 8, 'num_leaves': 35, 'learning_rate': 0.1995271217396981, 'min_child_weight': 0.03519969316820591, 'subsample': 0.7001621630041357, 'subsample_freq': 8, 'colsample_bytree': 0.9581099169242593, 'reg_alpha': 5.3939548965743, 'reg_lambda': 0.24827633265193133, 'max_bin': 421}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:05:36,755] Trial 85 finished with value: -0.18554571746867596 and parameters: {'max_depth': 8, 'num_leaves': 33, 'learning_rate': 0.19859840382066146, 'min_child_weight': 0.0314831259014542, 'subsample': 0.702940786071281, 'subsample_freq': 8, 'colsample_bytree': 0.5015267759383751, 'reg_alpha': 5.786055939533918, 'reg_lambda': 0.28586977106682965, 'max_bin': 421}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:05:52,049] Trial 86 finished with value: -0.12246687043954878 and parameters: {'max_depth': 10, 'num_leaves': 32, 'learning_rate': 0.14681676585203787, 'min_child_weight': 0.06891147628357047, 'subsample': 0.9471320998228278, 'subsample_freq': 6, 'colsample_bytree': 0.9440269200463214, 'reg_alpha': 4.07717382595236, 'reg_lambda': 0.2114970399288975, 'max_bin': 475}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:06:07,132] Trial 87 finished with value: -0.24421469526930015 and parameters: {'max_depth': 11, 'num_leaves': 36, 'learning_rate': 0.1575869596259274, 'min_child_weight': 0.11688851035138206, 'subsample': 0.7347310213616931, 'subsample_freq': 8, 'colsample_bytree': 0.9891621878991617, 'reg_alpha': 0.043468042520883945, 'reg_lambda': 0.25113193883382423, 'max_bin': 453}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:06:21,337] Trial 88 finished with value: -0.19180007359514809 and parameters: {'max_depth': 12, 'num_leaves': 30, 'learning_rate': 0.18111264623492002, 'min_child_weight': 0.047203788024752766, 'subsample': 0.7254164256544845, 'subsample_freq': 4, 'colsample_bytree': 0.9890286305368933, 'reg_alpha': 0.04905244889741098, 'reg_lambda': 0.10766115844803578, 'max_bin': 436}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:06:34,780] Trial 89 finished with value: -0.2159227516531285 and parameters: {'max_depth': 12, 'num_leaves': 35, 'learning_rate': 0.19990648837980696, 'min_child_weight': 0.010788116891519022, 'subsample': 0.7386150277110749, 'subsample_freq': 6, 'colsample_bytree': 0.9824441501634978, 'reg_alpha': 0.158672009627473, 'reg_lambda': 0.15456675124805777, 'max_bin': 136}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:06:50,034] Trial 90 finished with value: -0.2011248278254792 and parameters: {'max_depth': 10, 'num_leaves': 37, 'learning_rate': 0.16089371779423917, 'min_child_weight': 0.16840722509460224, 'subsample': 0.7589163989324976, 'subsample_freq': 1, 'colsample_bytree': 0.9723506454833549, 'reg_alpha': 0.036738312535088205, 'reg_lambda': 0.4829720606768906, 'max_bin': 449}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:07:05,423] Trial 91 finished with value: -0.19958269857932254 and parameters: {'max_depth': 7, 'num_leaves': 35, 'learning_rate': 0.16876738715339215, 'min_child_weight': 0.12043919610437641, 'subsample': 0.8075186247143552, 'subsample_freq': 8, 'colsample_bytree': 0.9996519171248723, 'reg_alpha': 0.025361738173298325, 'reg_lambda': 0.2679591480757087, 'max_bin': 455}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:07:20,345] Trial 92 finished with value: -0.18310376679364998 and parameters: {'max_depth': 8, 'num_leaves': 36, 'learning_rate': 0.17394970447544766, 'min_child_weight': 0.10161926405473896, 'subsample': 0.6931203001614342, 'subsample_freq': 8, 'colsample_bytree': 0.9693196303797132, 'reg_alpha': 0.015074242804563029, 'reg_lambda': 0.2634462790481226, 'max_bin': 488}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:07:35,722] Trial 93 finished with value: -0.13018650994083403 and parameters: {'max_depth': 6, 'num_leaves': 39, 'learning_rate': 0.18712815957388698, 'min_child_weight': 0.021610225648008585, 'subsample': 0.6687022120485221, 'subsample_freq': 8, 'colsample_bytree': 0.9555881528102736, 'reg_alpha': 0.08593333317297101, 'reg_lambda': 0.23100085319127733, 'max_bin': 427}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:07:51,969] Trial 94 finished with value: -0.2075117213085175 and parameters: {'max_depth': 11, 'num_leaves': 33, 'learning_rate': 0.17613216408754007, 'min_child_weight': 0.08187984115865793, 'subsample': 0.7066343618481026, 'subsample_freq': 8, 'colsample_bytree': 0.9154276708257804, 'reg_alpha': 13.132283968438117, 'reg_lambda': 0.4108465415042352, 'max_bin': 409}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:08:07,949] Trial 95 finished with value: -0.22440343727167034 and parameters: {'max_depth': 9, 'num_leaves': 40, 'learning_rate': 0.1693489876931733, 'min_child_weight': 0.20809935456640394, 'subsample': 0.6456736596488631, 'subsample_freq': 8, 'colsample_bytree': 0.9280995787606537, 'reg_alpha': 11.078933463257085, 'reg_lambda': 0.016982414961407715, 'max_bin': 466}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:08:23,729] Trial 96 finished with value: -0.19229209763022617 and parameters: {'max_depth': 9, 'num_leaves': 40, 'learning_rate': 0.13489483271842917, 'min_child_weight': 0.22474255413040717, 'subsample': 0.7470679082355831, 'subsample_freq': 8, 'colsample_bytree': 0.8925316894898159, 'reg_alpha': 0.2579797634198023, 'reg_lambda': 0.01660086389408978, 'max_bin': 475}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:08:38,855] Trial 97 finished with value: -0.14434919606345187 and parameters: {'max_depth': 11, 'num_leaves': 38, 'learning_rate': 0.1952125353034277, 'min_child_weight': 0.34241637516134493, 'subsample': 0.6810212983881839, 'subsample_freq': 4, 'colsample_bytree': 0.6199368144553036, 'reg_alpha': 6.764338900191316, 'reg_lambda': 0.011516504076240318, 'max_bin': 500}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:08:55,565] Trial 98 finished with value: -0.16453096964559558 and parameters: {'max_depth': 8, 'num_leaves': 35, 'learning_rate': 0.15898603144334658, 'min_child_weight': 0.141663841977895, 'subsample': 0.6630973670497589, 'subsample_freq': 6, 'colsample_bytree': 0.9448950205565474, 'reg_alpha': 10.793771853666971, 'reg_lambda': 0.02820307640808671, 'max_bin': 456}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:09:10,102] Trial 99 finished with value: -0.18714202543825442 and parameters: {'max_depth': 9, 'num_leaves': 36, 'learning_rate': 0.18741458507399772, 'min_child_weight': 0.28201973930840485, 'subsample': 0.6943713325283865, 'subsample_freq': 8, 'colsample_bytree': 0.9866270915271963, 'reg_alpha': 5.53599310674206, 'reg_lambda': 0.020675210878168985, 'max_bin': 482}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:09:28,578] Trial 100 finished with value: -0.19993846937785936 and parameters: {'max_depth': 10, 'num_leaves': 34, 'learning_rate': 0.0937584827667166, 'min_child_weight': 0.41953759663820667, 'subsample': 0.713940261151212, 'subsample_freq': 4, 'colsample_bytree': 0.9573516037474168, 'reg_alpha': 8.272259811263428, 'reg_lambda': 0.011110376175469575, 'max_bin': 441}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:09:44,223] Trial 101 finished with value: -0.21810885606939628 and parameters: {'max_depth': 7, 'num_leaves': 44, 'learning_rate': 0.1695639118386441, 'min_child_weight': 0.1813481453196066, 'subsample': 0.6536857951789434, 'subsample_freq': 8, 'colsample_bytree': 0.9253574684529353, 'reg_alpha': 13.63770730660803, 'reg_lambda': 0.014189866213196354, 'max_bin': 465}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:10:00,702] Trial 102 finished with value: -0.23372810113472084 and parameters: {'max_depth': 14, 'num_leaves': 39, 'learning_rate': 0.15441195995344537, 'min_child_weight': 0.05962095572809215, 'subsample': 0.6459143364963035, 'subsample_freq': 8, 'colsample_bytree': 0.906775731263774, 'reg_alpha': 11.082690713438662, 'reg_lambda': 0.1267841170004835, 'max_bin': 281}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:10:16,083] Trial 103 finished with value: -0.24414596701872665 and parameters: {'max_depth': 14, 'num_leaves': 38, 'learning_rate': 0.1560013490865949, 'min_child_weight': 0.030414393722666046, 'subsample': 0.6812293594418761, 'subsample_freq': 8, 'colsample_bytree': 0.9039365869273137, 'reg_alpha': 11.29180243302639, 'reg_lambda': 0.12672983905650856, 'max_bin': 273}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:10:33,131] Trial 104 finished with value: -0.18567118914029734 and parameters: {'max_depth': 15, 'num_leaves': 40, 'learning_rate': 0.1559786416391429, 'min_child_weight': 0.031121226220916866, 'subsample': 0.6760782815397351, 'subsample_freq': 8, 'colsample_bytree': 0.9047278486794168, 'reg_alpha': 11.055736175180588, 'reg_lambda': 0.1261234932162344, 'max_bin': 277}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:10:47,916] Trial 105 finished with value: -0.13817599384503582 and parameters: {'max_depth': 16, 'num_leaves': 38, 'learning_rate': 0.14586661021642794, 'min_child_weight': 0.05890617042578881, 'subsample': 0.647492842638546, 'subsample_freq': 8, 'colsample_bytree': 0.878922562237547, 'reg_alpha': 0.542875876877458, 'reg_lambda': 0.0784106330321161, 'max_bin': 265}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:11:02,933] Trial 106 finished with value: -0.16298760992451858 and parameters: {'max_depth': 14, 'num_leaves': 32, 'learning_rate': 0.15093973039726208, 'min_child_weight': 0.040025956137223435, 'subsample': 0.686601496318125, 'subsample_freq': 8, 'colsample_bytree': 0.529588635167166, 'reg_alpha': 1.0013563977385105, 'reg_lambda': 0.23740652295748732, 'max_bin': 212}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:11:18,154] Trial 107 finished with value: -0.21271178513329292 and parameters: {'max_depth': 17, 'num_leaves': 39, 'learning_rate': 0.16384626766139176, 'min_child_weight': 0.07665681521228317, 'subsample': 0.6995802378722157, 'subsample_freq': 8, 'colsample_bytree': 0.8651188432073486, 'reg_alpha': 8.8362576087471, 'reg_lambda': 0.16579648939340663, 'max_bin': 237}. Best is trial 46 with value: -0.24966558449429593.
# [I 2022-06-20 17:11:33,385] Trial 108 finished with value: -0.27194844125073364 and parameters: {'max_depth': 12, 'num_leaves': 41, 'learning_rate': 0.1539450082150945, 'min_child_weight': 0.019753217730461164, 'subsample': 0.7275340456340998, 'subsample_freq': 8, 'colsample_bytree': 0.8942007142675765, 'reg_alpha': 14.09927370462401, 'reg_lambda': 0.12240460206082455, 'max_bin': 255}. Best is trial 108 with value: -0.27194844125073364.
# ...
# [I 2022-06-20 20:33:12,676] Trial 865 finished with value: -0.24819204016872884 and parameters: {'max_depth': 9, 'num_leaves': 56, 'learning_rate': 0.1842286625131308, 'min_child_weight': 0.16334222282517363, 'subsample': 0.7167997627678382, 'subsample_freq': 6, 'colsample_bytree': 0.9156872242165977, 'reg_alpha': 0.26802039409738654, 'reg_lambda': 0.05078608197053957, 'max_bin': 361}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:33:27,693] Trial 866 finished with value: -0.2729323225625346 and parameters: {'max_depth': 10, 'num_leaves': 58, 'learning_rate': 0.19693191665167492, 'min_child_weight': 0.09140778535855863, 'subsample': 0.6703173544233754, 'subsample_freq': 6, 'colsample_bytree': 0.8969903077541996, 'reg_alpha': 3.410024393764402, 'reg_lambda': 0.042215094045597396, 'max_bin': 428}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:33:43,298] Trial 867 finished with value: -0.16334934224797423 and parameters: {'max_depth': 11, 'num_leaves': 60, 'learning_rate': 0.1961131409653905, 'min_child_weight': 0.07249943763456723, 'subsample': 0.6466782945754391, 'subsample_freq': 6, 'colsample_bytree': 0.8137445075619336, 'reg_alpha': 4.021628516355553, 'reg_lambda': 0.0315146829056809, 'max_bin': 433}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:33:58,482] Trial 868 finished with value: -0.20465200818440338 and parameters: {'max_depth': 10, 'num_leaves': 59, 'learning_rate': 0.19734359708659766, 'min_child_weight': 0.08271464662404447, 'subsample': 0.6553142068974874, 'subsample_freq': 6, 'colsample_bytree': 0.8869553246283935, 'reg_alpha': 3.2980451526917802, 'reg_lambda': 0.1845773575860623, 'max_bin': 443}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:34:13,415] Trial 869 finished with value: -0.22498384980455258 and parameters: {'max_depth': 11, 'num_leaves': 61, 'learning_rate': 0.1974512703784048, 'min_child_weight': 0.06921703642531574, 'subsample': 0.6644714737510218, 'subsample_freq': 8, 'colsample_bytree': 0.8736349644699898, 'reg_alpha': 3.3344884266078947, 'reg_lambda': 0.037435862292181335, 'max_bin': 424}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:34:29,193] Trial 870 finished with value: -0.19690700838998446 and parameters: {'max_depth': 11, 'num_leaves': 58, 'learning_rate': 0.19916066091694712, 'min_child_weight': 0.09094853352857594, 'subsample': 0.6684294172225923, 'subsample_freq': 6, 'colsample_bytree': 0.8995619367808866, 'reg_alpha': 2.788233567090043, 'reg_lambda': 0.033155097074191876, 'max_bin': 441}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:34:45,373] Trial 871 finished with value: -0.18333677894773237 and parameters: {'max_depth': 12, 'num_leaves': 58, 'learning_rate': 0.12700483001578594, 'min_child_weight': 0.06523316655169986, 'subsample': 0.6544644768750142, 'subsample_freq': 6, 'colsample_bytree': 0.8829969811228872, 'reg_alpha': 2.9358888900068676, 'reg_lambda': 0.0407819992053559, 'max_bin': 450}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:35:01,044] Trial 872 finished with value: -0.25145873094930116 and parameters: {'max_depth': 13, 'num_leaves': 60, 'learning_rate': 0.1958394591789195, 'min_child_weight': 0.05784290790591418, 'subsample': 0.6721075111550899, 'subsample_freq': 6, 'colsample_bytree': 0.8905423841724494, 'reg_alpha': 3.2471603975600694, 'reg_lambda': 0.02884067474760651, 'max_bin': 433}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:35:16,487] Trial 873 finished with value: -0.26305207038224615 and parameters: {'max_depth': 10, 'num_leaves': 62, 'learning_rate': 0.19359417585125932, 'min_child_weight': 0.07811583556498838, 'subsample': 0.6600698743043133, 'subsample_freq': 6, 'colsample_bytree': 0.8973270956872117, 'reg_alpha': 3.516957972596059, 'reg_lambda': 0.036058419130704296, 'max_bin': 424}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:35:32,092] Trial 874 finished with value: -0.1256692385042921 and parameters: {'max_depth': 11, 'num_leaves': 60, 'learning_rate': 0.19319831533588538, 'min_child_weight': 0.0991094650669387, 'subsample': 0.6747853454697081, 'subsample_freq': 6, 'colsample_bytree': 0.8616819186978695, 'reg_alpha': 2.327804639537192, 'reg_lambda': 0.15961532027312206, 'max_bin': 432}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:35:46,942] Trial 875 finished with value: -0.19187229282190665 and parameters: {'max_depth': 12, 'num_leaves': 57, 'learning_rate': 0.19921307752920772, 'min_child_weight': 0.006829603961746934, 'subsample': 0.6423982766414998, 'subsample_freq': 6, 'colsample_bytree': 0.8959809020850337, 'reg_alpha': 3.909761542538857, 'reg_lambda': 0.13459019428062363, 'max_bin': 420}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:36:02,617] Trial 876 finished with value: -0.1855998638201242 and parameters: {'max_depth': 10, 'num_leaves': 63, 'learning_rate': 0.19013241728503352, 'min_child_weight': 0.8686742654069378, 'subsample': 0.6681119080808079, 'subsample_freq': 6, 'colsample_bytree': 0.8827149855541848, 'reg_alpha': 3.993600187332273, 'reg_lambda': 0.03997775200732556, 'max_bin': 456}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:36:17,676] Trial 877 finished with value: -0.18222918566441637 and parameters: {'max_depth': 11, 'num_leaves': 58, 'learning_rate': 0.19993912754801013, 'min_child_weight': 0.08789111492620216, 'subsample': 0.680481126849286, 'subsample_freq': 8, 'colsample_bytree': 0.9043407770340137, 'reg_alpha': 4.513929838781259, 'reg_lambda': 0.1106718166790621, 'max_bin': 414}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:36:32,948] Trial 878 finished with value: -0.2939171588605157 and parameters: {'max_depth': 10, 'num_leaves': 56, 'learning_rate': 0.19394106402733352, 'min_child_weight': 0.0998222195732025, 'subsample': 0.6529511721245882, 'subsample_freq': 6, 'colsample_bytree': 0.894598352639583, 'reg_alpha': 2.618139138649586, 'reg_lambda': 0.044620724407044676, 'max_bin': 435}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:36:47,904] Trial 879 finished with value: -0.149628395944524 and parameters: {'max_depth': 11, 'num_leaves': 61, 'learning_rate': 0.195688055000339, 'min_child_weight': 0.09413441811895452, 'subsample': 0.631636648375867, 'subsample_freq': 6, 'colsample_bytree': 0.8722351940841384, 'reg_alpha': 2.812631113839842, 'reg_lambda': 0.045380754781339815, 'max_bin': 442}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:37:02,524] Trial 880 finished with value: -0.21637645661924085 and parameters: {'max_depth': 12, 'num_leaves': 59, 'learning_rate': 0.19490605128257218, 'min_child_weight': 0.08430764684219082, 'subsample': 0.643901777378746, 'subsample_freq': 6, 'colsample_bytree': 0.8800092593575995, 'reg_alpha': 2.6842883521186676, 'reg_lambda': 0.03533811401693123, 'max_bin': 465}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:37:16,973] Trial 881 finished with value: -0.18884301495198372 and parameters: {'max_depth': 10, 'num_leaves': 64, 'learning_rate': 0.19319867315909361, 'min_child_weight': 0.1036245920714829, 'subsample': 0.6353857970023877, 'subsample_freq': 6, 'colsample_bytree': 0.6883159670458586, 'reg_alpha': 2.4144342241710484, 'reg_lambda': 0.043099889264800746, 'max_bin': 431}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:37:32,300] Trial 882 finished with value: -0.2969106590440157 and parameters: {'max_depth': 13, 'num_leaves': 49, 'learning_rate': 0.1992346332562473, 'min_child_weight': 0.07611676915110269, 'subsample': 0.6514456547696916, 'subsample_freq': 1, 'colsample_bytree': 0.8952521640042199, 'reg_alpha': 3.464599354848723, 'reg_lambda': 0.03996240347085606, 'max_bin': 449}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:37:46,747] Trial 883 finished with value: -0.16773287149809102 and parameters: {'max_depth': 14, 'num_leaves': 48, 'learning_rate': 0.19875633930720646, 'min_child_weight': 0.05995891796942642, 'subsample': 0.6422559046904022, 'subsample_freq': 8, 'colsample_bytree': 0.8933499923499018, 'reg_alpha': 3.3744503846985703, 'reg_lambda': 0.03332169476380633, 'max_bin': 458}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:38:00,969] Trial 884 finished with value: -0.14656316622219018 and parameters: {'max_depth': 12, 'num_leaves': 50, 'learning_rate': 0.1996720942515463, 'min_child_weight': 0.06619947371850612, 'subsample': 0.6634880023918288, 'subsample_freq': 1, 'colsample_bytree': 0.6099332937155296, 'reg_alpha': 3.0748172376593668, 'reg_lambda': 0.04230202689099189, 'max_bin': 451}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:38:15,820] Trial 885 finished with value: -0.17523972230845525 and parameters: {'max_depth': 14, 'num_leaves': 49, 'learning_rate': 0.19929460204424332, 'min_child_weight': 0.07283781190168512, 'subsample': 0.6062300764994019, 'subsample_freq': 1, 'colsample_bytree': 0.8952724574746201, 'reg_alpha': 1.9963466406346912, 'reg_lambda': 0.03564884445777623, 'max_bin': 470}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:38:29,840] Trial 886 finished with value: -0.18706680407182857 and parameters: {'max_depth': 15, 'num_leaves': 49, 'learning_rate': 0.1999029712432866, 'min_child_weight': 0.07495363779588941, 'subsample': 0.6271004665415144, 'subsample_freq': 1, 'colsample_bytree': 0.908074231744561, 'reg_alpha': 3.015887354639948, 'reg_lambda': 0.027371220028815903, 'max_bin': 448}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:38:44,491] Trial 887 finished with value: -0.21934800431738352 and parameters: {'max_depth': 13, 'num_leaves': 50, 'learning_rate': 0.1960333804143495, 'min_child_weight': 0.053993550273325405, 'subsample': 0.6488584626113152, 'subsample_freq': 1, 'colsample_bytree': 0.8994275904292348, 'reg_alpha': 3.2550148786812585, 'reg_lambda': 0.04025876200074475, 'max_bin': 459}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:38:58,565] Trial 888 finished with value: -0.23341313924758186 and parameters: {'max_depth': 13, 'num_leaves': 51, 'learning_rate': 0.19584949219777442, 'min_child_weight': 0.06370070645209924, 'subsample': 0.6379912288772078, 'subsample_freq': 1, 'colsample_bytree': 0.890687857186428, 'reg_alpha': 2.159054324596011, 'reg_lambda': 0.04977079942284697, 'max_bin': 454}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:39:13,756] Trial 889 finished with value: -0.19839783817740517 and parameters: {'max_depth': 13, 'num_leaves': 50, 'learning_rate': 0.1927746227901842, 'min_child_weight': 0.04226500517665647, 'subsample': 0.6479656623496362, 'subsample_freq': 1, 'colsample_bytree': 0.8775193586644854, 'reg_alpha': 3.8132914171063637, 'reg_lambda': 0.029804405560140863, 'max_bin': 443}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:39:46,608] Trial 890 finished with value: -0.1925522746868851 and parameters: {'max_depth': 15, 'num_leaves': 52, 'learning_rate': 0.01650841460648969, 'min_child_weight': 0.08062550326842786, 'subsample': 0.6248947310657773, 'subsample_freq': 1, 'colsample_bytree': 0.9043865192906848, 'reg_alpha': 3.481974656091926, 'reg_lambda': 0.04593124802792612, 'max_bin': 441}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:40:01,629] Trial 891 finished with value: -0.18511113251450245 and parameters: {'max_depth': 14, 'num_leaves': 48, 'learning_rate': 0.1900723809592972, 'min_child_weight': 0.08900510865852775, 'subsample': 0.6514202230662584, 'subsample_freq': 6, 'colsample_bytree': 0.8859938320170799, 'reg_alpha': 3.6257167192378565, 'reg_lambda': 0.03938930057414547, 'max_bin': 466}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:40:15,946] Trial 892 finished with value: -0.16712464096713917 and parameters: {'max_depth': 13, 'num_leaves': 51, 'learning_rate': 0.19044612127826596, 'min_child_weight': 0.04934036260302147, 'subsample': 0.6520134962829768, 'subsample_freq': 1, 'colsample_bytree': 0.9120464868874129, 'reg_alpha': 2.956835928907015, 'reg_lambda': 0.04410305438438982, 'max_bin': 439}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:40:37,738] Trial 893 finished with value: -0.19263041244285425 and parameters: {'max_depth': 12, 'num_leaves': 49, 'learning_rate': 0.04424073638664599, 'min_child_weight': 0.0798129147999741, 'subsample': 0.6342268450202357, 'subsample_freq': 1, 'colsample_bytree': 0.7361742693873267, 'reg_alpha': 2.6131167975982597, 'reg_lambda': 0.03386849163380391, 'max_bin': 448}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:40:51,672] Trial 894 finished with value: -0.24464905992592773 and parameters: {'max_depth': 14, 'num_leaves': 52, 'learning_rate': 0.19976130726193436, 'min_child_weight': 0.033469725265020955, 'subsample': 0.6409911038879766, 'subsample_freq': 1, 'colsample_bytree': 0.8985346510238692, 'reg_alpha': 2.3350857094871134, 'reg_lambda': 0.03874498458199463, 'max_bin': 437}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:41:05,784] Trial 895 finished with value: -0.2416483626436639 and parameters: {'max_depth': 12, 'num_leaves': 51, 'learning_rate': 0.1952243473667598, 'min_child_weight': 0.10010619034471394, 'subsample': 0.6552769275484666, 'subsample_freq': 1, 'colsample_bytree': 0.8677886900569343, 'reg_alpha': 3.6583493835175953, 'reg_lambda': 0.04761222616346018, 'max_bin': 450}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:41:21,521] Trial 896 finished with value: -0.1534417953433304 and parameters: {'max_depth': 13, 'num_leaves': 53, 'learning_rate': 0.18875970039261697, 'min_child_weight': 0.07461630845151418, 'subsample': 0.6568644206850291, 'subsample_freq': 2, 'colsample_bytree': 0.9089041944651405, 'reg_alpha': 4.105488908917404, 'reg_lambda': 0.0333333659472224, 'max_bin': 461}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:41:35,690] Trial 897 finished with value: -0.1682934339951843 and parameters: {'max_depth': 13, 'num_leaves': 30, 'learning_rate': 0.1928144406379384, 'min_child_weight': 0.06490591253220875, 'subsample': 0.6573325867292449, 'subsample_freq': 1, 'colsample_bytree': 0.895044355777862, 'reg_alpha': 2.738076133068645, 'reg_lambda': 0.05082027015458133, 'max_bin': 442}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:41:49,823] Trial 898 finished with value: -0.18459323168929948 and parameters: {'max_depth': 12, 'num_leaves': 49, 'learning_rate': 0.19661642778913505, 'min_child_weight': 0.090821328013495, 'subsample': 0.8963888986778168, 'subsample_freq': 1, 'colsample_bytree': 0.8319033724046407, 'reg_alpha': 3.6126561256138348, 'reg_lambda': 0.04151234768111946, 'max_bin': 438}. Best is trial 540 with value: -0.30730964302153063.
# [I 2022-06-20 20:42:05,132] Trial 899 finished with value: -0.12607437820766382 and parameters: {'max_depth': 11, 'num_leaves': 53, 'learning_rate': 0.18750128928533152, 'min_child_weight': 0.056084372546891345, 'subsample': 0.6207242311103786, 'subsample_freq': 8, 'colsample_bytree': 0.8860153792963477, 'reg_alpha': 4.357808950404532, 'reg_lambda': 0.02885940620231637, 'max_bin': 434}. Best is trial 540 with value: -0.30730964302153063.
# [2022-06-21 04:42:05] {'max_depth': 10, 'num_leaves': 53, 'learning_rate': 0.182084650857355, 'min_child_weight': 0.14541699939166688, 'subsample': 0.6699877766848735, 'subsample_freq': 6, 'colsample_bytree': 0.9191130192042725, 'reg_alpha': 8.761278571375973, 'reg_lambda': 0.10030359501305366, 'max_bin': 383}
# [2022-06-21 04:42:05] Best score is -0.30730964302153063
# CPU times: user 10h 19min 51s, sys: 1min 28s, total: 10h 21min 19s
# Wall time: 4h 14s

# %%
'''
Re-fit best model
'''
params = {'selected_feats': selected_feats, 
          'lgbm_var_params': best_params.copy(), 
          'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
          'n_estimators': N_ESTIMATORS_REFIT, 
          'early_stopping_rounds': EARLY_STOPPING_ROUNDS_REFIT}

outputs = []
for fold in range(N_FOLD):
    outputs.append(train_model(fold, params, 'normal'))
    
cv_score = np.mean([x['best_score_'] for x in outputs])
cv_sharpe = np.mean([x['sharpe']['val'] for x in outputs])
log(f"Folds best iterations: {[x['best_iteration_'] for x in outputs]}")
log(f"Folds average num unique values in train: {[x['n_uniq_trn'] for x in outputs]}")
log(f"Folds average num unique values in validation: {[x['n_uniq_val'] for x in outputs]}")
log(f"Folds scores: {[x['best_score_'] for x in outputs]}")
log(f"Folds sharpes: {[x['sharpe']['val'] for x in outputs]}")
log(f'CV score: {cv_score}')
log(f'CV sharpe: {cv_sharpe}')

# export validation df
df_pred_val = pd.concat([x['df_pred_val'] for x in outputs]).reset_index(drop=True)
df_pred_val.to_feather('df_pred_val')
# Out:
# [2022-06-21 04:42:42] Folds best iterations: [8, 3, 6, 46, 2]
# [2022-06-21 04:42:42] Folds average num unique values in train: [1016.875, 122.4375, 231.95, 1992.0125, 21.120833333333334]
# [2022-06-21 04:42:42] Folds average num unique values in validation: [1099.5833333333333, 124.43333333333334, 226.98333333333332, 1997.5, 19.883333333333333]
# [2022-06-21 04:42:42] Folds scores: [0.6924899466724984, 0.6930286977233221, 0.6920771937441628, 0.6925336459299022, 0.6919952669817595]
# [2022-06-21 04:42:42] Folds sharpes: [0.29819816468622423, 0.21612525256841142, 0.38972213400373834, 0.3982512484841845, 0.23425141536509472]
# [2022-06-21 04:42:42] CV score: 0.692424950210329
# [2022-06-21 04:42:42] CV sharpe: 0.30730964302153063

# %%
'''
Signal Analysis
'''
analyze_signal(outputs)
# Out:
# [2022-06-21 04:42:45] Average % in top 200: 0.11476666666666664
# [2022-06-21 04:42:45] Average % in bottom 200: 0.10643333333333328
# [2022-06-21 04:42:46] Mean long returns: 0.19617844080873484
# [2022-06-21 04:42:46] Mean short returns: 0.2277588480201631
# [2022-06-21 04:42:46] Mean net returns: 0.42393728882889814
# [2022-06-21 04:42:46] Sharpe of long: 0.09318426794060863
# [2022-06-21 04:42:46] Sharpe of short: 0.09222262446121225
# [2022-06-21 04:42:46] Sharpe of net: 0.2845895200108751

# %% [markdown]
# # Debug
