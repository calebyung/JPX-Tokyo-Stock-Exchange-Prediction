# %% [markdown]
# # Version description
# - PCA feats
# - Full Run

# %%
# import libraries
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
from os.path import isfile, isdir, join
import numpy as np
import pandas as pd
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
import re
from IPython.display import display
from zipfile import ZipFile
import pickle
import unicodedata
import pytz
from joblib import Parallel, delayed
import shutil
import difflib
import random
import math
from shutil import copyfile
import itertools
import time
from tqdm import tqdm
import collections
from collections import deque
import gc

from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer
from sklearn.metrics import ndcg_score, accuracy_score, mean_squared_error

import lightgbm as lgbm
import optuna
from optuna import Trial, visualization

import matplotlib as mpl
from matplotlib import pyplot as plt

import jpx_tokyo_market_prediction

from utility_script import *
# from utility_script_jpx import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
'''
Notebook Parameters
'''
# basic
SEED = 0
JPX_PATH = '../input/jpx-tokyo-stock-exchange-prediction'

# data sacling
SCALER = StandardScaler()
SCALE_DAILY = False

# drop market features
DROP_MARKET_FEATS = False

# PCA
RUN_PCA = True
N_COMP = 0.9

# target definition
RANK_ASCENDING = False # set this to False if model prediction is same direction of Target
TARGET_POW = 0

# data split
N_FOLD = 5
TRN_SIZE = 240
VAL_SIZE = 60
TRN_VAL_GAP = 14
SPLIT_METHOD = 'trn_val_split_late_val'

# model fixed params
DEVICE_TYPE = 'CPU'
EVAL_METRIC = f'binary_logloss'
LGBM_VAR_PARAMS = dict(
    max_depth = 32,
    num_leaves = 32,
    learning_rate = 0.01,
    min_child_weight = 0.1,
    min_child_samples = 1,
    subsample = 0.65,
    subsample_freq = 1,
    colsample_bytree = 0.6,
    reg_alpha = 1.5,
    reg_lambda = 1.5,
    max_bin = 255,
)
LGBM_FIXED_PARAMS = dict(
    boosting_type = 'gbdt',
    objective = 'binary',
    n_estimators = 5000,
    n_jobs = -1,
    random_state = SEED,
    device_type = DEVICE_TYPE,
)

# feature importance
RUN_IMP = True
N_SHUFFLE = 12
N_FEATS_IMP_TEST = 10
N_ESTIMATORS_IMP = 50
EARLY_STOPPING_ROUNDS_IMP = 9999
FEAT_GROUPS = None # fixed output if not running IMP

# forward selection
RUN_FS = True
N_ESTIMATORS_FS = 5000
EARLY_STOPPING_ROUNDS_FS = 20
N_FEATS_FS = 20 # top N features considered for FS based on importance
N_FEATS_FINAL = None # top N features if skipping FS based on importance
SELECTED_FEATS = 'EarningToPriceRatio_raw, sharpe_3m, price_standard_dist_1m'.split(', ') # fixed features if skipping both IMP and FS

# hyperparameters tuning
RUN_HP = True
N_ESTIMATORS_HP = 5000
EARLY_STOPPING_ROUNDS_HP = 30
HP_OPT_HRS = 4
BEST_PARAMS = None

# re-fit
N_ESTIMATORS_REFIT = 5000
EARLY_STOPPING_ROUNDS_REFIT = 30

# %% [markdown]
# # Data preprocessing

# %%
'''
Train-Val split where validation periods are right after train period
'''
def trn_val_split_even_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).head(VAL_SIZE)
        else:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).loc[lambda x: x.notnull()]
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data


'''
Train-Val split where validation periods are farthest in future
'''
def trn_val_split_late_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    val_dates_list = full_dates.tail(VAL_SIZE * N_FOLD).values.reshape(N_FOLD, -1)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = val_dates_list[i]
        else:
            dates_val = np.concatenate(val_dates_list[i:])
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data

# %%
'''
Function to scale the features
'''
def jpx_data_scaling(full_data, scaler, daily):
    feats = time_features + stock_features
    
    if daily==False:
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[feats])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[feats] = scaler.transform(data_trn[feats]).astype(np.float32)
            data_val[feats] = scaler.transform(data_val[feats]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
            
    elif daily==True:
        # scale stock features for each day
        def transform_data(df, scaler, feats):
            df[feats] = scaler.fit_transform(df[feats]).astype(np.float32)
            return df
        full_data = full_data.groupby(['fold','trn_val','Date']).apply(lambda df: transform_data(df, scaler, stock_features))
        # then scale time features across days
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[time_features])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[time_features] = scaler.transform(data_trn[time_features]).astype(np.float32)
            data_val[time_features] = scaler.transform(data_val[time_features]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
        
    return data_scaled

# %%
'''
PCA Compression
'''
def pca_compress(full_data):
    # fit with one fold of traiing data
    pca = PCA(n_components=N_COMP, random_state=SEED)
    pca.fit(full_data.loc[lambda x: (x.fold==0) & (x.trn_val=='trn'), all_features])
    log(f'PCA shape of components: {pca.components_.shape}')
    
    # tranform the full dataset
    cols = [f'pc{x}' for x in range(pca.components_.shape[0])]
    compressed_data = []
    for fold in range(N_FOLD):
        for trn_val in ['trn','val']:
            X = pd.DataFrame(pca.transform(full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), all_features]), columns=cols)
            header = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), [c for c in full_data.columns if c not in all_features]].reset_index(drop=True)
            new_df = pd.concat([header, X], axis=1)
            compressed_data.append(new_df)
    compressed_data = pd.concat(compressed_data, axis=0).reset_index(drop=True)
    return compressed_data, cols

# %% [markdown]
# # Model Training Functions

# %%
'''
Function to get sub-columns from table for model fitting
'''
def get_dataset(df, selected_feats, trn_val):
    if trn_val=='val':
        df = df.groupby('Date').sample(frac=1.0, random_state=SEED)
    df = df.reset_index(drop=True)
    grp = df.groupby('Date').size().tolist()
    qid = df['Date']
    X = df[selected_feats]
    y = df['target_train']
    target = df['Target']
    header = df[id_cols]
    return X, y, grp, qid, header, target

'''
Function to predict scores within groups
'''
def pred_score(model, X):
    return pd.Series(model.predict_proba(X)[:,1])

'''
Function to predict rankings within groups
'''
def pred_rank(model, X, qid):
    X_ = X.assign(Date=qid)
    rnk = []
    for date in X_.Date.unique():
        rnk += pd.Series(model.predict_proba(X_.loc[lambda x: x.Date==date].drop('Date',axis=1))[:,1]).rank(method='first').tolist()
    return pd.Series(rnk)

'''
Function to transform model output to rank prediction table
'''
def get_pred_df(header, pred_model, y_true_train, y_true, rank_ascending):
    df_pred = pd.concat([header[['RowId','Date','SecuritiesCode']].assign(Date=lambda x: x.Date.dt.strftime('%Y-%m-%d'), SecuritiesCode=lambda x: x.SecuritiesCode.astype(int)).reset_index(drop=True),
                        pd.Series(pred_model).rename('pred_model').reset_index(drop=True),
                        y_true_train.reset_index(drop=True),
                        y_true.reset_index(drop=True)
                        ], axis=1)
    df_pred['Rank'] = df_pred.groupby('Date').pred_model.rank(method='first', ascending=rank_ascending).astype(int) - 1
    return df_pred

'''
Official function to calculate Sharpe Ratio given a prediction
'''
def _calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def my_calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return pd.DataFrame({'long':[purchase],'short':[short],'net':[purchase - short]})

def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    buf = df.groupby('Date').apply(_calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio

# %%
'''
Training function
'''
def train_model(fold, params, mode):
    # unpack model params
    selected_feats = params['selected_feats']
    lgbm_var_params = params['lgbm_var_params']
    lgbm_fixed_params = params['lgbm_fixed_params']
    lgbm_fixed_params['n_estimators'] = params['n_estimators']
    early_stopping_rounds = params['early_stopping_rounds']
    
    # define dataset
    data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
    data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
    X_trn, y_trn, grp_trn, qid_trn, header_trn, target_trn = get_dataset(data_trn, selected_feats, 'trn')
    X_val, y_val, grp_val, qid_val, header_val, target_val = get_dataset(data_val, selected_feats, 'val')
    # model fit
    model = lgbm.LGBMClassifier(**lgbm_fixed_params, **lgbm_var_params)
    model.fit(
        X = X_trn,
        y = y_trn,
        eval_set = [(X_val, y_val)],
        eval_names = ['Validation'],
        verbose = False,
        eval_metric = EVAL_METRIC,
        early_stopping_rounds = early_stopping_rounds
    )

    # output
    if mode == 'val_score_only':
        output = model.best_score_['Validation'][EVAL_METRIC] # this score is for minimization problem
        
    if mode == 'val_sharpe_only':
        pred_val = pred_score(model, X_val)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        output = sharpe_val * -1 # this score is for minimization problem
        
    if mode == 'feat_imp':
        model.set_params(importance_type='gain')
        imp_gain = model.feature_importances_
        model.set_params(importance_type='split')
        imp_split = model.feature_importances_
        output = pd.concat([
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_gain}).assign(imp_type='gain', imp=lambda x: x.imp.rank()),
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_split}).assign(imp_type='split', imp=lambda x: x.imp.rank())
        ], axis=0).assign(fold=fold)
    
    if mode == 'normal':
        # save model
        save_pkl(model, f"model{fold}")
        # number of distinct predicted values
        n_uniq_trn = pd.concat([pred_score(model, X_trn).rename('score'), header_trn], axis=1).groupby('Date').score.nunique().mean()
        n_uniq_val = pd.concat([pred_score(model, X_val).rename('score'), header_val], axis=1).groupby('Date').score.nunique().mean()
        # prediction
        pred_trn = pred_score(model, X_trn)
        pred_val = pred_score(model, X_val)
        # prediction df
        df_pred_trn = get_pred_df(header_trn, pred_trn, y_trn, target_trn, RANK_ASCENDING)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        # sharpe
        sharpe_trn = calc_spread_return_sharpe(df_pred_trn)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        # output dict
        output = dict(
            fold = fold,
            params = params,
            best_iteration_ = model.best_iteration_,
            best_score_ = model.best_score_['Validation'][EVAL_METRIC],
            sharpe = {'trn': sharpe_trn, 'val': sharpe_val},
            ann_sharpe = {'trn': sharpe_trn * np.sqrt(240), 'val': sharpe_val * np.sqrt(240)},
            evals_result_ = model.evals_result_['Validation'][EVAL_METRIC],
            feat_imp = pd.DataFrame(list(zip(model.feature_name_, model.feature_importances_)), columns=['feat','imp']),
            df_pred_val = df_pred_val,
            n_uniq_trn = n_uniq_trn,
            n_uniq_val = n_uniq_val,
        )
    return output

# %% [markdown]
# # Feature Importance

# %%
def run_feature_importance():
    # random sampling of features
    all_feats = all_features.copy()
    feat_groups = []
    for i in range(N_SHUFFLE):
        random.shuffle(all_feats)
        n_groups = math.floor(len(all_feats)/N_FEATS_IMP_TEST)
        feat_groups += np.array(all_feats[:N_FEATS_IMP_TEST*n_groups]).reshape(-1,N_FEATS_IMP_TEST).tolist()
    log(f'Total number of run: {len(feat_groups)}')
    
    # calculate feature importance
    df_imp = []
    for i, group in enumerate(feat_groups):
        for fold in range(N_FOLD):
            params = {'selected_feats': group, 
                      'lgbm_var_params': LGBM_VAR_PARAMS,
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_IMP,
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_IMP}
            df_imp.append(train_model(fold, params, 'feat_imp'))
        log(f'Completed running feature group {i}') if i%10==0 else None
    df_imp = pd.concat(df_imp)
    df_imp_agg = df_imp.groupby('feat').imp.mean().sort_values(ascending=False).reset_index()
    df_imp_agg.to_csv('df_imp_agg.csv', index=False)
    display(df_imp_agg.head(10))

    # plotting feature importance
    df_imp_agg.sort_values('imp', ascending=True).set_index('feat').plot.barh(figsize=(20, 20))
    
    # prepare feature list for forward selection
    feat_groups = df_imp_agg.head(N_FEATS_FS)
    feat_groups = [[x] for x in feat_groups.feat]
    return feat_groups

# %% [markdown]
# # Forward Selection

# %%
'''
Forward Selection function
'''
def forward_selection(feat_groups):
    base_feats = []
    hist = []
    while len(feat_groups) > 0:
        scores = []
        for feats in feat_groups:
            # calculate CV score
            params = {'selected_feats': base_feats + feats, 
                      'lgbm_var_params': LGBM_VAR_PARAMS, 
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_FS, 
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_FS}
            mean_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
            scores.append(mean_score)
            hist.append((mean_score,
                         len(base_feats + feats),
                         ', '.join(base_feats + feats)
                         ))
            log(f'Score: {mean_score}; Num features: {len(base_feats + feats)}; Features: {", ".join(base_feats + feats)}')
        # add the new feature (group) which gives minimum score
        base_feats += feat_groups[np.argmin(scores)]
        # remove the added feature (group) from remaining candidate pool
        del feat_groups[np.argmin(scores)]
    hist = pd.DataFrame(hist, columns=['score','len_feats','total_feats'])
    hist.to_csv('fs_hist.csv', index=False)
    return hist

# %% [markdown]
# # Hyperparameter Tuning

# %%
'''
Hyperparameter Optimization function
'''
def Objective(trial):
    lgbm_var_params = dict(
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True),
        num_leaves = trial.suggest_int('num_leaves', 16, 64, log=True),
        learning_rate = trial.suggest_float("learning_rate", 0.005, 0.2),
        min_child_weight = trial.suggest_float("min_child_weight", 1e-3, 4, log=True),
        subsample = trial.suggest_float("subsample", 0.5, 1),
        subsample_freq = trial.suggest_categorical("subsample_freq", [1,2,4,6,8]),
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1),
        reg_alpha = trial.suggest_float("reg_alpha", 1e-2, 16, log=True),
        reg_lambda = trial.suggest_float("reg_lambda", 1e-2, 16, log=True),
        max_bin = trial.suggest_int('max_bin', 50, 500),
    )
    
    # pack all params
    params = {'selected_feats': selected_feats, 
              'lgbm_var_params': lgbm_var_params, 
              'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
              'n_estimators': N_ESTIMATORS_HP, 
              'early_stopping_rounds': EARLY_STOPPING_ROUNDS_HP}
    # return average CV score
    cv_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
    return cv_score


def optimize_hp():
    # run optimization
    study = optuna.create_study(direction="minimize", study_name='LGBM optimization')
    study.optimize(Objective, timeout=HP_OPT_HRS*60*60)
    
    # save results
    best_params = study.best_params
    best_score = study.best_value
    log(best_params)
    log(f'Best score is {best_score}')
    trials = study.trials_dataframe()
    trials.to_csv(f'trials.csv', index=False)
    save_pkl(best_params, f'best_params')
    save_pkl(study, f'study')
    
    # visualise relationship between parameter and CV score
    for c in trials.columns:
        if c[:7]=='params_':
            new_plot()
            trials.plot.scatter(c, 'value')
            plt.grid()
            plt.title(c)
            plt.show()
    return best_params

# %% [markdown]
# # Signal Analysis

# %%
def analyze_signal(outputs):
    df = pd.concat([x['df_pred_val'] for x in outputs])
    df.Date = pd.to_datetime(df.Date)
    df['rank_pred'] = df.groupby('Date').pred_model.rank(method='first',ascending=False)
    df['rank_true'] = df.groupby('Date').target_train.rank(method='first',ascending=True)

    # distribution of model prediction
    new_plot()
    df.pred_model.hist(bins=100)
    plt.grid()
    plt.title('Distribution of model prediction')

    # percentage in correct region
    new_plot()
    n = 200
    top = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true>=2000-n) & (x.rank_pred>=2000-n)].shape[0]).divide(n)
    bottom = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true<=n) & (x.rank_pred<=n)].shape[0]).divide(n)
    top.rolling(20).mean().plot(label='top')
    bottom.rolling(20).mean().plot(label='bottom')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('% in correct region')
    log(f'Average % in top 200: {top.mean()}')
    log(f'Average % in bottom 200: {bottom.mean()}')

    # portfolio return analysis
    ret = df.groupby('Date').apply(my_calc_spread_return_per_day, 200, 2)
    ret = ret.reset_index().set_index('Date') \
        .assign(short = lambda x: -1 * x.short)

    # cumulative returns
    new_plot()
    ret.long.cumsum().plot(label='long')
    ret.short.cumsum().plot(label='short')
    ret.net.cumsum().plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Cumulative Returns')
    log(f'Mean long returns: {ret.long.mean()}')
    log(f'Mean short returns: {ret.short.mean()}')
    log(f'Mean net returns: {ret.net.mean()}')

    # rolling sharpes
    new_plot()
    ret.long.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='long')
    ret.short.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='short')
    ret.net.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Rolling Sharpes')
    log(f'Sharpe of long: {ret.long.mean() / ret.long.std()}')
    log(f'Sharpe of short: {ret.short.mean() / ret.short.std()}')
    log(f'Sharpe of net: {ret.net.mean() / ret.net.std()}')

# %% [markdown]
# # Execution

# %%
# %%time
'''
Preprocessing
'''
# load features
path = '../input/jpx-feature-engineering/features'
features = pd.concat([pd.concat(load_pkl(f'{path}/{filename}')) for filename in os.listdir(path)]).sort_values('RowId').reset_index(drop=True)

# train-val split
if SPLIT_METHOD == 'trn_val_split_late_val':
    full_data = trn_val_split_late_val(features, val_to_end=False)
elif SPLIT_METHOD == 'trn_val_split_even_val':
    full_data = trn_val_split_even_val(features, val_to_end=False)
display(full_data.groupby(['fold','trn_val']).agg({'Date':['min','max','nunique']}))

# add targets
targets = pd.concat([pd.read_csv(f'{JPX_PATH}/{folder}/stock_prices.csv', parse_dates=['Date']) for folder in ['train_files', 'supplemental_files']]) \
    .loc[:,['RowId','Target']] \
    .loc[lambda x: x.Target.notnull()] \
    .drop_duplicates() \
    .reset_index(drop=True)
full_data = full_data.merge(targets, how='inner', on='RowId')

# remove irregular data
full_data = full_data.loc[lambda x: x.volatility_1w!=0].reset_index(drop=True)

# derive training target
full_data['target_train'] = full_data.groupby(['fold','trn_val','Date']).Target.apply(lambda s: (s >= s.quantile(0.5)).astype(int))

# release memory
del features
gc.collect()

# define column types
id_cols = ['RowId','Date','SecuritiesCode','fold','trn_val']
all_features = [c for c in list(full_data) if c not in id_cols and c not in ['target_train','Target']]
cat_features = ['AdjustmentFactor','first_div']
time_features = [c for c in all_features if '_mkt' in c] + \
                [c for c in all_features if c[:4]=='sec_'] + \
                [c for c in all_features if c[-4:] in ['_sin','_cos']]
stock_features = [c for c in all_features if c not in cat_features + time_features]

# scaling
full_data = jpx_data_scaling(full_data=full_data, scaler=SCALER, daily=SCALE_DAILY)

# drop market features
if DROP_MARKET_FEATS:
    full_data = full_data.drop(time_features, axis=1)
    all_features = [c for c in all_features if c not in time_features]

# PCA compression
if RUN_PCA:
    full_data, all_features = pca_compress(full_data)
# Out:
#                    Date
#                     min        max nunique
# fold trn_val
# 0    trn     2019-01-16 2020-01-14     240
#      val     2021-03-05 2021-06-02      60
# 1    trn     2019-07-23 2020-07-16     240
#      val     2021-06-03 2021-08-30      60
# 2    trn     2020-01-30 2021-01-22     240
#      val     2021-08-31 2021-11-26      60
# 3    trn     2020-08-06 2021-07-29     240
#      val     2021-11-29 2022-02-25      60
# 4    trn     2021-02-10 2022-02-02     240
#      val     2022-02-28 2022-05-27      60
# [2022-06-19 01:31:45] PCA shape of components: (41, 85)
# CPU times: user 56.4 s, sys: 18.1 s, total: 1min 14s
# Wall time: 1min 9s

# %%
# %%time
'''
Feature importance
'''
if RUN_IMP:
    feat_groups = run_feature_importance()
else:
    # if not running feature importance, use pre-set FEAT_GROUPS for forward selection
    feat_groups = FEAT_GROUPS
# Out:
# [2022-06-19 01:31:56] Total number of run: 48
# [2022-06-19 01:32:08] Completed running feature group 0
# [2022-06-19 01:34:10] Completed running feature group 10
# [2022-06-19 01:36:11] Completed running feature group 20
# [2022-06-19 01:38:10] Completed running feature group 30
# [2022-06-19 01:40:08] Completed running feature group 40
#    feat       imp
# 0  pc35  8.583333
# 1  pc33  8.325000
# 2  pc27  8.175000
# 3   pc4  8.154167
# 4  pc36  7.679167
# 5  pc23  7.612500
# 6   pc2  7.612500
# 7   pc3  7.450000
# 8  pc20  7.416667
# 9   pc8  7.258333
# CPU times: user 29min 31s, sys: 4.39 s, total: 29min 36s
# Wall time: 9min 37s

# %%
# %%time
'''
Forward Selection
'''
if RUN_FS:
    # run FS
    fs_hist = forward_selection(feat_groups)
    display(fs_hist.sort_values('score', ascending=True).head(1))
    # output selected features
    selected_feats = fs_hist.sort_values('score', ascending=True).total_feats.iloc[0].split(', ')

else:
    # if not running both IMP and FS, output pre-set selected_feats
    if not RUN_IMP:
        selected_feats = SELECTED_FEATS
    # if ran IMP but not FS, output first N important features where N is pre-set
    elif RUN_IMP:
        selected_feats = [x[0] for x in feat_groups][:N_FEATS_FINAL]
# Out:
# [2022-06-19 01:41:56] Score: -0.2665121551384092; Num features: 1; Features: pc35
# [2022-06-19 01:42:16] Score: -0.10845536311103521; Num features: 1; Features: pc33
# [2022-06-19 01:42:49] Score: -0.14953545668378732; Num features: 1; Features: pc27
# [2022-06-19 01:43:01] Score: -0.03626242913036823; Num features: 1; Features: pc4
# [2022-06-19 01:43:22] Score: -0.08925296667887958; Num features: 1; Features: pc36
# [2022-06-19 01:43:54] Score: -0.14899633677019847; Num features: 1; Features: pc23
# [2022-06-19 01:44:06] Score: -0.028352807650493396; Num features: 1; Features: pc2
# [2022-06-19 01:44:19] Score: 0.03412193670271286; Num features: 1; Features: pc3
# [2022-06-19 01:44:38] Score: -0.037775614425325864; Num features: 1; Features: pc20
# [2022-06-19 01:44:50] Score: -0.061492583749748045; Num features: 1; Features: pc8
# [2022-06-19 01:45:10] Score: -0.03327511613452509; Num features: 1; Features: pc25
# [2022-06-19 01:45:23] Score: -0.03991971129180225; Num features: 1; Features: pc12
# [2022-06-19 01:45:57] Score: -0.1796590620273743; Num features: 1; Features: pc19
# [2022-06-19 01:46:15] Score: -0.11955294732605459; Num features: 1; Features: pc6
# [2022-06-19 01:46:44] Score: -0.13311183552391437; Num features: 1; Features: pc28
# [2022-06-19 01:46:56] Score: -0.09309425616513618; Num features: 1; Features: pc29
# [2022-06-19 01:47:28] Score: -0.05927932499217431; Num features: 1; Features: pc22
# [2022-06-19 01:47:40] Score: 0.03520812105721441; Num features: 1; Features: pc17
# [2022-06-19 01:47:59] Score: 0.009876755211130206; Num features: 1; Features: pc5
# [2022-06-19 01:48:17] Score: -0.13104363047545112; Num features: 1; Features: pc13
# [2022-06-19 01:48:46] Score: -0.18467316708353118; Num features: 2; Features: pc35, pc33
# [2022-06-19 01:49:19] Score: -0.2131640157707153; Num features: 2; Features: pc35, pc27
# [2022-06-19 01:49:43] Score: -0.20592889333513628; Num features: 2; Features: pc35, pc4
# [2022-06-19 01:50:12] Score: -0.18936916453356012; Num features: 2; Features: pc35, pc36
# [2022-06-19 01:50:47] Score: -0.19098147112348035; Num features: 2; Features: pc35, pc23
# [2022-06-19 01:51:10] Score: -0.14914149916545816; Num features: 2; Features: pc35, pc2
# [2022-06-19 01:51:39] Score: -0.1090781795483196; Num features: 2; Features: pc35, pc3
# [2022-06-19 01:52:07] Score: -0.132808383768977; Num features: 2; Features: pc35, pc20
# [2022-06-19 01:52:32] Score: -0.18585755377582963; Num features: 2; Features: pc35, pc8
# [2022-06-19 01:52:59] Score: -0.12297003040831744; Num features: 2; Features: pc35, pc25
# [2022-06-19 01:53:25] Score: -0.17185461828848617; Num features: 2; Features: pc35, pc12
# [2022-06-19 01:54:00] Score: -0.23114835739710413; Num features: 2; Features: pc35, pc19
# [2022-06-19 01:54:24] Score: -0.18561063679995052; Num features: 2; Features: pc35, pc6
# [2022-06-19 01:54:57] Score: -0.17292967101040943; Num features: 2; Features: pc35, pc28
# [2022-06-19 01:55:25] Score: -0.2430223393342304; Num features: 2; Features: pc35, pc29
# [2022-06-19 01:55:58] Score: -0.12486043661919459; Num features: 2; Features: pc35, pc22
# [2022-06-19 01:56:23] Score: -0.1362948659634477; Num features: 2; Features: pc35, pc17
# [2022-06-19 01:56:49] Score: -0.10562646111532539; Num features: 2; Features: pc35, pc5
# [2022-06-19 01:57:21] Score: -0.19009374019608405; Num features: 2; Features: pc35, pc13
# [2022-06-19 01:57:45] Score: -0.19071028102961515; Num features: 3; Features: pc35, pc29, pc33
# [2022-06-19 01:58:12] Score: -0.23281479797523952; Num features: 3; Features: pc35, pc29, pc27
# [2022-06-19 01:58:29] Score: -0.15454303876988776; Num features: 3; Features: pc35, pc29, pc4
# [2022-06-19 01:58:55] Score: -0.15975458466023662; Num features: 3; Features: pc35, pc29, pc36
# [2022-06-19 01:59:22] Score: -0.10194711912454062; Num features: 3; Features: pc35, pc29, pc23
# [2022-06-19 01:59:39] Score: -0.14311277637923306; Num features: 3; Features: pc35, pc29, pc2
# [2022-06-19 01:59:57] Score: -0.03294493084272008; Num features: 3; Features: pc35, pc29, pc3
# [2022-06-19 02:00:23] Score: -0.10962695220952576; Num features: 3; Features: pc35, pc29, pc20
# [2022-06-19 02:00:41] Score: -0.20510360493724974; Num features: 3; Features: pc35, pc29, pc8
# [2022-06-19 02:01:01] Score: -0.13765213079423547; Num features: 3; Features: pc35, pc29, pc25
# [2022-06-19 02:01:24] Score: -0.17379462835773166; Num features: 3; Features: pc35, pc29, pc12
# [2022-06-19 02:01:50] Score: -0.19579989669656245; Num features: 3; Features: pc35, pc29, pc19
# [2022-06-19 02:02:09] Score: -0.1535985631909542; Num features: 3; Features: pc35, pc29, pc6
# [2022-06-19 02:02:34] Score: -0.18622187730815046; Num features: 3; Features: pc35, pc29, pc28
# [2022-06-19 02:03:02] Score: -0.19438458484727456; Num features: 3; Features: pc35, pc29, pc22
# [2022-06-19 02:03:23] Score: -0.14093103221855977; Num features: 3; Features: pc35, pc29, pc17
# [2022-06-19 02:03:43] Score: -0.20061808369459938; Num features: 3; Features: pc35, pc29, pc5
# [2022-06-19 02:04:09] Score: -0.1691361939383229; Num features: 3; Features: pc35, pc29, pc13
# [2022-06-19 02:04:38] Score: -0.13979507993165047; Num features: 4; Features: pc35, pc29, pc27, pc33
# [2022-06-19 02:05:06] Score: -0.16211224083131337; Num features: 4; Features: pc35, pc29, pc27, pc4
# [2022-06-19 02:05:33] Score: -0.1707707720751183; Num features: 4; Features: pc35, pc29, pc27, pc36
# [2022-06-19 02:06:06] Score: -0.22343016685673853; Num features: 4; Features: pc35, pc29, pc27, pc23
# [2022-06-19 02:06:29] Score: -0.1634253989403463; Num features: 4; Features: pc35, pc29, pc27, pc2
# [2022-06-19 02:06:59] Score: -0.11179387061866711; Num features: 4; Features: pc35, pc29, pc27, pc3
# [2022-06-19 02:07:28] Score: -0.12684562763206092; Num features: 4; Features: pc35, pc29, pc27, pc20
# [2022-06-19 02:07:54] Score: -0.21341379474698935; Num features: 4; Features: pc35, pc29, pc27, pc8
# [2022-06-19 02:08:22] Score: -0.19489255348116194; Num features: 4; Features: pc35, pc29, pc27, pc25
# [2022-06-19 02:08:53] Score: -0.17704020991935404; Num features: 4; Features: pc35, pc29, pc27, pc12
# [2022-06-19 02:09:24] Score: -0.2107286134281771; Num features: 4; Features: pc35, pc29, pc27, pc19
# [2022-06-19 02:09:52] Score: -0.1850201972538173; Num features: 4; Features: pc35, pc29, pc27, pc6
# [2022-06-19 02:10:23] Score: -0.15873630949643563; Num features: 4; Features: pc35, pc29, pc27, pc28
# [2022-06-19 02:10:55] Score: -0.20488044131277378; Num features: 4; Features: pc35, pc29, pc27, pc22
# [2022-06-19 02:11:28] Score: -0.14561525797955566; Num features: 4; Features: pc35, pc29, pc27, pc17
# [2022-06-19 02:12:01] Score: -0.19725223739034675; Num features: 4; Features: pc35, pc29, pc27, pc5
# [2022-06-19 02:12:36] Score: -0.22008530767257595; Num features: 4; Features: pc35, pc29, pc27, pc13
# [2022-06-19 02:13:04] Score: -0.16576498664836903; Num features: 5; Features: pc35, pc29, pc27, pc23, pc33
# [2022-06-19 02:13:30] Score: -0.1722779573640476; Num features: 5; Features: pc35, pc29, pc27, pc23, pc4
# [2022-06-19 02:13:58] Score: -0.21246254459826108; Num features: 5; Features: pc35, pc29, pc27, pc23, pc36
# [2022-06-19 02:14:25] Score: -0.13361614354865042; Num features: 5; Features: pc35, pc29, pc27, pc23, pc2
# [2022-06-19 02:14:52] Score: -0.09771205637036015; Num features: 5; Features: pc35, pc29, pc27, pc23, pc3
# [2022-06-19 02:15:22] Score: -0.16281678266610117; Num features: 5; Features: pc35, pc29, pc27, pc23, pc20
# [2022-06-19 02:15:52] Score: -0.17689767095927994; Num features: 5; Features: pc35, pc29, pc27, pc23, pc8
# [2022-06-19 02:16:20] Score: -0.17799001159294753; Num features: 5; Features: pc35, pc29, pc27, pc23, pc25
# [2022-06-19 02:16:51] Score: -0.18491474655459225; Num features: 5; Features: pc35, pc29, pc27, pc23, pc12
# [2022-06-19 02:17:21] Score: -0.1781671804943964; Num features: 5; Features: pc35, pc29, pc27, pc23, pc19
# [2022-06-19 02:17:46] Score: -0.13162926657797933; Num features: 5; Features: pc35, pc29, pc27, pc23, pc6
# [2022-06-19 02:18:16] Score: -0.20007082246625307; Num features: 5; Features: pc35, pc29, pc27, pc23, pc28
# [2022-06-19 02:18:46] Score: -0.2214472611865908; Num features: 5; Features: pc35, pc29, pc27, pc23, pc22
# [2022-06-19 02:19:16] Score: -0.11529320885570167; Num features: 5; Features: pc35, pc29, pc27, pc23, pc17
# [2022-06-19 02:19:45] Score: -0.1567860272712615; Num features: 5; Features: pc35, pc29, pc27, pc23, pc5
# [2022-06-19 02:20:19] Score: -0.19692086813416737; Num features: 5; Features: pc35, pc29, pc27, pc23, pc13
# [2022-06-19 02:20:48] Score: -0.1482390328309534; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc33
# [2022-06-19 02:21:16] Score: -0.1704304976062248; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc4
# [2022-06-19 02:21:45] Score: -0.17407568955350633; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc36
# [2022-06-19 02:22:14] Score: -0.1271763352878161; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc2
# [2022-06-19 02:22:40] Score: -0.1067889771426822; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc3
# [2022-06-19 02:23:08] Score: -0.11683507406529822; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc20
# [2022-06-19 02:23:41] Score: -0.19155781213104456; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc8
# [2022-06-19 02:24:09] Score: -0.14989490606014105; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc25
# [2022-06-19 02:24:42] Score: -0.13870781845925384; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc12
# [2022-06-19 02:25:11] Score: -0.17938188764625473; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc19
# [2022-06-19 02:25:37] Score: -0.14455860849971025; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc6
# [2022-06-19 02:26:07] Score: -0.15213128411341467; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc28
# [2022-06-19 02:26:39] Score: -0.14046097266699348; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc17
# [2022-06-19 02:27:09] Score: -0.15030854410895608; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc5
# [2022-06-19 02:27:43] Score: -0.17636133358280573; Num features: 6; Features: pc35, pc29, pc27, pc23, pc22, pc13
# [2022-06-19 02:28:13] Score: -0.1467174302746432; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc33
# [2022-06-19 02:28:46] Score: -0.1877347170779943; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc4
# [2022-06-19 02:29:16] Score: -0.1807715863002674; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc36
# [2022-06-19 02:29:45] Score: -0.1631724473769775; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc2
# [2022-06-19 02:30:15] Score: -0.1551277153296259; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc3
# [2022-06-19 02:30:44] Score: -0.16475464063670597; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc20
# [2022-06-19 02:31:14] Score: -0.19353868227754198; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc25
# [2022-06-19 02:31:49] Score: -0.2056132216821987; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12
# [2022-06-19 02:32:20] Score: -0.19112094025433285; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc19
# [2022-06-19 02:32:49] Score: -0.1632930104398137; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc6
# [2022-06-19 02:33:17] Score: -0.17747002170651988; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc28
# [2022-06-19 02:33:49] Score: -0.14890599808354057; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc17
# [2022-06-19 02:34:23] Score: -0.16912795987084495; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc5
# [2022-06-19 02:34:57] Score: -0.1916013433513811; Num features: 7; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc13
# [2022-06-19 02:35:27] Score: -0.14325900623372842; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc33
# [2022-06-19 02:36:04] Score: -0.1962341948528353; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4
# [2022-06-19 02:36:36] Score: -0.17907229482620052; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc36
# [2022-06-19 02:37:07] Score: -0.13519736092526008; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc2
# [2022-06-19 02:37:37] Score: -0.1442355692324527; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc3
# [2022-06-19 02:38:09] Score: -0.18436877021498735; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc20
# [2022-06-19 02:38:45] Score: -0.19204649727473755; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc25
# [2022-06-19 02:39:23] Score: -0.19430083381426533; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc19
# [2022-06-19 02:39:55] Score: -0.17037237590454377; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc6
# [2022-06-19 02:40:28] Score: -0.18970823329129338; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc28
# [2022-06-19 02:41:02] Score: -0.10939023236739694; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc17
# [2022-06-19 02:41:36] Score: -0.16095064852494087; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc5
# [2022-06-19 02:42:17] Score: -0.1737896102990039; Num features: 8; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc13
# [2022-06-19 02:42:51] Score: -0.16963607419960267; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc33
# [2022-06-19 02:43:25] Score: -0.18389361053416417; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc36
# [2022-06-19 02:43:59] Score: -0.16907092743556298; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc2
# [2022-06-19 02:44:36] Score: -0.1720420403038929; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc3
# [2022-06-19 02:45:11] Score: -0.1767137616926039; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc20
# [2022-06-19 02:45:50] Score: -0.18140449014371215; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc25
# [2022-06-19 02:46:29] Score: -0.19329799853594154; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc19
# [2022-06-19 02:47:05] Score: -0.15553595507462764; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc6
# [2022-06-19 02:47:39] Score: -0.20033968751046674; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28
# [2022-06-19 02:48:19] Score: -0.14006369167184413; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc17
# [2022-06-19 02:48:55] Score: -0.1421531471629225; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc5
# [2022-06-19 02:49:33] Score: -0.19153385161987163; Num features: 9; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc13
# [2022-06-19 02:50:07] Score: -0.1760174762681255; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc33
# [2022-06-19 02:50:42] Score: -0.17759275217345388; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc36
# [2022-06-19 02:51:14] Score: -0.15053735145930472; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc2
# [2022-06-19 02:51:46] Score: -0.13280575999073957; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc3
# [2022-06-19 02:52:20] Score: -0.16297732367713597; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc20
# [2022-06-19 02:52:58] Score: -0.16644293723799025; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc25
# [2022-06-19 02:53:38] Score: -0.1947025693760805; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19
# [2022-06-19 02:54:10] Score: -0.16628117801630485; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc6
# [2022-06-19 02:54:46] Score: -0.15697808807883767; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc17
# [2022-06-19 02:55:23] Score: -0.147663897765047; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc5
# [2022-06-19 02:56:00] Score: -0.1678252447209964; Num features: 10; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc13
# [2022-06-19 02:56:34] Score: -0.20158629046491128; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc33
# [2022-06-19 02:57:08] Score: -0.1851065687570435; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc36
# [2022-06-19 02:57:38] Score: -0.14603234694673525; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc2
# [2022-06-19 02:58:11] Score: -0.13936172852074816; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc3
# [2022-06-19 02:58:45] Score: -0.17842738081428713; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc20
# [2022-06-19 02:59:24] Score: -0.20120680058348248; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc25
# [2022-06-19 03:00:02] Score: -0.18327005643245725; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc6
# [2022-06-19 03:00:36] Score: -0.14667584255968824; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc17
# [2022-06-19 03:01:13] Score: -0.16502160410072617; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc5
# [2022-06-19 03:01:48] Score: -0.21705226805359734; Num features: 11; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13
# [2022-06-19 03:02:28] Score: -0.17358765860325315; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33
# [2022-06-19 03:03:06] Score: -0.15416973789711688; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc36
# [2022-06-19 03:03:46] Score: -0.14099413031337407; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc2
# [2022-06-19 03:04:25] Score: -0.14767986871222244; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc3
# [2022-06-19 03:05:04] Score: -0.1621587529709283; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc20
# [2022-06-19 03:05:45] Score: -0.17121983803245067; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc25
# [2022-06-19 03:06:20] Score: -0.16874614474698085; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc6
# [2022-06-19 03:07:03] Score: -0.14028355601572934; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc17
# [2022-06-19 03:07:42] Score: -0.13028467159253107; Num features: 12; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc5
# [2022-06-19 03:08:18] Score: -0.15993537923848725; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc36
# [2022-06-19 03:08:51] Score: -0.1640855646666735; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc2
# [2022-06-19 03:09:26] Score: -0.13981646034287495; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc3
# [2022-06-19 03:10:01] Score: -0.18041074856867506; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc20
# [2022-06-19 03:10:36] Score: -0.1881930669476659; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25
# [2022-06-19 03:11:10] Score: -0.14592216551581155; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc6
# [2022-06-19 03:11:47] Score: -0.11865698299354799; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc17
# [2022-06-19 03:12:21] Score: -0.12767332359278225; Num features: 13; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc5
# [2022-06-19 03:12:54] Score: -0.1625563675735299; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc36
# [2022-06-19 03:13:29] Score: -0.14329902538426756; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc2
# [2022-06-19 03:14:06] Score: -0.14346460380369636; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc3
# [2022-06-19 03:14:41] Score: -0.17165218042120253; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc20
# [2022-06-19 03:15:18] Score: -0.18448298435002086; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6
# [2022-06-19 03:15:59] Score: -0.15324327716375774; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc17
# [2022-06-19 03:16:37] Score: -0.14624230003555927; Num features: 14; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc5
# [2022-06-19 03:17:13] Score: -0.1292124812001684; Num features: 15; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc36
# [2022-06-19 03:17:50] Score: -0.15520268122405198; Num features: 15; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc2
# [2022-06-19 03:18:29] Score: -0.10688806366026378; Num features: 15; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc3
# [2022-06-19 03:19:08] Score: -0.1404813056276334; Num features: 15; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc20
# [2022-06-19 03:19:44] Score: -0.14073736703687387; Num features: 15; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc17
# [2022-06-19 03:20:22] Score: -0.15543522683084326; Num features: 15; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5
# [2022-06-19 03:21:01] Score: -0.12110020758255238; Num features: 16; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc36
# [2022-06-19 03:21:42] Score: -0.14901025234197746; Num features: 16; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2
# [2022-06-19 03:22:20] Score: -0.10323312475539428; Num features: 16; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc3
# [2022-06-19 03:23:04] Score: -0.14368608564013302; Num features: 16; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc20
# [2022-06-19 03:23:46] Score: -0.14079263083183002; Num features: 16; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc17
# [2022-06-19 03:24:26] Score: -0.12829728148193215; Num features: 17; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc36
# [2022-06-19 03:25:07] Score: -0.10183721283415212; Num features: 17; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc3
# [2022-06-19 03:25:50] Score: -0.13275382975594974; Num features: 17; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc20
# [2022-06-19 03:26:36] Score: -0.15773909107069412; Num features: 17; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17
# [2022-06-19 03:27:18] Score: -0.12135888551496474; Num features: 18; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17, pc36
# [2022-06-19 03:27:57] Score: -0.08589184322734222; Num features: 18; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17, pc3
# [2022-06-19 03:28:43] Score: -0.13893444331378976; Num features: 18; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17, pc20
# [2022-06-19 03:29:26] Score: -0.14018807449637763; Num features: 19; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17, pc20, pc36
# [2022-06-19 03:30:11] Score: -0.07117008833495755; Num features: 19; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17, pc20, pc3
# [2022-06-19 03:30:54] Score: -0.09151588929994131; Num features: 20; Features: pc35, pc29, pc27, pc23, pc22, pc8, pc12, pc4, pc28, pc19, pc13, pc33, pc25, pc6, pc5, pc2, pc17, pc20, pc36, pc3
#       score  len_feats total_feats
# 0 -0.266512          1        pc35
# CPU times: user 5h 48min 22s, sys: 1min, total: 5h 49min 23s
# Wall time: 1h 49min 19s

# %%
# %%time
'''
Hyperparameter tuning
'''
if RUN_HP:
    # run optimization
    best_params = optimize_hp()
    
else:
    # if not running HP, use pre-set best parameters
    best_params = BEST_PARAMS
# Out:
# [I 2022-06-18 19:30:54,527] A new study created in memory with name: LGBM optimization
# [I 2022-06-18 19:31:09,104] Trial 0 finished with value: -0.14964875874209596 and parameters: {'max_depth': 17, 'num_leaves': 62, 'learning_rate': 0.18743459522893105, 'min_child_weight': 0.38508936732991983, 'subsample': 0.6024858683259564, 'subsample_freq': 8, 'colsample_bytree': 0.8355799359431743, 'reg_alpha': 3.613379069997194, 'reg_lambda': 0.5043064791260623, 'max_bin': 305}. Best is trial 0 with value: -0.14964875874209596.
# [I 2022-06-18 19:31:41,311] Trial 1 finished with value: -0.26878704917764595 and parameters: {'max_depth': 6, 'num_leaves': 26, 'learning_rate': 0.006168202928869958, 'min_child_weight': 0.05004521530880311, 'subsample': 0.8343972028333897, 'subsample_freq': 1, 'colsample_bytree': 0.6055630978815265, 'reg_alpha': 0.1323132092028721, 'reg_lambda': 0.8214437615708703, 'max_bin': 129}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:31:53,823] Trial 2 finished with value: -0.209355411677527 and parameters: {'max_depth': 5, 'num_leaves': 33, 'learning_rate': 0.1023470411602652, 'min_child_weight': 0.32487130862705627, 'subsample': 0.606576818474559, 'subsample_freq': 4, 'colsample_bytree': 0.7065364769398154, 'reg_alpha': 1.0630468610082555, 'reg_lambda': 1.2212611816865773, 'max_bin': 499}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:32:10,436] Trial 3 finished with value: -0.19038272213235924 and parameters: {'max_depth': 3, 'num_leaves': 20, 'learning_rate': 0.016921867038186763, 'min_child_weight': 0.049279968668678176, 'subsample': 0.7253036983540836, 'subsample_freq': 6, 'colsample_bytree': 0.8455266008858724, 'reg_alpha': 3.3931778297692317, 'reg_lambda': 0.061842337364495105, 'max_bin': 369}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:32:23,795] Trial 4 finished with value: -0.20578968405706685 and parameters: {'max_depth': 8, 'num_leaves': 32, 'learning_rate': 0.16914762688269663, 'min_child_weight': 0.03549196925382575, 'subsample': 0.5845324432223875, 'subsample_freq': 2, 'colsample_bytree': 0.7627785465443566, 'reg_alpha': 0.4153344156594879, 'reg_lambda': 8.158014484716727, 'max_bin': 133}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:32:35,350] Trial 5 finished with value: -0.2591215275001073 and parameters: {'max_depth': 4, 'num_leaves': 22, 'learning_rate': 0.13264825371335673, 'min_child_weight': 3.875136289366996, 'subsample': 0.7166602970474144, 'subsample_freq': 6, 'colsample_bytree': 0.6567616064322003, 'reg_alpha': 0.035402608785530136, 'reg_lambda': 0.019988591156246665, 'max_bin': 145}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:32:52,255] Trial 6 finished with value: -0.21439445295529058 and parameters: {'max_depth': 16, 'num_leaves': 36, 'learning_rate': 0.03614831084387666, 'min_child_weight': 3.1371921440931017, 'subsample': 0.6213114774834311, 'subsample_freq': 1, 'colsample_bytree': 0.7851390771530211, 'reg_alpha': 0.23131872691053326, 'reg_lambda': 11.175752185579773, 'max_bin': 366}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:33:06,309] Trial 7 finished with value: -0.254421760422108 and parameters: {'max_depth': 11, 'num_leaves': 46, 'learning_rate': 0.11863109516048988, 'min_child_weight': 0.07870854896154564, 'subsample': 0.5431521553370906, 'subsample_freq': 2, 'colsample_bytree': 0.9163087385328192, 'reg_alpha': 0.023065865849819397, 'reg_lambda': 0.5437692185598402, 'max_bin': 128}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:33:21,449] Trial 8 finished with value: -0.22572034358358248 and parameters: {'max_depth': 4, 'num_leaves': 20, 'learning_rate': 0.04036282687445058, 'min_child_weight': 0.001239178973930164, 'subsample': 0.600868437751371, 'subsample_freq': 2, 'colsample_bytree': 0.972793601840514, 'reg_alpha': 1.3713827157227514, 'reg_lambda': 0.9757166708037432, 'max_bin': 424}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:33:35,608] Trial 9 finished with value: -0.21713239417927244 and parameters: {'max_depth': 4, 'num_leaves': 21, 'learning_rate': 0.03518916970004063, 'min_child_weight': 0.7663589393790224, 'subsample': 0.9233037756405192, 'subsample_freq': 2, 'colsample_bytree': 0.96409845077104, 'reg_alpha': 0.5866417804381123, 'reg_lambda': 1.5876578651100566, 'max_bin': 395}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:33:48,242] Trial 10 finished with value: -0.2354954624821975 and parameters: {'max_depth': 30, 'num_leaves': 26, 'learning_rate': 0.07779679481836586, 'min_child_weight': 0.005788049362215035, 'subsample': 0.8998903540126749, 'subsample_freq': 1, 'colsample_bytree': 0.5347030904277068, 'reg_alpha': 14.857881969402015, 'reg_lambda': 0.11318685792778437, 'max_bin': 58}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:33:59,858] Trial 11 finished with value: -0.19162075324395283 and parameters: {'max_depth': 2, 'num_leaves': 26, 'learning_rate': 0.14174385779874035, 'min_child_weight': 3.3983984004948242, 'subsample': 0.8038401086055605, 'subsample_freq': 6, 'colsample_bytree': 0.6160459254158778, 'reg_alpha': 0.042926599269489836, 'reg_lambda': 0.011828325484329452, 'max_bin': 201}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:34:11,964] Trial 12 finished with value: -0.2030954634587257 and parameters: {'max_depth': 6, 'num_leaves': 16, 'learning_rate': 0.08130691776158117, 'min_child_weight': 0.008457241634048243, 'subsample': 0.7912599773931077, 'subsample_freq': 1, 'colsample_bytree': 0.6631354640650612, 'reg_alpha': 0.09127584930801476, 'reg_lambda': 0.011817807219191925, 'max_bin': 199}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:34:23,104] Trial 13 finished with value: -0.21626815242181086 and parameters: {'max_depth': 2, 'num_leaves': 24, 'learning_rate': 0.14014909104896153, 'min_child_weight': 0.1582518019775772, 'subsample': 0.7283610324205754, 'subsample_freq': 6, 'colsample_bytree': 0.5597580911720988, 'reg_alpha': 0.01297572444066706, 'reg_lambda': 0.11233179103088123, 'max_bin': 58}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:34:37,518] Trial 14 finished with value: -0.24578382471745516 and parameters: {'max_depth': 8, 'num_leaves': 40, 'learning_rate': 0.06958418465978003, 'min_child_weight': 0.012052619940988477, 'subsample': 0.9869387056402047, 'subsample_freq': 4, 'colsample_bytree': 0.5745449473991864, 'reg_alpha': 0.09372200562895056, 'reg_lambda': 3.377667405175661, 'max_bin': 230}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:35:04,147] Trial 15 finished with value: -0.23744233063496067 and parameters: {'max_depth': 3, 'num_leaves': 17, 'learning_rate': 0.007037177899378541, 'min_child_weight': 1.015071744864505, 'subsample': 0.8599914267799508, 'subsample_freq': 8, 'colsample_bytree': 0.6551557120145118, 'reg_alpha': 0.11516211832197429, 'reg_lambda': 0.032908148844884084, 'max_bin': 137}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:35:15,910] Trial 16 finished with value: -0.2636580413577517 and parameters: {'max_depth': 12, 'num_leaves': 28, 'learning_rate': 0.1389285023838698, 'min_child_weight': 0.01923913879906382, 'subsample': 0.6807980449154492, 'subsample_freq': 1, 'colsample_bytree': 0.5035167399578027, 'reg_alpha': 0.03623788050335733, 'reg_lambda': 0.2262731853821461, 'max_bin': 277}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:35:27,236] Trial 17 finished with value: -0.21520700432351098 and parameters: {'max_depth': 11, 'num_leaves': 28, 'learning_rate': 0.16564037842606472, 'min_child_weight': 0.022676203218056936, 'subsample': 0.7996918380214741, 'subsample_freq': 1, 'colsample_bytree': 0.5014726856390916, 'reg_alpha': 0.011631476367256838, 'reg_lambda': 0.22262982667480108, 'max_bin': 288}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:35:40,151] Trial 18 finished with value: -0.1934210817813155 and parameters: {'max_depth': 28, 'num_leaves': 45, 'learning_rate': 0.10307528164890999, 'min_child_weight': 0.0026167889884043186, 'subsample': 0.688754177935327, 'subsample_freq': 1, 'colsample_bytree': 0.5918686666777981, 'reg_alpha': 0.15777653657020296, 'reg_lambda': 0.23940220260811132, 'max_bin': 318}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:35:53,995] Trial 19 finished with value: -0.23750710994438112 and parameters: {'max_depth': 17, 'num_leaves': 30, 'learning_rate': 0.054447877233001665, 'min_child_weight': 0.08621196860378223, 'subsample': 0.5068925917675554, 'subsample_freq': 1, 'colsample_bytree': 0.5189974760943387, 'reg_alpha': 0.034897817818999324, 'reg_lambda': 2.609226272733156, 'max_bin': 240}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:36:06,950] Trial 20 finished with value: -0.18244760378718955 and parameters: {'max_depth': 11, 'num_leaves': 62, 'learning_rate': 0.19906790088423232, 'min_child_weight': 0.021509237923144908, 'subsample': 0.6501329832557412, 'subsample_freq': 1, 'colsample_bytree': 0.7082298863011985, 'reg_alpha': 0.06559149508407888, 'reg_lambda': 4.624413796481641, 'max_bin': 254}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:36:19,610] Trial 21 finished with value: -0.21282581678868434 and parameters: {'max_depth': 6, 'num_leaves': 23, 'learning_rate': 0.13613768236234594, 'min_child_weight': 0.003942666516593127, 'subsample': 0.6880320498794698, 'subsample_freq': 6, 'colsample_bytree': 0.6347831627538092, 'reg_alpha': 0.023981717368870937, 'reg_lambda': 0.03270443426841473, 'max_bin': 162}. Best is trial 1 with value: -0.26878704917764595.
# [I 2022-06-18 19:36:31,355] Trial 22 finished with value: -0.279661372710986 and parameters: {'max_depth': 3, 'num_leaves': 18, 'learning_rate': 0.1594861085657043, 'min_child_weight': 0.17234270410574645, 'subsample': 0.7659883284114195, 'subsample_freq': 6, 'colsample_bytree': 0.6951473453563725, 'reg_alpha': 0.04953625074491226, 'reg_lambda': 0.24049954361470688, 'max_bin': 97}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:36:42,259] Trial 23 finished with value: -0.23733084753632855 and parameters: {'max_depth': 3, 'num_leaves': 18, 'learning_rate': 0.16073441835345192, 'min_child_weight': 0.11096234372015232, 'subsample': 0.8393303376220895, 'subsample_freq': 1, 'colsample_bytree': 0.7126526980571787, 'reg_alpha': 0.19199121564709323, 'reg_lambda': 0.22142716595533646, 'max_bin': 72}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:36:55,024] Trial 24 finished with value: -0.2317925065822027 and parameters: {'max_depth': 9, 'num_leaves': 19, 'learning_rate': 0.15512260645052314, 'min_child_weight': 0.18869129356206435, 'subsample': 0.7636622865792807, 'subsample_freq': 4, 'colsample_bytree': 0.601218703424236, 'reg_alpha': 0.059501273228240496, 'reg_lambda': 0.6397732189339264, 'max_bin': 98}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:37:10,087] Trial 25 finished with value: -0.16334802493731232 and parameters: {'max_depth': 14, 'num_leaves': 25, 'learning_rate': 0.11500081243997834, 'min_child_weight': 0.017026885121839322, 'subsample': 0.8539076696439711, 'subsample_freq': 8, 'colsample_bytree': 0.5544295407938646, 'reg_alpha': 0.3238699375828796, 'reg_lambda': 0.1159677439682102, 'max_bin': 194}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:37:24,406] Trial 26 finished with value: -0.1538056988134301 and parameters: {'max_depth': 22, 'num_leaves': 36, 'learning_rate': 0.1790184230123458, 'min_child_weight': 0.045502686277425035, 'subsample': 0.765349209435247, 'subsample_freq': 6, 'colsample_bytree': 0.6918134561709689, 'reg_alpha': 0.024049875137987876, 'reg_lambda': 0.29053777915429263, 'max_bin': 91}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:37:36,126] Trial 27 finished with value: -0.18632048597525824 and parameters: {'max_depth': 5, 'num_leaves': 29, 'learning_rate': 0.153252745046246, 'min_child_weight': 0.2923042346087563, 'subsample': 0.6701387960998767, 'subsample_freq': 1, 'colsample_bytree': 0.7972084562030307, 'reg_alpha': 0.06191956219210983, 'reg_lambda': 0.815766473582827, 'max_bin': 178}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:37:47,802] Trial 28 finished with value: -0.22037454561010805 and parameters: {'max_depth': 6, 'num_leaves': 53, 'learning_rate': 0.10025947121506654, 'min_child_weight': 0.6574813366413537, 'subsample': 0.9037684017402788, 'subsample_freq': 1, 'colsample_bytree': 0.5392468107751245, 'reg_alpha': 0.017662790552900237, 'reg_lambda': 1.8605293619029144, 'max_bin': 105}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:38:00,154] Trial 29 finished with value: -0.23101514540815202 and parameters: {'max_depth': 21, 'num_leaves': 16, 'learning_rate': 0.18599890553496154, 'min_child_weight': 0.035147526909280594, 'subsample': 0.9625219065872865, 'subsample_freq': 8, 'colsample_bytree': 0.8411312158857471, 'reg_alpha': 0.1294487682238145, 'reg_lambda': 0.3575339425134806, 'max_bin': 305}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:38:13,636] Trial 30 finished with value: -0.20787910042058924 and parameters: {'max_depth': 13, 'num_leaves': 27, 'learning_rate': 0.12175347445222065, 'min_child_weight': 1.3951948469632631, 'subsample': 0.8353693655027243, 'subsample_freq': 6, 'colsample_bytree': 0.7412208267131057, 'reg_alpha': 0.5729574913047472, 'reg_lambda': 0.4416999390376155, 'max_bin': 331}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:38:25,340] Trial 31 finished with value: -0.2157552976492084 and parameters: {'max_depth': 4, 'num_leaves': 22, 'learning_rate': 0.13030125609398643, 'min_child_weight': 1.7759719070212914, 'subsample': 0.719788132068984, 'subsample_freq': 6, 'colsample_bytree': 0.6650931790637579, 'reg_alpha': 0.03850693502500431, 'reg_lambda': 0.024476236041817975, 'max_bin': 157}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:38:37,442] Trial 32 finished with value: -0.20207801179484228 and parameters: {'max_depth': 5, 'num_leaves': 23, 'learning_rate': 0.14774003865658059, 'min_child_weight': 0.4925852381392597, 'subsample': 0.7009492295007267, 'subsample_freq': 6, 'colsample_bytree': 0.6285261552254467, 'reg_alpha': 0.03753495433713145, 'reg_lambda': 0.04918199112844397, 'max_bin': 223}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:38:48,931] Trial 33 finished with value: -0.18627606802641647 and parameters: {'max_depth': 3, 'num_leaves': 19, 'learning_rate': 0.1757842027548095, 'min_child_weight': 0.24119782078721672, 'subsample': 0.7448818479473627, 'subsample_freq': 6, 'colsample_bytree': 0.6837585370813092, 'reg_alpha': 0.06406465285080676, 'reg_lambda': 0.06951387872098282, 'max_bin': 113}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:39:00,623] Trial 34 finished with value: -0.20450322130234797 and parameters: {'max_depth': 4, 'num_leaves': 21, 'learning_rate': 0.09543125979593262, 'min_child_weight': 0.1247423282542015, 'subsample': 0.6374670148399041, 'subsample_freq': 4, 'colsample_bytree': 0.737915552715207, 'reg_alpha': 0.010181488492289757, 'reg_lambda': 0.01849946763941448, 'max_bin': 270}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:39:14,359] Trial 35 finished with value: -0.2238628452103371 and parameters: {'max_depth': 8, 'num_leaves': 33, 'learning_rate': 0.1252058502855215, 'min_child_weight': 0.057138708460866015, 'subsample': 0.7720419265467917, 'subsample_freq': 6, 'colsample_bytree': 0.5834615132374659, 'reg_alpha': 0.22582040069447692, 'reg_lambda': 0.18930085020648957, 'max_bin': 481}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:39:27,972] Trial 36 finished with value: -0.2321389538661906 and parameters: {'max_depth': 7, 'num_leaves': 31, 'learning_rate': 0.10922414594020816, 'min_child_weight': 0.01486905624757476, 'subsample': 0.6680493093904397, 'subsample_freq': 6, 'colsample_bytree': 0.642575257959145, 'reg_alpha': 0.02090618006440195, 'reg_lambda': 0.15317462816991478, 'max_bin': 149}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:39:38,934] Trial 37 finished with value: -0.23297110619994327 and parameters: {'max_depth': 3, 'num_leaves': 18, 'learning_rate': 0.13198165545085816, 'min_child_weight': 0.033292364838417056, 'subsample': 0.8128387130073806, 'subsample_freq': 1, 'colsample_bytree': 0.794187157516033, 'reg_alpha': 0.08740624364805165, 'reg_lambda': 0.0817962214632719, 'max_bin': 80}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:39:53,948] Trial 38 finished with value: -0.22403889462999932 and parameters: {'max_depth': 5, 'num_leaves': 37, 'learning_rate': 0.09261291680314142, 'min_child_weight': 1.8513414880991999, 'subsample': 0.8816473241902739, 'subsample_freq': 2, 'colsample_bytree': 0.8896932686795747, 'reg_alpha': 1.317279798352265, 'reg_lambda': 1.358098693253007, 'max_bin': 346}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:40:04,538] Trial 39 finished with value: -0.22373986814430777 and parameters: {'max_depth': 2, 'num_leaves': 24, 'learning_rate': 0.19668495693811539, 'min_child_weight': 0.3705901428642072, 'subsample': 0.5954392674773011, 'subsample_freq': 8, 'colsample_bytree': 0.7614595525069549, 'reg_alpha': 0.37909827225854903, 'reg_lambda': 0.7142834326598546, 'max_bin': 122}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:40:17,272] Trial 40 finished with value: -0.20871165315540902 and parameters: {'max_depth': 4, 'num_leaves': 21, 'learning_rate': 0.17148108355055774, 'min_child_weight': 0.07527064808635603, 'subsample': 0.5659647419106297, 'subsample_freq': 4, 'colsample_bytree': 0.6132869094957196, 'reg_alpha': 2.211025530014796, 'reg_lambda': 15.434507182770773, 'max_bin': 172}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:40:31,449] Trial 41 finished with value: -0.20829691184624113 and parameters: {'max_depth': 10, 'num_leaves': 44, 'learning_rate': 0.11788985827360071, 'min_child_weight': 0.058656435095679964, 'subsample': 0.5433884149053786, 'subsample_freq': 2, 'colsample_bytree': 0.9900147457122628, 'reg_alpha': 0.02754278695096671, 'reg_lambda': 0.4938303980215147, 'max_bin': 132}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:40:47,591] Trial 42 finished with value: -0.2521174713927981 and parameters: {'max_depth': 7, 'num_leaves': 55, 'learning_rate': 0.112101018676691, 'min_child_weight': 0.009165937841741871, 'subsample': 0.7411558067720279, 'subsample_freq': 2, 'colsample_bytree': 0.9154460766051703, 'reg_alpha': 0.016032767954297266, 'reg_lambda': 0.5944767509552445, 'max_bin': 51}. Best is trial 22 with value: -0.279661372710986.
# [I 2022-06-18 19:41:06,160] Trial 43 finished with value: -0.2864507769450634 and parameters: {'max_depth': 12, 'num_leaves': 26, 'learning_rate': 0.02713650228826299, 'min_child_weight': 0.0011650992472356568, 'subsample': 0.6207217387976436, 'subsample_freq': 2, 'colsample_bytree': 0.8738185301823628, 'reg_alpha': 0.04854915667700963, 'reg_lambda': 1.0735955220764233, 'max_bin': 114}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:41:28,141] Trial 44 finished with value: -0.24461709541970605 and parameters: {'max_depth': 15, 'num_leaves': 27, 'learning_rate': 0.01719378576761945, 'min_child_weight': 0.001613480734577392, 'subsample': 0.6459270124897151, 'subsample_freq': 2, 'colsample_bytree': 0.875737662741024, 'reg_alpha': 0.047460117852017335, 'reg_lambda': 5.231362309452475, 'max_bin': 208}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:41:47,991] Trial 45 finished with value: -0.22101105426958295 and parameters: {'max_depth': 21, 'num_leaves': 25, 'learning_rate': 0.025892530659195365, 'min_child_weight': 0.004622782966894234, 'subsample': 0.6254121743082439, 'subsample_freq': 2, 'colsample_bytree': 0.7168328433935012, 'reg_alpha': 0.030272048073871224, 'reg_lambda': 1.0300485357720006, 'max_bin': 83}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:42:01,229] Trial 46 finished with value: -0.2379677873890576 and parameters: {'max_depth': 12, 'num_leaves': 20, 'learning_rate': 0.05222584593346148, 'min_child_weight': 0.0031428395777078834, 'subsample': 0.7195802536126016, 'subsample_freq': 1, 'colsample_bytree': 0.6852627044692579, 'reg_alpha': 5.598483885109208, 'reg_lambda': 1.9448677481076369, 'max_bin': 145}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:42:30,560] Trial 47 finished with value: -0.2532701280020122 and parameters: {'max_depth': 10, 'num_leaves': 22, 'learning_rate': 0.008550165596977525, 'min_child_weight': 0.002079698010585343, 'subsample': 0.7840920742515552, 'subsample_freq': 6, 'colsample_bytree': 0.8239839018666172, 'reg_alpha': 0.09248440196350358, 'reg_lambda': 0.3691364538513008, 'max_bin': 181}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:42:47,515] Trial 48 finished with value: -0.212940020436643 and parameters: {'max_depth': 6, 'num_leaves': 30, 'learning_rate': 0.02745233110718882, 'min_child_weight': 0.006885334682423216, 'subsample': 0.8203735008279458, 'subsample_freq': 2, 'colsample_bytree': 0.5177298363210096, 'reg_alpha': 0.15060777878307607, 'reg_lambda': 1.1727465789144929, 'max_bin': 395}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:43:02,349] Trial 49 finished with value: -0.23598919346494993 and parameters: {'max_depth': 18, 'num_leaves': 33, 'learning_rate': 0.050659590584821064, 'min_child_weight': 0.0012759048251278233, 'subsample': 0.5745635979652435, 'subsample_freq': 1, 'colsample_bytree': 0.9476195001931113, 'reg_alpha': 0.051264032488165, 'reg_lambda': 2.4680198347652955, 'max_bin': 114}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:43:16,896] Trial 50 finished with value: -0.26703684783940607 and parameters: {'max_depth': 9, 'num_leaves': 28, 'learning_rate': 0.14694175730576145, 'min_child_weight': 0.02402432623813475, 'subsample': 0.6078117255144576, 'subsample_freq': 6, 'colsample_bytree': 0.7791858125552682, 'reg_alpha': 0.01597247010405959, 'reg_lambda': 0.05364513672660791, 'max_bin': 251}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:43:30,317] Trial 51 finished with value: -0.15962172605760708 and parameters: {'max_depth': 8, 'num_leaves': 28, 'learning_rate': 0.1446848329465672, 'min_child_weight': 0.011233532584223294, 'subsample': 0.7057225344544158, 'subsample_freq': 6, 'colsample_bytree': 0.8614311486660474, 'reg_alpha': 0.01593086078755153, 'reg_lambda': 0.01551941841587268, 'max_bin': 288}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:43:42,870] Trial 52 finished with value: -0.21877261523891015 and parameters: {'max_depth': 9, 'num_leaves': 25, 'learning_rate': 0.16304194913715186, 'min_child_weight': 0.027884480380829472, 'subsample': 0.6132792169736762, 'subsample_freq': 6, 'colsample_bytree': 0.8138591089831384, 'reg_alpha': 0.07426162831056125, 'reg_lambda': 0.03284365269253521, 'max_bin': 257}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:43:56,614] Trial 53 finished with value: -0.23504013488597836 and parameters: {'max_depth': 13, 'num_leaves': 26, 'learning_rate': 0.15160954260924966, 'min_child_weight': 3.61118981129762, 'subsample': 0.6676898198990694, 'subsample_freq': 6, 'colsample_bytree': 0.7689350697234925, 'reg_alpha': 0.031167420030656243, 'reg_lambda': 0.048162115051305764, 'max_bin': 70}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:44:11,681] Trial 54 finished with value: -0.2690878772318872 and parameters: {'max_depth': 9, 'num_leaves': 23, 'learning_rate': 0.06646986145255278, 'min_child_weight': 0.043453497883789875, 'subsample': 0.5522489192396647, 'subsample_freq': 6, 'colsample_bytree': 0.6690358119941243, 'reg_alpha': 0.014166830129111989, 'reg_lambda': 0.01086581873593412, 'max_bin': 221}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:44:26,777] Trial 55 finished with value: -0.19028322053287922 and parameters: {'max_depth': 9, 'num_leaves': 32, 'learning_rate': 0.06199709200640966, 'min_child_weight': 0.045325737417957326, 'subsample': 0.5562480520480833, 'subsample_freq': 6, 'colsample_bytree': 0.6668268602913735, 'reg_alpha': 0.014047037760269694, 'reg_lambda': 0.14433031524545928, 'max_bin': 216}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:44:42,516] Trial 56 finished with value: -0.2352691301636419 and parameters: {'max_depth': 10, 'num_leaves': 29, 'learning_rate': 0.04399358052085845, 'min_child_weight': 0.02260230668533174, 'subsample': 0.5005653352490997, 'subsample_freq': 1, 'colsample_bytree': 0.7255863129002779, 'reg_alpha': 0.018227651319634133, 'reg_lambda': 0.010043823018661972, 'max_bin': 245}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:44:57,250] Trial 57 finished with value: -0.2381549204156252 and parameters: {'max_depth': 12, 'num_leaves': 24, 'learning_rate': 0.08251548097379084, 'min_child_weight': 0.08591226218850342, 'subsample': 0.5833728940266697, 'subsample_freq': 6, 'colsample_bytree': 0.696165862071989, 'reg_alpha': 0.04552620283069515, 'reg_lambda': 0.09277989519989857, 'max_bin': 303}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:45:16,282] Trial 58 finished with value: -0.24550871088914436 and parameters: {'max_depth': 16, 'num_leaves': 27, 'learning_rate': 0.016382685875832824, 'min_child_weight': 0.12446607364933322, 'subsample': 0.5185138183903257, 'subsample_freq': 1, 'colsample_bytree': 0.5589277579752886, 'reg_alpha': 0.011584608442462981, 'reg_lambda': 0.8634050128290955, 'max_bin': 270}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:45:32,862] Trial 59 finished with value: -0.26106182748939777 and parameters: {'max_depth': 7, 'num_leaves': 17, 'learning_rate': 0.029912589968774845, 'min_child_weight': 0.17614396053212256, 'subsample': 0.5980284790892084, 'subsample_freq': 8, 'colsample_bytree': 0.5032242419184709, 'reg_alpha': 0.022277158721795504, 'reg_lambda': 0.3389469509915278, 'max_bin': 185}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:45:48,014] Trial 60 finished with value: -0.21781943278857815 and parameters: {'max_depth': 18, 'num_leaves': 36, 'learning_rate': 0.0679797018974575, 'min_child_weight': 0.017623630675129093, 'subsample': 0.5235893922624307, 'subsample_freq': 2, 'colsample_bytree': 0.7740956785736193, 'reg_alpha': 0.12655421788776705, 'reg_lambda': 0.049142322917441215, 'max_bin': 242}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:46:02,955] Trial 61 finished with value: -0.21348963447759067 and parameters: {'max_depth': 7, 'num_leaves': 16, 'learning_rate': 0.03419939342279234, 'min_child_weight': 0.23641210780211872, 'subsample': 0.5989132041677734, 'subsample_freq': 8, 'colsample_bytree': 0.5014796938897351, 'reg_alpha': 0.021057738505849816, 'reg_lambda': 0.30867353938812436, 'max_bin': 200}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:46:20,832] Trial 62 finished with value: -0.2358099692605687 and parameters: {'max_depth': 8, 'num_leaves': 17, 'learning_rate': 0.02146994082386832, 'min_child_weight': 0.1620104049601181, 'subsample': 0.6249802313938613, 'subsample_freq': 8, 'colsample_bytree': 0.5358703178620523, 'reg_alpha': 0.02605953956375374, 'reg_lambda': 0.2929019516134546, 'max_bin': 225}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:46:56,820] Trial 63 finished with value: -0.20799238917931007 and parameters: {'max_depth': 11, 'num_leaves': 19, 'learning_rate': 0.005011252832529851, 'min_child_weight': 0.044043523277033335, 'subsample': 0.5525695804582577, 'subsample_freq': 8, 'colsample_bytree': 0.5221437177737248, 'reg_alpha': 0.03554341632864807, 'reg_lambda': 0.17221881499706793, 'max_bin': 185}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:47:13,199] Trial 64 finished with value: -0.24349534933494005 and parameters: {'max_depth': 9, 'num_leaves': 18, 'learning_rate': 0.0378319220392848, 'min_child_weight': 0.10644509914440357, 'subsample': 0.5922504467873871, 'subsample_freq': 8, 'colsample_bytree': 0.5762751571270699, 'reg_alpha': 0.013022277491736414, 'reg_lambda': 0.4879070929624102, 'max_bin': 163}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:47:28,261] Trial 65 finished with value: -0.23395180344996946 and parameters: {'max_depth': 14, 'num_leaves': 17, 'learning_rate': 0.03191389676655192, 'min_child_weight': 0.028190319357263106, 'subsample': 0.6132990525067823, 'subsample_freq': 4, 'colsample_bytree': 0.608523218280856, 'reg_alpha': 0.02209526177158361, 'reg_lambda': 0.22998560305089155, 'max_bin': 285}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:47:51,117] Trial 66 finished with value: -0.25388319169609386 and parameters: {'max_depth': 12, 'num_leaves': 23, 'learning_rate': 0.011611784579856954, 'min_child_weight': 0.4707371504821154, 'subsample': 0.652876667637403, 'subsample_freq': 1, 'colsample_bytree': 0.5587515906826732, 'reg_alpha': 0.04661033825518573, 'reg_lambda': 0.6951625760565207, 'max_bin': 126}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:48:05,283] Trial 67 finished with value: -0.21223216277630366 and parameters: {'max_depth': 8, 'num_leaves': 20, 'learning_rate': 0.048135267888011465, 'min_child_weight': 0.06974902230070779, 'subsample': 0.6887038312397114, 'subsample_freq': 6, 'colsample_bytree': 0.6456722338555415, 'reg_alpha': 0.010256821277102928, 'reg_lambda': 0.1162247674618744, 'max_bin': 102}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:48:19,119] Trial 68 finished with value: -0.21489306489664747 and parameters: {'max_depth': 5, 'num_leaves': 28, 'learning_rate': 0.05947291557135581, 'min_child_weight': 0.15636923795754987, 'subsample': 0.5378424449478066, 'subsample_freq': 8, 'colsample_bytree': 0.6747078129804137, 'reg_alpha': 0.07588689708307415, 'reg_lambda': 0.02696487359580895, 'max_bin': 258}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:48:32,150] Trial 69 finished with value: -0.25341105319010504 and parameters: {'max_depth': 11, 'num_leaves': 31, 'learning_rate': 0.1570944578378667, 'min_child_weight': 0.10111561730361214, 'subsample': 0.6340422389632607, 'subsample_freq': 6, 'colsample_bytree': 0.5428008226082237, 'reg_alpha': 0.055081167579388135, 'reg_lambda': 1.5358601512967653, 'max_bin': 232}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:48:44,098] Trial 70 finished with value: -0.18608583490239686 and parameters: {'max_depth': 10, 'num_leaves': 26, 'learning_rate': 0.14066937568483173, 'min_child_weight': 0.27486215956017607, 'subsample': 0.57618311720229, 'subsample_freq': 1, 'colsample_bytree': 0.6274854707707389, 'reg_alpha': 0.01857385975161355, 'reg_lambda': 0.3972747648195375, 'max_bin': 213}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:48:56,856] Trial 71 finished with value: -0.20347966308523674 and parameters: {'max_depth': 6, 'num_leaves': 22, 'learning_rate': 0.1284980437374884, 'min_child_weight': 0.013783517643830213, 'subsample': 0.7331492914789982, 'subsample_freq': 6, 'colsample_bytree': 0.5932426815781129, 'reg_alpha': 0.03252346875594743, 'reg_lambda': 0.015221775772606706, 'max_bin': 163}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:49:12,060] Trial 72 finished with value: -0.22823122355277267 and parameters: {'max_depth': 7, 'num_leaves': 25, 'learning_rate': 0.04271134503041782, 'min_child_weight': 2.641565958039192, 'subsample': 0.7567278389051847, 'subsample_freq': 6, 'colsample_bytree': 0.6568512110288338, 'reg_alpha': 0.026496544126531164, 'reg_lambda': 0.02249751575728123, 'max_bin': 144}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:49:25,757] Trial 73 finished with value: -0.22522301745816056 and parameters: {'max_depth': 9, 'num_leaves': 29, 'learning_rate': 0.1493938976286303, 'min_child_weight': 0.8722025821214184, 'subsample': 0.6800837557512861, 'subsample_freq': 6, 'colsample_bytree': 0.6217389212965966, 'reg_alpha': 0.10560008625976337, 'reg_lambda': 0.019323965331828306, 'max_bin': 136}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:49:39,470] Trial 74 finished with value: -0.23382295686214655 and parameters: {'max_depth': 13, 'num_leaves': 24, 'learning_rate': 0.1391192740416098, 'min_child_weight': 0.03675325738710377, 'subsample': 0.7045751615596736, 'subsample_freq': 6, 'colsample_bytree': 0.7049567130950769, 'reg_alpha': 0.015558746825384015, 'reg_lambda': 0.013010945170776222, 'max_bin': 94}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:49:59,177] Trial 75 finished with value: -0.23548533826064508 and parameters: {'max_depth': 6, 'num_leaves': 18, 'learning_rate': 0.013763368073107483, 'min_child_weight': 0.05401940029690802, 'subsample': 0.7882601639855485, 'subsample_freq': 1, 'colsample_bytree': 0.7307914816437804, 'reg_alpha': 0.26783831373176326, 'reg_lambda': 0.010083055268150167, 'max_bin': 191}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:50:10,764] Trial 76 finished with value: -0.1950216774224954 and parameters: {'max_depth': 4, 'num_leaves': 23, 'learning_rate': 0.13365140691839364, 'min_child_weight': 0.6040216013903338, 'subsample': 0.6508946884577618, 'subsample_freq': 6, 'colsample_bytree': 0.5065999057219641, 'reg_alpha': 0.03992466970263787, 'reg_lambda': 0.03870051087402572, 'max_bin': 156}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:50:27,290] Trial 77 finished with value: -0.1931012541637576 and parameters: {'max_depth': 2, 'num_leaves': 19, 'learning_rate': 0.021408533616380607, 'min_child_weight': 0.019424461454281783, 'subsample': 0.9482695580504724, 'subsample_freq': 4, 'colsample_bytree': 0.7516695420938764, 'reg_alpha': 0.06996271218419901, 'reg_lambda': 1.002452687696202, 'max_bin': 173}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:50:38,474] Trial 78 finished with value: -0.24945563445549396 and parameters: {'max_depth': 3, 'num_leaves': 20, 'learning_rate': 0.15795596805134904, 'min_child_weight': 0.010652450880731969, 'subsample': 0.8683561060860042, 'subsample_freq': 2, 'colsample_bytree': 0.6440582987310418, 'reg_alpha': 0.6627195533842657, 'reg_lambda': 0.5606675824450436, 'max_bin': 128}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:50:52,184] Trial 79 finished with value: -0.26027280282778187 and parameters: {'max_depth': 8, 'num_leaves': 17, 'learning_rate': 0.08532193616825726, 'min_child_weight': 1.239437964211127, 'subsample': 0.6077155828249575, 'subsample_freq': 8, 'colsample_bytree': 0.6756180798533187, 'reg_alpha': 0.021183959198379204, 'reg_lambda': 0.07950495135770076, 'max_bin': 111}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:51:06,688] Trial 80 finished with value: -0.19560485039288258 and parameters: {'max_depth': 8, 'num_leaves': 17, 'learning_rate': 0.07313511706037726, 'min_child_weight': 0.02839779091641372, 'subsample': 0.6129070741174395, 'subsample_freq': 8, 'colsample_bytree': 0.908268442890199, 'reg_alpha': 0.019067704356948507, 'reg_lambda': 0.06409047485897808, 'max_bin': 69}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:51:20,570] Trial 81 finished with value: -0.2825941916011497 and parameters: {'max_depth': 10, 'num_leaves': 16, 'learning_rate': 0.0820039489858496, 'min_child_weight': 2.427401792632769, 'subsample': 0.5594536266005943, 'subsample_freq': 8, 'colsample_bytree': 0.674327238237689, 'reg_alpha': 0.026375421738630448, 'reg_lambda': 0.13569556478645312, 'max_bin': 111}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:51:34,995] Trial 82 finished with value: -0.22247882202408437 and parameters: {'max_depth': 10, 'num_leaves': 16, 'learning_rate': 0.0875881563838735, 'min_child_weight': 1.2785335589539335, 'subsample': 0.5625250322918063, 'subsample_freq': 8, 'colsample_bytree': 0.6730099735755437, 'reg_alpha': 0.013357346365786988, 'reg_lambda': 0.13600345409525147, 'max_bin': 115}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:51:47,649] Trial 83 finished with value: -0.20274346122151982 and parameters: {'max_depth': 11, 'num_leaves': 18, 'learning_rate': 0.10564084957382731, 'min_child_weight': 2.7278838894703106, 'subsample': 0.5353173804131964, 'subsample_freq': 8, 'colsample_bytree': 0.7177494842273175, 'reg_alpha': 0.024129120768478615, 'reg_lambda': 0.08846534547343358, 'max_bin': 93}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:52:06,710] Trial 84 finished with value: -0.2055885815652861 and parameters: {'max_depth': 15, 'num_leaves': 34, 'learning_rate': 0.09538840218800643, 'min_child_weight': 0.06567958916623794, 'subsample': 0.5852649963466532, 'subsample_freq': 8, 'colsample_bytree': 0.6955916560696915, 'reg_alpha': 0.03710393295710835, 'reg_lambda': 0.2033451641801703, 'max_bin': 83}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:52:21,360] Trial 85 finished with value: -0.17878047566585215 and parameters: {'max_depth': 9, 'num_leaves': 17, 'learning_rate': 0.07939267426077525, 'min_child_weight': 0.2031726117714056, 'subsample': 0.5761507596321612, 'subsample_freq': 8, 'colsample_bytree': 0.6773686033835673, 'reg_alpha': 0.028985474207609295, 'reg_lambda': 0.2849346425512964, 'max_bin': 106}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:52:38,926] Trial 86 finished with value: -0.22924792650203135 and parameters: {'max_depth': 12, 'num_leaves': 30, 'learning_rate': 0.06445048208355875, 'min_child_weight': 0.0010151103144698738, 'subsample': 0.5503024482734573, 'subsample_freq': 8, 'colsample_bytree': 0.855586989341728, 'reg_alpha': 0.01609682511264324, 'reg_lambda': 0.18181302370656155, 'max_bin': 63}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:52:53,314] Trial 87 finished with value: -0.24406497461415336 and parameters: {'max_depth': 14, 'num_leaves': 26, 'learning_rate': 0.07575127159621076, 'min_child_weight': 2.2638372265544415, 'subsample': 0.6308509847624658, 'subsample_freq': 8, 'colsample_bytree': 0.7513864848241699, 'reg_alpha': 0.17910188305972422, 'reg_lambda': 0.11231576373208078, 'max_bin': 277}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:53:09,388] Trial 88 finished with value: -0.23172248262335438 and parameters: {'max_depth': 10, 'num_leaves': 27, 'learning_rate': 0.029111544882075246, 'min_child_weight': 1.7287912917543984, 'subsample': 0.6087942230549276, 'subsample_freq': 1, 'colsample_bytree': 0.6561446981949751, 'reg_alpha': 0.023324097213640274, 'reg_lambda': 0.07605020862373639, 'max_bin': 115}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:53:24,073] Trial 89 finished with value: -0.24348873081523575 and parameters: {'max_depth': 8, 'num_leaves': 16, 'learning_rate': 0.08614976042538663, 'min_child_weight': 0.3586708599384355, 'subsample': 0.5651238168606312, 'subsample_freq': 8, 'colsample_bytree': 0.5229632530204719, 'reg_alpha': 0.05400500286488309, 'reg_lambda': 0.05488458655839609, 'max_bin': 81}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:53:37,519] Trial 90 finished with value: -0.211616362502305 and parameters: {'max_depth': 7, 'num_leaves': 21, 'learning_rate': 0.18646472642601888, 'min_child_weight': 1.3564028572737639, 'subsample': 0.6019061932008131, 'subsample_freq': 2, 'colsample_bytree': 0.6007644658386828, 'reg_alpha': 0.04442448397914695, 'reg_lambda': 0.3516459844625848, 'max_bin': 140}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:53:50,604] Trial 91 finished with value: -0.257914531651932 and parameters: {'max_depth': 9, 'num_leaves': 17, 'learning_rate': 0.14523058397705607, 'min_child_weight': 3.945873890423889, 'subsample': 0.776611950568774, 'subsample_freq': 6, 'colsample_bytree': 0.7056543641838072, 'reg_alpha': 0.03001039008311808, 'reg_lambda': 0.15895028478532686, 'max_bin': 151}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:54:06,464] Trial 92 finished with value: -0.24321105292420558 and parameters: {'max_depth': 12, 'num_leaves': 19, 'learning_rate': 0.05729346262610327, 'min_child_weight': 2.176981602306389, 'subsample': 0.6623365828070726, 'subsample_freq': 6, 'colsample_bytree': 0.6365777988651139, 'reg_alpha': 0.018848917703998345, 'reg_lambda': 0.03936272595705358, 'max_bin': 122}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:54:19,068] Trial 93 finished with value: -0.21092833306542066 and parameters: {'max_depth': 7, 'num_leaves': 21, 'learning_rate': 0.17018554090556634, 'min_child_weight': 0.0063015352617225165, 'subsample': 0.5898194384563079, 'subsample_freq': 1, 'colsample_bytree': 0.9569822432630698, 'reg_alpha': 0.011535337132396508, 'reg_lambda': 0.24920808860020363, 'max_bin': 107}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:54:31,576] Trial 94 finished with value: -0.1947878928767078 and parameters: {'max_depth': 6, 'num_leaves': 29, 'learning_rate': 0.12280150758988767, 'min_child_weight': 2.784947650416665, 'subsample': 0.7155191362130381, 'subsample_freq': 6, 'colsample_bytree': 0.934829239434858, 'reg_alpha': 0.039326212860623065, 'reg_lambda': 0.10601333200592646, 'max_bin': 323}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:54:44,706] Trial 95 finished with value: -0.19090457052741877 and parameters: {'max_depth': 11, 'num_leaves': 22, 'learning_rate': 0.16391737878572488, 'min_child_weight': 0.04207149986139852, 'subsample': 0.6427498918299871, 'subsample_freq': 8, 'colsample_bytree': 0.6869654316415161, 'reg_alpha': 0.02148598433823752, 'reg_lambda': 0.015279780457671751, 'max_bin': 248}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:54:59,282] Trial 96 finished with value: -0.19999477999050613 and parameters: {'max_depth': 13, 'num_leaves': 28, 'learning_rate': 0.08931930111566055, 'min_child_weight': 0.023391514749475904, 'subsample': 0.8404398915607224, 'subsample_freq': 2, 'colsample_bytree': 0.6649619429915183, 'reg_alpha': 0.08138857803737257, 'reg_lambda': 0.8508767131423535, 'max_bin': 206}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:55:14,449] Trial 97 finished with value: -0.18559168851978206 and parameters: {'max_depth': 10, 'num_leaves': 24, 'learning_rate': 0.10078868798824865, 'min_child_weight': 0.9778194449410507, 'subsample': 0.6205797525419859, 'subsample_freq': 4, 'colsample_bytree': 0.5463297434499114, 'reg_alpha': 15.042073897264563, 'reg_lambda': 0.13442679380449643, 'max_bin': 305}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:55:26,737] Trial 98 finished with value: -0.21578301861028765 and parameters: {'max_depth': 5, 'num_leaves': 18, 'learning_rate': 0.07017239649685718, 'min_child_weight': 3.178184999292126, 'subsample': 0.5228418215689696, 'subsample_freq': 6, 'colsample_bytree': 0.785962751142293, 'reg_alpha': 0.05938123287437568, 'reg_lambda': 0.414287703994232, 'max_bin': 231}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:55:38,312] Trial 99 finished with value: -0.2806177769654731 and parameters: {'max_depth': 11, 'num_leaves': 25, 'learning_rate': 0.17672023689841201, 'min_child_weight': 1.602316049030237, 'subsample': 0.7982779370516312, 'subsample_freq': 1, 'colsample_bytree': 0.650700550094142, 'reg_alpha': 0.0150584896010666, 'reg_lambda': 0.2680964156858984, 'max_bin': 134}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:55:50,006] Trial 100 finished with value: -0.19381832063060292 and parameters: {'max_depth': 15, 'num_leaves': 25, 'learning_rate': 0.17665119188671555, 'min_child_weight': 0.710853404456824, 'subsample': 0.7595308934210465, 'subsample_freq': 1, 'colsample_bytree': 0.694074331044576, 'reg_alpha': 0.014138737579149355, 'reg_lambda': 0.3372885271101817, 'max_bin': 261}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:56:01,719] Trial 101 finished with value: -0.2745730949704836 and parameters: {'max_depth': 11, 'num_leaves': 27, 'learning_rate': 0.18101444763847274, 'min_child_weight': 1.1666926466365684, 'subsample': 0.798081974178062, 'subsample_freq': 1, 'colsample_bytree': 0.6506785670995119, 'reg_alpha': 0.03387956195268108, 'reg_lambda': 0.4651778600315398, 'max_bin': 134}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:56:13,322] Trial 102 finished with value: -0.19706030197688745 and parameters: {'max_depth': 13, 'num_leaves': 26, 'learning_rate': 0.1726480974795183, 'min_child_weight': 0.5847750305940361, 'subsample': 0.8062373726855773, 'subsample_freq': 1, 'colsample_bytree': 0.6533410814264708, 'reg_alpha': 0.026479376615310888, 'reg_lambda': 0.2647340463917546, 'max_bin': 119}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:56:26,619] Trial 103 finished with value: -0.26301279316812093 and parameters: {'max_depth': 11, 'num_leaves': 28, 'learning_rate': 0.18268636420334874, 'min_child_weight': 1.1634451472657676, 'subsample': 0.826543880451402, 'subsample_freq': 1, 'colsample_bytree': 0.6323905156320657, 'reg_alpha': 0.033525669638388725, 'reg_lambda': 0.488202276291763, 'max_bin': 132}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:56:38,674] Trial 104 finished with value: -0.23725507503111767 and parameters: {'max_depth': 14, 'num_leaves': 31, 'learning_rate': 0.1918867364409342, 'min_child_weight': 1.1181216439279613, 'subsample': 0.8261540730581228, 'subsample_freq': 1, 'colsample_bytree': 0.5687336747451789, 'reg_alpha': 0.03314154231599016, 'reg_lambda': 0.4673985598888398, 'max_bin': 133}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:56:51,334] Trial 105 finished with value: -0.22539478567606488 and parameters: {'max_depth': 11, 'num_leaves': 27, 'learning_rate': 0.17946875771745435, 'min_child_weight': 1.729585492602898, 'subsample': 0.8496911231762595, 'subsample_freq': 1, 'colsample_bytree': 0.6257372487266312, 'reg_alpha': 0.01587427649434503, 'reg_lambda': 0.7184162721754389, 'max_bin': 100}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:57:03,144] Trial 106 finished with value: -0.23800568693173116 and parameters: {'max_depth': 18, 'num_leaves': 30, 'learning_rate': 0.1673411932312688, 'min_child_weight': 0.03285762613931744, 'subsample': 0.8029331525996666, 'subsample_freq': 1, 'colsample_bytree': 0.8072197102564931, 'reg_alpha': 0.049590102105224854, 'reg_lambda': 0.5924014668441321, 'max_bin': 169}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:57:15,267] Trial 107 finished with value: -0.2241604529066465 and parameters: {'max_depth': 12, 'num_leaves': 28, 'learning_rate': 0.1934025038559999, 'min_child_weight': 1.540091144693575, 'subsample': 0.7757736207885502, 'subsample_freq': 1, 'colsample_bytree': 0.6099207511678046, 'reg_alpha': 0.011469127161955334, 'reg_lambda': 0.21698847010206948, 'max_bin': 467}. Best is trial 43 with value: -0.2864507769450634.
# [I 2022-06-18 19:57:27,267] Trial 108 finished with value: -0.2722259223257292 and parameters: {'max_depth': 9, 'num_leaves': 27, 'learning_rate': 0.18884681792471672, 'min_child_weight': 0.4758636296585148, 'subsample': 0.7937463830204591, 'subsample_freq': 1, 'colsample_bytree': 0.6367902400082369, 'reg_alpha': 0.1068702590242809, 'reg_lambda': 1.1728646673132872, 'max_bin': 153}. Best is trial 43 with value: -0.2864507769450634.
# ...
# [I 2022-06-18 23:21:58,355] Trial 945 finished with value: -0.22902806089373673 and parameters: {'max_depth': 19, 'num_leaves': 31, 'learning_rate': 0.047342282804777314, 'min_child_weight': 0.034896911501742234, 'subsample': 0.804266144892068, 'subsample_freq': 2, 'colsample_bytree': 0.9250540807565791, 'reg_alpha': 5.929900690756848, 'reg_lambda': 0.043876152729139764, 'max_bin': 127}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:22:17,403] Trial 946 finished with value: -0.23139120633575364 and parameters: {'max_depth': 18, 'num_leaves': 33, 'learning_rate': 0.061568974708971456, 'min_child_weight': 0.09318349963539482, 'subsample': 0.7877816003738647, 'subsample_freq': 2, 'colsample_bytree': 0.9028524814641079, 'reg_alpha': 10.880014676951387, 'reg_lambda': 0.630047263878435, 'max_bin': 138}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:22:33,615] Trial 947 finished with value: -0.2415612766806195 and parameters: {'max_depth': 17, 'num_leaves': 28, 'learning_rate': 0.04316191066656527, 'min_child_weight': 0.06662306644889035, 'subsample': 0.7577208574437502, 'subsample_freq': 4, 'colsample_bytree': 0.8726302684352881, 'reg_alpha': 6.831139230296378, 'reg_lambda': 0.0741401870041676, 'max_bin': 121}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:22:51,345] Trial 948 finished with value: -0.1956543956807386 and parameters: {'max_depth': 24, 'num_leaves': 29, 'learning_rate': 0.0552556374671489, 'min_child_weight': 0.05544898040172135, 'subsample': 0.7753430541175793, 'subsample_freq': 2, 'colsample_bytree': 0.9124561114124317, 'reg_alpha': 8.007599521963641, 'reg_lambda': 0.7792413546100033, 'max_bin': 146}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:23:07,597] Trial 949 finished with value: -0.24648600661254494 and parameters: {'max_depth': 20, 'num_leaves': 30, 'learning_rate': 0.06601718143532026, 'min_child_weight': 0.040604011575275545, 'subsample': 0.8143622581646649, 'subsample_freq': 2, 'colsample_bytree': 0.8548896346410669, 'reg_alpha': 5.624213205225247, 'reg_lambda': 0.015440637478087493, 'max_bin': 133}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:23:24,523] Trial 950 finished with value: -0.24937948155446915 and parameters: {'max_depth': 6, 'num_leaves': 30, 'learning_rate': 0.04973285850501888, 'min_child_weight': 0.02840965920127229, 'subsample': 0.844004708585038, 'subsample_freq': 6, 'colsample_bytree': 0.9507865436075756, 'reg_alpha': 9.821651718689587, 'reg_lambda': 0.020039090125105918, 'max_bin': 108}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:23:38,271] Trial 951 finished with value: -0.2355994101255218 and parameters: {'max_depth': 7, 'num_leaves': 32, 'learning_rate': 0.14496079805013, 'min_child_weight': 0.15285107709573093, 'subsample': 0.7996180569338103, 'subsample_freq': 2, 'colsample_bytree': 0.8391182450550423, 'reg_alpha': 0.45647099773756905, 'reg_lambda': 0.5222757482526106, 'max_bin': 122}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:23:54,345] Trial 952 finished with value: -0.2677794985127268 and parameters: {'max_depth': 21, 'num_leaves': 29, 'learning_rate': 0.03968452862275799, 'min_child_weight': 0.043018772298649255, 'subsample': 0.5907465385601016, 'subsample_freq': 1, 'colsample_bytree': 0.8846307828853719, 'reg_alpha': 4.488674891259799, 'reg_lambda': 1.0368301197145289, 'max_bin': 147}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:24:09,077] Trial 953 finished with value: -0.23060218111856004 and parameters: {'max_depth': 16, 'num_leaves': 27, 'learning_rate': 0.04549755537463407, 'min_child_weight': 0.03512530559696524, 'subsample': 0.8282190248683631, 'subsample_freq': 1, 'colsample_bytree': 0.8143698102495763, 'reg_alpha': 13.166744205386673, 'reg_lambda': 1.5036345933376503, 'max_bin': 134}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:24:24,243] Trial 954 finished with value: -0.23678042861522225 and parameters: {'max_depth': 19, 'num_leaves': 31, 'learning_rate': 0.05689040457634383, 'min_child_weight': 0.02998150536535518, 'subsample': 0.8138226169462156, 'subsample_freq': 1, 'colsample_bytree': 0.9302358509552043, 'reg_alpha': 5.209078122835519, 'reg_lambda': 0.05824636580427952, 'max_bin': 153}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:24:42,369] Trial 955 finished with value: -0.23231389002045547 and parameters: {'max_depth': 17, 'num_leaves': 28, 'learning_rate': 0.03531766116018867, 'min_child_weight': 0.0487795155591879, 'subsample': 0.7722416735655762, 'subsample_freq': 2, 'colsample_bytree': 0.9006530795627025, 'reg_alpha': 6.684419368923505, 'reg_lambda': 0.03383926631899722, 'max_bin': 116}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:24:58,024] Trial 956 finished with value: -0.2699832586911846 and parameters: {'max_depth': 18, 'num_leaves': 31, 'learning_rate': 0.05164425995970669, 'min_child_weight': 0.008573779097791532, 'subsample': 0.6128757628831807, 'subsample_freq': 1, 'colsample_bytree': 0.5091270463459765, 'reg_alpha': 8.235898522612926, 'reg_lambda': 0.8829119277964326, 'max_bin': 364}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:25:12,072] Trial 957 finished with value: -0.22321655242151212 and parameters: {'max_depth': 16, 'num_leaves': 29, 'learning_rate': 0.061647777898202034, 'min_child_weight': 0.035745646167297224, 'subsample': 0.7901369605028324, 'subsample_freq': 1, 'colsample_bytree': 0.8909411844486271, 'reg_alpha': 6.115210820066314, 'reg_lambda': 0.04885242150521472, 'max_bin': 143}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:25:29,621] Trial 958 finished with value: -0.2847393286488288 and parameters: {'max_depth': 19, 'num_leaves': 30, 'learning_rate': 0.04224953174881786, 'min_child_weight': 0.02559093536229605, 'subsample': 0.804671330671577, 'subsample_freq': 1, 'colsample_bytree': 0.9180970293334306, 'reg_alpha': 11.801362450535954, 'reg_lambda': 0.6064993431467958, 'max_bin': 129}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:25:48,703] Trial 959 finished with value: -0.22340702020330672 and parameters: {'max_depth': 17, 'num_leaves': 32, 'learning_rate': 0.047104709191625314, 'min_child_weight': 0.0011378996365758295, 'subsample': 0.8209615286061221, 'subsample_freq': 2, 'colsample_bytree': 0.9334767821218172, 'reg_alpha': 1.6177042151875012, 'reg_lambda': 1.2630065238815558, 'max_bin': 106}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:26:03,462] Trial 960 finished with value: -0.23728715297045624 and parameters: {'max_depth': 18, 'num_leaves': 28, 'learning_rate': 0.05487955871749354, 'min_child_weight': 0.20834737202986559, 'subsample': 0.834926684140831, 'subsample_freq': 1, 'colsample_bytree': 0.9093292066501686, 'reg_alpha': 5.037321793474433, 'reg_lambda': 0.0698039135362683, 'max_bin': 139}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:26:18,943] Trial 961 finished with value: -0.2646251568474122 and parameters: {'max_depth': 20, 'num_leaves': 45, 'learning_rate': 0.05170118478345174, 'min_child_weight': 0.05718967613481245, 'subsample': 0.7595313029803255, 'subsample_freq': 1, 'colsample_bytree': 0.8793959546906572, 'reg_alpha': 7.172038543911649, 'reg_lambda': 0.5439174697889072, 'max_bin': 153}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:26:34,016] Trial 962 finished with value: -0.24881670681159562 and parameters: {'max_depth': 16, 'num_leaves': 30, 'learning_rate': 0.059183804341627726, 'min_child_weight': 0.043950949512689345, 'subsample': 0.786071851449169, 'subsample_freq': 1, 'colsample_bytree': 0.9586674267858026, 'reg_alpha': 10.341232572973261, 'reg_lambda': 1.8856946084561932, 'max_bin': 125}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:26:53,491] Trial 963 finished with value: -0.24184642395372094 and parameters: {'max_depth': 18, 'num_leaves': 29, 'learning_rate': 0.02664612524113648, 'min_child_weight': 0.03197611228008388, 'subsample': 0.7973240326277462, 'subsample_freq': 2, 'colsample_bytree': 0.8937262220711979, 'reg_alpha': 0.05749143010610909, 'reg_lambda': 0.6914995785367609, 'max_bin': 136}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:27:10,736] Trial 964 finished with value: -0.2238802439729069 and parameters: {'max_depth': 22, 'num_leaves': 31, 'learning_rate': 0.037576560914406976, 'min_child_weight': 0.03721461685225266, 'subsample': 0.7684125919670677, 'subsample_freq': 1, 'colsample_bytree': 0.9224491752812657, 'reg_alpha': 0.010005827996172558, 'reg_lambda': 7.244613622877666, 'max_bin': 115}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:27:27,205] Trial 965 finished with value: -0.2559671836651934 and parameters: {'max_depth': 11, 'num_leaves': 33, 'learning_rate': 0.042187295122885334, 'min_child_weight': 0.07748797450449055, 'subsample': 0.8140401912203393, 'subsample_freq': 4, 'colsample_bytree': 0.9403587798639534, 'reg_alpha': 4.077562406102676, 'reg_lambda': 0.03799960498753522, 'max_bin': 145}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:27:41,938] Trial 966 finished with value: -0.24184199697601966 and parameters: {'max_depth': 16, 'num_leaves': 27, 'learning_rate': 0.06446404709867336, 'min_child_weight': 0.1290890517696868, 'subsample': 0.8473331619648327, 'subsample_freq': 1, 'colsample_bytree': 0.8629452066900116, 'reg_alpha': 13.763610193057962, 'reg_lambda': 0.06517550459581917, 'max_bin': 157}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:27:58,056] Trial 967 finished with value: -0.26577880101854023 and parameters: {'max_depth': 20, 'num_leaves': 28, 'learning_rate': 0.03093868419046085, 'min_child_weight': 0.33840009250727554, 'subsample': 0.7817074039621085, 'subsample_freq': 1, 'colsample_bytree': 0.9057672098385101, 'reg_alpha': 8.691458092501898, 'reg_lambda': 4.287723618758683, 'max_bin': 436}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:28:17,783] Trial 968 finished with value: -0.2721704226930803 and parameters: {'max_depth': 12, 'num_leaves': 29, 'learning_rate': 0.04779960723277843, 'min_child_weight': 0.026800138001086642, 'subsample': 0.8230079098818236, 'subsample_freq': 2, 'colsample_bytree': 0.8765376635607459, 'reg_alpha': 6.024382783692722, 'reg_lambda': 1.0785027186365435, 'max_bin': 126}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:28:31,561] Trial 969 finished with value: -0.24236339204682283 and parameters: {'max_depth': 17, 'num_leaves': 30, 'learning_rate': 0.053021055226777226, 'min_child_weight': 0.04711209612856323, 'subsample': 0.8056813200081631, 'subsample_freq': 1, 'colsample_bytree': 0.9196562414582846, 'reg_alpha': 5.075538040765091, 'reg_lambda': 0.8235059773835252, 'max_bin': 134}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:28:46,722] Trial 970 finished with value: -0.24648922605880066 and parameters: {'max_depth': 19, 'num_leaves': 31, 'learning_rate': 0.05720863729989756, 'min_child_weight': 0.03241978195157979, 'subsample': 0.8359230502889508, 'subsample_freq': 1, 'colsample_bytree': 0.8961836285609645, 'reg_alpha': 8.808674514037907, 'reg_lambda': 0.07564638420592784, 'max_bin': 405}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:29:01,530] Trial 971 finished with value: -0.26534202311014654 and parameters: {'max_depth': 11, 'num_leaves': 32, 'learning_rate': 0.04671964342019575, 'min_child_weight': 0.10300995911159602, 'subsample': 0.7932589763465004, 'subsample_freq': 1, 'colsample_bytree': 0.8843058343772768, 'reg_alpha': 7.092206951435326, 'reg_lambda': 0.05833256326196642, 'max_bin': 148}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:29:18,016] Trial 972 finished with value: -0.20394048660266706 and parameters: {'max_depth': 15, 'num_leaves': 50, 'learning_rate': 0.06848439513776829, 'min_child_weight': 0.001621908308937655, 'subsample': 0.756944497251674, 'subsample_freq': 2, 'colsample_bytree': 0.8492061187997334, 'reg_alpha': 11.33081523722683, 'reg_lambda': 2.3778627598777953, 'max_bin': 92}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:29:31,930] Trial 973 finished with value: -0.24451693716363404 and parameters: {'max_depth': 21, 'num_leaves': 30, 'learning_rate': 0.06082074183973941, 'min_child_weight': 0.04070566770893907, 'subsample': 0.7736177215713786, 'subsample_freq': 1, 'colsample_bytree': 0.9088716062663997, 'reg_alpha': 0.01201716590837608, 'reg_lambda': 0.048504759627810784, 'max_bin': 116}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:29:50,797] Trial 974 finished with value: -0.19307033052433892 and parameters: {'max_depth': 18, 'num_leaves': 27, 'learning_rate': 0.03484634316233497, 'min_child_weight': 0.06367772833484926, 'subsample': 0.8188869940897371, 'subsample_freq': 6, 'colsample_bytree': 0.934759867742811, 'reg_alpha': 4.776819401826747, 'reg_lambda': 0.9414959063275584, 'max_bin': 140}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:30:05,284] Trial 975 finished with value: -0.2574773046751654 and parameters: {'max_depth': 17, 'num_leaves': 28, 'learning_rate': 0.04329462698607681, 'min_child_weight': 0.5280561406665155, 'subsample': 0.8057161835213316, 'subsample_freq': 1, 'colsample_bytree': 0.8693556425558875, 'reg_alpha': 6.359682883226979, 'reg_lambda': 0.7056299477077334, 'max_bin': 156}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:30:24,475] Trial 976 finished with value: -0.1991128837214739 and parameters: {'max_depth': 19, 'num_leaves': 29, 'learning_rate': 0.05000977003828824, 'min_child_weight': 0.16872733094485853, 'subsample': 0.7889693436288024, 'subsample_freq': 2, 'colsample_bytree': 0.9016780150273723, 'reg_alpha': 0.3720567226351544, 'reg_lambda': 0.49896365306117646, 'max_bin': 123}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:30:39,477] Trial 977 finished with value: -0.23691336266916746 and parameters: {'max_depth': 12, 'num_leaves': 31, 'learning_rate': 0.03978552749109143, 'min_child_weight': 0.02849916541122515, 'subsample': 0.827899485699567, 'subsample_freq': 1, 'colsample_bytree': 0.923033434921951, 'reg_alpha': 0.06747904947261305, 'reg_lambda': 1.3503709303979317, 'max_bin': 132}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:30:53,219] Trial 978 finished with value: -0.19112731223473522 and parameters: {'max_depth': 11, 'num_leaves': 33, 'learning_rate': 0.054757741164826734, 'min_child_weight': 0.05470615544618009, 'subsample': 0.9206032324553152, 'subsample_freq': 1, 'colsample_bytree': 0.539604277428498, 'reg_alpha': 7.502228922692585, 'reg_lambda': 3.593818654372336, 'max_bin': 162}. Best is trial 928 with value: -0.31339865379482756.
# [I 2022-06-18 23:31:06,493] Trial 979 finished with value: -0.3125729014405333 and parameters: {'max_depth': 16, 'num_leaves': 29, 'learning_rate': 0.16349986091828853, 'min_child_weight': 0.265426475375744, 'subsample': 0.7776778439899126, 'subsample_freq': 1, 'colsample_bytree': 0.9509532436563715, 'reg_alpha': 9.942648808668421, 'reg_lambda': 0.010208427753961292, 'max_bin': 317}. Best is trial 928 with value: -0.31339865379482756.
# [2022-06-19 07:31:06] {'max_depth': 19, 'num_leaves': 29, 'learning_rate': 0.0474219671679029, 'min_child_weight': 0.03186701574109326, 'subsample': 0.8306446583049816, 'subsample_freq': 2, 'colsample_bytree': 0.8940299929060795, 'reg_alpha': 6.253705339538041, 'reg_lambda': 0.0644169585840278, 'max_bin': 130}
# [2022-06-19 07:31:06] Best score is -0.31339865379482756
# CPU times: user 9h 45min 55s, sys: 1min 29s, total: 9h 47min 24s
# Wall time: 4h 14s

# %%
'''
Re-fit best model
'''
params = {'selected_feats': selected_feats, 
          'lgbm_var_params': best_params.copy(), 
          'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
          'n_estimators': N_ESTIMATORS_REFIT, 
          'early_stopping_rounds': EARLY_STOPPING_ROUNDS_REFIT}

outputs = []
for fold in range(N_FOLD):
    outputs.append(train_model(fold, params, 'normal'))
    
cv_score = np.mean([x['best_score_'] for x in outputs])
cv_sharpe = np.mean([x['sharpe']['val'] for x in outputs])
log(f"Folds best iterations: {[x['best_iteration_'] for x in outputs]}")
log(f"Folds average num unique values in train: {[x['n_uniq_trn'] for x in outputs]}")
log(f"Folds average num unique values in validation: {[x['n_uniq_val'] for x in outputs]}")
log(f"Folds scores: {[x['best_score_'] for x in outputs]}")
log(f"Folds sharpes: {[x['sharpe']['val'] for x in outputs]}")
log(f'CV score: {cv_score}')
log(f'CV sharpe: {cv_sharpe}')
# Out:
# [2022-06-19 07:31:50] Folds best iterations: [15, 42, 1, 3, 116]
# [2022-06-19 07:31:50] Folds average num unique values in train: [70.90416666666667, 96.55416666666666, 21.666666666666668, 36.15833333333333, 91.29583333333333]
# [2022-06-19 07:31:50] Folds average num unique values in validation: [65.38333333333334, 92.51666666666667, 22.45, 36.6, 102.75]
# [2022-06-19 07:31:50] Folds scores: [0.6930598576950372, 0.693073240719582, 0.6931279285331972, 0.69313937052421, 0.6926609689610088]
# [2022-06-19 07:31:50] Folds sharpes: [0.3405672981318076, 0.5198879301892344, 0.23972871897074052, 0.19540667726141223, 0.27140264442094303]
# [2022-06-19 07:31:50] CV score: 0.693012273286607
# [2022-06-19 07:31:50] CV sharpe: 0.31339865379482756

# %%
'''
Signal Analysis
'''
analyze_signal(outputs)
# Out:
# [2022-06-19 07:31:52] Average % in top 200: 0.12333333333333335
# [2022-06-19 07:31:52] Average % in bottom 200: 0.12044999999999995
# [2022-06-19 07:31:53] Mean long returns: 0.09164257734892785
# [2022-06-19 07:31:53] Mean short returns: 0.12813923270810249
# [2022-06-19 07:31:53] Mean net returns: 0.21978181005703035
# [2022-06-19 07:31:53] Sharpe of long: 0.043241656356479016
# [2022-06-19 07:31:53] Sharpe of short: 0.05644567389185595
# [2022-06-19 07:31:53] Sharpe of net: 0.2814954189704166

# %% [markdown]
# # Debug
