# %% [markdown]
# # Version description
# - Normal feats
# - Split FS bewteen stock and market feats
# - Full Run

# %%
# import libraries
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
from os.path import isfile, isdir, join
import numpy as np
import pandas as pd
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
import re
from IPython.display import display
from zipfile import ZipFile
import pickle
import unicodedata
import pytz
from joblib import Parallel, delayed
import shutil
import difflib
import random
import math
from shutil import copyfile
import itertools
import time
from tqdm import tqdm
import collections
from collections import deque
import gc

from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer
from sklearn.metrics import ndcg_score, accuracy_score, mean_squared_error

import lightgbm as lgbm
import optuna
from optuna import Trial, visualization

import matplotlib as mpl
from matplotlib import pyplot as plt

import jpx_tokyo_market_prediction

from utility_script import *
# from utility_script_jpx import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
'''
Notebook Parameters
'''
# basic
SEED = 0
JPX_PATH = '../input/jpx-tokyo-stock-exchange-prediction'

# data sacling
SCALER = StandardScaler()
SCALE_DAILY = False

# drop market features
DROP_MARKET_FEATS = False

# PCA
RUN_PCA = False
N_COMP = 0.9

# target definition
RANK_ASCENDING = False # set this to False if model prediction is same direction of Target
TARGET_POW = 0

# data split
N_FOLD = 5
TRN_SIZE = 240
VAL_SIZE = 60
TRN_VAL_GAP = 14
SPLIT_METHOD = 'trn_val_split_late_val'

# model fixed params
DEVICE_TYPE = 'CPU'
EVAL_METRIC = f'binary_logloss'
LGBM_VAR_PARAMS = dict(
    max_depth = 32,
    num_leaves = 32,
    learning_rate = 0.01,
    min_child_weight = 0.1,
    min_child_samples = 1,
    subsample = 0.65,
    subsample_freq = 1,
    colsample_bytree = 0.6,
    reg_alpha = 1.5,
    reg_lambda = 1.5,
    max_bin = 255,
)
LGBM_FIXED_PARAMS = dict(
    boosting_type = 'gbdt',
    objective = 'binary',
    n_estimators = 5000,
    n_jobs = -1,
    random_state = SEED,
    device_type = DEVICE_TYPE,
)

# feature importance
RUN_IMP = True
N_SHUFFLE = 12
N_FEATS_IMP_TEST = 10
N_ESTIMATORS_IMP = 50
EARLY_STOPPING_ROUNDS_IMP = 9999
FEAT_GROUPS = None # fixed output if not running IMP

# forward selection
RUN_FS = True
SPLIT_MARKET_FEATS = {'n_stock_feats': 20, 'n_market_feats': 10}
N_ESTIMATORS_FS = 5000
EARLY_STOPPING_ROUNDS_FS = 20
N_FEATS_FS = 20 # top N features considered for FS based on importance
N_FEATS_FINAL = None # top N features if skipping FS based on importance
SELECTED_FEATS = 'EarningToPriceRatio_raw, sharpe_3m, price_standard_dist_1m'.split(', ') # fixed features if skipping both IMP and FS

# hyperparameters tuning
RUN_HP = True
N_ESTIMATORS_HP = 5000
EARLY_STOPPING_ROUNDS_HP = 30
HP_OPT_HRS = 4
BEST_PARAMS = None

# re-fit
N_ESTIMATORS_REFIT = 5000
EARLY_STOPPING_ROUNDS_REFIT = 30

# %% [markdown]
# # Data preprocessing

# %%
'''
Train-Val split where validation periods are right after train period
'''
def trn_val_split_even_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).head(VAL_SIZE)
        else:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).loc[lambda x: x.notnull()]
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data


'''
Train-Val split where validation periods are farthest in future
'''
def trn_val_split_late_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    val_dates_list = full_dates.tail(VAL_SIZE * N_FOLD).values.reshape(N_FOLD, -1)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = val_dates_list[i]
        else:
            dates_val = np.concatenate(val_dates_list[i:])
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data

# %%
'''
Function to scale the features
'''
def jpx_data_scaling(full_data, scaler, daily):
    feats = time_features + stock_features
    
    if daily==False:
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[feats])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[feats] = scaler.transform(data_trn[feats]).astype(np.float32)
            data_val[feats] = scaler.transform(data_val[feats]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
            
    elif daily==True:
        # scale stock features for each day
        def transform_data(df, scaler, feats):
            df[feats] = scaler.fit_transform(df[feats]).astype(np.float32)
            return df
        full_data = full_data.groupby(['fold','trn_val','Date']).apply(lambda df: transform_data(df, scaler, stock_features))
        # then scale time features across days
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[time_features])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[time_features] = scaler.transform(data_trn[time_features]).astype(np.float32)
            data_val[time_features] = scaler.transform(data_val[time_features]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
        
    return data_scaled

# %%
'''
PCA Compression
'''
def pca_compress(full_data):
    # fit with one fold of traiing data
    pca = PCA(n_components=N_COMP, random_state=SEED)
    pca.fit(full_data.loc[lambda x: (x.fold==0) & (x.trn_val=='trn'), all_features])
    log(f'PCA shape of components: {pca.components_.shape}')
    
    # tranform the full dataset
    cols = [f'pc{x}' for x in range(pca.components_.shape[0])]
    compressed_data = []
    for fold in range(N_FOLD):
        for trn_val in ['trn','val']:
            X = pd.DataFrame(pca.transform(full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), all_features]), columns=cols)
            header = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), [c for c in full_data.columns if c not in all_features]].reset_index(drop=True)
            new_df = pd.concat([header, X], axis=1)
            compressed_data.append(new_df)
    compressed_data = pd.concat(compressed_data, axis=0).reset_index(drop=True)
    return compressed_data, cols

# %% [markdown]
# # Model Training Functions

# %%
'''
Function to get sub-columns from table for model fitting
'''
def get_dataset(df, selected_feats, trn_val):
    if trn_val=='val':
        df = df.groupby('Date').sample(frac=1.0, random_state=SEED)
    df = df.reset_index(drop=True)
    grp = df.groupby('Date').size().tolist()
    qid = df['Date']
    X = df[selected_feats]
    y = df['target_train']
    target = df['Target']
    header = df[id_cols]
    return X, y, grp, qid, header, target

'''
Function to predict scores within groups
'''
def pred_score(model, X):
    return pd.Series(model.predict_proba(X)[:,1])

'''
Function to predict rankings within groups
'''
def pred_rank(model, X, qid):
    X_ = X.assign(Date=qid)
    rnk = []
    for date in X_.Date.unique():
        rnk += pd.Series(model.predict_proba(X_.loc[lambda x: x.Date==date].drop('Date',axis=1))[:,1]).rank(method='first').tolist()
    return pd.Series(rnk)

'''
Function to transform model output to rank prediction table
'''
def get_pred_df(header, pred_model, y_true_train, y_true, rank_ascending):
    df_pred = pd.concat([header[['RowId','Date','SecuritiesCode']].assign(Date=lambda x: x.Date.dt.strftime('%Y-%m-%d'), SecuritiesCode=lambda x: x.SecuritiesCode.astype(int)).reset_index(drop=True),
                        pd.Series(pred_model).rename('pred_model').reset_index(drop=True),
                        y_true_train.reset_index(drop=True),
                        y_true.reset_index(drop=True)
                        ], axis=1)
    df_pred['Rank'] = df_pred.groupby('Date').pred_model.rank(method='first', ascending=rank_ascending).astype(int) - 1
    return df_pred

'''
Official function to calculate Sharpe Ratio given a prediction
'''
def _calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def my_calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return pd.DataFrame({'long':[purchase],'short':[short],'net':[purchase - short]})

def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    buf = df.groupby('Date').apply(_calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio

# %%
'''
Training function
'''
def train_model(fold, params, mode):
    # unpack model params
    selected_feats = params['selected_feats']
    lgbm_var_params = params['lgbm_var_params']
    lgbm_fixed_params = params['lgbm_fixed_params']
    lgbm_fixed_params['n_estimators'] = params['n_estimators']
    early_stopping_rounds = params['early_stopping_rounds']
    
    # define dataset
    data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
    data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
    X_trn, y_trn, grp_trn, qid_trn, header_trn, target_trn = get_dataset(data_trn, selected_feats, 'trn')
    X_val, y_val, grp_val, qid_val, header_val, target_val = get_dataset(data_val, selected_feats, 'val')
    # model fit
    model = lgbm.LGBMClassifier(**lgbm_fixed_params, **lgbm_var_params)
    model.fit(
        X = X_trn,
        y = y_trn,
        eval_set = [(X_val, y_val)],
        eval_names = ['Validation'],
        verbose = False,
        eval_metric = EVAL_METRIC,
        early_stopping_rounds = early_stopping_rounds
    )

    # output
    if mode == 'val_score_only':
        output = model.best_score_['Validation'][EVAL_METRIC] # this score is for minimization problem
        
    if mode == 'val_sharpe_only':
        pred_val = pred_score(model, X_val)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        output = sharpe_val * -1 # this score is for minimization problem
        
    if mode == 'feat_imp':
        model.set_params(importance_type='gain')
        imp_gain = model.feature_importances_
        model.set_params(importance_type='split')
        imp_split = model.feature_importances_
        output = pd.concat([
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_gain}).assign(imp_type='gain', imp=lambda x: x.imp.rank()),
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_split}).assign(imp_type='split', imp=lambda x: x.imp.rank())
        ], axis=0).assign(fold=fold)
    
    if mode == 'normal':
        # save model
        save_pkl(model, f"model{fold}")
        # number of distinct predicted values
        n_uniq_trn = pd.concat([pred_score(model, X_trn).rename('score'), header_trn], axis=1).groupby('Date').score.nunique().mean()
        n_uniq_val = pd.concat([pred_score(model, X_val).rename('score'), header_val], axis=1).groupby('Date').score.nunique().mean()
        # prediction
        pred_trn = pred_score(model, X_trn)
        pred_val = pred_score(model, X_val)
        # prediction df
        df_pred_trn = get_pred_df(header_trn, pred_trn, y_trn, target_trn, RANK_ASCENDING)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        # sharpe
        sharpe_trn = calc_spread_return_sharpe(df_pred_trn)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        # output dict
        output = dict(
            fold = fold,
            params = params,
            best_iteration_ = model.best_iteration_,
            best_score_ = model.best_score_['Validation'][EVAL_METRIC],
            sharpe = {'trn': sharpe_trn, 'val': sharpe_val},
            ann_sharpe = {'trn': sharpe_trn * np.sqrt(240), 'val': sharpe_val * np.sqrt(240)},
            evals_result_ = model.evals_result_['Validation'][EVAL_METRIC],
            feat_imp = pd.DataFrame(list(zip(model.feature_name_, model.feature_importances_)), columns=['feat','imp']),
            df_pred_val = df_pred_val,
            n_uniq_trn = n_uniq_trn,
            n_uniq_val = n_uniq_val,
        )
    return output

# %% [markdown]
# # Feature Importance

# %%
def run_feature_importance():
    # random sampling of features
    all_feats = all_features.copy()
    feat_groups = []
    for i in range(N_SHUFFLE):
        random.shuffle(all_feats)
        n_groups = math.floor(len(all_feats)/N_FEATS_IMP_TEST)
        feat_groups += np.array(all_feats[:N_FEATS_IMP_TEST*n_groups]).reshape(-1,N_FEATS_IMP_TEST).tolist()
    log(f'Total number of run: {len(feat_groups)}')
    
    # calculate feature importance
    df_imp = []
    for i, group in enumerate(feat_groups):
        for fold in range(N_FOLD):
            params = {'selected_feats': group, 
                      'lgbm_var_params': LGBM_VAR_PARAMS,
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_IMP,
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_IMP}
            df_imp.append(train_model(fold, params, 'feat_imp'))
        log(f'Completed running feature group {i}') if i%10==0 else None
    df_imp = pd.concat(df_imp)
    df_imp_agg = df_imp.groupby('feat').imp.mean().sort_values(ascending=False).reset_index()
    df_imp_agg.to_csv('df_imp_agg.csv', index=False)
    display(df_imp_agg.head(10))

    # plotting feature importance
    df_imp_agg.sort_values('imp', ascending=True).set_index('feat').plot.barh(figsize=(20, 20))
    return df_imp_agg

# %% [markdown]
# # Forward Selection

# %%
'''
Forward Selection function
'''
def forward_selection(base_feats, feat_groups, name):
    if base_feats==None:
        base_feats = []
    hist = []
    while len(feat_groups) > 0:
        scores = []
        for feats in feat_groups:
            # calculate CV score
            params = {'selected_feats': base_feats + feats, 
                      'lgbm_var_params': LGBM_VAR_PARAMS, 
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_FS, 
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_FS}
            mean_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
            scores.append(mean_score)
            hist.append((mean_score,
                         len(base_feats + feats),
                         ', '.join(base_feats + feats)
                         ))
            log(f'Score: {mean_score}; Num features: {len(base_feats + feats)}; Features: {", ".join(base_feats + feats)}')
        # add the new feature (group) which gives minimum score
        base_feats += feat_groups[np.argmin(scores)]
        # remove the added feature (group) from remaining candidate pool
        del feat_groups[np.argmin(scores)]
    hist = pd.DataFrame(hist, columns=['score','len_feats','total_feats'])
    hist.to_csv(f'fs_hist_{name}.csv', index=False)
    return hist

# %% [markdown]
# # Hyperparameter Tuning

# %%
'''
Hyperparameter Optimization function
'''
def Objective(trial):
    lgbm_var_params = dict(
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True),
        num_leaves = trial.suggest_int('num_leaves', 16, 64, log=True),
        learning_rate = trial.suggest_float("learning_rate", 0.005, 0.2),
        min_child_weight = trial.suggest_float("min_child_weight", 1e-3, 4, log=True),
        subsample = trial.suggest_float("subsample", 0.5, 1),
        subsample_freq = trial.suggest_categorical("subsample_freq", [1,2,4,6,8]),
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1),
        reg_alpha = trial.suggest_float("reg_alpha", 1e-2, 16, log=True),
        reg_lambda = trial.suggest_float("reg_lambda", 1e-2, 16, log=True),
        max_bin = trial.suggest_int('max_bin', 50, 500),
    )
    
    # pack all params
    params = {'selected_feats': selected_feats, 
              'lgbm_var_params': lgbm_var_params, 
              'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
              'n_estimators': N_ESTIMATORS_HP, 
              'early_stopping_rounds': EARLY_STOPPING_ROUNDS_HP}
    # return average CV score
    cv_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
    return cv_score


def optimize_hp():
    # run optimization
    study = optuna.create_study(direction="minimize", study_name='LGBM optimization')
    study.optimize(Objective, timeout=HP_OPT_HRS*60*60)
    
    # save results
    best_params = study.best_params
    best_score = study.best_value
    log(best_params)
    log(f'Best score is {best_score}')
    trials = study.trials_dataframe()
    trials.to_csv(f'trials.csv', index=False)
    save_pkl(best_params, f'best_params')
    save_pkl(study, f'study')
    
    # visualise relationship between parameter and CV score
    for c in trials.columns:
        if c[:7]=='params_':
            new_plot()
            trials.plot.scatter(c, 'value')
            plt.grid()
            plt.title(c)
            plt.show()
    return best_params

# %% [markdown]
# # Signal Analysis

# %%
def analyze_signal(outputs):
    df = pd.concat([x['df_pred_val'] for x in outputs])
    df.Date = pd.to_datetime(df.Date)
    df['rank_pred'] = df.groupby('Date').pred_model.rank(method='first',ascending=False)
    df['rank_true'] = df.groupby('Date').target_train.rank(method='first',ascending=True)

    # distribution of model prediction
    new_plot()
    df.pred_model.hist(bins=100)
    plt.grid()
    plt.title('Distribution of model prediction')

    # percentage in correct region
    new_plot()
    n = 200
    top = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true>=2000-n) & (x.rank_pred>=2000-n)].shape[0]).divide(n)
    bottom = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true<=n) & (x.rank_pred<=n)].shape[0]).divide(n)
    top.rolling(20).mean().plot(label='top')
    bottom.rolling(20).mean().plot(label='bottom')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('% in correct region')
    log(f'Average % in top 200: {top.mean()}')
    log(f'Average % in bottom 200: {bottom.mean()}')

    # portfolio return analysis
    ret = df.groupby('Date').apply(my_calc_spread_return_per_day, 200, 2)
    ret = ret.reset_index().set_index('Date') \
        .assign(short = lambda x: -1 * x.short)

    # cumulative returns
    new_plot()
    ret.long.cumsum().plot(label='long')
    ret.short.cumsum().plot(label='short')
    ret.net.cumsum().plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Cumulative Returns')
    log(f'Mean long returns: {ret.long.mean()}')
    log(f'Mean short returns: {ret.short.mean()}')
    log(f'Mean net returns: {ret.net.mean()}')

    # rolling sharpes
    new_plot()
    ret.long.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='long')
    ret.short.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='short')
    ret.net.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Rolling Sharpes')
    log(f'Sharpe of long: {ret.long.mean() / ret.long.std()}')
    log(f'Sharpe of short: {ret.short.mean() / ret.short.std()}')
    log(f'Sharpe of net: {ret.net.mean() / ret.net.std()}')

# %% [markdown]
# # Execution

# %%
# %%time
'''
Preprocessing
'''
# load features
path = '../input/jpx-feature-engineering/features'
features = pd.concat([pd.concat(load_pkl(f'{path}/{filename}')) for filename in os.listdir(path)]).sort_values('RowId').reset_index(drop=True)

# train-val split
if SPLIT_METHOD == 'trn_val_split_late_val':
    full_data = trn_val_split_late_val(features, val_to_end=False)
elif SPLIT_METHOD == 'trn_val_split_even_val':
    full_data = trn_val_split_even_val(features, val_to_end=False)
display(full_data.groupby(['fold','trn_val']).agg({'Date':['min','max','nunique']}))

# add targets
targets = pd.concat([pd.read_csv(f'{JPX_PATH}/{folder}/stock_prices.csv', parse_dates=['Date']) for folder in ['train_files', 'supplemental_files']]) \
    .loc[:,['RowId','Target']] \
    .loc[lambda x: x.Target.notnull()] \
    .drop_duplicates() \
    .reset_index(drop=True)
full_data = full_data.merge(targets, how='inner', on='RowId')

# remove irregular data
full_data = full_data.loc[lambda x: x.volatility_1w!=0].reset_index(drop=True)

# derive training target
full_data['target_train'] = full_data.groupby(['fold','trn_val','Date']).Target.apply(lambda s: (s >= s.quantile(0.5)).astype(int))

# release memory
del features
gc.collect()

# define column types
id_cols = ['RowId','Date','SecuritiesCode','fold','trn_val']
all_features = [c for c in list(full_data) if c not in id_cols and c not in ['target_train','Target']]
cat_features = ['AdjustmentFactor','first_div']
time_features = [c for c in all_features if '_mkt' in c] + \
                [c for c in all_features if c[:4]=='sec_'] + \
                [c for c in all_features if c[-4:] in ['_sin','_cos']]
stock_features = [c for c in all_features if c not in cat_features + time_features]

# scaling
full_data = jpx_data_scaling(full_data=full_data, scaler=SCALER, daily=SCALE_DAILY)

# drop market features
if DROP_MARKET_FEATS:
    full_data = full_data.drop(time_features, axis=1)
    all_features = [c for c in all_features if c not in time_features]

# PCA compression
if RUN_PCA:
    full_data, all_features = pca_compress(full_data)
# Out:
#                    Date
#                     min        max nunique
# fold trn_val
# 0    trn     2019-01-16 2020-01-14     240
#      val     2021-03-05 2021-06-02      60
# 1    trn     2019-07-23 2020-07-16     240
#      val     2021-06-03 2021-08-30      60
# 2    trn     2020-01-30 2021-01-22     240
#      val     2021-08-31 2021-11-26      60
# 3    trn     2020-08-06 2021-07-29     240
#      val     2021-11-29 2022-02-25      60
# 4    trn     2021-02-10 2022-02-02     240
#      val     2022-02-28 2022-05-27      60
# CPU times: user 36.9 s, sys: 2.48 s, total: 39.4 s
# Wall time: 48.6 s

# %%
# %%time
'''
Feature importance
'''
if RUN_IMP:
    df_imp_agg = run_feature_importance()
# Out:
# [2022-06-20 01:29:06] Total number of run: 96
# [2022-06-20 01:29:19] Completed running feature group 0
# [2022-06-20 01:31:35] Completed running feature group 10
# [2022-06-20 01:33:48] Completed running feature group 20
# [2022-06-20 01:36:12] Completed running feature group 30
# [2022-06-20 01:38:27] Completed running feature group 40
# [2022-06-20 01:40:44] Completed running feature group 50
# [2022-06-20 01:42:58] Completed running feature group 60
# [2022-06-20 01:45:16] Completed running feature group 70
# [2022-06-20 01:47:28] Completed running feature group 80
# [2022-06-20 01:49:59] Completed running feature group 90
#                           feat       imp
# 0                   vol_mkt_3d  9.354545
# 1            sec_volatility_3m  8.981818
# 2                   ret_mkt_1m  8.912500
# 3                   ret_mkt_3m  8.904545
# 4            sec_volatility_1w  8.840909
# 5                   vol_mkt_1w  8.727273
# 6         sec_cross_sect_ret_3  8.725000
# 7                   vol_mkt_1m  8.541667
# 8  sec_dollar_standard_dist_1w  8.535000
# 9  sec_dollar_standard_dist_1m  8.529167
# CPU times: user 1h 4min 14s, sys: 10.7 s, total: 1h 4min 25s
# Wall time: 22min 13s

# %%
# %%time
'''
Forward Selection
'''
if RUN_FS:
    # run FS
    if SPLIT_MARKET_FEATS != None:
        # FS for stock features
        feat_groups = [[x] for x in df_imp_agg.loc[lambda x: ~x.feat.isin(time_features)].head(SPLIT_MARKET_FEATS['n_stock_feats']).feat]
        fs_hist_stock = forward_selection(base_feats=None, feat_groups=feat_groups, name='stock')
        # FS for market features
        base_feats = fs_hist_stock.sort_values('score', ascending=True).total_feats.iloc[0].split(', ')
        feat_groups = [[x] for x in df_imp_agg.loc[lambda x: x.feat.isin(time_features)].head(SPLIT_MARKET_FEATS['n_market_feats']).feat]
        fs_hist = forward_selection(base_feats=base_feats, feat_groups=feat_groups, name='market')
    
    else:
        feat_groups = [[x] for x in df_imp_agg.head(N_FEATS_FS).feat]
        fs_hist = forward_selection(base_feats=None, feat_groups=feat_groups, name='')
        
    # output selected features
    display(fs_hist.sort_values('score', ascending=True).head(1))
    selected_feats = fs_hist.sort_values('score', ascending=True).total_feats.iloc[0].split(', ')

else:
    # if not running both IMP and FS, output pre-set selected_feats
    if not RUN_IMP:
        selected_feats = SELECTED_FEATS
    # if ran IMP but not FS, output first N important features where N is pre-set
    elif RUN_IMP:
        selected_feats = [x[0] for x in feat_groups][:N_FEATS_FINAL]
# Out:
# [2022-06-20 01:51:42] Score: -0.09664034878494401; Num features: 1; Features: days_since_last_div
# [2022-06-20 01:52:08] Score: -0.009574330656859177; Num features: 1; Features: volatility_1m
# [2022-06-20 01:52:19] Score: 0.0917556328529915; Num features: 1; Features: price_ma_pctg_ch_3d
# [2022-06-20 01:52:44] Score: 0.020417720469944306; Num features: 1; Features: volatility_3m
# [2022-06-20 01:53:10] Score: -0.06399176217074438; Num features: 1; Features: BookToMarketRatio_raw
# [2022-06-20 01:53:34] Score: -0.019906954112004747; Num features: 1; Features: volatility_12m
# [2022-06-20 01:53:48] Score: 0.07556297426110808; Num features: 1; Features: price_ma_pctg_ch_1w
# [2022-06-20 01:54:14] Score: -0.05227044069195332; Num features: 1; Features: beta
# [2022-06-20 01:54:40] Score: 0.06241595184626434; Num features: 1; Features: volatility_1w
# [2022-06-20 01:55:06] Score: -0.00032182904795066935; Num features: 1; Features: RS_sqrt_vol
# [2022-06-20 01:55:27] Score: 0.030267248553262405; Num features: 1; Features: exret_1w
# [2022-06-20 01:55:46] Score: -0.06596424058107522; Num features: 1; Features: ProfitoMarketRatio_raw
# [2022-06-20 01:56:03] Score: 0.07051449073610057; Num features: 1; Features: price_standard_dist_1m
# [2022-06-20 01:56:21] Score: 0.04707750175586092; Num features: 1; Features: exret_3d
# [2022-06-20 01:56:36] Score: -0.039065513153524814; Num features: 1; Features: days_since_last_fin
# [2022-06-20 01:56:48] Score: 0.15908039354651002; Num features: 1; Features: ret
# [2022-06-20 01:57:00] Score: -0.04579772445891609; Num features: 1; Features: price_standard_dist_12m
# [2022-06-20 01:57:20] Score: -0.018065696549152445; Num features: 1; Features: exret_1m
# [2022-06-20 01:58:09] Score: -0.2053636437585876; Num features: 1; Features: div_ratio
# [2022-06-20 01:58:29] Score: -0.1172456524022176; Num features: 1; Features: ProfitoMarketRatio_diff
# [2022-06-20 01:59:06] Score: -0.12132054171872744; Num features: 2; Features: div_ratio, days_since_last_div
# [2022-06-20 02:00:16] Score: -0.09221665942577037; Num features: 2; Features: div_ratio, volatility_1m
# [2022-06-20 02:01:08] Score: 0.012983290098707292; Num features: 2; Features: div_ratio, price_ma_pctg_ch_3d
# [2022-06-20 02:02:12] Score: -0.046182426711059356; Num features: 2; Features: div_ratio, volatility_3m
# [2022-06-20 02:03:18] Score: -0.15236114180064306; Num features: 2; Features: div_ratio, BookToMarketRatio_raw
# [2022-06-20 02:04:19] Score: -0.08889518000100917; Num features: 2; Features: div_ratio, volatility_12m
# [2022-06-20 02:05:13] Score: -0.015209023238443345; Num features: 2; Features: div_ratio, price_ma_pctg_ch_1w
# [2022-06-20 02:06:19] Score: -0.1282134138953696; Num features: 2; Features: div_ratio, beta
# [2022-06-20 02:07:28] Score: -0.0511671356711193; Num features: 2; Features: div_ratio, volatility_1w
# [2022-06-20 02:08:34] Score: -0.10147915547381299; Num features: 2; Features: div_ratio, RS_sqrt_vol
# [2022-06-20 02:09:35] Score: -0.07522343905629716; Num features: 2; Features: div_ratio, exret_1w
# [2022-06-20 02:10:35] Score: -0.15838542390424598; Num features: 2; Features: div_ratio, ProfitoMarketRatio_raw
# [2022-06-20 02:11:36] Score: -0.046949845084002975; Num features: 2; Features: div_ratio, price_standard_dist_1m
# [2022-06-20 02:12:35] Score: -0.06872503358975386; Num features: 2; Features: div_ratio, exret_3d
# [2022-06-20 02:13:27] Score: -0.10544918386668374; Num features: 2; Features: div_ratio, days_since_last_fin
# [2022-06-20 02:14:22] Score: 0.021158753444203114; Num features: 2; Features: div_ratio, ret
# [2022-06-20 02:15:20] Score: -0.14533072301320685; Num features: 2; Features: div_ratio, price_standard_dist_12m
# [2022-06-20 02:16:22] Score: -0.11388273861385653; Num features: 2; Features: div_ratio, exret_1m
# [2022-06-20 02:17:22] Score: -0.1778419126002805; Num features: 2; Features: div_ratio, ProfitoMarketRatio_diff
# [2022-06-20 02:17:57] Score: -0.15172107799484089; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, days_since_last_div
# [2022-06-20 02:18:53] Score: -0.0950762316290638; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, volatility_1m
# [2022-06-20 02:19:36] Score: -0.0330635689045093; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, price_ma_pctg_ch_3d
# [2022-06-20 02:20:41] Score: -0.07059195094375549; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, volatility_3m
# [2022-06-20 02:21:37] Score: -0.1598134969437973; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, BookToMarketRatio_raw
# [2022-06-20 02:22:35] Score: -0.10097708967186152; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, volatility_12m
# [2022-06-20 02:23:23] Score: -0.04922034325869154; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, price_ma_pctg_ch_1w
# [2022-06-20 02:24:20] Score: -0.10232645430393525; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, beta
# [2022-06-20 02:25:17] Score: -0.08084509566364659; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, volatility_1w
# [2022-06-20 02:26:14] Score: -0.09945270636644585; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, RS_sqrt_vol
# [2022-06-20 02:27:03] Score: -0.09149642582841704; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, exret_1w
# [2022-06-20 02:27:49] Score: -0.20032802080357995; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw
# [2022-06-20 02:28:39] Score: -0.10908287080682796; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, price_standard_dist_1m
# [2022-06-20 02:29:29] Score: -0.09577957107207123; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, exret_3d
# [2022-06-20 02:30:15] Score: -0.16186884675256422; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, days_since_last_fin
# [2022-06-20 02:30:57] Score: -0.014769549402672884; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, ret
# [2022-06-20 02:31:46] Score: -0.1612905992794411; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, price_standard_dist_12m
# [2022-06-20 02:32:37] Score: -0.13237871297056422; Num features: 3; Features: div_ratio, ProfitoMarketRatio_diff, exret_1m
# [2022-06-20 02:33:12] Score: -0.18327370650974215; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_div
# [2022-06-20 02:34:25] Score: -0.11296080592270275; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, volatility_1m
# [2022-06-20 02:35:32] Score: -0.09211597942147168; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, price_ma_pctg_ch_3d
# [2022-06-20 02:36:47] Score: -0.11304300227965261; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, volatility_3m
# [2022-06-20 02:37:58] Score: -0.16884937625152163; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, BookToMarketRatio_raw
# [2022-06-20 02:39:15] Score: -0.12080552889951694; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, volatility_12m
# [2022-06-20 02:40:20] Score: -0.09512372644475357; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, price_ma_pctg_ch_1w
# [2022-06-20 02:41:36] Score: -0.13462815072295692; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, beta
# [2022-06-20 02:42:50] Score: -0.1092514057496152; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, volatility_1w
# [2022-06-20 02:44:09] Score: -0.12495984469563079; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, RS_sqrt_vol
# [2022-06-20 02:45:19] Score: -0.14574761066464878; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, exret_1w
# [2022-06-20 02:46:23] Score: -0.14221575436461148; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, price_standard_dist_1m
# [2022-06-20 02:47:32] Score: -0.11214237287285908; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, exret_3d
# [2022-06-20 02:48:30] Score: -0.2043823132637589; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin
# [2022-06-20 02:49:32] Score: -0.0935767171884273; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, ret
# [2022-06-20 02:50:33] Score: -0.16876108844426593; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, price_standard_dist_12m
# [2022-06-20 02:51:43] Score: -0.1563556341802677; Num features: 4; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, exret_1m
# [2022-06-20 02:52:20] Score: -0.1475396654616778; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, days_since_last_div
# [2022-06-20 02:53:25] Score: -0.12308823862922906; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, volatility_1m
# [2022-06-20 02:54:13] Score: -0.117776346449175; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_ma_pctg_ch_3d
# [2022-06-20 02:55:11] Score: -0.11021512881481085; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, volatility_3m
# [2022-06-20 02:56:05] Score: -0.1703267607266983; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, BookToMarketRatio_raw
# [2022-06-20 02:56:59] Score: -0.12125405511371809; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, volatility_12m
# [2022-06-20 02:57:51] Score: -0.132972742608982; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_ma_pctg_ch_1w
# [2022-06-20 02:58:54] Score: -0.17261705649972234; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, beta
# [2022-06-20 02:59:57] Score: -0.14293326456023608; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, volatility_1w
# [2022-06-20 03:00:57] Score: -0.1428231499708526; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, RS_sqrt_vol
# [2022-06-20 03:01:56] Score: -0.1563351259528196; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, exret_1w
# [2022-06-20 03:02:48] Score: -0.17608543295150864; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m
# [2022-06-20 03:03:46] Score: -0.15089998552846912; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, exret_3d
# [2022-06-20 03:04:40] Score: -0.11451456118191364; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, ret
# [2022-06-20 03:05:32] Score: -0.16590057645031736; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_12m
# [2022-06-20 03:06:31] Score: -0.16742339456512967; Num features: 5; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, exret_1m
# [2022-06-20 03:07:15] Score: -0.1644423355408004; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, days_since_last_div
# [2022-06-20 03:08:13] Score: -0.12526672649569642; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, volatility_1m
# [2022-06-20 03:09:01] Score: -0.15227518073563567; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, price_ma_pctg_ch_3d
# [2022-06-20 03:09:57] Score: -0.12823332664533604; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, volatility_3m
# [2022-06-20 03:10:50] Score: -0.18448302125306051; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw
# [2022-06-20 03:11:52] Score: -0.12770691064419348; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, volatility_12m
# [2022-06-20 03:12:41] Score: -0.13964545894163632; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, price_ma_pctg_ch_1w
# [2022-06-20 03:13:38] Score: -0.1654924472180596; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, beta
# [2022-06-20 03:14:35] Score: -0.13235511191474303; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, volatility_1w
# [2022-06-20 03:15:31] Score: -0.15203420655057195; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, RS_sqrt_vol
# [2022-06-20 03:16:27] Score: -0.16368922564211455; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, exret_1w
# [2022-06-20 03:17:22] Score: -0.16177897479441136; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, exret_3d
# [2022-06-20 03:18:14] Score: -0.11651186392097453; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, ret
# [2022-06-20 03:19:04] Score: -0.1631233409202907; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, price_standard_dist_12m
# [2022-06-20 03:20:01] Score: -0.17438796414612376; Num features: 6; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, exret_1m
# [2022-06-20 03:20:41] Score: -0.12496354822321762; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, days_since_last_div
# [2022-06-20 03:21:47] Score: -0.13760931017006933; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, volatility_1m
# [2022-06-20 03:22:39] Score: -0.13303608748424461; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, price_ma_pctg_ch_3d
# [2022-06-20 03:23:43] Score: -0.13005251168811144; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, volatility_3m
# [2022-06-20 03:24:44] Score: -0.13536525683582204; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, volatility_12m
# [2022-06-20 03:25:43] Score: -0.16020298619047277; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, price_ma_pctg_ch_1w
# [2022-06-20 03:26:44] Score: -0.1539822971205174; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, beta
# [2022-06-20 03:27:45] Score: -0.14610236562593348; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, volatility_1w
# [2022-06-20 03:28:49] Score: -0.14935935135672587; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, RS_sqrt_vol
# [2022-06-20 03:29:51] Score: -0.16813634213781456; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_1w
# [2022-06-20 03:30:53] Score: -0.1764158166454655; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d
# [2022-06-20 03:31:48] Score: -0.12634991621519098; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, ret
# [2022-06-20 03:32:39] Score: -0.17104100046210885; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, price_standard_dist_12m
# [2022-06-20 03:33:42] Score: -0.16296285211553477; Num features: 7; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_1m
# [2022-06-20 03:34:32] Score: -0.11223967039933469; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, days_since_last_div
# [2022-06-20 03:35:43] Score: -0.14836474802929736; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, volatility_1m
# [2022-06-20 03:36:42] Score: -0.13333087507163216; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, price_ma_pctg_ch_3d
# [2022-06-20 03:37:45] Score: -0.14105941567175373; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, volatility_3m
# [2022-06-20 03:38:44] Score: -0.13063458594503272; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, volatility_12m
# [2022-06-20 03:39:46] Score: -0.14850342738141964; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, price_ma_pctg_ch_1w
# [2022-06-20 03:40:55] Score: -0.1588057696615266; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta
# [2022-06-20 03:42:01] Score: -0.14505410907911565; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, volatility_1w
# [2022-06-20 03:43:04] Score: -0.1531173754017672; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, RS_sqrt_vol
# [2022-06-20 03:44:05] Score: -0.15270411809150902; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, exret_1w
# [2022-06-20 03:45:11] Score: -0.11872904994216231; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, ret
# [2022-06-20 03:46:11] Score: -0.14814482960198275; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, price_standard_dist_12m
# [2022-06-20 03:47:15] Score: -0.1575800015331395; Num features: 8; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, exret_1m
# [2022-06-20 03:48:09] Score: -0.10769121424336925; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, days_since_last_div
# [2022-06-20 03:49:28] Score: -0.15343779021826812; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, volatility_1m
# [2022-06-20 03:50:33] Score: -0.13947251244071493; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, price_ma_pctg_ch_3d
# [2022-06-20 03:51:47] Score: -0.15400869547135623; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, volatility_3m
# [2022-06-20 03:52:59] Score: -0.15420191238260655; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, volatility_12m
# [2022-06-20 03:54:00] Score: -0.15826644246935256; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, price_ma_pctg_ch_1w
# [2022-06-20 03:55:14] Score: -0.15628420414066085; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, volatility_1w
# [2022-06-20 03:56:26] Score: -0.16931306808612567; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol
# [2022-06-20 03:57:40] Score: -0.14259457402866332; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, exret_1w
# [2022-06-20 03:58:52] Score: -0.1354201007170072; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, ret
# [2022-06-20 04:00:04] Score: -0.1641772865427829; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, price_standard_dist_12m
# [2022-06-20 04:01:16] Score: -0.14938901007372968; Num features: 9; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, exret_1m
# [2022-06-20 04:02:12] Score: -0.11154953867830089; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, days_since_last_div
# [2022-06-20 04:03:31] Score: -0.17944605680037645; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, volatility_1m
# [2022-06-20 04:04:45] Score: -0.15664322369715608; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, price_ma_pctg_ch_3d
# [2022-06-20 04:06:00] Score: -0.15548830415657405; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, volatility_3m
# [2022-06-20 04:07:12] Score: -0.15693761383138194; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, volatility_12m
# [2022-06-20 04:08:28] Score: -0.17789283886602553; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, price_ma_pctg_ch_1w
# [2022-06-20 04:09:46] Score: -0.1685029034820792; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, volatility_1w
# [2022-06-20 04:11:05] Score: -0.17287123306803168; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1w
# [2022-06-20 04:12:27] Score: -0.13102707839214087; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, ret
# [2022-06-20 04:13:47] Score: -0.18401768705850177; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, price_standard_dist_12m
# [2022-06-20 04:15:04] Score: -0.19132602582776054; Num features: 10; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m
# [2022-06-20 04:15:57] Score: -0.11391819313149174; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, days_since_last_div
# [2022-06-20 04:17:06] Score: -0.17384066223415798; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m
# [2022-06-20 04:18:15] Score: -0.1494284789298232; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, price_ma_pctg_ch_3d
# [2022-06-20 04:19:30] Score: -0.17010751120312168; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_3m
# [2022-06-20 04:20:40] Score: -0.1684593071034012; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_12m
# [2022-06-20 04:21:51] Score: -0.171175855666286; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, price_ma_pctg_ch_1w
# [2022-06-20 04:23:07] Score: -0.1639516150642016; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1w
# [2022-06-20 04:24:19] Score: -0.16345840266657005; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, exret_1w
# [2022-06-20 04:25:29] Score: -0.12240361405728226; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, ret
# [2022-06-20 04:26:49] Score: -0.17153091587106145; Num features: 11; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, price_standard_dist_12m
# [2022-06-20 04:27:39] Score: -0.10715590640696951; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, days_since_last_div
# [2022-06-20 04:28:49] Score: -0.15178618156105525; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, price_ma_pctg_ch_3d
# [2022-06-20 04:29:57] Score: -0.15132000868452605; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, volatility_3m
# [2022-06-20 04:31:08] Score: -0.15845395475179963; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, volatility_12m
# [2022-06-20 04:32:19] Score: -0.1710154027166618; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, price_ma_pctg_ch_1w
# [2022-06-20 04:33:32] Score: -0.16870030132701597; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, volatility_1w
# [2022-06-20 04:34:47] Score: -0.1728586353611783; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w
# [2022-06-20 04:35:59] Score: -0.1421929121327672; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, ret
# [2022-06-20 04:37:18] Score: -0.16562024955755794; Num features: 12; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, price_standard_dist_12m
# [2022-06-20 04:38:12] Score: -0.10970349174756025; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, days_since_last_div
# [2022-06-20 04:39:23] Score: -0.1400409742083133; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_3d
# [2022-06-20 04:40:28] Score: -0.15875787695702412; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, volatility_3m
# [2022-06-20 04:41:33] Score: -0.15530703160047116; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, volatility_12m
# [2022-06-20 04:42:42] Score: -0.17166225767428256; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w
# [2022-06-20 04:43:56] Score: -0.16726919975979715; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, volatility_1w
# [2022-06-20 04:45:07] Score: -0.13721873494022163; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, ret
# [2022-06-20 04:46:18] Score: -0.1681479094755996; Num features: 13; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_standard_dist_12m
# [2022-06-20 04:47:14] Score: -0.10346090960148029; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, days_since_last_div
# [2022-06-20 04:48:26] Score: -0.16403286208206003; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, price_ma_pctg_ch_3d
# [2022-06-20 04:49:38] Score: -0.1744515754607553; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m
# [2022-06-20 04:50:43] Score: -0.15976186737094283; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_12m
# [2022-06-20 04:52:04] Score: -0.16838398563993273; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_1w
# [2022-06-20 04:53:18] Score: -0.14081408057276396; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, ret
# [2022-06-20 04:54:31] Score: -0.1672215812547612; Num features: 14; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, price_standard_dist_12m
# [2022-06-20 04:55:33] Score: -0.1162735429970502; Num features: 15; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, days_since_last_div
# [2022-06-20 04:56:52] Score: -0.15637848374317592; Num features: 15; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, price_ma_pctg_ch_3d
# [2022-06-20 04:58:07] Score: -0.15829575375298105; Num features: 15; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_12m
# [2022-06-20 04:59:26] Score: -0.17037664556881088; Num features: 15; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w
# [2022-06-20 05:00:47] Score: -0.15408352625481933; Num features: 15; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, ret
# [2022-06-20 05:02:09] Score: -0.1680452297405736; Num features: 15; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, price_standard_dist_12m
# [2022-06-20 05:03:06] Score: -0.10463735337610505; Num features: 16; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, days_since_last_div
# [2022-06-20 05:04:25] Score: -0.14676518188704857; Num features: 16; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_ma_pctg_ch_3d
# [2022-06-20 05:05:41] Score: -0.15254606948209148; Num features: 16; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, volatility_12m
# [2022-06-20 05:06:59] Score: -0.14940585314466046; Num features: 16; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, ret
# [2022-06-20 05:08:14] Score: -0.1659812602182658; Num features: 16; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m
# [2022-06-20 05:09:15] Score: -0.09921223428750675; Num features: 17; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, days_since_last_div
# [2022-06-20 05:10:23] Score: -0.13058199344914115; Num features: 17; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, price_ma_pctg_ch_3d
# [2022-06-20 05:11:45] Score: -0.16324608471762442; Num features: 17; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m
# [2022-06-20 05:12:54] Score: -0.12804000263864973; Num features: 17; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, ret
# [2022-06-20 05:13:58] Score: -0.10281642358083998; Num features: 18; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m, days_since_last_div
# [2022-06-20 05:15:18] Score: -0.14257952347376004; Num features: 18; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m, price_ma_pctg_ch_3d
# [2022-06-20 05:16:43] Score: -0.14478332997213444; Num features: 18; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m, ret
# [2022-06-20 05:17:36] Score: -0.0904904495299745; Num features: 19; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m, ret, days_since_last_div
# [2022-06-20 05:18:52] Score: -0.133313413077687; Num features: 19; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m, ret, price_ma_pctg_ch_3d
# [2022-06-20 05:19:58] Score: -0.08929064362106293; Num features: 20; Features: div_ratio, ProfitoMarketRatio_diff, ProfitoMarketRatio_raw, days_since_last_fin, price_standard_dist_1m, BookToMarketRatio_raw, exret_3d, beta, RS_sqrt_vol, exret_1m, volatility_1m, exret_1w, price_ma_pctg_ch_1w, volatility_3m, volatility_1w, price_standard_dist_12m, volatility_12m, ret, price_ma_pctg_ch_3d, days_since_last_div
# [2022-06-20 05:21:14] Score: -0.20838689477452058; Num features: 2; Features: div_ratio, vol_mkt_3d
# [2022-06-20 05:22:19] Score: -0.20699585191571052; Num features: 2; Features: div_ratio, sec_volatility_3m
# [2022-06-20 05:23:22] Score: -0.20424108207293754; Num features: 2; Features: div_ratio, ret_mkt_1m
# [2022-06-20 05:24:46] Score: -0.20901966007785627; Num features: 2; Features: div_ratio, ret_mkt_3m
# [2022-06-20 05:26:04] Score: -0.20922946655078906; Num features: 2; Features: div_ratio, sec_volatility_1w
# [2022-06-20 05:27:08] Score: -0.20924252081386313; Num features: 2; Features: div_ratio, vol_mkt_1w
# [2022-06-20 05:28:27] Score: -0.2078026515628378; Num features: 2; Features: div_ratio, sec_cross_sect_ret_3
# [2022-06-20 05:29:31] Score: -0.20430113243564355; Num features: 2; Features: div_ratio, vol_mkt_1m
# [2022-06-20 05:30:41] Score: -0.20949913637138567; Num features: 2; Features: div_ratio, sec_dollar_standard_dist_1w
# [2022-06-20 05:31:24] Score: -0.2053212721550302; Num features: 2; Features: div_ratio, sec_dollar_standard_dist_1m
# [2022-06-20 05:32:03] Score: -0.21047338145226754; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_3d
# [2022-06-20 05:32:28] Score: -0.21042036954327098; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, sec_volatility_3m
# [2022-06-20 05:32:53] Score: -0.20929874857843034; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, ret_mkt_1m
# [2022-06-20 05:33:28] Score: -0.21017700134719006; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, ret_mkt_3m
# [2022-06-20 05:34:02] Score: -0.2123838602132424; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, sec_volatility_1w
# [2022-06-20 05:34:36] Score: -0.21286256245043553; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w
# [2022-06-20 05:35:05] Score: -0.21188910726524712; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, sec_cross_sect_ret_3
# [2022-06-20 05:35:33] Score: -0.20848174147582793; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1m
# [2022-06-20 05:36:00] Score: -0.20807486476899523; Num features: 3; Features: div_ratio, sec_dollar_standard_dist_1w, sec_dollar_standard_dist_1m
# [2022-06-20 05:36:55] Score: -0.21095378646043925; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, vol_mkt_3d
# [2022-06-20 05:37:45] Score: -0.21037408522654677; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_volatility_3m
# [2022-06-20 05:38:28] Score: -0.20965532886858623; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, ret_mkt_1m
# [2022-06-20 05:39:36] Score: -0.2110505124841618; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, ret_mkt_3m
# [2022-06-20 05:40:50] Score: -0.21127605158102836; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_volatility_1w
# [2022-06-20 05:41:44] Score: -0.2119503161991608; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3
# [2022-06-20 05:42:29] Score: -0.20664890994983512; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, vol_mkt_1m
# [2022-06-20 05:43:17] Score: -0.17882941874312808; Num features: 4; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_dollar_standard_dist_1m
# [2022-06-20 05:44:10] Score: -0.21039279115317905; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, vol_mkt_3d
# [2022-06-20 05:44:51] Score: -0.21021771775995593; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, sec_volatility_3m
# [2022-06-20 05:45:30] Score: -0.21049128001945502; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_1m
# [2022-06-20 05:46:19] Score: -0.2126078081607011; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m
# [2022-06-20 05:47:10] Score: -0.21220275191005497; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, sec_volatility_1w
# [2022-06-20 05:47:51] Score: -0.20881567288710526; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, vol_mkt_1m
# [2022-06-20 05:48:33] Score: -0.2114858415703033; Num features: 5; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, sec_dollar_standard_dist_1m
# [2022-06-20 05:49:20] Score: -0.21023614872363267; Num features: 6; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_3d
# [2022-06-20 05:49:57] Score: -0.21161281389698616; Num features: 6; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, sec_volatility_3m
# [2022-06-20 05:50:33] Score: -0.2105264275098669; Num features: 6; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, ret_mkt_1m
# [2022-06-20 05:51:19] Score: -0.21596663741332955; Num features: 6; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, sec_volatility_1w
# [2022-06-20 05:52:01] Score: -0.2167722023464652; Num features: 6; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m
# [2022-06-20 05:52:40] Score: -0.21301335925041584; Num features: 6; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, sec_dollar_standard_dist_1m
# [2022-06-20 05:53:23] Score: -0.21023977312249115; Num features: 7; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, vol_mkt_3d
# [2022-06-20 05:54:00] Score: -0.21079749013191607; Num features: 7; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_3m
# [2022-06-20 05:54:38] Score: -0.2097694895293909; Num features: 7; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, ret_mkt_1m
# [2022-06-20 05:55:24] Score: -0.21184252413743962; Num features: 7; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w
# [2022-06-20 05:56:05] Score: -0.2112361657273778; Num features: 7; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_dollar_standard_dist_1m
# [2022-06-20 05:56:58] Score: -0.2111816629431535; Num features: 8; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d
# [2022-06-20 05:57:37] Score: -0.21063755279102167; Num features: 8; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, sec_volatility_3m
# [2022-06-20 05:58:18] Score: -0.2100583481549239; Num features: 8; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, ret_mkt_1m
# [2022-06-20 05:59:03] Score: -0.20953770876570213; Num features: 8; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, sec_dollar_standard_dist_1m
# [2022-06-20 05:59:49] Score: -0.21024275482917246; Num features: 9; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d, sec_volatility_3m
# [2022-06-20 06:00:35] Score: -0.21093543280990987; Num features: 9; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d, ret_mkt_1m
# [2022-06-20 06:01:26] Score: -0.21136450329164308; Num features: 9; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d, sec_dollar_standard_dist_1m
# [2022-06-20 06:02:11] Score: -0.20986317941914065; Num features: 10; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d, sec_dollar_standard_dist_1m, sec_volatility_3m
# [2022-06-20 06:03:01] Score: -0.20971250035666852; Num features: 10; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d, sec_dollar_standard_dist_1m, ret_mkt_1m
# [2022-06-20 06:03:31] Score: -0.20908497181899835; Num features: 11; Features: div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m, sec_volatility_1w, vol_mkt_3d, sec_dollar_standard_dist_1m, sec_volatility_3m, ret_mkt_1m
#        score  len_feats  \
# 38 -0.216772          6
#
#                                                                                          total_feats
# 38  div_ratio, sec_dollar_standard_dist_1w, vol_mkt_1w, sec_cross_sect_ret_3, ret_mkt_3m, vol_mkt_1m
# CPU times: user 14h 46min 1s, sys: 1min 43s, total: 14h 47min 44s
# Wall time: 4h 12min 10s

# %%
# %%time
'''
Hyperparameter tuning
'''
if RUN_HP:
    # run optimization
    best_params = optimize_hp()
    
else:
    # if not running HP, use pre-set best parameters
    best_params = BEST_PARAMS
# Out:
# [I 2022-06-19 22:03:31,633] A new study created in memory with name: LGBM optimization
# [I 2022-06-19 22:03:46,428] Trial 0 finished with value: -0.18574207190703773 and parameters: {'max_depth': 4, 'num_leaves': 37, 'learning_rate': 0.1091915014204986, 'min_child_weight': 0.019361855874119743, 'subsample': 0.5144045794893626, 'subsample_freq': 4, 'colsample_bytree': 0.7404600216439854, 'reg_alpha': 1.351437085081811, 'reg_lambda': 0.15227235438918263, 'max_bin': 187}. Best is trial 0 with value: -0.18574207190703773.
# [I 2022-06-19 22:04:04,015] Trial 1 finished with value: -0.2096868194905907 and parameters: {'max_depth': 18, 'num_leaves': 60, 'learning_rate': 0.1251795235412048, 'min_child_weight': 0.00967184164427689, 'subsample': 0.6181685933654478, 'subsample_freq': 4, 'colsample_bytree': 0.8614737583693198, 'reg_alpha': 1.6933808991921644, 'reg_lambda': 0.29139644687656063, 'max_bin': 235}. Best is trial 1 with value: -0.2096868194905907.
# [I 2022-06-19 22:04:19,404] Trial 2 finished with value: -0.21212583045644787 and parameters: {'max_depth': 16, 'num_leaves': 19, 'learning_rate': 0.14700074433305846, 'min_child_weight': 0.05321940953837043, 'subsample': 0.6492191060572008, 'subsample_freq': 4, 'colsample_bytree': 0.9455755607870131, 'reg_alpha': 1.4433836066094032, 'reg_lambda': 6.874510417110919, 'max_bin': 133}. Best is trial 2 with value: -0.21212583045644787.
# [I 2022-06-19 22:05:00,181] Trial 3 finished with value: -0.2071879559928098 and parameters: {'max_depth': 7, 'num_leaves': 49, 'learning_rate': 0.009249025875998192, 'min_child_weight': 0.01604974556381509, 'subsample': 0.8920647027871688, 'subsample_freq': 6, 'colsample_bytree': 0.89627057369539, 'reg_alpha': 0.2681959767054688, 'reg_lambda': 0.18546823981956745, 'max_bin': 401}. Best is trial 2 with value: -0.21212583045644787.
# [I 2022-06-19 22:05:21,538] Trial 4 finished with value: -0.21269960499691504 and parameters: {'max_depth': 12, 'num_leaves': 30, 'learning_rate': 0.06389003567215389, 'min_child_weight': 0.04346850583442154, 'subsample': 0.6363193320821474, 'subsample_freq': 6, 'colsample_bytree': 0.5159923669810027, 'reg_alpha': 0.010026196366686167, 'reg_lambda': 0.03996034258331687, 'max_bin': 456}. Best is trial 4 with value: -0.21269960499691504.
# [I 2022-06-19 22:05:40,988] Trial 5 finished with value: -0.21687805935309665 and parameters: {'max_depth': 5, 'num_leaves': 26, 'learning_rate': 0.10497691182042766, 'min_child_weight': 0.0014939131315714045, 'subsample': 0.6536469096041908, 'subsample_freq': 8, 'colsample_bytree': 0.8920349721181138, 'reg_alpha': 0.04327323540771989, 'reg_lambda': 0.018672273045688446, 'max_bin': 462}. Best is trial 5 with value: -0.21687805935309665.
# [I 2022-06-19 22:05:59,396] Trial 6 finished with value: -0.21118614638548006 and parameters: {'max_depth': 2, 'num_leaves': 16, 'learning_rate': 0.13636785863615739, 'min_child_weight': 0.12037477997820098, 'subsample': 0.7624249801316101, 'subsample_freq': 4, 'colsample_bytree': 0.5039816498509027, 'reg_alpha': 1.615357446885923, 'reg_lambda': 3.919185574013676, 'max_bin': 294}. Best is trial 5 with value: -0.21687805935309665.
# [I 2022-06-19 22:06:19,590] Trial 7 finished with value: -0.21329675366089873 and parameters: {'max_depth': 7, 'num_leaves': 16, 'learning_rate': 0.06172758816916653, 'min_child_weight': 0.0753405486323676, 'subsample': 0.5351660244956074, 'subsample_freq': 4, 'colsample_bytree': 0.9781029764968145, 'reg_alpha': 0.8004453158813627, 'reg_lambda': 0.4343569618218917, 'max_bin': 158}. Best is trial 5 with value: -0.21687805935309665.
# [I 2022-06-19 22:06:38,285] Trial 8 finished with value: -0.18648387679353579 and parameters: {'max_depth': 12, 'num_leaves': 35, 'learning_rate': 0.10387902972625897, 'min_child_weight': 0.37820491756824665, 'subsample': 0.790507157411444, 'subsample_freq': 8, 'colsample_bytree': 0.6255027201812602, 'reg_alpha': 0.37117614274735294, 'reg_lambda': 3.1269078433481297, 'max_bin': 426}. Best is trial 5 with value: -0.21687805935309665.
# [I 2022-06-19 22:06:55,166] Trial 9 finished with value: -0.21257945732733244 and parameters: {'max_depth': 16, 'num_leaves': 44, 'learning_rate': 0.19707200625581814, 'min_child_weight': 1.9101244434898577, 'subsample': 0.5193762833887969, 'subsample_freq': 4, 'colsample_bytree': 0.8012730314381802, 'reg_alpha': 0.908095991966234, 'reg_lambda': 5.7701873193278175, 'max_bin': 483}. Best is trial 5 with value: -0.21687805935309665.
# [I 2022-06-19 22:07:08,447] Trial 10 finished with value: -0.21706136217552321 and parameters: {'max_depth': 30, 'num_leaves': 25, 'learning_rate': 0.19155829553396328, 'min_child_weight': 0.0022148993682943705, 'subsample': 0.9884084385998091, 'subsample_freq': 8, 'colsample_bytree': 0.7231470063182247, 'reg_alpha': 0.032774229621972926, 'reg_lambda': 0.011721815170419512, 'max_bin': 50}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:07:21,864] Trial 11 finished with value: -0.18256824396243967 and parameters: {'max_depth': 32, 'num_leaves': 25, 'learning_rate': 0.18740088735051702, 'min_child_weight': 0.0013604506436013179, 'subsample': 0.9814378588188828, 'subsample_freq': 8, 'colsample_bytree': 0.706858277700734, 'reg_alpha': 0.03349567260121026, 'reg_lambda': 0.010615059785652511, 'max_bin': 330}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:07:34,722] Trial 12 finished with value: -0.21011089702064156 and parameters: {'max_depth': 4, 'num_leaves': 23, 'learning_rate': 0.16302709281651825, 'min_child_weight': 0.0015413030646541995, 'subsample': 0.856771060722485, 'subsample_freq': 8, 'colsample_bytree': 0.6410748638722202, 'reg_alpha': 0.08235193208651138, 'reg_lambda': 0.010589780024427812, 'max_bin': 69}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:07:53,187] Trial 13 finished with value: -0.21171342297296997 and parameters: {'max_depth': 4, 'num_leaves': 25, 'learning_rate': 0.06521164815652458, 'min_child_weight': 0.0035503523028036946, 'subsample': 0.973568873342495, 'subsample_freq': 2, 'colsample_bytree': 0.805320744735455, 'reg_alpha': 8.495640905592074, 'reg_lambda': 0.043571138138843814, 'max_bin': 357}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:08:51,132] Trial 14 finished with value: -0.211324159266352 and parameters: {'max_depth': 2, 'num_leaves': 30, 'learning_rate': 0.010680231313202296, 'min_child_weight': 0.004597428100653136, 'subsample': 0.7069658967159373, 'subsample_freq': 1, 'colsample_bytree': 0.6708909189649165, 'reg_alpha': 0.048424211356165175, 'reg_lambda': 0.044705180498421065, 'max_bin': 53}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:09:07,810] Trial 15 finished with value: -0.20804597570326244 and parameters: {'max_depth': 32, 'num_leaves': 21, 'learning_rate': 0.17121575691802995, 'min_child_weight': 0.004773175250084056, 'subsample': 0.8639347288689374, 'subsample_freq': 8, 'colsample_bytree': 0.8063246145083439, 'reg_alpha': 0.012174578883807664, 'reg_lambda': 1.0694682146026957, 'max_bin': 224}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:09:21,201] Trial 16 finished with value: -0.21297054947348698 and parameters: {'max_depth': 3, 'num_leaves': 26, 'learning_rate': 0.08028117379506715, 'min_child_weight': 0.0011056228674908917, 'subsample': 0.7016271329106722, 'subsample_freq': 8, 'colsample_bytree': 0.8817398898936799, 'reg_alpha': 0.11437438766789358, 'reg_lambda': 0.02423442075041857, 'max_bin': 110}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:09:48,442] Trial 17 finished with value: -0.2121956104242856 and parameters: {'max_depth': 9, 'num_leaves': 19, 'learning_rate': 0.03558715344188426, 'min_child_weight': 0.39111002537465156, 'subsample': 0.5938872411308221, 'subsample_freq': 1, 'colsample_bytree': 0.5761978486577847, 'reg_alpha': 0.028548613453560353, 'reg_lambda': 0.08992033193389928, 'max_bin': 364}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:10:07,107] Trial 18 finished with value: -0.18533553568226788 and parameters: {'max_depth': 5, 'num_leaves': 29, 'learning_rate': 0.1608357245672633, 'min_child_weight': 0.0026799041312363845, 'subsample': 0.9262734187283044, 'subsample_freq': 2, 'colsample_bytree': 0.7289698846836035, 'reg_alpha': 0.15198706174104779, 'reg_lambda': 0.019194464362048143, 'max_bin': 281}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:10:24,573] Trial 19 finished with value: -0.21079061310267472 and parameters: {'max_depth': 3, 'num_leaves': 36, 'learning_rate': 0.1229860128737412, 'min_child_weight': 0.009341039389677274, 'subsample': 0.8049566905390892, 'subsample_freq': 8, 'colsample_bytree': 0.9986128821330995, 'reg_alpha': 0.01964486192285068, 'reg_lambda': 1.1946336911492212, 'max_bin': 496}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:10:42,122] Trial 20 finished with value: -0.20953903249709788 and parameters: {'max_depth': 6, 'num_leaves': 21, 'learning_rate': 0.08553702208707968, 'min_child_weight': 2.852497650480007, 'subsample': 0.6982382322860172, 'subsample_freq': 8, 'colsample_bytree': 0.7752667639469747, 'reg_alpha': 0.06690799565746908, 'reg_lambda': 0.08084667151846457, 'max_bin': 219}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:11:02,953] Trial 21 finished with value: -0.21278738006400802 and parameters: {'max_depth': 9, 'num_leaves': 16, 'learning_rate': 0.036647020261372065, 'min_child_weight': 0.12532976479789865, 'subsample': 0.5622276181521197, 'subsample_freq': 8, 'colsample_bytree': 0.9831160615821026, 'reg_alpha': 4.596443852522056, 'reg_lambda': 0.6740312158431732, 'max_bin': 154}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:11:23,610] Trial 22 finished with value: -0.21059005094667987 and parameters: {'max_depth': 23, 'num_leaves': 18, 'learning_rate': 0.03452587810010761, 'min_child_weight': 0.2962261287404009, 'subsample': 0.5443339185879053, 'subsample_freq': 1, 'colsample_bytree': 0.9609818827453915, 'reg_alpha': 0.6661883844647482, 'reg_lambda': 0.3623405437994097, 'max_bin': 103}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:11:44,540] Trial 23 finished with value: -0.21347381135904517 and parameters: {'max_depth': 7, 'num_leaves': 27, 'learning_rate': 0.08340285520288004, 'min_child_weight': 0.027087937862906104, 'subsample': 0.6679017391541474, 'subsample_freq': 2, 'colsample_bytree': 0.9176085040423725, 'reg_alpha': 0.14491170988288643, 'reg_lambda': 0.018937691635458484, 'max_bin': 173}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:12:03,554] Trial 24 finished with value: -0.21100654611250885 and parameters: {'max_depth': 3, 'num_leaves': 27, 'learning_rate': 0.08753634994510434, 'min_child_weight': 0.027283361563748484, 'subsample': 0.6848926845185946, 'subsample_freq': 2, 'colsample_bytree': 0.9196107108100602, 'reg_alpha': 0.19858228385407897, 'reg_lambda': 0.019432113574803584, 'max_bin': 190}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:12:20,601] Trial 25 finished with value: -0.20926217622180068 and parameters: {'max_depth': 23, 'num_leaves': 33, 'learning_rate': 0.11677002131152192, 'min_child_weight': 0.007527935745744, 'subsample': 0.7319920717466523, 'subsample_freq': 2, 'colsample_bytree': 0.8624391535788283, 'reg_alpha': 0.045311694455158424, 'reg_lambda': 0.025299046404645684, 'max_bin': 81}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:12:35,992] Trial 26 finished with value: -0.21272941265679002 and parameters: {'max_depth': 11, 'num_leaves': 23, 'learning_rate': 0.1461524373571199, 'min_child_weight': 0.0025834216503783547, 'subsample': 0.664206251941106, 'subsample_freq': 2, 'colsample_bytree': 0.8436719613014391, 'reg_alpha': 0.02207512926600169, 'reg_lambda': 0.010472357327822054, 'max_bin': 262}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:12:50,497] Trial 27 finished with value: -0.20983773747233245 and parameters: {'max_depth': 5, 'num_leaves': 22, 'learning_rate': 0.09263791400772954, 'min_child_weight': 0.0021439050005155114, 'subsample': 0.8213296439805361, 'subsample_freq': 6, 'colsample_bytree': 0.9192415586061546, 'reg_alpha': 0.08791596602385156, 'reg_lambda': 0.07510521394614368, 'max_bin': 307}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:13:15,741] Trial 28 finished with value: -0.21305796722453124 and parameters: {'max_depth': 9, 'num_leaves': 28, 'learning_rate': 0.050166857095387526, 'min_child_weight': 0.0010461562353058578, 'subsample': 0.5826465689811097, 'subsample_freq': 2, 'colsample_bytree': 0.8322795715254425, 'reg_alpha': 0.016507517216780232, 'reg_lambda': 14.075271521844703, 'max_bin': 176}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:13:34,078] Trial 29 finished with value: -0.209350568589948 and parameters: {'max_depth': 5, 'num_leaves': 41, 'learning_rate': 0.1050433646870244, 'min_child_weight': 0.014998299942264343, 'subsample': 0.7560559813298421, 'subsample_freq': 8, 'colsample_bytree': 0.7563715175551892, 'reg_alpha': 0.0510032877243263, 'reg_lambda': 0.1682080803039157, 'max_bin': 109}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:13:54,531] Trial 30 finished with value: -0.18441033453467756 and parameters: {'max_depth': 24, 'num_leaves': 40, 'learning_rate': 0.18151862690356166, 'min_child_weight': 0.025397893480449435, 'subsample': 0.6171748166200725, 'subsample_freq': 8, 'colsample_bytree': 0.7021837367143674, 'reg_alpha': 0.15519201414935532, 'reg_lambda': 0.01549223066699382, 'max_bin': 199}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:14:13,017] Trial 31 finished with value: -0.2076274429124357 and parameters: {'max_depth': 6, 'num_leaves': 33, 'learning_rate': 0.07215899542851993, 'min_child_weight': 0.1330742711812088, 'subsample': 0.590158535672647, 'subsample_freq': 4, 'colsample_bytree': 0.9475778014143171, 'reg_alpha': 0.543904388692995, 'reg_lambda': 0.6769517406547404, 'max_bin': 148}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:14:28,979] Trial 32 finished with value: -0.2127848259133458 and parameters: {'max_depth': 7, 'num_leaves': 18, 'learning_rate': 0.09715471555079902, 'min_child_weight': 0.9182274110454007, 'subsample': 0.5003887260314341, 'subsample_freq': 4, 'colsample_bytree': 0.9175348505291033, 'reg_alpha': 2.939292892646154, 'reg_lambda': 0.03423438713634265, 'max_bin': 244}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:14:51,481] Trial 33 finished with value: -0.2097978265638128 and parameters: {'max_depth': 8, 'num_leaves': 61, 'learning_rate': 0.05242005580737394, 'min_child_weight': 0.06780454513128624, 'subsample': 0.6704077018557919, 'subsample_freq': 4, 'colsample_bytree': 0.970072724690324, 'reg_alpha': 0.3097115528013754, 'reg_lambda': 0.28166630456005914, 'max_bin': 132}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:15:12,001] Trial 34 finished with value: -0.20645436111408394 and parameters: {'max_depth': 14, 'num_leaves': 24, 'learning_rate': 0.05268688616496178, 'min_child_weight': 0.0064533801418582655, 'subsample': 0.6147200913046872, 'subsample_freq': 4, 'colsample_bytree': 0.9018232399583925, 'reg_alpha': 1.052434744101345, 'reg_lambda': 0.12295053167025144, 'max_bin': 166}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:15:27,344] Trial 35 finished with value: -0.20546830778528474 and parameters: {'max_depth': 6, 'num_leaves': 21, 'learning_rate': 0.136129183395916, 'min_child_weight': 0.013708142063584752, 'subsample': 0.5420039877443003, 'subsample_freq': 6, 'colsample_bytree': 0.9398459988620569, 'reg_alpha': 0.2124728177895719, 'reg_lambda': 0.05856585987553869, 'max_bin': 51}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:15:48,355] Trial 36 finished with value: -0.21417279640996711 and parameters: {'max_depth': 4, 'num_leaves': 52, 'learning_rate': 0.023335600302116878, 'min_child_weight': 0.0710095858337708, 'subsample': 0.650131747250383, 'subsample_freq': 2, 'colsample_bytree': 0.9982940070255466, 'reg_alpha': 0.5579481866614264, 'reg_lambda': 0.23936965901514465, 'max_bin': 127}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:16:13,267] Trial 37 finished with value: -0.2109093860385706 and parameters: {'max_depth': 3, 'num_leaves': 55, 'learning_rate': 0.01994779529465561, 'min_child_weight': 0.03287677961255119, 'subsample': 0.6378421614950951, 'subsample_freq': 2, 'colsample_bytree': 0.8749234018186739, 'reg_alpha': 0.1297369044576098, 'reg_lambda': 0.030200111174302526, 'max_bin': 122}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:16:34,754] Trial 38 finished with value: -0.21350643108551984 and parameters: {'max_depth': 4, 'num_leaves': 55, 'learning_rate': 0.025270920131845898, 'min_child_weight': 0.04702613954480292, 'subsample': 0.7287484318393069, 'subsample_freq': 2, 'colsample_bytree': 0.9958117716673712, 'reg_alpha': 0.4875201531539088, 'reg_lambda': 0.016926423227106087, 'max_bin': 100}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:17:04,119] Trial 39 finished with value: -0.21198098478840782 and parameters: {'max_depth': 4, 'num_leaves': 54, 'learning_rate': 0.019120902880101844, 'min_child_weight': 0.09513509523386929, 'subsample': 0.7702066136593267, 'subsample_freq': 2, 'colsample_bytree': 0.9989467775294951, 'reg_alpha': 2.3508604029586295, 'reg_lambda': 0.015091645744388172, 'max_bin': 82}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:17:36,470] Trial 40 finished with value: -0.20803442129726407 and parameters: {'max_depth': 2, 'num_leaves': 48, 'learning_rate': 0.025234199847898004, 'min_child_weight': 0.2604655790530536, 'subsample': 0.7230499971325007, 'subsample_freq': 2, 'colsample_bytree': 0.5822641730246045, 'reg_alpha': 0.403785366510756, 'reg_lambda': 0.05476532173515373, 'max_bin': 437}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:18:13,934] Trial 41 finished with value: -0.21320707101501202 and parameters: {'max_depth': 5, 'num_leaves': 64, 'learning_rate': 0.007416735144974512, 'min_child_weight': 0.044472381672214886, 'subsample': 0.6530184843074254, 'subsample_freq': 2, 'colsample_bytree': 0.938851960281268, 'reg_alpha': 0.49973365617614185, 'reg_lambda': 0.024221125621058503, 'max_bin': 93}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:18:28,758] Trial 42 finished with value: -0.21134111519885526 and parameters: {'max_depth': 4, 'num_leaves': 54, 'learning_rate': 0.1330969634011841, 'min_child_weight': 0.05381999475445525, 'subsample': 0.7391589682026428, 'subsample_freq': 2, 'colsample_bytree': 0.9613814261829136, 'reg_alpha': 0.2263957001928732, 'reg_lambda': 0.015062790541243478, 'max_bin': 127}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:18:46,763] Trial 43 finished with value: -0.21350630836492718 and parameters: {'max_depth': 18, 'num_leaves': 49, 'learning_rate': 0.11199472371693442, 'min_child_weight': 0.1704063738209642, 'subsample': 0.6788422426386764, 'subsample_freq': 2, 'colsample_bytree': 0.8949358753042901, 'reg_alpha': 1.1664659153935333, 'reg_lambda': 0.01454876187088208, 'max_bin': 68}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:19:04,850] Trial 44 finished with value: -0.2109391971453022 and parameters: {'max_depth': 18, 'num_leaves': 48, 'learning_rate': 0.11294308886391044, 'min_child_weight': 0.19395308565176517, 'subsample': 0.9461552978707941, 'subsample_freq': 6, 'colsample_bytree': 0.7635152795276295, 'reg_alpha': 1.7152663568303832, 'reg_lambda': 0.012410359760790243, 'max_bin': 73}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:19:22,830] Trial 45 finished with value: -0.21534969203338536 and parameters: {'max_depth': 27, 'num_leaves': 51, 'learning_rate': 0.19930672433005817, 'min_child_weight': 0.4418232757969309, 'subsample': 0.7853332602383676, 'subsample_freq': 2, 'colsample_bytree': 0.8349500801676463, 'reg_alpha': 1.0609765068518842, 'reg_lambda': 0.03891592115676517, 'max_bin': 60}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:19:42,320] Trial 46 finished with value: -0.2138457814820444 and parameters: {'max_depth': 27, 'num_leaves': 51, 'learning_rate': 0.18874022449357533, 'min_child_weight': 0.9037976859303175, 'subsample': 0.844694728553016, 'subsample_freq': 8, 'colsample_bytree': 0.8340978178650303, 'reg_alpha': 0.7179510826884823, 'reg_lambda': 0.11157365511806532, 'max_bin': 92}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:20:00,093] Trial 47 finished with value: -0.2148702037806713 and parameters: {'max_depth': 27, 'num_leaves': 45, 'learning_rate': 0.19824862665537352, 'min_child_weight': 0.9706942105923605, 'subsample': 0.840658416871375, 'subsample_freq': 8, 'colsample_bytree': 0.8353324972440844, 'reg_alpha': 0.7594072623279627, 'reg_lambda': 0.12221513192789679, 'max_bin': 397}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:20:17,287] Trial 48 finished with value: -0.20761105474246838 and parameters: {'max_depth': 28, 'num_leaves': 42, 'learning_rate': 0.19926673689115715, 'min_child_weight': 0.6761956621707494, 'subsample': 0.9241257536081386, 'subsample_freq': 8, 'colsample_bytree': 0.798003509237624, 'reg_alpha': 1.4535226862339845, 'reg_lambda': 0.2368478219241058, 'max_bin': 413}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:20:37,205] Trial 49 finished with value: -0.1827513326951289 and parameters: {'max_depth': 28, 'num_leaves': 38, 'learning_rate': 0.17473027312640876, 'min_child_weight': 1.6845192779554985, 'subsample': 0.8885661837777353, 'subsample_freq': 8, 'colsample_bytree': 0.7260379794406853, 'reg_alpha': 3.716079365208206, 'reg_lambda': 0.20954379374482787, 'max_bin': 461}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:20:55,359] Trial 50 finished with value: -0.20892411007913597 and parameters: {'max_depth': 20, 'num_leaves': 45, 'learning_rate': 0.1586407238363921, 'min_child_weight': 3.837588949196294, 'subsample': 0.781040189558688, 'subsample_freq': 8, 'colsample_bytree': 0.7836718419786008, 'reg_alpha': 5.66277402389804, 'reg_lambda': 0.14847072336160885, 'max_bin': 379}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:21:15,222] Trial 51 finished with value: -0.21422227765868868 and parameters: {'max_depth': 28, 'num_leaves': 51, 'learning_rate': 0.19141428651088155, 'min_child_weight': 0.7081432412566235, 'subsample': 0.8364952081610043, 'subsample_freq': 8, 'colsample_bytree': 0.8240290604828099, 'reg_alpha': 0.7506132895033415, 'reg_lambda': 0.13693490341650658, 'max_bin': 446}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:21:31,605] Trial 52 finished with value: -0.2150023568424627 and parameters: {'max_depth': 20, 'num_leaves': 45, 'learning_rate': 0.18872276458713713, 'min_child_weight': 0.4849484597876667, 'subsample': 0.8326589436348566, 'subsample_freq': 8, 'colsample_bytree': 0.8222967249796066, 'reg_alpha': 0.8764481398164278, 'reg_lambda': 0.43187439958476337, 'max_bin': 448}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:21:51,267] Trial 53 finished with value: -0.21108482622961744 and parameters: {'max_depth': 31, 'num_leaves': 44, 'learning_rate': 0.18802113845661134, 'min_child_weight': 0.5488624012042832, 'subsample': 0.8254095046775438, 'subsample_freq': 8, 'colsample_bytree': 0.8158784379769648, 'reg_alpha': 2.109164728325242, 'reg_lambda': 0.05973275555769244, 'max_bin': 467}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:22:09,908] Trial 54 finished with value: -0.20532850000605607 and parameters: {'max_depth': 21, 'num_leaves': 58, 'learning_rate': 0.19401539723278483, 'min_child_weight': 1.2923969258510277, 'subsample': 0.8862207986534033, 'subsample_freq': 8, 'colsample_bytree': 0.8582465301316293, 'reg_alpha': 0.8419168523496939, 'reg_lambda': 0.4485799752752957, 'max_bin': 441}. Best is trial 10 with value: -0.21706136217552321.
# [I 2022-06-19 22:22:26,513] Trial 55 finished with value: -0.22140370188461672 and parameters: {'max_depth': 26, 'num_leaves': 46, 'learning_rate': 0.17392323412552022, 'min_child_weight': 0.4150819461705938, 'subsample': 0.8046369527246393, 'subsample_freq': 8, 'colsample_bytree': 0.8221431145134969, 'reg_alpha': 1.0894955585830794, 'reg_lambda': 1.1153154068653515, 'max_bin': 395}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:22:43,319] Trial 56 finished with value: -0.21069197010673704 and parameters: {'max_depth': 15, 'num_leaves': 46, 'learning_rate': 0.17937692362941135, 'min_child_weight': 0.44262380937559825, 'subsample': 0.8017259583211522, 'subsample_freq': 8, 'colsample_bytree': 0.8534784999725145, 'reg_alpha': 1.1862186596299706, 'reg_lambda': 1.7410657472420008, 'max_bin': 378}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:22:57,185] Trial 57 finished with value: -0.18435121553869765 and parameters: {'max_depth': 24, 'num_leaves': 31, 'learning_rate': 0.167783272167379, 'min_child_weight': 1.3297420111821494, 'subsample': 0.8579994171238161, 'subsample_freq': 1, 'colsample_bytree': 0.6874120631492773, 'reg_alpha': 1.8156785987862596, 'reg_lambda': 1.2554593686453923, 'max_bin': 401}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:23:13,501] Trial 58 finished with value: -0.22029869262906604 and parameters: {'max_depth': 20, 'num_leaves': 38, 'learning_rate': 0.19996942609069115, 'min_child_weight': 0.3038880368642324, 'subsample': 0.8013244791178831, 'subsample_freq': 8, 'colsample_bytree': 0.7878261821939919, 'reg_alpha': 0.010744782274514088, 'reg_lambda': 2.5911657447350938, 'max_bin': 345}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:23:29,407] Trial 59 finished with value: -0.18159700793061967 and parameters: {'max_depth': 21, 'num_leaves': 38, 'learning_rate': 0.15035192592394478, 'min_child_weight': 0.2947065822127205, 'subsample': 0.7946410780600336, 'subsample_freq': 8, 'colsample_bytree': 0.7473425716361992, 'reg_alpha': 0.010114157212997259, 'reg_lambda': 2.1878601683237173, 'max_bin': 336}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:23:45,928] Trial 60 finished with value: -0.2102130834160635 and parameters: {'max_depth': 18, 'num_leaves': 35, 'learning_rate': 0.18362497792884488, 'min_child_weight': 0.0018424798889745886, 'subsample': 0.8182301209763461, 'subsample_freq': 8, 'colsample_bytree': 0.7942750129080755, 'reg_alpha': 0.03524452532691879, 'reg_lambda': 4.3119379485454346, 'max_bin': 484}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:24:02,036] Trial 61 finished with value: -0.2052773049638974 and parameters: {'max_depth': 26, 'num_leaves': 43, 'learning_rate': 0.19986858383314784, 'min_child_weight': 0.4643517412422433, 'subsample': 0.7805465734395405, 'subsample_freq': 8, 'colsample_bytree': 0.8181626571079186, 'reg_alpha': 0.01436794873046198, 'reg_lambda': 0.5502847818947134, 'max_bin': 409}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:24:18,200] Trial 62 finished with value: -0.21025514619929933 and parameters: {'max_depth': 31, 'num_leaves': 46, 'learning_rate': 0.17525564393988538, 'min_child_weight': 0.20023779811320597, 'subsample': 0.9953318542818363, 'subsample_freq': 8, 'colsample_bytree': 0.7771109344225432, 'reg_alpha': 0.028032245006616996, 'reg_lambda': 0.8212484580049281, 'max_bin': 389}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:24:36,415] Trial 63 finished with value: -0.2092740315275643 and parameters: {'max_depth': 13, 'num_leaves': 40, 'learning_rate': 0.19223797745320315, 'min_child_weight': 1.036855693648618, 'subsample': 0.9031460685016822, 'subsample_freq': 8, 'colsample_bytree': 0.8764063467326672, 'reg_alpha': 0.970457694963114, 'reg_lambda': 2.3525877310948, 'max_bin': 354}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:24:55,578] Trial 64 finished with value: -0.20809216537181605 and parameters: {'max_depth': 21, 'num_leaves': 25, 'learning_rate': 0.168375441004688, 'min_child_weight': 2.4066808108067606, 'subsample': 0.7550384417894357, 'subsample_freq': 8, 'colsample_bytree': 0.845283316449322, 'reg_alpha': 0.35767411716721514, 'reg_lambda': 6.595481342069631, 'max_bin': 333}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:25:12,624] Trial 65 finished with value: -0.18503838261614952 and parameters: {'max_depth': 16, 'num_leaves': 34, 'learning_rate': 0.18375705560082384, 'min_child_weight': 0.3415030433431514, 'subsample': 0.9598704516027777, 'subsample_freq': 8, 'colsample_bytree': 0.7281383350436386, 'reg_alpha': 13.64653365976343, 'reg_lambda': 1.4943196237381196, 'max_bin': 429}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:25:26,864] Trial 66 finished with value: -0.20879596827536143 and parameters: {'max_depth': 26, 'num_leaves': 37, 'learning_rate': 0.15331935551067935, 'min_child_weight': 0.6255549758171409, 'subsample': 0.8110241135861449, 'subsample_freq': 1, 'colsample_bytree': 0.7674143542080064, 'reg_alpha': 0.08907516662510248, 'reg_lambda': 3.695402649945764, 'max_bin': 420}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:25:41,571] Trial 67 finished with value: -0.18178490399381153 and parameters: {'max_depth': 24, 'num_leaves': 39, 'learning_rate': 0.19474868600384776, 'min_child_weight': 0.003207379231937707, 'subsample': 0.8403708408243753, 'subsample_freq': 8, 'colsample_bytree': 0.6681246349598052, 'reg_alpha': 0.06403707434934336, 'reg_lambda': 0.03562360141898422, 'max_bin': 476}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:26:00,160] Trial 68 finished with value: -0.20659602733294696 and parameters: {'max_depth': 30, 'num_leaves': 29, 'learning_rate': 0.17728960640323732, 'min_child_weight': 0.0013414503311575702, 'subsample': 0.8769562499204429, 'subsample_freq': 8, 'colsample_bytree': 0.7900298993697865, 'reg_alpha': 0.021710799817334068, 'reg_lambda': 9.588774707400818, 'max_bin': 312}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:26:17,158] Trial 69 finished with value: -0.20822599729878286 and parameters: {'max_depth': 11, 'num_leaves': 43, 'learning_rate': 0.1859306130403865, 'min_child_weight': 0.23961018997747693, 'subsample': 0.9104440989011442, 'subsample_freq': 8, 'colsample_bytree': 0.8137224297680422, 'reg_alpha': 0.012010135282790244, 'reg_lambda': 0.8984633403932712, 'max_bin': 498}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:26:35,676] Trial 70 finished with value: -0.2084467962151865 and parameters: {'max_depth': 19, 'num_leaves': 47, 'learning_rate': 0.1429277311874189, 'min_child_weight': 0.09816695022028177, 'subsample': 0.7733082740447138, 'subsample_freq': 6, 'colsample_bytree': 0.8918974810299783, 'reg_alpha': 0.01732416777246861, 'reg_lambda': 0.024440951965302066, 'max_bin': 365}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:26:55,567] Trial 71 finished with value: -0.2134516319470682 and parameters: {'max_depth': 29, 'num_leaves': 50, 'learning_rate': 0.19143267635906555, 'min_child_weight': 0.8019413138538913, 'subsample': 0.8381320406058392, 'subsample_freq': 8, 'colsample_bytree': 0.8335758766076802, 'reg_alpha': 0.6864921669880694, 'reg_lambda': 0.33570135126411405, 'max_bin': 453}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:27:14,371] Trial 72 finished with value: -0.19910219217705952 and parameters: {'max_depth': 22, 'num_leaves': 57, 'learning_rate': 0.19904040045777277, 'min_child_weight': 0.6938460907828393, 'subsample': 0.8731734867505139, 'subsample_freq': 8, 'colsample_bytree': 0.8194821193813014, 'reg_alpha': 1.2746597618868138, 'reg_lambda': 0.0949469501134838, 'max_bin': 442}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:27:29,663] Trial 73 finished with value: -0.20928606733627336 and parameters: {'max_depth': 25, 'num_leaves': 27, 'learning_rate': 0.1705588016326392, 'min_child_weight': 0.5491075610297789, 'subsample': 0.8297131800569708, 'subsample_freq': 8, 'colsample_bytree': 0.8637893874893028, 'reg_alpha': 0.8664994066540134, 'reg_lambda': 0.4572059039226188, 'max_bin': 390}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:27:46,466] Trial 74 finished with value: -0.21229852115061254 and parameters: {'max_depth': 32, 'num_leaves': 52, 'learning_rate': 0.1914254729985606, 'min_child_weight': 0.3795317128458711, 'subsample': 0.790215857982251, 'subsample_freq': 8, 'colsample_bytree': 0.8375633865451665, 'reg_alpha': 0.5810055533877793, 'reg_lambda': 2.728444586880971, 'max_bin': 450}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:28:02,234] Trial 75 finished with value: -0.21139750487215642 and parameters: {'max_depth': 28, 'num_leaves': 42, 'learning_rate': 0.18212061800293572, 'min_child_weight': 1.1709763409059915, 'subsample': 0.860921667735042, 'subsample_freq': 8, 'colsample_bytree': 0.8251232301544408, 'reg_alpha': 0.43106475914629333, 'reg_lambda': 0.010584183131258543, 'max_bin': 431}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:28:16,574] Trial 76 finished with value: -0.20837800807452816 and parameters: {'max_depth': 23, 'num_leaves': 24, 'learning_rate': 0.19469482418166473, 'min_child_weight': 1.765827669902146, 'subsample': 0.8138585354237, 'subsample_freq': 8, 'colsample_bytree': 0.800977780826734, 'reg_alpha': 0.31157992207805163, 'reg_lambda': 0.6381484532253168, 'max_bin': 474}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:28:35,780] Trial 77 finished with value: -0.20871370918163987 and parameters: {'max_depth': 19, 'num_leaves': 45, 'learning_rate': 0.16374844220279516, 'min_child_weight': 0.005141434284606899, 'subsample': 0.8490736884841076, 'subsample_freq': 8, 'colsample_bytree': 0.8722124105132927, 'reg_alpha': 2.6705676681696415, 'reg_lambda': 0.044889128484478465, 'max_bin': 418}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:28:49,822] Trial 78 finished with value: -0.1818023707713243 and parameters: {'max_depth': 17, 'num_leaves': 50, 'learning_rate': 0.18867823449036625, 'min_child_weight': 0.4814127979417357, 'subsample': 0.713262121467617, 'subsample_freq': 1, 'colsample_bytree': 0.7096515553941927, 'reg_alpha': 0.038092410907264215, 'reg_lambda': 0.1370935605025174, 'max_bin': 348}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:29:05,623] Trial 79 finished with value: -0.20526630341383809 and parameters: {'max_depth': 25, 'num_leaves': 32, 'learning_rate': 0.1745100838362869, 'min_child_weight': 0.152435373262542, 'subsample': 0.7657812310314849, 'subsample_freq': 8, 'colsample_bytree': 0.7547632376356419, 'reg_alpha': 0.754383976454146, 'reg_lambda': 0.07318197687169373, 'max_bin': 317}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:29:23,619] Trial 80 finished with value: -0.20856907810706185 and parameters: {'max_depth': 22, 'num_leaves': 48, 'learning_rate': 0.1795275385680811, 'min_child_weight': 0.3368393324783273, 'subsample': 0.7490932590573511, 'subsample_freq': 4, 'colsample_bytree': 0.8460598831741568, 'reg_alpha': 0.02671265761134913, 'reg_lambda': 0.029965294479263868, 'max_bin': 62}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:29:44,765] Trial 81 finished with value: -0.18378911730326752 and parameters: {'max_depth': 27, 'num_leaves': 53, 'learning_rate': 0.07642291700058387, 'min_child_weight': 0.8473680327786715, 'subsample': 0.6382364570405256, 'subsample_freq': 2, 'colsample_bytree': 0.7430670723049752, 'reg_alpha': 0.5891886642633821, 'reg_lambda': 0.250858674300219, 'max_bin': 276}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:30:03,378] Trial 82 finished with value: -0.21244967418021873 and parameters: {'max_depth': 29, 'num_leaves': 60, 'learning_rate': 0.19983223885014129, 'min_child_weight': 0.24373505237342602, 'subsample': 0.8034914786681597, 'subsample_freq': 2, 'colsample_bytree': 0.7754927597567213, 'reg_alpha': 1.4535852211166305, 'reg_lambda': 0.21521927003089703, 'max_bin': 399}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:30:21,289] Trial 83 finished with value: -0.20948880204527712 and parameters: {'max_depth': 32, 'num_leaves': 52, 'learning_rate': 0.1288278473268076, 'min_child_weight': 0.08105321164508644, 'subsample': 0.7443189949797333, 'subsample_freq': 8, 'colsample_bytree': 0.8083467955572737, 'reg_alpha': 0.9315453595300732, 'reg_lambda': 0.16306018941918565, 'max_bin': 56}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:30:42,113] Trial 84 finished with value: -0.21089738752538478 and parameters: {'max_depth': 26, 'num_leaves': 57, 'learning_rate': 0.05966496692051827, 'min_child_weight': 0.011847652655441588, 'subsample': 0.6086004461346037, 'subsample_freq': 2, 'colsample_bytree': 0.907372451199424, 'reg_alpha': 1.090123441921619, 'reg_lambda': 0.35724576143259557, 'max_bin': 294}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:31:08,293] Trial 85 finished with value: -0.20917671673700983 and parameters: {'max_depth': 20, 'num_leaves': 50, 'learning_rate': 0.04350407473659347, 'min_child_weight': 0.017767357248294664, 'subsample': 0.789365489712213, 'subsample_freq': 6, 'colsample_bytree': 0.7878547560902958, 'reg_alpha': 0.47418322550961695, 'reg_lambda': 0.10813788658229388, 'max_bin': 253}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:31:24,293] Trial 86 finished with value: -0.21122188659932828 and parameters: {'max_depth': 6, 'num_leaves': 20, 'learning_rate': 0.18544745863642279, 'min_child_weight': 0.7190820223450117, 'subsample': 0.8286660878053272, 'subsample_freq': 8, 'colsample_bytree': 0.826418452688607, 'reg_alpha': 0.35319634843828923, 'reg_lambda': 0.17355968009194772, 'max_bin': 117}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:31:41,341] Trial 87 finished with value: -0.21827443482799874 and parameters: {'max_depth': 24, 'num_leaves': 26, 'learning_rate': 0.12055379236906105, 'min_child_weight': 0.0022161609437960556, 'subsample': 0.6886113163059412, 'subsample_freq': 2, 'colsample_bytree': 0.928374069806324, 'reg_alpha': 0.6645773965881078, 'reg_lambda': 0.2933489574126388, 'max_bin': 216}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:31:56,317] Trial 88 finished with value: -0.20859394430734307 and parameters: {'max_depth': 22, 'num_leaves': 26, 'learning_rate': 0.09928819539448284, 'min_child_weight': 0.0021749646580619675, 'subsample': 0.8724887019107775, 'subsample_freq': 8, 'colsample_bytree': 0.8896297117744327, 'reg_alpha': 0.6293634090371422, 'reg_lambda': 0.019944831229544362, 'max_bin': 226}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:32:11,941] Trial 89 finished with value: -0.2048699794562577 and parameters: {'max_depth': 29, 'num_leaves': 24, 'learning_rate': 0.10653216745994532, 'min_child_weight': 0.0036040040087908817, 'subsample': 0.6986250439522018, 'subsample_freq': 8, 'colsample_bytree': 0.8657558921034171, 'reg_alpha': 1.9484544788783633, 'reg_lambda': 0.2963517544894911, 'max_bin': 210}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:32:27,480] Trial 90 finished with value: -0.2138115216543875 and parameters: {'max_depth': 15, 'num_leaves': 28, 'learning_rate': 0.12290454282314632, 'min_child_weight': 0.0017703601178965364, 'subsample': 0.6265451373727117, 'subsample_freq': 2, 'colsample_bytree': 0.9237803488560387, 'reg_alpha': 1.3888580590204618, 'reg_lambda': 0.013430340868371452, 'max_bin': 372}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:32:45,665] Trial 91 finished with value: -0.21578548951581916 and parameters: {'max_depth': 24, 'num_leaves': 22, 'learning_rate': 0.19403220560688764, 'min_child_weight': 0.0012689466040355334, 'subsample': 0.644513297746983, 'subsample_freq': 2, 'colsample_bytree': 0.9521623850227459, 'reg_alpha': 0.8054475080018753, 'reg_lambda': 0.19964154815413523, 'max_bin': 487}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:33:01,857] Trial 92 finished with value: -0.21116054725895358 and parameters: {'max_depth': 23, 'num_leaves': 22, 'learning_rate': 0.19519371341493055, 'min_child_weight': 0.0010340812355443252, 'subsample': 0.6561703653318556, 'subsample_freq': 2, 'colsample_bytree': 0.9331382794755378, 'reg_alpha': 0.7410815693803414, 'reg_lambda': 0.20014538073128657, 'max_bin': 483}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:33:19,260] Trial 93 finished with value: -0.20896121632283166 and parameters: {'max_depth': 26, 'num_leaves': 26, 'learning_rate': 0.18932144082292232, 'min_child_weight': 0.0020416415327768685, 'subsample': 0.6799795769291788, 'subsample_freq': 2, 'colsample_bytree': 0.9774724330279414, 'reg_alpha': 0.9538053889920277, 'reg_lambda': 0.5281701564096756, 'max_bin': 457}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:33:39,572] Trial 94 finished with value: -0.2059607696737457 and parameters: {'max_depth': 24, 'num_leaves': 20, 'learning_rate': 0.11754794311577034, 'min_child_weight': 0.001265353298432943, 'subsample': 0.7139794079810527, 'subsample_freq': 2, 'colsample_bytree': 0.8500181939911363, 'reg_alpha': 1.665589130811132, 'reg_lambda': 0.9789898868301637, 'max_bin': 492}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:34:00,530] Trial 95 finished with value: -0.20731925183517347 and parameters: {'max_depth': 20, 'num_leaves': 23, 'learning_rate': 0.09338227202982918, 'min_child_weight': 0.0015914530131569547, 'subsample': 0.7805932809937814, 'subsample_freq': 4, 'colsample_bytree': 0.9542435458524666, 'reg_alpha': 0.28138802542685465, 'reg_lambda': 0.2857198095154391, 'max_bin': 467}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:34:19,849] Trial 96 finished with value: -0.21164418041567198 and parameters: {'max_depth': 17, 'num_leaves': 22, 'learning_rate': 0.19657546601263132, 'min_child_weight': 0.0024318199091282336, 'subsample': 0.6047763282989972, 'subsample_freq': 2, 'colsample_bytree': 0.9096855729648091, 'reg_alpha': 0.8218656609882293, 'reg_lambda': 0.14289151563658928, 'max_bin': 450}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:34:36,085] Trial 97 finished with value: -0.2109269715605763 and parameters: {'max_depth': 30, 'num_leaves': 29, 'learning_rate': 0.1797092822853374, 'min_child_weight': 0.003250481558452616, 'subsample': 0.8517870655044896, 'subsample_freq': 8, 'colsample_bytree': 0.806346291066497, 'reg_alpha': 1.0840775695525822, 'reg_lambda': 0.012268229535119603, 'max_bin': 407}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:34:48,581] Trial 98 finished with value: -0.20741347093281165 and parameters: {'max_depth': 27, 'num_leaves': 17, 'learning_rate': 0.18632086701397557, 'min_child_weight': 0.520244413003845, 'subsample': 0.6864979297659712, 'subsample_freq': 1, 'colsample_bytree': 0.8864481577438477, 'reg_alpha': 0.4527265652924373, 'reg_lambda': 0.021429903250242126, 'max_bin': 438}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:35:05,042] Trial 99 finished with value: -0.2145275828070517 and parameters: {'max_depth': 8, 'num_leaves': 30, 'learning_rate': 0.16432256257955613, 'min_child_weight': 0.001205147454109839, 'subsample': 0.6292243616913871, 'subsample_freq': 8, 'colsample_bytree': 0.9268418449262893, 'reg_alpha': 0.05719211134413387, 'reg_lambda': 1.5992090218466657, 'max_bin': 425}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:35:20,605] Trial 100 finished with value: -0.21329097663327085 and parameters: {'max_depth': 8, 'num_leaves': 31, 'learning_rate': 0.16313740391181994, 'min_child_weight': 0.001312569462095883, 'subsample': 0.6366100031944394, 'subsample_freq': 2, 'colsample_bytree': 0.9314590733944818, 'reg_alpha': 0.06453750750484166, 'reg_lambda': 1.7218405627963094, 'max_bin': 427}. Best is trial 55 with value: -0.22140370188461672.
# [I 2022-06-19 22:35:38,009] Trial 101 finished with value: -0.22353180005239004 and parameters: {'max_depth': 25, 'num_leaves': 25, 'learning_rate': 0.19050964936012016, 'min_child_weight': 0.0014886940219762171, 'subsample': 0.5794351479195687, 'subsample_freq': 8, 'colsample_bytree': 0.9539454860525223, 'reg_alpha': 0.053526953188137216, 'reg_lambda': 1.3882699740662547, 'max_bin': 392}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:35:56,751] Trial 102 finished with value: -0.2145079938127219 and parameters: {'max_depth': 25, 'num_leaves': 25, 'learning_rate': 0.17228796830968893, 'min_child_weight': 0.0015393450912745577, 'subsample': 0.5590513616101304, 'subsample_freq': 8, 'colsample_bytree': 0.9482011594374038, 'reg_alpha': 0.04317870221529427, 'reg_lambda': 1.2601426289396251, 'max_bin': 389}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:36:11,738] Trial 103 finished with value: -0.21567256933795825 and parameters: {'max_depth': 22, 'num_leaves': 28, 'learning_rate': 0.15782007573505893, 'min_child_weight': 0.001126650229083856, 'subsample': 0.5992904472085924, 'subsample_freq': 8, 'colsample_bytree': 0.9671704504518404, 'reg_alpha': 0.09455043063552168, 'reg_lambda': 1.8759915495104764, 'max_bin': 400}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:36:28,096] Trial 104 finished with value: -0.21225304970460795 and parameters: {'max_depth': 22, 'num_leaves': 28, 'learning_rate': 0.1567879996493438, 'min_child_weight': 0.0027555881304783844, 'subsample': 0.5800811014487666, 'subsample_freq': 8, 'colsample_bytree': 0.9680715321691202, 'reg_alpha': 0.10322258300792174, 'reg_lambda': 1.935757722468702, 'max_bin': 141}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:36:42,537] Trial 105 finished with value: -0.21199778175867454 and parameters: {'max_depth': 19, 'num_leaves': 23, 'learning_rate': 0.18354802497743183, 'min_child_weight': 0.001550483930878556, 'subsample': 0.5722051650957205, 'subsample_freq': 8, 'colsample_bytree': 0.9894258056146206, 'reg_alpha': 0.05376847593417161, 'reg_lambda': 2.3736099147312593, 'max_bin': 348}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:36:58,118] Trial 106 finished with value: -0.21008154039569743 and parameters: {'max_depth': 24, 'num_leaves': 27, 'learning_rate': 0.14161386893646147, 'min_child_weight': 0.003958650575764382, 'subsample': 0.6454224276982088, 'subsample_freq': 6, 'colsample_bytree': 0.9579376370149217, 'reg_alpha': 0.023658475198915424, 'reg_lambda': 0.7662107777764646, 'max_bin': 79}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:37:15,011] Trial 107 finished with value: -0.2224470444737155 and parameters: {'max_depth': 21, 'num_leaves': 26, 'learning_rate': 0.19678523884881888, 'min_child_weight': 0.001013333142711707, 'subsample': 0.6008254019198633, 'subsample_freq': 8, 'colsample_bytree': 0.9753722387775884, 'reg_alpha': 0.07697845604067165, 'reg_lambda': 3.268976168549113, 'max_bin': 394}. Best is trial 101 with value: -0.22353180005239004.
# [I 2022-06-19 22:37:33,681] Trial 108 finished with value: -0.20902457069796743 and parameters: {'max_depth': 17, 'num_leaves': 26, 'learning_rate': 0.1918226035623961, 'min_child_weight': 0.0010195724412074565, 'subsample': 0.5999710754218595, 'subsample_freq': 8, 'colsample_bytree': 0.9425313884356281, 'reg_alpha': 0.07392663887261983, 'reg_lambda': 3.3111105095770474, 'max_bin': 380}. Best is trial 101 with value: -0.22353180005239004.
# ...
# [I 2022-06-20 01:54:09,125] Trial 800 finished with value: -0.21313591278692923 and parameters: {'max_depth': 7, 'num_leaves': 38, 'learning_rate': 0.1961523987224539, 'min_child_weight': 0.267522456461757, 'subsample': 0.7923956914011904, 'subsample_freq': 4, 'colsample_bytree': 0.9845957107684883, 'reg_alpha': 0.16500518172636822, 'reg_lambda': 2.8053516977396296, 'max_bin': 92}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:54:26,496] Trial 801 finished with value: -0.21074043703505496 and parameters: {'max_depth': 25, 'num_leaves': 35, 'learning_rate': 0.1892021989233106, 'min_child_weight': 0.16248552939181493, 'subsample': 0.7811156524681703, 'subsample_freq': 8, 'colsample_bytree': 0.9750437307262974, 'reg_alpha': 0.04863929801026392, 'reg_lambda': 3.308072265884723, 'max_bin': 85}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:54:42,371] Trial 802 finished with value: -0.21957548016093456 and parameters: {'max_depth': 23, 'num_leaves': 36, 'learning_rate': 0.1815278482226639, 'min_child_weight': 0.2796676793358553, 'subsample': 0.7995949461179409, 'subsample_freq': 8, 'colsample_bytree': 0.965818037840434, 'reg_alpha': 0.12994848511857757, 'reg_lambda': 3.7356306218052517, 'max_bin': 108}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:54:58,778] Trial 803 finished with value: -0.20755321510833413 and parameters: {'max_depth': 22, 'num_leaves': 31, 'learning_rate': 0.19231836219064483, 'min_child_weight': 0.0677617371884746, 'subsample': 0.816184259904151, 'subsample_freq': 8, 'colsample_bytree': 0.9536797240115923, 'reg_alpha': 0.059875835097497956, 'reg_lambda': 8.688868955119476, 'max_bin': 125}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:55:14,902] Trial 804 finished with value: -0.20530783213263834 and parameters: {'max_depth': 27, 'num_leaves': 37, 'learning_rate': 0.17972016119750223, 'min_child_weight': 0.1793306918491069, 'subsample': 0.811010429429106, 'subsample_freq': 8, 'colsample_bytree': 0.9999577320683478, 'reg_alpha': 0.18221539595729824, 'reg_lambda': 2.677177318734982, 'max_bin': 289}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:55:29,994] Trial 805 finished with value: -0.21047280247239963 and parameters: {'max_depth': 19, 'num_leaves': 29, 'learning_rate': 0.18643729106381784, 'min_child_weight': 0.05611871355568914, 'subsample': 0.7908444419723881, 'subsample_freq': 8, 'colsample_bytree': 0.9814633324688125, 'reg_alpha': 0.1487747043112763, 'reg_lambda': 5.864985349696229, 'max_bin': 66}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:55:46,441] Trial 806 finished with value: -0.20932695921132663 and parameters: {'max_depth': 29, 'num_leaves': 28, 'learning_rate': 0.1965302557637829, 'min_child_weight': 0.4130395805541905, 'subsample': 0.7740990232026824, 'subsample_freq': 8, 'colsample_bytree': 0.971259236579012, 'reg_alpha': 1.6278729755186796, 'reg_lambda': 4.1940158013557, 'max_bin': 115}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:56:04,208] Trial 807 finished with value: -0.2163900100225115 and parameters: {'max_depth': 24, 'num_leaves': 32, 'learning_rate': 0.1908526746167087, 'min_child_weight': 0.3272317090065924, 'subsample': 0.8220395021166962, 'subsample_freq': 8, 'colsample_bytree': 0.9873258376593436, 'reg_alpha': 0.04964501722942961, 'reg_lambda': 3.3314769926435073, 'max_bin': 97}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:56:20,183] Trial 808 finished with value: -0.2202043875345041 and parameters: {'max_depth': 21, 'num_leaves': 34, 'learning_rate': 0.18382358162804838, 'min_child_weight': 0.04653649182803334, 'subsample': 0.7921662681472824, 'subsample_freq': 8, 'colsample_bytree': 0.9056506155765712, 'reg_alpha': 0.10124521260566212, 'reg_lambda': 2.788580848706543, 'max_bin': 89}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:56:39,221] Trial 809 finished with value: -0.21467071789863224 and parameters: {'max_depth': 20, 'num_leaves': 39, 'learning_rate': 0.18838525651137916, 'min_child_weight': 0.4193488698049932, 'subsample': 0.8024900021426539, 'subsample_freq': 8, 'colsample_bytree': 0.9793279519219483, 'reg_alpha': 0.08314758024811743, 'reg_lambda': 3.234669829357508, 'max_bin': 131}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:56:57,477] Trial 810 finished with value: -0.21637827279535932 and parameters: {'max_depth': 25, 'num_leaves': 35, 'learning_rate': 0.17900095871885754, 'min_child_weight': 0.23022433019834937, 'subsample': 0.7664536220640472, 'subsample_freq': 8, 'colsample_bytree': 0.9604245431441771, 'reg_alpha': 0.21088914279957388, 'reg_lambda': 3.7825534551394444, 'max_bin': 101}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:57:16,757] Trial 811 finished with value: -0.21054219693798668 and parameters: {'max_depth': 19, 'num_leaves': 33, 'learning_rate': 0.193114476508235, 'min_child_weight': 0.41636031217347114, 'subsample': 0.78032257182505, 'subsample_freq': 8, 'colsample_bytree': 0.9910847721186435, 'reg_alpha': 0.06656767096948125, 'reg_lambda': 2.7167374034776492, 'max_bin': 316}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:57:39,548] Trial 812 finished with value: -0.20812387541747657 and parameters: {'max_depth': 27, 'num_leaves': 30, 'learning_rate': 0.18407728180260075, 'min_child_weight': 0.20844120344040332, 'subsample': 0.8059051420908603, 'subsample_freq': 2, 'colsample_bytree': 0.943284672737881, 'reg_alpha': 0.010069271439166002, 'reg_lambda': 4.662137015297299, 'max_bin': 79}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:57:59,014] Trial 813 finished with value: -0.2182602038513844 and parameters: {'max_depth': 31, 'num_leaves': 36, 'learning_rate': 0.1880223514646842, 'min_child_weight': 0.33929534244844495, 'subsample': 0.8324085716862782, 'subsample_freq': 8, 'colsample_bytree': 0.9713608490540372, 'reg_alpha': 0.11675226040764854, 'reg_lambda': 3.1233223745924974, 'max_bin': 80}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:58:15,389] Trial 814 finished with value: -0.21294696249564424 and parameters: {'max_depth': 11, 'num_leaves': 34, 'learning_rate': 0.1959965134956288, 'min_child_weight': 0.4113627670432597, 'subsample': 0.7974456732076278, 'subsample_freq': 8, 'colsample_bytree': 0.9850556029423693, 'reg_alpha': 0.04375208121665216, 'reg_lambda': 2.4965954954440486, 'max_bin': 130}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:58:31,268] Trial 815 finished with value: -0.20785375723736782 and parameters: {'max_depth': 23, 'num_leaves': 38, 'learning_rate': 0.1802824095737717, 'min_child_weight': 0.26776821291494957, 'subsample': 0.8142961237481547, 'subsample_freq': 8, 'colsample_bytree': 0.9633526291443724, 'reg_alpha': 0.05409109851027662, 'reg_lambda': 3.9186999286815674, 'max_bin': 71}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:58:47,585] Trial 816 finished with value: -0.2115058866452185 and parameters: {'max_depth': 20, 'num_leaves': 37, 'learning_rate': 0.16976701609457476, 'min_child_weight': 0.2997740327184564, 'subsample': 0.7892993483245937, 'subsample_freq': 8, 'colsample_bytree': 0.9800980204681304, 'reg_alpha': 0.16752680715378782, 'reg_lambda': 2.884636000283401, 'max_bin': 116}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:59:03,082] Trial 817 finished with value: -0.21840239978225018 and parameters: {'max_depth': 22, 'num_leaves': 28, 'learning_rate': 0.1382744149902352, 'min_child_weight': 0.2609696934335369, 'subsample': 0.8054654000676001, 'subsample_freq': 8, 'colsample_bytree': 0.9927424680438265, 'reg_alpha': 0.13287302215757565, 'reg_lambda': 6.187065913503848, 'max_bin': 100}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:59:18,614] Trial 818 finished with value: -0.2096108659938632 and parameters: {'max_depth': 19, 'num_leaves': 21, 'learning_rate': 0.1921113247329705, 'min_child_weight': 0.4730068627258521, 'subsample': 0.8272340960470266, 'subsample_freq': 8, 'colsample_bytree': 0.9500047200558078, 'reg_alpha': 0.06051516582740985, 'reg_lambda': 5.225186043243452, 'max_bin': 88}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:59:33,315] Trial 819 finished with value: -0.21188233129887063 and parameters: {'max_depth': 26, 'num_leaves': 29, 'learning_rate': 0.19997876916249158, 'min_child_weight': 0.5555652136651317, 'subsample': 0.7846227639411316, 'subsample_freq': 1, 'colsample_bytree': 0.9744178824749781, 'reg_alpha': 0.04704790940353773, 'reg_lambda': 3.307928481153535, 'max_bin': 327}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 01:59:48,815] Trial 820 finished with value: -0.22468196017811826 and parameters: {'max_depth': 29, 'num_leaves': 31, 'learning_rate': 0.17624404984301853, 'min_child_weight': 0.17059373890013022, 'subsample': 0.8001025535656939, 'subsample_freq': 8, 'colsample_bytree': 0.991451280119163, 'reg_alpha': 0.20248757604570133, 'reg_lambda': 4.299973044545325, 'max_bin': 109}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:00:04,601] Trial 821 finished with value: -0.21906430626026602 and parameters: {'max_depth': 29, 'num_leaves': 31, 'learning_rate': 0.1690417421130697, 'min_child_weight': 0.20912545903312665, 'subsample': 0.799246310840487, 'subsample_freq': 8, 'colsample_bytree': 0.9999597128454643, 'reg_alpha': 0.22168475942124824, 'reg_lambda': 6.444871096838754, 'max_bin': 114}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:00:20,819] Trial 822 finished with value: -0.20760324774603908 and parameters: {'max_depth': 30, 'num_leaves': 31, 'learning_rate': 0.17307290410118784, 'min_child_weight': 0.1714003148354428, 'subsample': 0.8100738139388851, 'subsample_freq': 8, 'colsample_bytree': 0.982251472661461, 'reg_alpha': 0.19781535171181783, 'reg_lambda': 5.331233681790629, 'max_bin': 112}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:00:37,375] Trial 823 finished with value: -0.2161833372588803 and parameters: {'max_depth': 28, 'num_leaves': 32, 'learning_rate': 0.17622707733638504, 'min_child_weight': 0.12949847616968688, 'subsample': 0.8193392275621277, 'subsample_freq': 8, 'colsample_bytree': 0.9673604920039443, 'reg_alpha': 0.1914189739712051, 'reg_lambda': 4.5404745031373785, 'max_bin': 121}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:00:52,834] Trial 824 finished with value: -0.2114140756246763 and parameters: {'max_depth': 29, 'num_leaves': 30, 'learning_rate': 0.17784903488930198, 'min_child_weight': 0.12184745816554443, 'subsample': 0.7482174492541851, 'subsample_freq': 8, 'colsample_bytree': 0.992661163828945, 'reg_alpha': 0.18051298952455014, 'reg_lambda': 4.681587050908965, 'max_bin': 103}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:01:09,176] Trial 825 finished with value: -0.2063675967914591 and parameters: {'max_depth': 29, 'num_leaves': 32, 'learning_rate': 0.17424470419657792, 'min_child_weight': 0.18710617292171436, 'subsample': 0.7857989942587377, 'subsample_freq': 4, 'colsample_bytree': 0.9999930690704801, 'reg_alpha': 0.23246592715684594, 'reg_lambda': 4.191950641271472, 'max_bin': 123}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:01:25,641] Trial 826 finished with value: -0.2141101761466278 and parameters: {'max_depth': 30, 'num_leaves': 30, 'learning_rate': 0.17642294838470515, 'min_child_weight': 0.22721454034219754, 'subsample': 0.7963767722259627, 'subsample_freq': 8, 'colsample_bytree': 0.9564775590981469, 'reg_alpha': 0.1604335602824462, 'reg_lambda': 5.293443222067551, 'max_bin': 139}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:01:40,665] Trial 827 finished with value: -0.20332068429524433 and parameters: {'max_depth': 18, 'num_leaves': 31, 'learning_rate': 0.18132552267209337, 'min_child_weight': 0.03077113450087395, 'subsample': 0.8080921141625358, 'subsample_freq': 6, 'colsample_bytree': 0.9812355802963586, 'reg_alpha': 0.14801336422137093, 'reg_lambda': 4.285298207097778, 'max_bin': 102}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:01:56,987] Trial 828 finished with value: -0.2137509740667877 and parameters: {'max_depth': 32, 'num_leaves': 33, 'learning_rate': 0.16699357225774103, 'min_child_weight': 0.07959935298244872, 'subsample': 0.7751904316663832, 'subsample_freq': 8, 'colsample_bytree': 0.9714935605056735, 'reg_alpha': 0.19928415711025727, 'reg_lambda': 3.7380599718052525, 'max_bin': 91}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:02:13,473] Trial 829 finished with value: -0.21384927537312598 and parameters: {'max_depth': 27, 'num_leaves': 31, 'learning_rate': 0.1815542769245164, 'min_child_weight': 0.24266202392896732, 'subsample': 0.7944139510566811, 'subsample_freq': 8, 'colsample_bytree': 0.9895949143612754, 'reg_alpha': 0.2412494986981896, 'reg_lambda': 0.3118829124849841, 'max_bin': 110}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:02:30,044] Trial 830 finished with value: -0.21609125732760742 and parameters: {'max_depth': 31, 'num_leaves': 29, 'learning_rate': 0.17264183075324685, 'min_child_weight': 0.10120101299354577, 'subsample': 0.8031888570372026, 'subsample_freq': 8, 'colsample_bytree': 0.9616052020473629, 'reg_alpha': 0.15969815263292536, 'reg_lambda': 3.4168653155838435, 'max_bin': 94}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:02:45,736] Trial 831 finished with value: -0.20909917715281728 and parameters: {'max_depth': 21, 'num_leaves': 30, 'learning_rate': 0.17774116539960097, 'min_child_weight': 0.3517749371408541, 'subsample': 0.7631178463298344, 'subsample_freq': 8, 'colsample_bytree': 0.9765093179332287, 'reg_alpha': 0.13788059193774135, 'reg_lambda': 3.8922905740975615, 'max_bin': 101}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:03:05,564] Trial 832 finished with value: -0.21656693447000017 and parameters: {'max_depth': 18, 'num_leaves': 28, 'learning_rate': 0.18422749153456736, 'min_child_weight': 0.1740919157453768, 'subsample': 0.8197107487706355, 'subsample_freq': 8, 'colsample_bytree': 0.9859065550763504, 'reg_alpha': 0.17066091910719425, 'reg_lambda': 4.810677734487168, 'max_bin': 77}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:03:24,116] Trial 833 finished with value: -0.211532114661801 and parameters: {'max_depth': 32, 'num_leaves': 32, 'learning_rate': 0.16768739035647062, 'min_child_weight': 0.13357938504981667, 'subsample': 0.7840224783519657, 'subsample_freq': 8, 'colsample_bytree': 0.9694121973755122, 'reg_alpha': 0.1030221774518578, 'reg_lambda': 2.5127244618583635, 'max_bin': 114}. Best is trial 756 with value: -0.22782619759389738.
# [I 2022-06-20 02:03:38,943] Trial 834 finished with value: -0.21643961639852236 and parameters: {'max_depth': 20, 'num_leaves': 29, 'learning_rate': 0.18033353763946336, 'min_child_weight': 0.30401684925300043, 'subsample': 0.810331690351227, 'subsample_freq': 8, 'colsample_bytree': 0.936575666558509, 'reg_alpha': 0.19695718770348233, 'reg_lambda': 3.6914540032392216, 'max_bin': 110}. Best is trial 756 with value: -0.22782619759389738.
# [2022-06-20 10:03:38] {'max_depth': 19, 'num_leaves': 36, 'learning_rate': 0.19556442502960814, 'min_child_weight': 0.281833217849683, 'subsample': 0.8122289411791767, 'subsample_freq': 8, 'colsample_bytree': 0.9566555862125016, 'reg_alpha': 0.05529716743026185, 'reg_lambda': 3.4277402093010507, 'max_bin': 107}
# [2022-06-20 10:03:38] Best score is -0.22782619759389738
# CPU times: user 9h 47min 22s, sys: 1min 30s, total: 9h 48min 52s
# Wall time: 4h 9s

# %%
'''
Re-fit best model
'''
params = {'selected_feats': selected_feats, 
          'lgbm_var_params': best_params.copy(), 
          'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
          'n_estimators': N_ESTIMATORS_REFIT, 
          'early_stopping_rounds': EARLY_STOPPING_ROUNDS_REFIT}

outputs = []
for fold in range(N_FOLD):
    outputs.append(train_model(fold, params, 'normal'))
    
cv_score = np.mean([x['best_score_'] for x in outputs])
cv_sharpe = np.mean([x['sharpe']['val'] for x in outputs])
log(f"Folds best iterations: {[x['best_iteration_'] for x in outputs]}")
log(f"Folds average num unique values in train: {[x['n_uniq_trn'] for x in outputs]}")
log(f"Folds average num unique values in validation: {[x['n_uniq_val'] for x in outputs]}")
log(f"Folds scores: {[x['best_score_'] for x in outputs]}")
log(f"Folds sharpes: {[x['sharpe']['val'] for x in outputs]}")
log(f'CV score: {cv_score}')
log(f'CV sharpe: {cv_sharpe}')

# export validation df
df_pred_val = pd.concat([x['df_pred_val'] for x in outputs]).reset_index(drop=True)
df_pred_val.to_feather('df_pred_val')
# Out:
# [2022-06-20 10:04:10] Folds best iterations: [1, 2, 9, 1, 6]
# [2022-06-20 10:04:10] Folds average num unique values in train: [1.375, 1.4583333333333333, 2.2416666666666667, 1.3208333333333333, 1.6375]
# [2022-06-20 10:04:10] Folds average num unique values in validation: [1.3666666666666667, 1.5166666666666666, 2.2333333333333334, 1.3833333333333333, 1.6333333333333333]
# [2022-06-20 10:04:10] Folds scores: [0.6929884203763502, 0.6930268121117183, 0.692267436866035, 0.6936826682552448, 0.6917450453827529]
# [2022-06-20 10:04:10] Folds sharpes: [0.26390422227987326, 0.2884076249217434, 0.09987502839807556, 0.16585660468775493, 0.32108750768203975]
# [2022-06-20 10:04:10] CV score: 0.6927420765984202
# [2022-06-20 10:04:10] CV sharpe: 0.22782619759389738

# %%
'''
Signal Analysis
'''
analyze_signal(outputs)
# Out:
# [2022-06-20 10:04:12] Average % in top 200: 0.4899666666666668
# [2022-06-20 10:04:12] Average % in bottom 200: 0.49548333333333316
# [2022-06-20 10:04:13] Mean long returns: 0.04077079848425486
# [2022-06-20 10:04:13] Mean short returns: 0.09056404361205467
# [2022-06-20 10:04:13] Mean net returns: 0.13133484209630944
# [2022-06-20 10:04:13] Sharpe of long: 0.018960426111004746
# [2022-06-20 10:04:13] Sharpe of short: 0.04108833902453044
# [2022-06-20 10:04:13] Sharpe of net: 0.2256003875638831

# %% [markdown]
# # Debug
