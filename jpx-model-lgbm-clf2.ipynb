# %% [markdown]
# # Version description
# - Ordinary features
# - drop market feats
# - Full Run

# %%
# import libraries
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
from os.path import isfile, isdir, join
import numpy as np
import pandas as pd
from datetime import datetime, date
from dateutil.relativedelta import relativedelta
import re
from IPython.display import display
from zipfile import ZipFile
import pickle
import unicodedata
import pytz
from joblib import Parallel, delayed
import shutil
import difflib
import random
import math
from shutil import copyfile
import itertools
import time
from tqdm import tqdm
import collections
from collections import deque
import gc

from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer
from sklearn.metrics import ndcg_score, accuracy_score, mean_squared_error

import lightgbm as lgbm
import optuna
from optuna import Trial, visualization

import matplotlib as mpl
from matplotlib import pyplot as plt

import jpx_tokyo_market_prediction

from utility_script import *
# from utility_script_jpx import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
'''
Notebook Parameters
'''
# basic
SEED = 0
JPX_PATH = '../input/jpx-tokyo-stock-exchange-prediction'

# data sacling
SCALER = StandardScaler()
SCALE_DAILY = False

# drop market features
DROP_MARKET_FEATS = True

# PCA
RUN_PCA = False
N_COMP = 0.9

# target definition
RANK_ASCENDING = False # set this to False if model prediction is same direction of Target
TARGET_POW = 0

# data split
N_FOLD = 5
TRN_SIZE = 240
VAL_SIZE = 60
TRN_VAL_GAP = 14
SPLIT_METHOD = 'trn_val_split_late_val'

# model fixed params
DEVICE_TYPE = 'CPU'
EVAL_METRIC = f'binary_logloss'
LGBM_VAR_PARAMS = dict(
    max_depth = 32,
    num_leaves = 32,
    learning_rate = 0.01,
    min_child_weight = 0.1,
    min_child_samples = 1,
    subsample = 0.65,
    subsample_freq = 1,
    colsample_bytree = 0.6,
    reg_alpha = 1.5,
    reg_lambda = 1.5,
    max_bin = 255,
)
LGBM_FIXED_PARAMS = dict(
    boosting_type = 'gbdt',
    objective = 'binary',
    n_estimators = 5000,
    n_jobs = -1,
    random_state = SEED,
    device_type = DEVICE_TYPE,
)

# feature importance
RUN_IMP = True
N_SHUFFLE = 12
N_FEATS_IMP_TEST = 10
N_ESTIMATORS_IMP = 50
EARLY_STOPPING_ROUNDS_IMP = 9999
FEAT_GROUPS = None # fixed output if not running IMP

# forward selection
RUN_FS = True
N_ESTIMATORS_FS = 5000
EARLY_STOPPING_ROUNDS_FS = 20
N_FEATS_FS = 20 # top N features considered for FS based on importance
N_FEATS_FINAL = None # top N features if skipping FS based on importance
SELECTED_FEATS = 'EarningToPriceRatio_raw, sharpe_3m, price_standard_dist_1m'.split(', ') # fixed features if skipping both IMP and FS

# hyperparameters tuning
RUN_HP = True
N_ESTIMATORS_HP = 5000
EARLY_STOPPING_ROUNDS_HP = 30
HP_OPT_HRS = 4
BEST_PARAMS = None

# re-fit
N_ESTIMATORS_REFIT = 5000
EARLY_STOPPING_ROUNDS_REFIT = 30

# %% [markdown]
# # Data preprocessing

# %%
'''
Train-Val split where validation periods are right after train period
'''
def trn_val_split_even_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).head(VAL_SIZE)
        else:
            dates_val = full_dates.loc[lambda x: x>=date].shift(-TRN_SIZE).shift(-TRN_VAL_GAP).loc[lambda x: x.notnull()]
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data


'''
Train-Val split where validation periods are farthest in future
'''
def trn_val_split_late_val(features, val_to_end):
    # define start date of each fold
    fold_dates = features.Date.drop_duplicates().reset_index(drop=True)
    fold_dates = fold_dates.shift(TRN_SIZE + TRN_VAL_GAP + VAL_SIZE).loc[lambda x: x.notnull()].reset_index(drop=True)
    fold_dates = fold_dates.loc[np.linspace(0, fold_dates.shape[0]-1, N_FOLD).astype(int)].reset_index(drop=True)

    # create and append train + val data
    full_dates = features.Date.drop_duplicates().reset_index(drop=True)
    val_dates_list = full_dates.tail(VAL_SIZE * N_FOLD).values.reshape(N_FOLD, -1)
    full_data = []
    for i, date in enumerate(fold_dates):
        dates_trn = full_dates.loc[lambda x: x>=date].head(TRN_SIZE)
        if val_to_end==False:
            dates_val = val_dates_list[i]
        else:
            dates_val = np.concatenate(val_dates_list[i:])
        full_data.append(features.loc[lambda x: x.Date.isin(dates_trn)].assign(fold=i, trn_val='trn'))
        full_data.append(features.loc[lambda x: x.Date.isin(dates_val)].assign(fold=i, trn_val='val'))
    full_data = pd.concat(full_data).reset_index(drop=True)
    return full_data

# %%
'''
Function to scale the features
'''
def jpx_data_scaling(full_data, scaler, daily):
    feats = time_features + stock_features
    
    if daily==False:
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[feats])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[feats] = scaler.transform(data_trn[feats]).astype(np.float32)
            data_val[feats] = scaler.transform(data_val[feats]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
            
    elif daily==True:
        # scale stock features for each day
        def transform_data(df, scaler, feats):
            df[feats] = scaler.fit_transform(df[feats]).astype(np.float32)
            return df
        full_data = full_data.groupby(['fold','trn_val','Date']).apply(lambda df: transform_data(df, scaler, stock_features))
        # then scale time features across days
        data_scaled = []
        for fold in range(N_FOLD):
            # locate train and val datasets
            data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
            data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
            # fit scaler
            scaler = scaler.fit(data_trn[time_features])
            save_pkl(scaler, f'scaler{fold}')
            # transform data
            data_trn[time_features] = scaler.transform(data_trn[time_features]).astype(np.float32)
            data_val[time_features] = scaler.transform(data_val[time_features]).astype(np.float32)
            # store transformed data
            data_scaled.append(data_trn)
            data_scaled.append(data_val)
        data_scaled = pd.concat(data_scaled).reset_index(drop=True)
        
    return data_scaled

# %%
'''
PCA Compression
'''
def pca_compress(full_data):
    # fit with one fold of traiing data
    pca = PCA(n_components=N_COMP, random_state=SEED)
    pca.fit(full_data.loc[lambda x: (x.fold==0) & (x.trn_val=='trn'), all_features])
    log(f'PCA shape of components: {pca.components_.shape}')
    
    # tranform the full dataset
    cols = [f'pc{x}' for x in range(pca.components_.shape[0])]
    compressed_data = []
    for fold in range(N_FOLD):
        for trn_val in ['trn','val']:
            X = pd.DataFrame(pca.transform(full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), all_features]), columns=cols)
            header = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val==trn_val), [c for c in full_data.columns if c not in all_features]].reset_index(drop=True)
            new_df = pd.concat([header, X], axis=1)
            compressed_data.append(new_df)
    compressed_data = pd.concat(compressed_data, axis=0).reset_index(drop=True)
    return compressed_data, cols

# %% [markdown]
# # Model Training Functions

# %%
'''
Function to get sub-columns from table for model fitting
'''
def get_dataset(df, selected_feats, trn_val):
    if trn_val=='val':
        df = df.groupby('Date').sample(frac=1.0, random_state=SEED)
    df = df.reset_index(drop=True)
    grp = df.groupby('Date').size().tolist()
    qid = df['Date']
    X = df[selected_feats]
    y = df['target_train']
    target = df['Target']
    header = df[id_cols]
    return X, y, grp, qid, header, target

'''
Function to predict scores within groups
'''
def pred_score(model, X):
    return pd.Series(model.predict_proba(X)[:,1])

'''
Function to predict rankings within groups
'''
def pred_rank(model, X, qid):
    X_ = X.assign(Date=qid)
    rnk = []
    for date in X_.Date.unique():
        rnk += pd.Series(model.predict_proba(X_.loc[lambda x: x.Date==date].drop('Date',axis=1))[:,1]).rank(method='first').tolist()
    return pd.Series(rnk)

'''
Function to transform model output to rank prediction table
'''
def get_pred_df(header, pred_model, y_true_train, y_true, rank_ascending):
    df_pred = pd.concat([header[['RowId','Date','SecuritiesCode']].assign(Date=lambda x: x.Date.dt.strftime('%Y-%m-%d'), SecuritiesCode=lambda x: x.SecuritiesCode.astype(int)).reset_index(drop=True),
                        pd.Series(pred_model).rename('pred_model').reset_index(drop=True),
                        y_true_train.reset_index(drop=True),
                        y_true.reset_index(drop=True)
                        ], axis=1)
    df_pred['Rank'] = df_pred.groupby('Date').pred_model.rank(method='first', ascending=rank_ascending).astype(int) - 1
    return df_pred

'''
Official function to calculate Sharpe Ratio given a prediction
'''
def _calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def my_calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return pd.DataFrame({'long':[purchase],'short':[short],'net':[purchase - short]})

def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    buf = df.groupby('Date').apply(_calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio

# %%
'''
Training function
'''
def train_model(fold, params, mode):
    # unpack model params
    selected_feats = params['selected_feats']
    lgbm_var_params = params['lgbm_var_params']
    lgbm_fixed_params = params['lgbm_fixed_params']
    lgbm_fixed_params['n_estimators'] = params['n_estimators']
    early_stopping_rounds = params['early_stopping_rounds']
    
    # define dataset
    data_trn = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='trn')]
    data_val = full_data.loc[lambda x: (x.fold==fold) & (x.trn_val=='val')]
    X_trn, y_trn, grp_trn, qid_trn, header_trn, target_trn = get_dataset(data_trn, selected_feats, 'trn')
    X_val, y_val, grp_val, qid_val, header_val, target_val = get_dataset(data_val, selected_feats, 'val')
    # model fit
    model = lgbm.LGBMClassifier(**lgbm_fixed_params, **lgbm_var_params)
    model.fit(
        X = X_trn,
        y = y_trn,
        eval_set = [(X_val, y_val)],
        eval_names = ['Validation'],
        verbose = False,
        eval_metric = EVAL_METRIC,
        early_stopping_rounds = early_stopping_rounds
    )

    # output
    if mode == 'val_score_only':
        output = model.best_score_['Validation'][EVAL_METRIC] # this score is for minimization problem
        
    if mode == 'val_sharpe_only':
        pred_val = pred_score(model, X_val)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        output = sharpe_val * -1 # this score is for minimization problem
        
    if mode == 'feat_imp':
        model.set_params(importance_type='gain')
        imp_gain = model.feature_importances_
        model.set_params(importance_type='split')
        imp_split = model.feature_importances_
        output = pd.concat([
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_gain}).assign(imp_type='gain', imp=lambda x: x.imp.rank()),
            pd.DataFrame({'feat':model.feature_name_, 'imp':imp_split}).assign(imp_type='split', imp=lambda x: x.imp.rank())
        ], axis=0).assign(fold=fold)
    
    if mode == 'normal':
        # save model
        save_pkl(model, f"model{fold}")
        # number of distinct predicted values
        n_uniq_trn = pd.concat([pred_score(model, X_trn).rename('score'), header_trn], axis=1).groupby('Date').score.nunique().mean()
        n_uniq_val = pd.concat([pred_score(model, X_val).rename('score'), header_val], axis=1).groupby('Date').score.nunique().mean()
        # prediction
        pred_trn = pred_score(model, X_trn)
        pred_val = pred_score(model, X_val)
        # prediction df
        df_pred_trn = get_pred_df(header_trn, pred_trn, y_trn, target_trn, RANK_ASCENDING)
        df_pred_val = get_pred_df(header_val, pred_val, y_val, target_val, RANK_ASCENDING)
        # sharpe
        sharpe_trn = calc_spread_return_sharpe(df_pred_trn)
        sharpe_val = calc_spread_return_sharpe(df_pred_val)
        # output dict
        output = dict(
            fold = fold,
            params = params,
            best_iteration_ = model.best_iteration_,
            best_score_ = model.best_score_['Validation'][EVAL_METRIC],
            sharpe = {'trn': sharpe_trn, 'val': sharpe_val},
            ann_sharpe = {'trn': sharpe_trn * np.sqrt(240), 'val': sharpe_val * np.sqrt(240)},
            evals_result_ = model.evals_result_['Validation'][EVAL_METRIC],
            feat_imp = pd.DataFrame(list(zip(model.feature_name_, model.feature_importances_)), columns=['feat','imp']),
            df_pred_val = df_pred_val,
            n_uniq_trn = n_uniq_trn,
            n_uniq_val = n_uniq_val,
        )
    return output

# %% [markdown]
# # Feature Importance

# %%
def run_feature_importance():
    # random sampling of features
    all_feats = all_features.copy()
    feat_groups = []
    for i in range(N_SHUFFLE):
        random.shuffle(all_feats)
        n_groups = math.floor(len(all_feats)/N_FEATS_IMP_TEST)
        feat_groups += np.array(all_feats[:N_FEATS_IMP_TEST*n_groups]).reshape(-1,N_FEATS_IMP_TEST).tolist()
    log(f'Total number of run: {len(feat_groups)}')
    
    # calculate feature importance
    df_imp = []
    for i, group in enumerate(feat_groups):
        for fold in range(N_FOLD):
            params = {'selected_feats': group, 
                      'lgbm_var_params': LGBM_VAR_PARAMS,
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_IMP,
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_IMP}
            df_imp.append(train_model(fold, params, 'feat_imp'))
        log(f'Completed running feature group {i}') if i%10==0 else None
    df_imp = pd.concat(df_imp)
    df_imp_agg = df_imp.groupby('feat').imp.mean().sort_values(ascending=False).reset_index()
    df_imp_agg.to_csv('df_imp_agg.csv', index=False)
    display(df_imp_agg.head(10))

    # plotting feature importance
    df_imp_agg.sort_values('imp', ascending=True).set_index('feat').plot.barh(figsize=(20, 20))
    
    # prepare feature list for forward selection
    feat_groups = df_imp_agg.head(N_FEATS_FS)
    feat_groups = [[x] for x in feat_groups.feat]
    return feat_groups

# %% [markdown]
# # Forward Selection

# %%
'''
Forward Selection function
'''
def forward_selection(feat_groups):
    base_feats = []
    hist = []
    while len(feat_groups) > 0:
        scores = []
        for feats in feat_groups:
            # calculate CV score
            params = {'selected_feats': base_feats + feats, 
                      'lgbm_var_params': LGBM_VAR_PARAMS, 
                      'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
                      'n_estimators': N_ESTIMATORS_FS, 
                      'early_stopping_rounds': EARLY_STOPPING_ROUNDS_FS}
            mean_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
            scores.append(mean_score)
            hist.append((mean_score,
                         len(base_feats + feats),
                         ', '.join(base_feats + feats)
                         ))
            log(f'Score: {mean_score}; Num features: {len(base_feats + feats)}; Features: {", ".join(base_feats + feats)}')
        # add the new feature (group) which gives minimum score
        base_feats += feat_groups[np.argmin(scores)]
        # remove the added feature (group) from remaining candidate pool
        del feat_groups[np.argmin(scores)]
    hist = pd.DataFrame(hist, columns=['score','len_feats','total_feats'])
    hist.to_csv('fs_hist.csv', index=False)
    return hist

# %% [markdown]
# # Hyperparameter Tuning

# %%
'''
Hyperparameter Optimization function
'''
def Objective(trial):
    lgbm_var_params = dict(
        max_depth = trial.suggest_int('max_depth', 2, 32, log=True),
        num_leaves = trial.suggest_int('num_leaves', 16, 64, log=True),
        learning_rate = trial.suggest_float("learning_rate", 0.005, 0.2),
        min_child_weight = trial.suggest_float("min_child_weight", 1e-3, 4, log=True),
        subsample = trial.suggest_float("subsample", 0.5, 1),
        subsample_freq = trial.suggest_categorical("subsample_freq", [1,2,4,6,8]),
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1),
        reg_alpha = trial.suggest_float("reg_alpha", 1e-2, 16, log=True),
        reg_lambda = trial.suggest_float("reg_lambda", 1e-2, 16, log=True),
        max_bin = trial.suggest_int('max_bin', 50, 500),
    )
    
    # pack all params
    params = {'selected_feats': selected_feats, 
              'lgbm_var_params': lgbm_var_params, 
              'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
              'n_estimators': N_ESTIMATORS_HP, 
              'early_stopping_rounds': EARLY_STOPPING_ROUNDS_HP}
    # return average CV score
    cv_score = np.mean([train_model(fold, params, 'val_sharpe_only') for fold in range(N_FOLD)])
    return cv_score


def optimize_hp():
    # run optimization
    study = optuna.create_study(direction="minimize", study_name='LGBM optimization')
    study.optimize(Objective, timeout=HP_OPT_HRS*60*60)
    
    # save results
    best_params = study.best_params
    best_score = study.best_value
    log(best_params)
    log(f'Best score is {best_score}')
    trials = study.trials_dataframe()
    trials.to_csv(f'trials.csv', index=False)
    save_pkl(best_params, f'best_params')
    save_pkl(study, f'study')
    
    # visualise relationship between parameter and CV score
    for c in trials.columns:
        if c[:7]=='params_':
            new_plot()
            trials.plot.scatter(c, 'value')
            plt.grid()
            plt.title(c)
            plt.show()
    return best_params

# %% [markdown]
# # Signal Analysis

# %%
def analyze_signal(outputs):
    df = pd.concat([x['df_pred_val'] for x in outputs])
    df.Date = pd.to_datetime(df.Date)
    df['rank_pred'] = df.groupby('Date').pred_model.rank(method='first',ascending=False)
    df['rank_true'] = df.groupby('Date').target_train.rank(method='first',ascending=True)

    # distribution of model prediction
    new_plot()
    df.pred_model.hist(bins=100)
    plt.grid()
    plt.title('Distribution of model prediction')

    # percentage in correct region
    new_plot()
    n = 200
    top = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true>=2000-n) & (x.rank_pred>=2000-n)].shape[0]).divide(n)
    bottom = df.groupby('Date').apply(lambda df: df.loc[lambda x: (x.rank_true<=n) & (x.rank_pred<=n)].shape[0]).divide(n)
    top.rolling(20).mean().plot(label='top')
    bottom.rolling(20).mean().plot(label='bottom')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('% in correct region')
    log(f'Average % in top 200: {top.mean()}')
    log(f'Average % in bottom 200: {bottom.mean()}')

    # portfolio return analysis
    ret = df.groupby('Date').apply(my_calc_spread_return_per_day, 200, 2)
    ret = ret.reset_index().set_index('Date') \
        .assign(short = lambda x: -1 * x.short)

    # cumulative returns
    new_plot()
    ret.long.cumsum().plot(label='long')
    ret.short.cumsum().plot(label='short')
    ret.net.cumsum().plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Cumulative Returns')
    log(f'Mean long returns: {ret.long.mean()}')
    log(f'Mean short returns: {ret.short.mean()}')
    log(f'Mean net returns: {ret.net.mean()}')

    # rolling sharpes
    new_plot()
    ret.long.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='long')
    ret.short.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='short')
    ret.net.rolling(60).apply(lambda s: s.mean()/s.std()).plot(label='net')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.grid()
    plt.title('Rolling Sharpes')
    log(f'Sharpe of long: {ret.long.mean() / ret.long.std()}')
    log(f'Sharpe of short: {ret.short.mean() / ret.short.std()}')
    log(f'Sharpe of net: {ret.net.mean() / ret.net.std()}')

# %% [markdown]
# # Execution

# %%
# %%time
'''
Preprocessing
'''
# load features
path = '../input/jpx-feature-engineering/features'
features = pd.concat([pd.concat(load_pkl(f'{path}/{filename}')) for filename in os.listdir(path)]).sort_values('RowId').reset_index(drop=True)

# train-val split
if SPLIT_METHOD == 'trn_val_split_late_val':
    full_data = trn_val_split_late_val(features, val_to_end=False)
elif SPLIT_METHOD == 'trn_val_split_even_val':
    full_data = trn_val_split_even_val(features, val_to_end=False)
display(full_data.groupby(['fold','trn_val']).agg({'Date':['min','max','nunique']}))

# add targets
targets = pd.concat([pd.read_csv(f'{JPX_PATH}/{folder}/stock_prices.csv', parse_dates=['Date']) for folder in ['train_files', 'supplemental_files']]) \
    .loc[:,['RowId','Target']] \
    .loc[lambda x: x.Target.notnull()] \
    .drop_duplicates() \
    .reset_index(drop=True)
full_data = full_data.merge(targets, how='inner', on='RowId')

# remove irregular data
full_data = full_data.loc[lambda x: x.volatility_1w!=0].reset_index(drop=True)

# derive training target
full_data['target_train'] = full_data.groupby(['fold','trn_val','Date']).Target.apply(lambda s: (s >= s.quantile(0.5)).astype(int))

# release memory
del features
gc.collect()

# define column types
id_cols = ['RowId','Date','SecuritiesCode','fold','trn_val']
all_features = [c for c in list(full_data) if c not in id_cols and c not in ['target_train','Target']]
cat_features = ['AdjustmentFactor','first_div']
time_features = [c for c in all_features if '_mkt' in c] + \
                [c for c in all_features if c[:4]=='sec_'] + \
                [c for c in all_features if c[-4:] in ['_sin','_cos']]
stock_features = [c for c in all_features if c not in cat_features + time_features]

# scaling
full_data = jpx_data_scaling(full_data=full_data, scaler=SCALER, daily=SCALE_DAILY)

# drop market features
if DROP_MARKET_FEATS:
    full_data = full_data.drop(time_features, axis=1)
    all_features = [c for c in all_features if c not in time_features]

# PCA compression
if RUN_PCA:
    full_data, all_features = pca_compress(full_data)
# Out:
#                    Date
#                     min        max nunique
# fold trn_val
# 0    trn     2019-01-16 2020-01-14     240
#      val     2021-03-05 2021-06-02      60
# 1    trn     2019-07-23 2020-07-16     240
#      val     2021-06-03 2021-08-30      60
# 2    trn     2020-01-30 2021-01-22     240
#      val     2021-08-31 2021-11-26      60
# 3    trn     2020-08-06 2021-07-29     240
#      val     2021-11-29 2022-02-25      60
# 4    trn     2021-02-10 2022-02-02     240
#      val     2022-02-28 2022-05-27      60
# CPU times: user 39.1 s, sys: 6.61 s, total: 45.7 s
# Wall time: 51.4 s

# %%
# %%time
'''
Feature importance
'''
if RUN_IMP:
    feat_groups = run_feature_importance()
else:
    # if not running feature importance, use pre-set FEAT_GROUPS for forward selection
    feat_groups = FEAT_GROUPS
# Out:
# [2022-06-19 01:31:15] Total number of run: 60
# [2022-06-19 01:31:29] Completed running feature group 0
# [2022-06-19 01:34:04] Completed running feature group 10
# [2022-06-19 01:36:39] Completed running feature group 20
# [2022-06-19 01:39:16] Completed running feature group 30
# [2022-06-19 01:41:48] Completed running feature group 40
# [2022-06-19 01:44:18] Completed running feature group 50
#                       feat       imp
# 0      days_since_last_div  9.990909
# 1      days_since_last_fin  8.633333
# 2      price_ma_pctg_ch_3d  8.600000
# 3      price_ma_pctg_ch_1w  8.527778
# 4                      ret  8.268182
# 5            volatility_3m  8.204167
# 6            volatility_1m  7.950000
# 7                 exret_1w  7.720000
# 8              RS_sqrt_vol  7.640000
# 9  EarningToPriceRatio_raw  7.461111
# CPU times: user 41min 28s, sys: 5.92 s, total: 41min 34s
# Wall time: 15min 22s

# %%
# %%time
'''
Forward Selection
'''
if RUN_FS:
    # run FS
    fs_hist = forward_selection(feat_groups)
    display(fs_hist.sort_values('score', ascending=True).head(1))
    # output selected features
    selected_feats = fs_hist.sort_values('score', ascending=True).total_feats.iloc[0].split(', ')

else:
    # if not running both IMP and FS, output pre-set selected_feats
    if not RUN_IMP:
        selected_feats = SELECTED_FEATS
    # if ran IMP but not FS, output first N important features where N is pre-set
    elif RUN_IMP:
        selected_feats = [x[0] for x in feat_groups][:N_FEATS_FINAL]
# Out:
# [2022-06-19 01:47:02] Score: -0.09664034878494401; Num features: 1; Features: days_since_last_div
# [2022-06-19 01:47:21] Score: -0.039065513153524814; Num features: 1; Features: days_since_last_fin
# [2022-06-19 01:47:37] Score: 0.0917556328529915; Num features: 1; Features: price_ma_pctg_ch_3d
# [2022-06-19 01:47:56] Score: 0.07556297426110808; Num features: 1; Features: price_ma_pctg_ch_1w
# [2022-06-19 01:48:13] Score: 0.15908039354651002; Num features: 1; Features: ret
# [2022-06-19 01:48:41] Score: 0.020417720469944306; Num features: 1; Features: volatility_3m
# [2022-06-19 01:49:12] Score: -0.009574330656859177; Num features: 1; Features: volatility_1m
# [2022-06-19 01:49:35] Score: 0.030267248553262405; Num features: 1; Features: exret_1w
# [2022-06-19 01:50:03] Score: -0.00032182904795066935; Num features: 1; Features: RS_sqrt_vol
# [2022-06-19 01:50:27] Score: -0.09729767547008156; Num features: 1; Features: EarningToPriceRatio_raw
# [2022-06-19 01:50:45] Score: -0.04579772445891609; Num features: 1; Features: price_standard_dist_12m
# [2022-06-19 01:51:06] Score: 0.04707750175586092; Num features: 1; Features: exret_3d
# [2022-06-19 01:51:34] Score: -0.019906954112004747; Num features: 1; Features: volatility_12m
# [2022-06-19 01:52:03] Score: 0.06241595184626434; Num features: 1; Features: volatility_1w
# [2022-06-19 01:52:28] Score: -0.018065696549152445; Num features: 1; Features: exret_1m
# [2022-06-19 01:52:51] Score: -0.06596424058107522; Num features: 1; Features: ProfitoMarketRatio_raw
# [2022-06-19 01:53:08] Score: -0.05830569024559018; Num features: 1; Features: price_standard_dist_6m
# [2022-06-19 01:53:37] Score: -0.06399176217074438; Num features: 1; Features: BookToMarketRatio_raw
# [2022-06-19 01:53:55] Score: -0.03650017200549605; Num features: 1; Features: ForecastOperatingProfit_pctg
# [2022-06-19 01:54:17] Score: 0.01811711737697546; Num features: 1; Features: exret_3m
# [2022-06-19 01:54:50] Score: -0.16335786077821343; Num features: 2; Features: EarningToPriceRatio_raw, days_since_last_div
# [2022-06-19 01:55:15] Score: -0.10355680642002488; Num features: 2; Features: EarningToPriceRatio_raw, days_since_last_fin
# [2022-06-19 01:55:39] Score: 0.031722782091988075; Num features: 2; Features: EarningToPriceRatio_raw, price_ma_pctg_ch_3d
# [2022-06-19 01:56:05] Score: 0.003032236420637613; Num features: 2; Features: EarningToPriceRatio_raw, price_ma_pctg_ch_1w
# [2022-06-19 01:56:28] Score: 0.06197756012783776; Num features: 2; Features: EarningToPriceRatio_raw, ret
# [2022-06-19 01:57:04] Score: -0.007142603106915832; Num features: 2; Features: EarningToPriceRatio_raw, volatility_3m
# [2022-06-19 01:57:39] Score: -0.035943302949798826; Num features: 2; Features: EarningToPriceRatio_raw, volatility_1m
# [2022-06-19 01:58:09] Score: -0.010024175725077872; Num features: 2; Features: EarningToPriceRatio_raw, exret_1w
# [2022-06-19 01:58:46] Score: -0.0357001068365671; Num features: 2; Features: EarningToPriceRatio_raw, RS_sqrt_vol
# [2022-06-19 01:59:11] Score: -0.10350408696836026; Num features: 2; Features: EarningToPriceRatio_raw, price_standard_dist_12m
# [2022-06-19 01:59:38] Score: -0.008878842467880474; Num features: 2; Features: EarningToPriceRatio_raw, exret_3d
# [2022-06-19 02:00:15] Score: -0.06862096111805875; Num features: 2; Features: EarningToPriceRatio_raw, volatility_12m
# [2022-06-19 02:00:53] Score: -0.022667552364776588; Num features: 2; Features: EarningToPriceRatio_raw, volatility_1w
# [2022-06-19 02:01:25] Score: -0.06275241859581553; Num features: 2; Features: EarningToPriceRatio_raw, exret_1m
# [2022-06-19 02:01:50] Score: -0.08880615494924031; Num features: 2; Features: EarningToPriceRatio_raw, ProfitoMarketRatio_raw
# [2022-06-19 02:02:16] Score: -0.13170838971672066; Num features: 2; Features: EarningToPriceRatio_raw, price_standard_dist_6m
# [2022-06-19 02:02:50] Score: -0.07334934415709873; Num features: 2; Features: EarningToPriceRatio_raw, BookToMarketRatio_raw
# [2022-06-19 02:03:17] Score: -0.13224279378036868; Num features: 2; Features: EarningToPriceRatio_raw, ForecastOperatingProfit_pctg
# [2022-06-19 02:03:46] Score: -0.07582715493312156; Num features: 2; Features: EarningToPriceRatio_raw, exret_3m
# [2022-06-19 02:04:14] Score: -0.19200216715227372; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, days_since_last_fin
# [2022-06-19 02:04:41] Score: -0.09119791830778291; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, price_ma_pctg_ch_3d
# [2022-06-19 02:05:13] Score: -0.09221572511578364; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, price_ma_pctg_ch_1w
# [2022-06-19 02:05:40] Score: -0.08716423443953543; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, ret
# [2022-06-19 02:06:16] Score: -0.09439680813766745; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, volatility_3m
# [2022-06-19 02:06:56] Score: -0.0930301530282832; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, volatility_1m
# [2022-06-19 02:07:28] Score: -0.11512060309666908; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, exret_1w
# [2022-06-19 02:08:03] Score: -0.11575245603104771; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, RS_sqrt_vol
# [2022-06-19 02:08:33] Score: -0.2073006688431181; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, price_standard_dist_12m
# [2022-06-19 02:09:05] Score: -0.08478474913427925; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, exret_3d
# [2022-06-19 02:09:41] Score: -0.13486498600907515; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, volatility_12m
# [2022-06-19 02:10:14] Score: -0.12343647657128942; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, volatility_1w
# [2022-06-19 02:10:48] Score: -0.1114826840732287; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, exret_1m
# [2022-06-19 02:11:20] Score: -0.18785024377739198; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, ProfitoMarketRatio_raw
# [2022-06-19 02:11:50] Score: -0.20175499312927006; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, price_standard_dist_6m
# [2022-06-19 02:12:29] Score: -0.18919690575854894; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, BookToMarketRatio_raw
# [2022-06-19 02:13:01] Score: -0.22983011837030137; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg
# [2022-06-19 02:13:31] Score: -0.15274490984592087; Num features: 3; Features: EarningToPriceRatio_raw, days_since_last_div, exret_3m
# [2022-06-19 02:14:03] Score: -0.1559597679627101; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, days_since_last_fin
# [2022-06-19 02:14:37] Score: -0.07204503798878234; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_ma_pctg_ch_3d
# [2022-06-19 02:15:06] Score: -0.07668141064383599; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_ma_pctg_ch_1w
# [2022-06-19 02:15:39] Score: -0.07495536644187173; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, ret
# [2022-06-19 02:16:14] Score: -0.07244734404121586; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, volatility_3m
# [2022-06-19 02:16:49] Score: -0.06358278718528643; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, volatility_1m
# [2022-06-19 02:17:26] Score: -0.09407153533165666; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, exret_1w
# [2022-06-19 02:17:59] Score: -0.06080364251998118; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, RS_sqrt_vol
# [2022-06-19 02:18:35] Score: -0.18106107583771863; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_12m
# [2022-06-19 02:19:11] Score: -0.07699943023893781; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, exret_3d
# [2022-06-19 02:19:43] Score: -0.09197376484612098; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, volatility_12m
# [2022-06-19 02:20:15] Score: -0.07159420293032086; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, volatility_1w
# [2022-06-19 02:20:52] Score: -0.1465668903769068; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, exret_1m
# [2022-06-19 02:21:24] Score: -0.1540561486108265; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, ProfitoMarketRatio_raw
# [2022-06-19 02:22:00] Score: -0.20190030236074402; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m
# [2022-06-19 02:22:31] Score: -0.13106839529503905; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, BookToMarketRatio_raw
# [2022-06-19 02:23:08] Score: -0.14950408133830553; Num features: 4; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, exret_3m
# [2022-06-19 02:23:43] Score: -0.19151809945316225; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, days_since_last_fin
# [2022-06-19 02:24:16] Score: -0.10509992636960033; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_ma_pctg_ch_3d
# [2022-06-19 02:24:48] Score: -0.1031739098953155; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_ma_pctg_ch_1w
# [2022-06-19 02:25:24] Score: -0.07471179029007677; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, ret
# [2022-06-19 02:26:03] Score: -0.09809294743313535; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, volatility_3m
# [2022-06-19 02:26:41] Score: -0.0974907017657967; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, volatility_1m
# [2022-06-19 02:27:17] Score: -0.17967494025750422; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, exret_1w
# [2022-06-19 02:27:52] Score: -0.11659150468131826; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, RS_sqrt_vol
# [2022-06-19 02:28:31] Score: -0.25226507355100064; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m
# [2022-06-19 02:29:07] Score: -0.15014428052902115; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, exret_3d
# [2022-06-19 02:29:37] Score: -0.10149471471988211; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, volatility_12m
# [2022-06-19 02:30:13] Score: -0.1169207636093437; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, volatility_1w
# [2022-06-19 02:30:53] Score: -0.21242650268765867; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, exret_1m
# [2022-06-19 02:31:26] Score: -0.18935875206216282; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, ProfitoMarketRatio_raw
# [2022-06-19 02:32:00] Score: -0.1622107496182339; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, BookToMarketRatio_raw
# [2022-06-19 02:32:40] Score: -0.21765049729128857; Num features: 5; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, exret_3m
# [2022-06-19 02:33:18] Score: -0.24067004095412914; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, days_since_last_fin
# [2022-06-19 02:33:54] Score: -0.10132852124669463; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, price_ma_pctg_ch_3d
# [2022-06-19 02:34:30] Score: -0.10722421076425923; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, price_ma_pctg_ch_1w
# [2022-06-19 02:35:04] Score: -0.12391920559753848; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ret
# [2022-06-19 02:35:43] Score: -0.10649655930965603; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, volatility_3m
# [2022-06-19 02:36:19] Score: -0.08890777436870625; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, volatility_1m
# [2022-06-19 02:37:01] Score: -0.2175486568142798; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, exret_1w
# [2022-06-19 02:37:41] Score: -0.14167122237417962; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, RS_sqrt_vol
# [2022-06-19 02:38:25] Score: -0.14658991013071831; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, exret_3d
# [2022-06-19 02:39:03] Score: -0.13436254571865652; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, volatility_12m
# [2022-06-19 02:39:43] Score: -0.15219547722934398; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, volatility_1w
# [2022-06-19 02:40:27] Score: -0.20309869358294969; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, exret_1m
# [2022-06-19 02:41:01] Score: -0.24843329206535056; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw
# [2022-06-19 02:41:33] Score: -0.1949343436653615; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, BookToMarketRatio_raw
# [2022-06-19 02:42:17] Score: -0.22052066086102623; Num features: 6; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, exret_3m
# [2022-06-19 02:42:51] Score: -0.1712195862571924; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, days_since_last_fin
# [2022-06-19 02:43:30] Score: -0.0956513040293753; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, price_ma_pctg_ch_3d
# [2022-06-19 02:44:07] Score: -0.11555704833392082; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, price_ma_pctg_ch_1w
# [2022-06-19 02:44:39] Score: -0.10136118930354188; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, ret
# [2022-06-19 02:45:22] Score: -0.10535219820355782; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, volatility_3m
# [2022-06-19 02:46:00] Score: -0.09336991393619873; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, volatility_1m
# [2022-06-19 02:46:42] Score: -0.18279903063718397; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w
# [2022-06-19 02:47:21] Score: -0.11362079890737639; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, RS_sqrt_vol
# [2022-06-19 02:47:58] Score: -0.13556376482920562; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_3d
# [2022-06-19 02:48:33] Score: -0.13890230003286114; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, volatility_12m
# [2022-06-19 02:49:13] Score: -0.12708953314636168; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, volatility_1w
# [2022-06-19 02:49:59] Score: -0.15528290295236452; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1m
# [2022-06-19 02:50:33] Score: -0.15592595783204627; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, BookToMarketRatio_raw
# [2022-06-19 02:51:10] Score: -0.17999069711816068; Num features: 7; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_3m
# [2022-06-19 02:51:52] Score: -0.14057736721091096; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, days_since_last_fin
# [2022-06-19 02:52:29] Score: -0.07831022411253521; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, price_ma_pctg_ch_3d
# [2022-06-19 02:53:07] Score: -0.09829443306165735; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, price_ma_pctg_ch_1w
# [2022-06-19 02:53:46] Score: -0.10915727301245895; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, ret
# [2022-06-19 02:54:27] Score: -0.10393224421655393; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, volatility_3m
# [2022-06-19 02:55:10] Score: -0.08940207848326034; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, volatility_1m
# [2022-06-19 02:55:53] Score: -0.09912024803418742; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, RS_sqrt_vol
# [2022-06-19 02:56:39] Score: -0.08658057046199553; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, exret_3d
# [2022-06-19 02:57:18] Score: -0.10273688535026944; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, volatility_12m
# [2022-06-19 02:57:57] Score: -0.10294353700249839; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, volatility_1w
# [2022-06-19 02:58:45] Score: -0.15008970151614692; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, exret_1m
# [2022-06-19 02:59:24] Score: -0.15622909609628086; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw
# [2022-06-19 03:00:06] Score: -0.15283757194026956; Num features: 8; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, exret_3m
# [2022-06-19 03:00:49] Score: -0.14649944529063988; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, days_since_last_fin
# [2022-06-19 03:01:33] Score: -0.09380806970412678; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, price_ma_pctg_ch_3d
# [2022-06-19 03:02:14] Score: -0.12184606016418478; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, price_ma_pctg_ch_1w
# [2022-06-19 03:02:56] Score: -0.11564625891650233; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, ret
# [2022-06-19 03:03:37] Score: -0.11169605734248234; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, volatility_3m
# [2022-06-19 03:04:18] Score: -0.07860267238552818; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, volatility_1m
# [2022-06-19 03:05:04] Score: -0.11817046495937393; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, RS_sqrt_vol
# [2022-06-19 03:05:45] Score: -0.13209379944080055; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3d
# [2022-06-19 03:06:26] Score: -0.11376890212241367; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, volatility_12m
# [2022-06-19 03:07:07] Score: -0.10895374821506743; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, volatility_1w
# [2022-06-19 03:07:54] Score: -0.14541183771908414; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_1m
# [2022-06-19 03:08:41] Score: -0.14897746704837775; Num features: 9; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m
# [2022-06-19 03:09:24] Score: -0.1311710704235408; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin
# [2022-06-19 03:10:07] Score: -0.07921069745226059; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, price_ma_pctg_ch_3d
# [2022-06-19 03:10:48] Score: -0.10583801964268344; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, price_ma_pctg_ch_1w
# [2022-06-19 03:11:34] Score: -0.09145071925187402; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, ret
# [2022-06-19 03:12:16] Score: -0.10121432452031875; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, volatility_3m
# [2022-06-19 03:12:58] Score: -0.08312880122481324; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, volatility_1m
# [2022-06-19 03:13:42] Score: -0.10816492742005342; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, RS_sqrt_vol
# [2022-06-19 03:14:22] Score: -0.11515083639448745; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, exret_3d
# [2022-06-19 03:15:06] Score: -0.09562260232635722; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, volatility_12m
# [2022-06-19 03:15:50] Score: -0.09607808945372527; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, volatility_1w
# [2022-06-19 03:16:34] Score: -0.1184841797352679; Num features: 10; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, exret_1m
# [2022-06-19 03:17:17] Score: -0.08169790014227973; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, price_ma_pctg_ch_3d
# [2022-06-19 03:18:02] Score: -0.10957432150345352; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, price_ma_pctg_ch_1w
# [2022-06-19 03:18:48] Score: -0.07781298295856695; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, ret
# [2022-06-19 03:19:30] Score: -0.09489383236309354; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, volatility_3m
# [2022-06-19 03:20:12] Score: -0.07828108602880997; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, volatility_1m
# [2022-06-19 03:20:59] Score: -0.11387031107525783; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, RS_sqrt_vol
# [2022-06-19 03:21:39] Score: -0.1011584732930098; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_3d
# [2022-06-19 03:22:19] Score: -0.08959211629085484; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, volatility_12m
# [2022-06-19 03:23:07] Score: -0.10786376109246194; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, volatility_1w
# [2022-06-19 03:23:51] Score: -0.12750361426427445; Num features: 11; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m
# [2022-06-19 03:24:32] Score: -0.09380589825394867; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, price_ma_pctg_ch_3d
# [2022-06-19 03:25:18] Score: -0.11147678536706665; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, price_ma_pctg_ch_1w
# [2022-06-19 03:26:03] Score: -0.10161250367676103; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, ret
# [2022-06-19 03:26:47] Score: -0.10393384970475021; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, volatility_3m
# [2022-06-19 03:27:32] Score: -0.0808698950884416; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, volatility_1m
# [2022-06-19 03:28:19] Score: -0.10487560213965416; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, RS_sqrt_vol
# [2022-06-19 03:29:05] Score: -0.12318786888237214; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d
# [2022-06-19 03:29:47] Score: -0.0955096505455004; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, volatility_12m
# [2022-06-19 03:30:31] Score: -0.10408688007903774; Num features: 12; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, volatility_1w
# [2022-06-19 03:31:20] Score: -0.09339253571887854; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_3d
# [2022-06-19 03:32:08] Score: -0.12155887839895936; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w
# [2022-06-19 03:33:01] Score: -0.10778419670667712; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, ret
# [2022-06-19 03:33:43] Score: -0.098337833572093; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, volatility_3m
# [2022-06-19 03:34:22] Score: -0.07389313017095933; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, volatility_1m
# [2022-06-19 03:35:09] Score: -0.10576947896137356; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, RS_sqrt_vol
# [2022-06-19 03:35:53] Score: -0.10552071422073991; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, volatility_12m
# [2022-06-19 03:36:36] Score: -0.07080141874046496; Num features: 13; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, volatility_1w
# [2022-06-19 03:37:22] Score: -0.09402507342794546; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, price_ma_pctg_ch_3d
# [2022-06-19 03:38:06] Score: -0.11058881649524706; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, ret
# [2022-06-19 03:38:52] Score: -0.10078631795552037; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, volatility_3m
# [2022-06-19 03:39:40] Score: -0.0879138159706216; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, volatility_1m
# [2022-06-19 03:40:32] Score: -0.11814627244427112; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol
# [2022-06-19 03:41:19] Score: -0.10974376333153153; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, volatility_12m
# [2022-06-19 03:42:10] Score: -0.10308514127724444; Num features: 14; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, volatility_1w
# [2022-06-19 03:43:00] Score: -0.07971433809519685; Num features: 15; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, price_ma_pctg_ch_3d
# [2022-06-19 03:43:45] Score: -0.06544001180728924; Num features: 15; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, ret
# [2022-06-19 03:44:37] Score: -0.09742706534246348; Num features: 15; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_3m
# [2022-06-19 03:45:21] Score: -0.0874701757462881; Num features: 15; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_1m
# [2022-06-19 03:46:08] Score: -0.09764269430016419; Num features: 15; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m
# [2022-06-19 03:46:57] Score: -0.0807156163348978; Num features: 15; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_1w
# [2022-06-19 03:47:44] Score: -0.0942533058662514; Num features: 16; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, price_ma_pctg_ch_3d
# [2022-06-19 03:48:31] Score: -0.08860676803609732; Num features: 16; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, ret
# [2022-06-19 03:49:15] Score: -0.103509686928613; Num features: 16; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m
# [2022-06-19 03:50:02] Score: -0.08965410178613763; Num features: 16; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_1m
# [2022-06-19 03:50:48] Score: -0.0999647383289722; Num features: 16; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_1w
# [2022-06-19 03:51:44] Score: -0.09997927790470157; Num features: 17; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d
# [2022-06-19 03:52:32] Score: -0.0965189941609684; Num features: 17; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, ret
# [2022-06-19 03:53:22] Score: -0.09927007853151146; Num features: 17; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, volatility_1m
# [2022-06-19 03:54:14] Score: -0.09958676860358272; Num features: 17; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, volatility_1w
# [2022-06-19 03:54:58] Score: -0.09606576944807907; Num features: 18; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d, ret
# [2022-06-19 03:55:47] Score: -0.09377183955470768; Num features: 18; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d, volatility_1m
# [2022-06-19 03:56:36] Score: -0.08808519387407472; Num features: 18; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d, volatility_1w
# [2022-06-19 03:57:23] Score: -0.08567796314301619; Num features: 19; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d, ret, volatility_1m
# [2022-06-19 03:58:11] Score: -0.07708283999258356; Num features: 19; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d, ret, volatility_1w
# [2022-06-19 03:58:56] Score: -0.08407590522303873; Num features: 20; Features: EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m, ProfitoMarketRatio_raw, exret_1w, BookToMarketRatio_raw, exret_3m, days_since_last_fin, exret_1m, exret_3d, price_ma_pctg_ch_1w, RS_sqrt_vol, volatility_12m, volatility_3m, price_ma_pctg_ch_3d, ret, volatility_1m, volatility_1w
#        score  len_feats  \
# 82 -0.252265          5
#
#                                                                                                                     total_feats
# 82  EarningToPriceRatio_raw, days_since_last_div, ForecastOperatingProfit_pctg, price_standard_dist_6m, price_standard_dist_12m
# CPU times: user 6h 35min 14s, sys: 1min 10s, total: 6h 36min 24s
# Wall time: 2h 12min 17s

# %%
# %%time
'''
Hyperparameter tuning
'''
if RUN_HP:
    # run optimization
    best_params = optimize_hp()
    
else:
    # if not running HP, use pre-set best parameters
    best_params = BEST_PARAMS
# Out:
# [I 2022-06-18 19:58:56,630] A new study created in memory with name: LGBM optimization
# [I 2022-06-18 19:59:18,834] Trial 0 finished with value: -0.17392329122237626 and parameters: {'max_depth': 32, 'num_leaves': 51, 'learning_rate': 0.03350120099570497, 'min_child_weight': 0.005283869388839416, 'subsample': 0.7122963148151603, 'subsample_freq': 1, 'colsample_bytree': 0.9767277771105292, 'reg_alpha': 1.3722155975675168, 'reg_lambda': 0.3003344678217056, 'max_bin': 454}. Best is trial 0 with value: -0.17392329122237626.
# [I 2022-06-18 19:59:35,999] Trial 1 finished with value: -0.25539543558679717 and parameters: {'max_depth': 4, 'num_leaves': 42, 'learning_rate': 0.1993002465595014, 'min_child_weight': 0.011691117261466728, 'subsample': 0.6814757496974091, 'subsample_freq': 6, 'colsample_bytree': 0.6027299368779332, 'reg_alpha': 7.82602235585891, 'reg_lambda': 0.16550796773686155, 'max_bin': 303}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 19:59:58,924] Trial 2 finished with value: -0.22926753268855188 and parameters: {'max_depth': 11, 'num_leaves': 58, 'learning_rate': 0.0584661023347189, 'min_child_weight': 0.06574577688049195, 'subsample': 0.9085561344874241, 'subsample_freq': 2, 'colsample_bytree': 0.82556919672994, 'reg_alpha': 4.7493355818945115, 'reg_lambda': 0.7572483623929787, 'max_bin': 372}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:00:23,495] Trial 3 finished with value: -0.25133189727740307 and parameters: {'max_depth': 4, 'num_leaves': 29, 'learning_rate': 0.05240596104323447, 'min_child_weight': 0.039351258030199746, 'subsample': 0.7185880851816785, 'subsample_freq': 2, 'colsample_bytree': 0.6840928343255042, 'reg_alpha': 14.082575829696594, 'reg_lambda': 0.18445074815205775, 'max_bin': 206}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:00:39,670] Trial 4 finished with value: -0.15147990776783124 and parameters: {'max_depth': 3, 'num_leaves': 19, 'learning_rate': 0.16531116845603974, 'min_child_weight': 1.384199850796532, 'subsample': 0.8364639907448548, 'subsample_freq': 1, 'colsample_bytree': 0.7812395550810918, 'reg_alpha': 0.2685752119087677, 'reg_lambda': 0.15255020661262056, 'max_bin': 274}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:00:58,113] Trial 5 finished with value: -0.2160465334972302 and parameters: {'max_depth': 2, 'num_leaves': 57, 'learning_rate': 0.1850461588308092, 'min_child_weight': 0.1516021665415609, 'subsample': 0.957358080774531, 'subsample_freq': 2, 'colsample_bytree': 0.6802525719285697, 'reg_alpha': 0.15304299525141585, 'reg_lambda': 4.462245425985078, 'max_bin': 167}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:01:16,869] Trial 6 finished with value: -0.1472330287727738 and parameters: {'max_depth': 8, 'num_leaves': 50, 'learning_rate': 0.11605027172696086, 'min_child_weight': 0.02338081170992668, 'subsample': 0.8211404912187932, 'subsample_freq': 2, 'colsample_bytree': 0.7735841212020063, 'reg_alpha': 0.045571879491252756, 'reg_lambda': 0.11195983584478907, 'max_bin': 499}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:01:34,963] Trial 7 finished with value: -0.1690467328042358 and parameters: {'max_depth': 8, 'num_leaves': 58, 'learning_rate': 0.13966683196518853, 'min_child_weight': 0.005498691063464162, 'subsample': 0.8497827246828422, 'subsample_freq': 1, 'colsample_bytree': 0.7422346371256647, 'reg_alpha': 0.012119734089652638, 'reg_lambda': 2.714810587844187, 'max_bin': 370}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:02:02,126] Trial 8 finished with value: -0.24120798967263563 and parameters: {'max_depth': 9, 'num_leaves': 23, 'learning_rate': 0.019855539524421397, 'min_child_weight': 0.0026530754175035248, 'subsample': 0.7656612388421409, 'subsample_freq': 8, 'colsample_bytree': 0.7225114450345944, 'reg_alpha': 0.012852062446222183, 'reg_lambda': 0.07473106303082382, 'max_bin': 372}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:02:21,082] Trial 9 finished with value: -0.2393341856558142 and parameters: {'max_depth': 6, 'num_leaves': 23, 'learning_rate': 0.18546235923850396, 'min_child_weight': 0.05365998912041286, 'subsample': 0.7514508507806674, 'subsample_freq': 2, 'colsample_bytree': 0.6507419323281556, 'reg_alpha': 6.903037053489403, 'reg_lambda': 0.02934104671532764, 'max_bin': 235}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:02:39,852] Trial 10 finished with value: -0.17851256498176044 and parameters: {'max_depth': 17, 'num_leaves': 38, 'learning_rate': 0.0803822638312198, 'min_child_weight': 0.0010150172532770983, 'subsample': 0.5674273632336935, 'subsample_freq': 6, 'colsample_bytree': 0.5045408721157033, 'reg_alpha': 1.3648861304866402, 'reg_lambda': 0.02231981750200964, 'max_bin': 53}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:03:01,844] Trial 11 finished with value: -0.23630976950500843 and parameters: {'max_depth': 4, 'num_leaves': 35, 'learning_rate': 0.09093688946180119, 'min_child_weight': 0.37214666360996485, 'subsample': 0.619610294899954, 'subsample_freq': 4, 'colsample_bytree': 0.5695511833174737, 'reg_alpha': 14.610800583046307, 'reg_lambda': 0.8134775560703844, 'max_bin': 153}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:03:22,475] Trial 12 finished with value: -0.18175498589431596 and parameters: {'max_depth': 4, 'num_leaves': 30, 'learning_rate': 0.05316830954178766, 'min_child_weight': 0.014795741881904141, 'subsample': 0.6562404179985875, 'subsample_freq': 6, 'colsample_bytree': 0.6076109631588172, 'reg_alpha': 1.6134883891322989, 'reg_lambda': 0.4315684269807596, 'max_bin': 201}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:03:40,352] Trial 13 finished with value: -0.16945352560245575 and parameters: {'max_depth': 2, 'num_leaves': 41, 'learning_rate': 0.13628805388092446, 'min_child_weight': 0.017286115193655412, 'subsample': 0.5134924524402853, 'subsample_freq': 6, 'colsample_bytree': 0.5446856872284305, 'reg_alpha': 15.294228508341197, 'reg_lambda': 0.05412462208002931, 'max_bin': 305}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:04:38,584] Trial 14 finished with value: -0.22735176206352592 and parameters: {'max_depth': 5, 'num_leaves': 29, 'learning_rate': 0.006172919479200185, 'min_child_weight': 3.82922830254558, 'subsample': 0.6765056352204157, 'subsample_freq': 4, 'colsample_bytree': 0.8621544393255374, 'reg_alpha': 3.900717437952602, 'reg_lambda': 0.010560014101177137, 'max_bin': 124}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:04:58,308] Trial 15 finished with value: -0.19117627384641958 and parameters: {'max_depth': 3, 'num_leaves': 16, 'learning_rate': 0.06661011240785855, 'min_child_weight': 0.3343223572585698, 'subsample': 0.5842766361817601, 'subsample_freq': 8, 'colsample_bytree': 0.631790078268299, 'reg_alpha': 0.528619385581091, 'reg_lambda': 1.7794666132205137, 'max_bin': 289}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:05:16,503] Trial 16 finished with value: -0.20181135410469625 and parameters: {'max_depth': 3, 'num_leaves': 26, 'learning_rate': 0.1245784051976204, 'min_child_weight': 0.04505908846645746, 'subsample': 0.7261239207802674, 'subsample_freq': 6, 'colsample_bytree': 0.6845484515801599, 'reg_alpha': 2.779206775249356, 'reg_lambda': 0.21303590247018228, 'max_bin': 84}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:05:36,625] Trial 17 finished with value: -0.23717127808393315 and parameters: {'max_depth': 5, 'num_leaves': 44, 'learning_rate': 0.1569733925163082, 'min_child_weight': 0.006257098326333058, 'subsample': 0.7940627115539418, 'subsample_freq': 6, 'colsample_bytree': 0.5999775637691324, 'reg_alpha': 8.543649349173924, 'reg_lambda': 13.358577153438189, 'max_bin': 235}. Best is trial 1 with value: -0.25539543558679717.
# [I 2022-06-18 20:05:55,498] Trial 18 finished with value: -0.2564996167812367 and parameters: {'max_depth': 18, 'num_leaves': 33, 'learning_rate': 0.10272540497676913, 'min_child_weight': 0.15728804193367896, 'subsample': 0.6688401968615693, 'subsample_freq': 2, 'colsample_bytree': 0.9542829537856808, 'reg_alpha': 0.6578587739993637, 'reg_lambda': 0.720827452293396, 'max_bin': 337}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:06:13,987] Trial 19 finished with value: -0.20727158520041833 and parameters: {'max_depth': 16, 'num_leaves': 34, 'learning_rate': 0.10001026559459289, 'min_child_weight': 0.12031888588388377, 'subsample': 0.6457120299001895, 'subsample_freq': 4, 'colsample_bytree': 0.9839780975434043, 'reg_alpha': 0.6368311918668466, 'reg_lambda': 0.7590918633105231, 'max_bin': 331}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:06:32,271] Trial 20 finished with value: -0.20093101273634817 and parameters: {'max_depth': 22, 'num_leaves': 43, 'learning_rate': 0.19771126679517453, 'min_child_weight': 0.59776079979049, 'subsample': 0.5173744474935941, 'subsample_freq': 8, 'colsample_bytree': 0.9149665393075266, 'reg_alpha': 0.11534195832520758, 'reg_lambda': 7.343188090744658, 'max_bin': 426}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:06:58,050] Trial 21 finished with value: -0.22517012469226874 and parameters: {'max_depth': 32, 'num_leaves': 27, 'learning_rate': 0.04025836989847797, 'min_child_weight': 0.11558061190139791, 'subsample': 0.6965425024155738, 'subsample_freq': 2, 'colsample_bytree': 0.6847373056328949, 'reg_alpha': 2.4907751119636297, 'reg_lambda': 0.41232068977257896, 'max_bin': 249}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:07:16,692] Trial 22 finished with value: -0.20424263742661317 and parameters: {'max_depth': 4, 'num_leaves': 33, 'learning_rate': 0.08006520897917713, 'min_child_weight': 0.03365562134835332, 'subsample': 0.6058562085720116, 'subsample_freq': 2, 'colsample_bytree': 0.9153793061296959, 'reg_alpha': 7.664248082862559, 'reg_lambda': 1.495128612769277, 'max_bin': 328}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:07:34,923] Trial 23 finished with value: -0.2092867742123233 and parameters: {'max_depth': 6, 'num_leaves': 38, 'learning_rate': 0.11453827595086917, 'min_child_weight': 0.009605379880755565, 'subsample': 0.6829881986884778, 'subsample_freq': 2, 'colsample_bytree': 0.8207385028852363, 'reg_alpha': 0.05446186718664016, 'reg_lambda': 0.10020485568559145, 'max_bin': 195}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:07:52,483] Trial 24 finished with value: -0.25219982097156496 and parameters: {'max_depth': 12, 'num_leaves': 24, 'learning_rate': 0.16513175062996716, 'min_child_weight': 0.0024082263964159017, 'subsample': 0.7711108846357295, 'subsample_freq': 2, 'colsample_bytree': 0.719272226668993, 'reg_alpha': 1.0865495131581224, 'reg_lambda': 0.043595531122894354, 'max_bin': 410}. Best is trial 18 with value: -0.2564996167812367.
# [I 2022-06-18 20:08:10,248] Trial 25 finished with value: -0.26458574808423896 and parameters: {'max_depth': 14, 'num_leaves': 23, 'learning_rate': 0.16005072944957205, 'min_child_weight': 0.0019258950853919406, 'subsample': 0.8764945287199436, 'subsample_freq': 6, 'colsample_bytree': 0.8801574228272511, 'reg_alpha': 0.9528337888326824, 'reg_lambda': 0.057623340940479155, 'max_bin': 447}. Best is trial 25 with value: -0.26458574808423896.
# [I 2022-06-18 20:08:26,858] Trial 26 finished with value: -0.20391173316380468 and parameters: {'max_depth': 22, 'num_leaves': 19, 'learning_rate': 0.1979604378103856, 'min_child_weight': 0.0013238053784681077, 'subsample': 0.9749557942293752, 'subsample_freq': 6, 'colsample_bytree': 0.937142755770965, 'reg_alpha': 0.30872663708954995, 'reg_lambda': 0.015094495468618609, 'max_bin': 491}. Best is trial 25 with value: -0.26458574808423896.
# [I 2022-06-18 20:08:44,905] Trial 27 finished with value: -0.26575852917690507 and parameters: {'max_depth': 13, 'num_leaves': 48, 'learning_rate': 0.14589822509259742, 'min_child_weight': 0.002388829272842453, 'subsample': 0.8836478406003646, 'subsample_freq': 6, 'colsample_bytree': 0.8715490430664301, 'reg_alpha': 0.8514286641310514, 'reg_lambda': 0.035206661891512794, 'max_bin': 416}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:09:03,072] Trial 28 finished with value: -0.22000671370125296 and parameters: {'max_depth': 14, 'num_leaves': 20, 'learning_rate': 0.146875498478254, 'min_child_weight': 0.0025057450684743744, 'subsample': 0.8842305085963461, 'subsample_freq': 6, 'colsample_bytree': 0.8743308322607727, 'reg_alpha': 0.7061807084041596, 'reg_lambda': 0.03400211989879534, 'max_bin': 448}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:09:19,986] Trial 29 finished with value: -0.21870389820847755 and parameters: {'max_depth': 21, 'num_leaves': 64, 'learning_rate': 0.13061141275632931, 'min_child_weight': 0.003170644336123232, 'subsample': 0.9362523922202879, 'subsample_freq': 1, 'colsample_bytree': 0.9584922997489415, 'reg_alpha': 0.17428083043553644, 'reg_lambda': 0.29785681878394527, 'max_bin': 404}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:09:38,625] Trial 30 finished with value: -0.2059728990441161 and parameters: {'max_depth': 29, 'num_leaves': 48, 'learning_rate': 0.15178409451513752, 'min_child_weight': 0.0015600313397947725, 'subsample': 0.8665478435007821, 'subsample_freq': 6, 'colsample_bytree': 0.8754232072477467, 'reg_alpha': 1.0936268102921518, 'reg_lambda': 0.019843826198688817, 'max_bin': 456}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:09:56,152] Trial 31 finished with value: -0.18858886009840276 and parameters: {'max_depth': 11, 'num_leaves': 47, 'learning_rate': 0.1823192188657983, 'min_child_weight': 0.009574447266885347, 'subsample': 0.8998503918452393, 'subsample_freq': 6, 'colsample_bytree': 0.9896103794659588, 'reg_alpha': 1.9568281106975856, 'reg_lambda': 0.06781904342198371, 'max_bin': 342}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:10:14,487] Trial 32 finished with value: -0.2225161567167536 and parameters: {'max_depth': 17, 'num_leaves': 38, 'learning_rate': 0.17315547245463486, 'min_child_weight': 0.003917211078684428, 'subsample': 0.9176159977467121, 'subsample_freq': 6, 'colsample_bytree': 0.8373582033350635, 'reg_alpha': 0.38770348034924645, 'reg_lambda': 0.12093953596603714, 'max_bin': 395}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:10:33,282] Trial 33 finished with value: -0.23719304704234445 and parameters: {'max_depth': 12, 'num_leaves': 53, 'learning_rate': 0.1098282475188199, 'min_child_weight': 0.008075065564422735, 'subsample': 0.8043570232000928, 'subsample_freq': 6, 'colsample_bytree': 0.9003677723750274, 'reg_alpha': 0.8236305146077937, 'reg_lambda': 0.25822897091050445, 'max_bin': 462}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:10:51,033] Trial 34 finished with value: -0.2209647905590682 and parameters: {'max_depth': 10, 'num_leaves': 31, 'learning_rate': 0.17540000072527936, 'min_child_weight': 0.001902970266049334, 'subsample': 0.7231158509529179, 'subsample_freq': 6, 'colsample_bytree': 0.9500698317050178, 'reg_alpha': 4.03298006772182, 'reg_lambda': 0.5230691618324934, 'max_bin': 365}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:11:08,740] Trial 35 finished with value: -0.20230920742504047 and parameters: {'max_depth': 14, 'num_leaves': 40, 'learning_rate': 0.1627871616172717, 'min_child_weight': 0.08660972671741612, 'subsample': 0.6400987206937722, 'subsample_freq': 6, 'colsample_bytree': 0.8059228914911164, 'reg_alpha': 0.2143074745849651, 'reg_lambda': 0.15099586352930133, 'max_bin': 305}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:11:25,811] Trial 36 finished with value: -0.22640519134506537 and parameters: {'max_depth': 24, 'num_leaves': 46, 'learning_rate': 0.1507045683641213, 'min_child_weight': 0.004880375160081482, 'subsample': 0.9930195183148051, 'subsample_freq': 1, 'colsample_bytree': 0.8497843519978786, 'reg_alpha': 0.4534432170057861, 'reg_lambda': 0.07469553266243818, 'max_bin': 425}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:11:45,690] Trial 37 finished with value: -0.20888393518834128 and parameters: {'max_depth': 19, 'num_leaves': 53, 'learning_rate': 0.12626976460691713, 'min_child_weight': 0.19976764084958734, 'subsample': 0.8392765788740553, 'subsample_freq': 6, 'colsample_bytree': 0.7858440799198589, 'reg_alpha': 2.7554625483003203, 'reg_lambda': 0.033106047835763555, 'max_bin': 273}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:12:02,635] Trial 38 finished with value: -0.19057106802082774 and parameters: {'max_depth': 27, 'num_leaves': 16, 'learning_rate': 0.19133416736098044, 'min_child_weight': 0.02448592134830599, 'subsample': 0.9439827718704505, 'subsample_freq': 8, 'colsample_bytree': 0.8954578519648931, 'reg_alpha': 0.10069784543987563, 'reg_lambda': 0.9888369567253722, 'max_bin': 354}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:12:21,507] Trial 39 finished with value: -0.24853498089645515 and parameters: {'max_depth': 8, 'num_leaves': 35, 'learning_rate': 0.14099173464811188, 'min_child_weight': 0.0010558121366021662, 'subsample': 0.7894195504871506, 'subsample_freq': 2, 'colsample_bytree': 0.9273763674014801, 'reg_alpha': 1.0316587133253625, 'reg_lambda': 0.17863617442241297, 'max_bin': 382}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:12:37,979] Trial 40 finished with value: -0.19128130558217146 and parameters: {'max_depth': 7, 'num_leaves': 26, 'learning_rate': 0.17574996816513233, 'min_child_weight': 0.07077051692093471, 'subsample': 0.7430239528275753, 'subsample_freq': 1, 'colsample_bytree': 0.961415647389006, 'reg_alpha': 0.30834146925950795, 'reg_lambda': 0.04549923118662405, 'max_bin': 478}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:12:55,456] Trial 41 finished with value: -0.233718878686438 and parameters: {'max_depth': 13, 'num_leaves': 22, 'learning_rate': 0.16447068434246284, 'min_child_weight': 0.002321480722968735, 'subsample': 0.7682573868159375, 'subsample_freq': 2, 'colsample_bytree': 0.7458291367407532, 'reg_alpha': 1.3521494878407954, 'reg_lambda': 0.04363334158557601, 'max_bin': 403}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:13:12,652] Trial 42 finished with value: -0.1859255231295712 and parameters: {'max_depth': 15, 'num_leaves': 24, 'learning_rate': 0.165838220187684, 'min_child_weight': 0.0036440388523652353, 'subsample': 0.8624482665696641, 'subsample_freq': 2, 'colsample_bytree': 0.709003230103669, 'reg_alpha': 0.9276387249756344, 'reg_lambda': 0.08813174331267187, 'max_bin': 433}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:13:31,467] Trial 43 finished with value: -0.2156190318629354 and parameters: {'max_depth': 10, 'num_leaves': 21, 'learning_rate': 0.18217530882551958, 'min_child_weight': 0.013604584913719952, 'subsample': 0.816962060156405, 'subsample_freq': 2, 'colsample_bytree': 0.8039999086769976, 'reg_alpha': 6.007916369373494, 'reg_lambda': 0.023406291392772394, 'max_bin': 405}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:13:50,900] Trial 44 finished with value: -0.2246571257116964 and parameters: {'max_depth': 12, 'num_leaves': 18, 'learning_rate': 0.09849510219405311, 'min_child_weight': 0.0017425816693464966, 'subsample': 0.7084568229405981, 'subsample_freq': 2, 'colsample_bytree': 0.7653658365941503, 'reg_alpha': 0.5545466874448184, 'reg_lambda': 0.05823445944224346, 'max_bin': 317}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:14:08,613] Trial 45 finished with value: -0.2445235341650908 and parameters: {'max_depth': 9, 'num_leaves': 28, 'learning_rate': 0.15899091967700033, 'min_child_weight': 0.006037420713027786, 'subsample': 0.6631164211689557, 'subsample_freq': 4, 'colsample_bytree': 0.6539355503733527, 'reg_alpha': 1.9031706571525466, 'reg_lambda': 0.12201726797138444, 'max_bin': 381}. Best is trial 27 with value: -0.26575852917690507.
# [I 2022-06-18 20:14:27,705] Trial 46 finished with value: -0.2713218952890456 and parameters: {'max_depth': 19, 'num_leaves': 24, 'learning_rate': 0.13739211309892474, 'min_child_weight': 0.8143513563828483, 'subsample': 0.766905724281718, 'subsample_freq': 2, 'colsample_bytree': 0.5731358455691992, 'reg_alpha': 10.670897702542948, 'reg_lambda': 0.013870186885319826, 'max_bin': 439}. Best is trial 46 with value: -0.2713218952890456.
# [I 2022-06-18 20:14:47,686] Trial 47 finished with value: -0.19770380359325462 and parameters: {'max_depth': 18, 'num_leaves': 62, 'learning_rate': 0.1221325694657388, 'min_child_weight': 1.9746413589513425, 'subsample': 0.5473842985418673, 'subsample_freq': 6, 'colsample_bytree': 0.5061680383743477, 'reg_alpha': 11.007828975551892, 'reg_lambda': 0.013105342054320379, 'max_bin': 473}. Best is trial 46 with value: -0.2713218952890456.
# [I 2022-06-18 20:15:07,039] Trial 48 finished with value: -0.22625651367322233 and parameters: {'max_depth': 19, 'num_leaves': 50, 'learning_rate': 0.13837546399548656, 'min_child_weight': 0.9032788880280325, 'subsample': 0.6261295589600193, 'subsample_freq': 6, 'colsample_bytree': 0.5575477870169467, 'reg_alpha': 5.133732956509063, 'reg_lambda': 0.016316173036625855, 'max_bin': 441}. Best is trial 46 with value: -0.2713218952890456.
# [I 2022-06-18 20:15:30,916] Trial 49 finished with value: -0.28130471457277484 and parameters: {'max_depth': 25, 'num_leaves': 25, 'learning_rate': 0.08210665567440277, 'min_child_weight': 0.2504681779625912, 'subsample': 0.8883971710636179, 'subsample_freq': 8, 'colsample_bytree': 0.5857951664186661, 'reg_alpha': 10.354611482272494, 'reg_lambda': 0.01017928884351591, 'max_bin': 353}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:15:52,039] Trial 50 finished with value: -0.26829976869481076 and parameters: {'max_depth': 27, 'num_leaves': 24, 'learning_rate': 0.08436663493404518, 'min_child_weight': 0.2679676619573931, 'subsample': 0.9118291697332958, 'subsample_freq': 8, 'colsample_bytree': 0.5386000652948535, 'reg_alpha': 10.252957892691652, 'reg_lambda': 0.010577280195201367, 'max_bin': 353}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:16:14,741] Trial 51 finished with value: -0.27046093057907516 and parameters: {'max_depth': 27, 'num_leaves': 25, 'learning_rate': 0.0748841683522083, 'min_child_weight': 0.27544287061136724, 'subsample': 0.8852800747871756, 'subsample_freq': 8, 'colsample_bytree': 0.5356954280571321, 'reg_alpha': 8.90833135361069, 'reg_lambda': 0.0107406737681235, 'max_bin': 353}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:16:37,626] Trial 52 finished with value: -0.24455718155473108 and parameters: {'max_depth': 25, 'num_leaves': 25, 'learning_rate': 0.06807862395618514, 'min_child_weight': 0.3217025127736666, 'subsample': 0.887593928971438, 'subsample_freq': 8, 'colsample_bytree': 0.5215621971907456, 'reg_alpha': 10.05814930930215, 'reg_lambda': 0.014128791298477529, 'max_bin': 362}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:16:59,957] Trial 53 finished with value: -0.2538406112366237 and parameters: {'max_depth': 32, 'num_leaves': 22, 'learning_rate': 0.07728556645662864, 'min_child_weight': 0.5581438766844893, 'subsample': 0.925365048067998, 'subsample_freq': 8, 'colsample_bytree': 0.5860382176457504, 'reg_alpha': 11.544543802817804, 'reg_lambda': 0.010659847513776405, 'max_bin': 389}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:17:22,281] Trial 54 finished with value: -0.19349466567660106 and parameters: {'max_depth': 27, 'num_leaves': 23, 'learning_rate': 0.0904008365534385, 'min_child_weight': 0.22786699692436535, 'subsample': 0.8602115509212541, 'subsample_freq': 8, 'colsample_bytree': 0.5762834902607024, 'reg_alpha': 14.232542588547638, 'reg_lambda': 0.010038540701825997, 'max_bin': 419}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:17:44,591] Trial 55 finished with value: -0.23672739329210354 and parameters: {'max_depth': 21, 'num_leaves': 28, 'learning_rate': 0.06123421263410568, 'min_child_weight': 0.6102584490128872, 'subsample': 0.9619688116944513, 'subsample_freq': 8, 'colsample_bytree': 0.5360924324202634, 'reg_alpha': 4.106418711732624, 'reg_lambda': 0.02659065572168153, 'max_bin': 291}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:18:08,881] Trial 56 finished with value: -0.2502273086017995 and parameters: {'max_depth': 24, 'num_leaves': 25, 'learning_rate': 0.0416022706058933, 'min_child_weight': 1.4331955370323277, 'subsample': 0.8997051016884651, 'subsample_freq': 8, 'colsample_bytree': 0.6280700404706409, 'reg_alpha': 6.217040758312839, 'reg_lambda': 0.01938496422365995, 'max_bin': 475}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:18:27,723] Trial 57 finished with value: -0.23029833914818948 and parameters: {'max_depth': 16, 'num_leaves': 21, 'learning_rate': 0.09204637429810107, 'min_child_weight': 0.41349164159421825, 'subsample': 0.8287629297540147, 'subsample_freq': 8, 'colsample_bytree': 0.6020782203752604, 'reg_alpha': 0.017658068736529642, 'reg_lambda': 0.016756505931729254, 'max_bin': 356}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:18:51,264] Trial 58 finished with value: -0.21118845045711745 and parameters: {'max_depth': 27, 'num_leaves': 18, 'learning_rate': 0.08465346813463971, 'min_child_weight': 0.9272153224235569, 'subsample': 0.8821599412380073, 'subsample_freq': 8, 'colsample_bytree': 0.5372727631967826, 'reg_alpha': 9.1317770766118, 'reg_lambda': 0.012351293481429887, 'max_bin': 444}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:19:11,530] Trial 59 finished with value: -0.2570684835949783 and parameters: {'max_depth': 30, 'num_leaves': 30, 'learning_rate': 0.10808715459033956, 'min_child_weight': 2.6133569784097586, 'subsample': 0.8457064331429315, 'subsample_freq': 8, 'colsample_bytree': 0.5615796643802256, 'reg_alpha': 7.615679204961732, 'reg_lambda': 0.029061161037764786, 'max_bin': 260}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:19:32,728] Trial 60 finished with value: -0.23145432915162584 and parameters: {'max_depth': 20, 'num_leaves': 27, 'learning_rate': 0.06898310793424131, 'min_child_weight': 0.26261120344217775, 'subsample': 0.913126729946943, 'subsample_freq': 8, 'colsample_bytree': 0.6287129453683906, 'reg_alpha': 3.386965019153746, 'reg_lambda': 0.020557780858487022, 'max_bin': 376}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:19:53,354] Trial 61 finished with value: -0.20939097699919634 and parameters: {'max_depth': 29, 'num_leaves': 30, 'learning_rate': 0.11033651146671178, 'min_child_weight': 2.759752050334351, 'subsample': 0.8490909099031668, 'subsample_freq': 8, 'colsample_bytree': 0.5558406628825672, 'reg_alpha': 7.468203491228758, 'reg_lambda': 0.029320085461727777, 'max_bin': 246}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:20:16,878] Trial 62 finished with value: -0.20033396632562833 and parameters: {'max_depth': 32, 'num_leaves': 24, 'learning_rate': 0.07284231284334967, 'min_child_weight': 0.8794791218613438, 'subsample': 0.8768376993193997, 'subsample_freq': 8, 'colsample_bytree': 0.5221328433193746, 'reg_alpha': 11.639520170384108, 'reg_lambda': 0.02497295113007732, 'max_bin': 265}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:20:43,256] Trial 63 finished with value: -0.19969192814939377 and parameters: {'max_depth': 23, 'num_leaves': 26, 'learning_rate': 0.04854073895880895, 'min_child_weight': 1.5512069043048253, 'subsample': 0.9353407146714386, 'subsample_freq': 8, 'colsample_bytree': 0.5812621188646665, 'reg_alpha': 15.86645738128152, 'reg_lambda': 0.03808856472238068, 'max_bin': 217}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:21:06,389] Trial 64 finished with value: -0.24857036745130717 and parameters: {'max_depth': 26, 'num_leaves': 22, 'learning_rate': 0.06042862683957313, 'min_child_weight': 0.1617076649912167, 'subsample': 0.9015514982829891, 'subsample_freq': 8, 'colsample_bytree': 0.5584223721504853, 'reg_alpha': 5.2964469550661, 'reg_lambda': 0.01647087630625612, 'max_bin': 342}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:21:27,886] Trial 65 finished with value: -0.23266009367095447 and parameters: {'max_depth': 29, 'num_leaves': 29, 'learning_rate': 0.08634323250437821, 'min_child_weight': 0.4683273372085829, 'subsample': 0.8503552046796098, 'subsample_freq': 4, 'colsample_bytree': 0.5226657653930347, 'reg_alpha': 8.481272946792453, 'reg_lambda': 0.012542550792381174, 'max_bin': 493}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:21:47,559] Trial 66 finished with value: -0.2352873522587482 and parameters: {'max_depth': 22, 'num_leaves': 32, 'learning_rate': 0.10302496807464664, 'min_child_weight': 3.9066246747166926, 'subsample': 0.8108686076322702, 'subsample_freq': 8, 'colsample_bytree': 0.5046423463783641, 'reg_alpha': 6.438774829380932, 'reg_lambda': 0.010358915013372756, 'max_bin': 327}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:22:07,023] Trial 67 finished with value: -0.23195716910445344 and parameters: {'max_depth': 17, 'num_leaves': 25, 'learning_rate': 0.14467939350942396, 'min_child_weight': 0.7291647750032089, 'subsample': 0.7888594107577269, 'subsample_freq': 8, 'colsample_bytree': 0.6052088669323307, 'reg_alpha': 11.928534975327311, 'reg_lambda': 0.02124200174502627, 'max_bin': 312}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:22:32,995] Trial 68 finished with value: -0.23606856081289762 and parameters: {'max_depth': 20, 'num_leaves': 20, 'learning_rate': 0.02622694067635202, 'min_child_weight': 2.4158011947574094, 'subsample': 0.8393437528955886, 'subsample_freq': 8, 'colsample_bytree': 0.651140021802938, 'reg_alpha': 3.4368712347339634, 'reg_lambda': 0.02918162483431109, 'max_bin': 460}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:22:50,278] Trial 69 finished with value: -0.2153577446789062 and parameters: {'max_depth': 29, 'num_leaves': 23, 'learning_rate': 0.1326554776318943, 'min_child_weight': 1.215425982480367, 'subsample': 0.9547783148914608, 'subsample_freq': 1, 'colsample_bytree': 0.5428165833886157, 'reg_alpha': 4.688063612719856, 'reg_lambda': 0.017316580013951203, 'max_bin': 286}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:23:10,513] Trial 70 finished with value: -0.2659548720978764 and parameters: {'max_depth': 15, 'num_leaves': 27, 'learning_rate': 0.11802649492965687, 'min_child_weight': 0.11560105163347724, 'subsample': 0.8743256831902898, 'subsample_freq': 4, 'colsample_bytree': 0.5620457903374418, 'reg_alpha': 2.2272835283901427, 'reg_lambda': 0.05476511843002062, 'max_bin': 165}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:23:29,875] Trial 71 finished with value: -0.27681559870764155 and parameters: {'max_depth': 14, 'num_leaves': 28, 'learning_rate': 0.1190173718604509, 'min_child_weight': 0.12353936912096083, 'subsample': 0.8881473414910038, 'subsample_freq': 4, 'colsample_bytree': 0.5615398795902189, 'reg_alpha': 1.5083743583844398, 'reg_lambda': 0.05492680407229372, 'max_bin': 78}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:23:47,965] Trial 72 finished with value: -0.24074256069085215 and parameters: {'max_depth': 15, 'num_leaves': 27, 'learning_rate': 0.1196718211993302, 'min_child_weight': 0.12005421106529196, 'subsample': 0.9246302632073329, 'subsample_freq': 4, 'colsample_bytree': 0.5827291745321076, 'reg_alpha': 1.7771655841985858, 'reg_lambda': 0.06015037719258554, 'max_bin': 91}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:24:06,352] Trial 73 finished with value: -0.1401362417459735 and parameters: {'max_depth': 13, 'num_leaves': 24, 'learning_rate': 0.127442620141412, 'min_child_weight': 0.09979538551777381, 'subsample': 0.871710754678122, 'subsample_freq': 4, 'colsample_bytree': 0.5920724893301176, 'reg_alpha': 2.2236524380797222, 'reg_lambda': 0.04836162564305181, 'max_bin': 54}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:24:25,355] Trial 74 finished with value: -0.2506753570993897 and parameters: {'max_depth': 15, 'num_leaves': 26, 'learning_rate': 0.1146728391729191, 'min_child_weight': 0.05624777609921109, 'subsample': 0.9041481436715172, 'subsample_freq': 4, 'colsample_bytree': 0.6181597221486794, 'reg_alpha': 1.3858214088275274, 'reg_lambda': 0.09531949747935803, 'max_bin': 113}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:24:47,233] Trial 75 finished with value: -0.26229689744530627 and parameters: {'max_depth': 11, 'num_leaves': 28, 'learning_rate': 0.07521823385680342, 'min_child_weight': 0.17587651824325637, 'subsample': 0.8872583342014495, 'subsample_freq': 4, 'colsample_bytree': 0.571216311283367, 'reg_alpha': 1.4500068881860015, 'reg_lambda': 0.0371880247076921, 'max_bin': 168}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:25:06,821] Trial 76 finished with value: -0.2261767246214615 and parameters: {'max_depth': 18, 'num_leaves': 25, 'learning_rate': 0.13449248785527182, 'min_child_weight': 0.2947011868186658, 'subsample': 0.9795915220410817, 'subsample_freq': 4, 'colsample_bytree': 0.5316540824931177, 'reg_alpha': 0.8556971764887437, 'reg_lambda': 0.01282446676621665, 'max_bin': 140}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:25:25,643] Trial 77 finished with value: -0.2453522403367608 and parameters: {'max_depth': 13, 'num_leaves': 21, 'learning_rate': 0.15428290532628697, 'min_child_weight': 0.08321482460933738, 'subsample': 0.89372411043773, 'subsample_freq': 4, 'colsample_bytree': 0.5534531813033614, 'reg_alpha': 2.815509677495704, 'reg_lambda': 0.06820758142388726, 'max_bin': 418}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:25:44,890] Trial 78 finished with value: -0.2141457039258022 and parameters: {'max_depth': 16, 'num_leaves': 31, 'learning_rate': 0.09499711657359797, 'min_child_weight': 0.13871227055935711, 'subsample': 0.9160384443905584, 'subsample_freq': 4, 'colsample_bytree': 0.8891287907438238, 'reg_alpha': 0.6563527252509773, 'reg_lambda': 0.014497712385452116, 'max_bin': 120}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:26:03,095] Trial 79 finished with value: -0.24675199557401556 and parameters: {'max_depth': 14, 'num_leaves': 23, 'learning_rate': 0.14464149760727327, 'min_child_weight': 0.21326060454118476, 'subsample': 0.8607336416271095, 'subsample_freq': 6, 'colsample_bytree': 0.615459704407266, 'reg_alpha': 1.1505506952757638, 'reg_lambda': 3.196416409359476, 'max_bin': 389}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:26:23,487] Trial 80 finished with value: -0.1799629161702326 and parameters: {'max_depth': 10, 'num_leaves': 27, 'learning_rate': 0.08240070260137812, 'min_child_weight': 0.3854344394492807, 'subsample': 0.8247141685572983, 'subsample_freq': 4, 'colsample_bytree': 0.6650189372201383, 'reg_alpha': 2.300620480036965, 'reg_lambda': 0.03391840688871118, 'max_bin': 172}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:26:43,878] Trial 81 finished with value: -0.2473441103955208 and parameters: {'max_depth': 11, 'num_leaves': 28, 'learning_rate': 0.0762117664499414, 'min_child_weight': 0.16690045948535895, 'subsample': 0.8844088614148481, 'subsample_freq': 4, 'colsample_bytree': 0.5699163347271599, 'reg_alpha': 1.5479684300005103, 'reg_lambda': 0.050482347498892355, 'max_bin': 175}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:27:03,649] Trial 82 finished with value: -0.2515136108953092 and parameters: {'max_depth': 11, 'num_leaves': 28, 'learning_rate': 0.10539643751184195, 'min_child_weight': 0.03186117642140734, 'subsample': 0.938147111128881, 'subsample_freq': 4, 'colsample_bytree': 0.5672267028452018, 'reg_alpha': 1.2637291489622946, 'reg_lambda': 0.03610550831578137, 'max_bin': 62}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:27:22,446] Trial 83 finished with value: -0.24123559476248566 and parameters: {'max_depth': 9, 'num_leaves': 26, 'learning_rate': 0.12017850587602769, 'min_child_weight': 0.18985360161281228, 'subsample': 0.8718768360252808, 'subsample_freq': 4, 'colsample_bytree': 0.5488898540777778, 'reg_alpha': 0.7787609047716557, 'reg_lambda': 0.01939431747691634, 'max_bin': 220}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:27:44,577] Trial 84 finished with value: -0.23072547415342473 and parameters: {'max_depth': 12, 'num_leaves': 29, 'learning_rate': 0.053503053322432576, 'min_child_weight': 0.06891741776796309, 'subsample': 0.890643325305952, 'subsample_freq': 4, 'colsample_bytree': 0.5168801257330676, 'reg_alpha': 1.6258594326866036, 'reg_lambda': 0.024096869556399034, 'max_bin': 156}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:28:03,447] Trial 85 finished with value: -0.23059775821561232 and parameters: {'max_depth': 14, 'num_leaves': 24, 'learning_rate': 0.0973097964772738, 'min_child_weight': 0.2474451632477243, 'subsample': 0.9119320657036657, 'subsample_freq': 6, 'colsample_bytree': 0.5003750746920077, 'reg_alpha': 0.9439329304239752, 'reg_lambda': 0.08090014300790846, 'max_bin': 79}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:28:21,714] Trial 86 finished with value: -0.24136553207208764 and parameters: {'max_depth': 23, 'num_leaves': 35, 'learning_rate': 0.08953161791716709, 'min_child_weight': 0.09591139743909229, 'subsample': 0.9481725497765388, 'subsample_freq': 1, 'colsample_bytree': 0.8340014910169844, 'reg_alpha': 0.5045228009156429, 'reg_lambda': 0.14654378908195745, 'max_bin': 186}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:28:47,989] Trial 87 finished with value: -0.2762814460820518 and parameters: {'max_depth': 19, 'num_leaves': 23, 'learning_rate': 0.06430972143222714, 'min_child_weight': 0.04621411756088421, 'subsample': 0.8567730545650141, 'subsample_freq': 2, 'colsample_bytree': 0.5886671026103206, 'reg_alpha': 13.41798607325885, 'reg_lambda': 0.04069775333176369, 'max_bin': 134}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:29:07,064] Trial 88 finished with value: -0.2240792960867261 and parameters: {'max_depth': 19, 'num_leaves': 20, 'learning_rate': 0.12984837551302475, 'min_child_weight': 0.04879362814396032, 'subsample': 0.924299963451658, 'subsample_freq': 2, 'colsample_bytree': 0.8630980458425033, 'reg_alpha': 9.144100383925107, 'reg_lambda': 0.06235123134362911, 'max_bin': 105}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:29:26,218] Trial 89 finished with value: -0.21965543377314015 and parameters: {'max_depth': 25, 'num_leaves': 22, 'learning_rate': 0.1496379450259344, 'min_child_weight': 0.13318348897262652, 'subsample': 0.7502750853529981, 'subsample_freq': 2, 'colsample_bytree': 0.9992199820356599, 'reg_alpha': 13.20807339874242, 'reg_lambda': 0.01145377303166064, 'max_bin': 434}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:29:50,717] Trial 90 finished with value: -0.24327146027706953 and parameters: {'max_depth': 21, 'num_leaves': 25, 'learning_rate': 0.0661444694514361, 'min_child_weight': 0.29481590224903576, 'subsample': 0.8534871858790591, 'subsample_freq': 2, 'colsample_bytree': 0.5912435331639765, 'reg_alpha': 10.006137361207108, 'reg_lambda': 0.04238679817459572, 'max_bin': 134}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:30:10,944] Trial 91 finished with value: -0.22753134156595262 and parameters: {'max_depth': 17, 'num_leaves': 24, 'learning_rate': 0.07364124164413435, 'min_child_weight': 0.34178347150654365, 'subsample': 0.8742177403440812, 'subsample_freq': 2, 'colsample_bytree': 0.5771938367303364, 'reg_alpha': 0.3868211325377665, 'reg_lambda': 0.1135803285369226, 'max_bin': 151}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:30:32,969] Trial 92 finished with value: -0.26388033550912204 and parameters: {'max_depth': 16, 'num_leaves': 23, 'learning_rate': 0.07984012822242538, 'min_child_weight': 0.44685942923303845, 'subsample': 0.8329935036823225, 'subsample_freq': 6, 'colsample_bytree': 0.5447102233857491, 'reg_alpha': 15.814001733593916, 'reg_lambda': 0.054236562765618744, 'max_bin': 97}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:30:51,157] Trial 93 finished with value: -0.2211982837547537 and parameters: {'max_depth': 16, 'num_leaves': 23, 'learning_rate': 0.17113465430496866, 'min_child_weight': 0.47166510804016337, 'subsample': 0.8646392514706979, 'subsample_freq': 6, 'colsample_bytree': 0.5308994726954992, 'reg_alpha': 13.493933447848548, 'reg_lambda': 0.05361932043858281, 'max_bin': 96}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:31:12,308] Trial 94 finished with value: -0.21241770111726313 and parameters: {'max_depth': 17, 'num_leaves': 22, 'learning_rate': 0.0802094766647302, 'min_child_weight': 0.018246851184785733, 'subsample': 0.830675366839414, 'subsample_freq': 6, 'colsample_bytree': 0.5481404111120831, 'reg_alpha': 12.772188515230397, 'reg_lambda': 0.2089448693966988, 'max_bin': 69}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:31:32,382] Trial 95 finished with value: -0.21922851669831833 and parameters: {'max_depth': 20, 'num_leaves': 23, 'learning_rate': 0.14136734234221762, 'min_child_weight': 0.538965212175924, 'subsample': 0.8002067998759652, 'subsample_freq': 6, 'colsample_bytree': 0.5401667724735432, 'reg_alpha': 15.32225113921899, 'reg_lambda': 0.014512990321411087, 'max_bin': 109}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:31:51,285] Trial 96 finished with value: -0.2545526105994696 and parameters: {'max_depth': 15, 'num_leaves': 21, 'learning_rate': 0.15882941316385304, 'min_child_weight': 0.0011946519095889666, 'subsample': 0.7832619325402206, 'subsample_freq': 6, 'colsample_bytree': 0.5916151303637804, 'reg_alpha': 10.11803440213503, 'reg_lambda': 0.08051534774833478, 'max_bin': 350}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:32:15,519] Trial 97 finished with value: -0.2552054583531949 and parameters: {'max_depth': 23, 'num_leaves': 27, 'learning_rate': 0.05565976480179531, 'min_child_weight': 0.25551075430443515, 'subsample': 0.8383841144898342, 'subsample_freq': 2, 'colsample_bytree': 0.5126060988799386, 'reg_alpha': 7.012383264361484, 'reg_lambda': 0.06902817789002585, 'max_bin': 132}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:32:34,886] Trial 98 finished with value: -0.23827580661446116 and parameters: {'max_depth': 13, 'num_leaves': 19, 'learning_rate': 0.061161473739454464, 'min_child_weight': 0.7685323217035486, 'subsample': 0.7398645456241009, 'subsample_freq': 6, 'colsample_bytree': 0.5630292788227984, 'reg_alpha': 5.425233640067411, 'reg_lambda': 0.01855141671608806, 'max_bin': 81}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:32:55,181] Trial 99 finished with value: -0.17517180947176286 and parameters: {'max_depth': 19, 'num_leaves': 26, 'learning_rate': 0.0872920573845563, 'min_child_weight': 0.002143887331272088, 'subsample': 0.8184879012680352, 'subsample_freq': 2, 'colsample_bytree': 0.5291159470299622, 'reg_alpha': 8.64341917523102, 'reg_lambda': 0.04200462936121085, 'max_bin': 398}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:33:18,767] Trial 100 finished with value: -0.2445305778685089 and parameters: {'max_depth': 26, 'num_leaves': 25, 'learning_rate': 0.06671246842981772, 'min_child_weight': 0.0031241118986508215, 'subsample': 0.8958602853356089, 'subsample_freq': 6, 'colsample_bytree': 0.6397741769713209, 'reg_alpha': 15.929244524479282, 'reg_lambda': 0.025728592506323276, 'max_bin': 468}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:33:38,909] Trial 101 finished with value: -0.2280170960747816 and parameters: {'max_depth': 18, 'num_leaves': 29, 'learning_rate': 0.07055227776811757, 'min_child_weight': 0.17801680083605126, 'subsample': 0.8883773798345145, 'subsample_freq': 4, 'colsample_bytree': 0.569513574624182, 'reg_alpha': 3.3512471787929345, 'reg_lambda': 0.0325286731453388, 'max_bin': 159}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:33:59,849] Trial 102 finished with value: -0.20977478707976274 and parameters: {'max_depth': 14, 'num_leaves': 23, 'learning_rate': 0.07870463785854356, 'min_child_weight': 0.11227232415207544, 'subsample': 0.8772745153136671, 'subsample_freq': 4, 'colsample_bytree': 0.5755738860264324, 'reg_alpha': 10.216453709792328, 'reg_lambda': 0.03826008196609997, 'max_bin': 369}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:34:20,904] Trial 103 finished with value: -0.21257307432684952 and parameters: {'max_depth': 12, 'num_leaves': 24, 'learning_rate': 0.08286779297088859, 'min_child_weight': 0.45791172332174207, 'subsample': 0.9035799004227688, 'subsample_freq': 8, 'colsample_bytree': 0.6134275337425863, 'reg_alpha': 11.613155362612035, 'reg_lambda': 0.010123465875237932, 'max_bin': 99}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:34:42,389] Trial 104 finished with value: -0.20071112955637832 and parameters: {'max_depth': 11, 'num_leaves': 27, 'learning_rate': 0.09382871304810436, 'min_child_weight': 0.21175925352820182, 'subsample': 0.8548064444157516, 'subsample_freq': 6, 'colsample_bytree': 0.5986183192525465, 'reg_alpha': 2.0564448031340845, 'reg_lambda': 0.052183161752382516, 'max_bin': 413}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:35:01,820] Trial 105 finished with value: -0.25184816960403966 and parameters: {'max_depth': 16, 'num_leaves': 30, 'learning_rate': 0.0719064910161936, 'min_child_weight': 0.15147673723252061, 'subsample': 0.9083058435222954, 'subsample_freq': 1, 'colsample_bytree': 0.733802370578702, 'reg_alpha': 7.63444646102387, 'reg_lambda': 0.022743396398832258, 'max_bin': 449}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:35:24,620] Trial 106 finished with value: -0.20555096794270247 and parameters: {'max_depth': 21, 'num_leaves': 32, 'learning_rate': 0.06369695657131615, 'min_child_weight': 1.1441268066849386, 'subsample': 0.9308130237205865, 'subsample_freq': 2, 'colsample_bytree': 0.5469230172197894, 'reg_alpha': 4.60312073872057, 'reg_lambda': 0.100529105550085, 'max_bin': 483}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:35:42,498] Trial 107 finished with value: -0.20592842069709408 and parameters: {'max_depth': 7, 'num_leaves': 25, 'learning_rate': 0.11334920493038722, 'min_child_weight': 0.6906813246859866, 'subsample': 0.8687108197107622, 'subsample_freq': 8, 'colsample_bytree': 0.916386096097761, 'reg_alpha': 1.0172457852248864, 'reg_lambda': 0.01229273288200511, 'max_bin': 119}. Best is trial 49 with value: -0.28130471457277484.
# [I 2022-06-18 20:36:04,981] Trial 108 finished with value: -0.16906149265851128 and parameters: {'max_depth': 5, 'num_leaves': 28, 'learning_rate': 0.048090568214433374, 'min_child_weight': 0.0014880448404412435, 'subsample': 0.8421878409953819, 'subsample_freq': 4, 'colsample_bytree': 0.5605567351948878, 'reg_alpha': 0.570407487173873, 'reg_lambda': 0.015301422701033959, 'max_bin': 146}. Best is trial 49 with value: -0.28130471457277484.
# ...
# [I 2022-06-18 23:48:18,383] Trial 685 finished with value: -0.2624899621965964 and parameters: {'max_depth': 26, 'num_leaves': 43, 'learning_rate': 0.07857631649749737, 'min_child_weight': 0.5333114360486061, 'subsample': 0.7420125281066144, 'subsample_freq': 6, 'colsample_bytree': 0.7433837607001421, 'reg_alpha': 0.11518554684834682, 'reg_lambda': 1.4352076824227074, 'max_bin': 118}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:48:38,739] Trial 686 finished with value: -0.24905536704178424 and parameters: {'max_depth': 23, 'num_leaves': 46, 'learning_rate': 0.08138839128006958, 'min_child_weight': 0.6945371594559148, 'subsample': 0.7620471959133062, 'subsample_freq': 6, 'colsample_bytree': 0.7319429648821052, 'reg_alpha': 0.16718154767747795, 'reg_lambda': 1.6659575362483419, 'max_bin': 134}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:48:56,518] Trial 687 finished with value: -0.18494170416934136 and parameters: {'max_depth': 2, 'num_leaves': 44, 'learning_rate': 0.09169110203589592, 'min_child_weight': 0.8142803769025181, 'subsample': 0.74896413730616, 'subsample_freq': 6, 'colsample_bytree': 0.7468537362481835, 'reg_alpha': 0.19148041804100452, 'reg_lambda': 1.3364000343697353, 'max_bin': 104}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:49:15,100] Trial 688 finished with value: -0.28653401100603054 and parameters: {'max_depth': 27, 'num_leaves': 47, 'learning_rate': 0.08589160339690781, 'min_child_weight': 0.5868295548764247, 'subsample': 0.741180925658913, 'subsample_freq': 6, 'colsample_bytree': 0.7354609141233989, 'reg_alpha': 0.2506273963371009, 'reg_lambda': 1.9687765042835597, 'max_bin': 66}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:49:33,679] Trial 689 finished with value: -0.20989282526464986 and parameters: {'max_depth': 24, 'num_leaves': 45, 'learning_rate': 0.09135879500378782, 'min_child_weight': 0.48736448163130824, 'subsample': 0.7792428720807951, 'subsample_freq': 6, 'colsample_bytree': 0.9991141580644649, 'reg_alpha': 0.10187074953951421, 'reg_lambda': 1.2807013942254937, 'max_bin': 162}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:49:52,755] Trial 690 finished with value: -0.2691486486677072 and parameters: {'max_depth': 29, 'num_leaves': 47, 'learning_rate': 0.0832344824024506, 'min_child_weight': 0.2779159653479011, 'subsample': 0.7555068298257513, 'subsample_freq': 6, 'colsample_bytree': 0.7529539342396369, 'reg_alpha': 0.28903858307563846, 'reg_lambda': 1.559412488465116, 'max_bin': 114}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:50:12,681] Trial 691 finished with value: -0.2526552521658473 and parameters: {'max_depth': 25, 'num_leaves': 46, 'learning_rate': 0.08807746468549618, 'min_child_weight': 0.6906906928069947, 'subsample': 0.7443972394619962, 'subsample_freq': 6, 'colsample_bytree': 0.7272889324829317, 'reg_alpha': 0.13895798397816034, 'reg_lambda': 1.176329339296923, 'max_bin': 76}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:50:31,785] Trial 692 finished with value: -0.24294714600359396 and parameters: {'max_depth': 32, 'num_leaves': 43, 'learning_rate': 0.07995673432013094, 'min_child_weight': 0.6179027824164031, 'subsample': 0.7673148094878294, 'subsample_freq': 6, 'colsample_bytree': 0.7379233623434379, 'reg_alpha': 0.10235613967797473, 'reg_lambda': 1.2493300814301485, 'max_bin': 148}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:50:50,861] Trial 693 finished with value: -0.292973319489452 and parameters: {'max_depth': 28, 'num_leaves': 49, 'learning_rate': 0.09235169364363985, 'min_child_weight': 0.32966141114566855, 'subsample': 0.7439239823215138, 'subsample_freq': 6, 'colsample_bytree': 0.7296846792258347, 'reg_alpha': 0.2012130073771049, 'reg_lambda': 1.8000665436959935, 'max_bin': 125}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:51:11,189] Trial 694 finished with value: -0.28237401906142656 and parameters: {'max_depth': 22, 'num_leaves': 48, 'learning_rate': 0.08726369942749254, 'min_child_weight': 0.4404871130912797, 'subsample': 0.7602116394709469, 'subsample_freq': 6, 'colsample_bytree': 0.7622325300051227, 'reg_alpha': 0.15972323565648341, 'reg_lambda': 2.2500876951485886, 'max_bin': 139}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:51:28,599] Trial 695 finished with value: -0.2518835934055925 and parameters: {'max_depth': 8, 'num_leaves': 43, 'learning_rate': 0.09428972395748152, 'min_child_weight': 0.8389956673137613, 'subsample': 0.7386192444271943, 'subsample_freq': 1, 'colsample_bytree': 0.7443484122232266, 'reg_alpha': 0.1348612081179155, 'reg_lambda': 1.4992111306154676, 'max_bin': 117}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:51:48,189] Trial 696 finished with value: -0.23596389913631138 and parameters: {'max_depth': 20, 'num_leaves': 45, 'learning_rate': 0.08325008398253136, 'min_child_weight': 0.7061740564673024, 'subsample': 0.7470746222484023, 'subsample_freq': 6, 'colsample_bytree': 0.7710379238816716, 'reg_alpha': 0.08949593485528713, 'reg_lambda': 0.03442599886267888, 'max_bin': 183}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:52:07,082] Trial 697 finished with value: -0.2653265435424415 and parameters: {'max_depth': 30, 'num_leaves': 43, 'learning_rate': 0.08931153637776125, 'min_child_weight': 0.6067033135382992, 'subsample': 0.7552138766562992, 'subsample_freq': 8, 'colsample_bytree': 0.7301089609411554, 'reg_alpha': 0.3861021012363447, 'reg_lambda': 1.3943010027616771, 'max_bin': 130}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:52:25,631] Trial 698 finished with value: -0.2830986335132197 and parameters: {'max_depth': 28, 'num_leaves': 44, 'learning_rate': 0.07737187464980891, 'min_child_weight': 0.5004235690873559, 'subsample': 0.7758732516119842, 'subsample_freq': 6, 'colsample_bytree': 0.7387967783352382, 'reg_alpha': 0.1103773328671161, 'reg_lambda': 1.1382269751937673, 'max_bin': 105}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:52:44,580] Trial 699 finished with value: -0.2588641897037144 and parameters: {'max_depth': 26, 'num_leaves': 48, 'learning_rate': 0.09384323384977546, 'min_child_weight': 0.8594399085232046, 'subsample': 0.7321269125948882, 'subsample_freq': 6, 'colsample_bytree': 0.748600532955866, 'reg_alpha': 0.1861661514541122, 'reg_lambda': 1.7134650318834765, 'max_bin': 122}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:53:03,558] Trial 700 finished with value: -0.27883948007389536 and parameters: {'max_depth': 30, 'num_leaves': 42, 'learning_rate': 0.08560751043502147, 'min_child_weight': 0.7837342930974895, 'subsample': 0.7401220646858568, 'subsample_freq': 6, 'colsample_bytree': 0.7252339476452438, 'reg_alpha': 0.14333412512671828, 'reg_lambda': 1.224489269158192, 'max_bin': 226}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:53:22,071] Trial 701 finished with value: -0.22460905750351823 and parameters: {'max_depth': 23, 'num_leaves': 46, 'learning_rate': 0.0894266068555656, 'min_child_weight': 0.5640930446406562, 'subsample': 0.7325116735745962, 'subsample_freq': 4, 'colsample_bytree': 0.7565573073097605, 'reg_alpha': 0.10326689224136358, 'reg_lambda': 1.4125737217212446, 'max_bin': 86}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:53:40,813] Trial 702 finished with value: -0.3065240728562369 and parameters: {'max_depth': 32, 'num_leaves': 30, 'learning_rate': 0.08223139864853023, 'min_child_weight': 0.7122845062020815, 'subsample': 0.7520056498929254, 'subsample_freq': 6, 'colsample_bytree': 0.7218168429418459, 'reg_alpha': 0.057245741792625, 'reg_lambda': 1.086206459740026, 'max_bin': 141}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:53:59,580] Trial 703 finished with value: -0.2545581727690682 and parameters: {'max_depth': 32, 'num_leaves': 32, 'learning_rate': 0.09404667369947427, 'min_child_weight': 0.37439434763576795, 'subsample': 0.7658261318456266, 'subsample_freq': 6, 'colsample_bytree': 0.714544925670273, 'reg_alpha': 0.3063699851516619, 'reg_lambda': 1.0750128681724007, 'max_bin': 151}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:54:18,116] Trial 704 finished with value: -0.27117079611225126 and parameters: {'max_depth': 32, 'num_leaves': 30, 'learning_rate': 0.08258774147316074, 'min_child_weight': 0.6577131849035345, 'subsample': 0.7526736388267646, 'subsample_freq': 6, 'colsample_bytree': 0.726905243698585, 'reg_alpha': 0.05393119447756221, 'reg_lambda': 1.0665586078507805, 'max_bin': 145}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:54:37,200] Trial 705 finished with value: -0.30057871342877535 and parameters: {'max_depth': 32, 'num_leaves': 42, 'learning_rate': 0.07867866931182159, 'min_child_weight': 0.49220652248980756, 'subsample': 0.757127280359359, 'subsample_freq': 6, 'colsample_bytree': 0.7362018991625928, 'reg_alpha': 0.06465765909212275, 'reg_lambda': 1.3306879923321928, 'max_bin': 154}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:54:56,756] Trial 706 finished with value: -0.2854267742280542 and parameters: {'max_depth': 30, 'num_leaves': 30, 'learning_rate': 0.07707631678527022, 'min_child_weight': 0.3270072818339706, 'subsample': 0.7734471976600944, 'subsample_freq': 6, 'colsample_bytree': 0.7387555175475737, 'reg_alpha': 0.059920400151412305, 'reg_lambda': 1.108459835256757, 'max_bin': 168}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:55:15,635] Trial 707 finished with value: -0.26743258669310566 and parameters: {'max_depth': 29, 'num_leaves': 31, 'learning_rate': 0.07741459090195532, 'min_child_weight': 0.43729657388115295, 'subsample': 0.7581661547943228, 'subsample_freq': 6, 'colsample_bytree': 0.7184573129462918, 'reg_alpha': 0.04678492971595131, 'reg_lambda': 0.9759801618567169, 'max_bin': 158}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:55:35,279] Trial 708 finished with value: -0.26975786300640026 and parameters: {'max_depth': 31, 'num_leaves': 42, 'learning_rate': 0.08669891643530195, 'min_child_weight': 0.3889856987164169, 'subsample': 0.7647741805422232, 'subsample_freq': 6, 'colsample_bytree': 0.7483876901924953, 'reg_alpha': 0.04409859686608631, 'reg_lambda': 1.2346821463255135, 'max_bin': 161}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:55:53,815] Trial 709 finished with value: -0.26456862965595906 and parameters: {'max_depth': 28, 'num_leaves': 31, 'learning_rate': 0.09158177950256838, 'min_child_weight': 0.4621796464798443, 'subsample': 0.7442395356123942, 'subsample_freq': 6, 'colsample_bytree': 0.7370984553610054, 'reg_alpha': 0.07675589199495929, 'reg_lambda': 0.9558151727038366, 'max_bin': 138}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:56:12,632] Trial 710 finished with value: -0.27826883707533134 and parameters: {'max_depth': 30, 'num_leaves': 30, 'learning_rate': 0.09475689949622364, 'min_child_weight': 0.1691972501899263, 'subsample': 0.7598649065076327, 'subsample_freq': 6, 'colsample_bytree': 0.710337751661099, 'reg_alpha': 0.06183181288668725, 'reg_lambda': 2.193202421148359, 'max_bin': 140}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:56:31,775] Trial 711 finished with value: -0.29469928779806154 and parameters: {'max_depth': 32, 'num_leaves': 32, 'learning_rate': 0.08013763516409836, 'min_child_weight': 0.011174110896669375, 'subsample': 0.735672032023267, 'subsample_freq': 6, 'colsample_bytree': 0.7235803129577876, 'reg_alpha': 0.030992187165745803, 'reg_lambda': 1.6522303561562335, 'max_bin': 133}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:56:49,876] Trial 712 finished with value: -0.24307482898319316 and parameters: {'max_depth': 28, 'num_leaves': 20, 'learning_rate': 0.09645997387962994, 'min_child_weight': 0.5041023568016064, 'subsample': 0.7878078857931358, 'subsample_freq': 6, 'colsample_bytree': 0.736660427805694, 'reg_alpha': 0.07126874231211089, 'reg_lambda': 1.1381562847744455, 'max_bin': 152}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:57:10,441] Trial 713 finished with value: -0.29192144474488924 and parameters: {'max_depth': 30, 'num_leaves': 42, 'learning_rate': 0.08960465994505656, 'min_child_weight': 0.9059794910970966, 'subsample': 0.7468025474444608, 'subsample_freq': 6, 'colsample_bytree': 0.750727967925429, 'reg_alpha': 0.04491052933093613, 'reg_lambda': 1.305031234671471, 'max_bin': 131}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:57:29,555] Trial 714 finished with value: -0.25428353408630755 and parameters: {'max_depth': 27, 'num_leaves': 42, 'learning_rate': 0.07935279581851983, 'min_child_weight': 0.007393707937520077, 'subsample': 0.7793175439229214, 'subsample_freq': 6, 'colsample_bytree': 0.7231977312676607, 'reg_alpha': 0.05314275827689841, 'reg_lambda': 1.0254815524910412, 'max_bin': 175}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:57:48,697] Trial 715 finished with value: -0.286518389701147 and parameters: {'max_depth': 32, 'num_leaves': 42, 'learning_rate': 0.08646543038726084, 'min_child_weight': 0.3960923569271797, 'subsample': 0.7273290569318739, 'subsample_freq': 6, 'colsample_bytree': 0.7149195047055247, 'reg_alpha': 0.06732116314527156, 'reg_lambda': 0.9088004721789633, 'max_bin': 142}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:58:08,336] Trial 716 finished with value: -0.24798119449428263 and parameters: {'max_depth': 29, 'num_leaves': 30, 'learning_rate': 0.08430094485433134, 'min_child_weight': 0.5252328362980985, 'subsample': 0.769370274936653, 'subsample_freq': 6, 'colsample_bytree': 0.7413870108651472, 'reg_alpha': 0.05658796878114539, 'reg_lambda': 1.6775016725238343, 'max_bin': 153}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:58:28,174] Trial 717 finished with value: -0.2663200167747854 and parameters: {'max_depth': 26, 'num_leaves': 44, 'learning_rate': 0.09195162035641209, 'min_child_weight': 0.7298086721032596, 'subsample': 0.7361980830938675, 'subsample_freq': 6, 'colsample_bytree': 0.7304200195675679, 'reg_alpha': 0.03691062843735417, 'reg_lambda': 2.054813421684255, 'max_bin': 127}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:58:46,397] Trial 718 finished with value: -0.21811744675313333 and parameters: {'max_depth': 30, 'num_leaves': 43, 'learning_rate': 0.09794645643547102, 'min_child_weight': 0.6505741608445996, 'subsample': 0.7532965703045368, 'subsample_freq': 1, 'colsample_bytree': 0.7089532596114039, 'reg_alpha': 0.06119430031527035, 'reg_lambda': 1.449096162854202, 'max_bin': 133}. Best is trial 669 with value: -0.34478343800813044.
# [I 2022-06-18 23:59:04,994] Trial 719 finished with value: -0.2553059144339027 and parameters: {'max_depth': 28, 'num_leaves': 31, 'learning_rate': 0.08908094897871145, 'min_child_weight': 0.9091329502380165, 'subsample': 0.7269775275535201, 'subsample_freq': 6, 'colsample_bytree': 0.7600805410733028, 'reg_alpha': 0.07384939608847917, 'reg_lambda': 1.0602544774759026, 'max_bin': 142}. Best is trial 669 with value: -0.34478343800813044.
# [2022-06-19 07:59:04] {'max_depth': 27, 'num_leaves': 44, 'learning_rate': 0.08058431622110411, 'min_child_weight': 0.6744208400407078, 'subsample': 0.7517851247136174, 'subsample_freq': 6, 'colsample_bytree': 0.757174343130615, 'reg_alpha': 0.16445145651507795, 'reg_lambda': 1.3936539085795858, 'max_bin': 133}
# [2022-06-19 07:59:04] Best score is -0.34478343800813044
# CPU times: user 8h 40min 33s, sys: 1min 20s, total: 8h 41min 53s
# Wall time: 4h 10s

# %%
'''
Re-fit best model
'''
params = {'selected_feats': selected_feats, 
          'lgbm_var_params': best_params.copy(), 
          'lgbm_fixed_params': LGBM_FIXED_PARAMS, 
          'n_estimators': N_ESTIMATORS_REFIT, 
          'early_stopping_rounds': EARLY_STOPPING_ROUNDS_REFIT}

outputs = []
for fold in range(N_FOLD):
    outputs.append(train_model(fold, params, 'normal'))
    
cv_score = np.mean([x['best_score_'] for x in outputs])
cv_sharpe = np.mean([x['sharpe']['val'] for x in outputs])
log(f"Folds best iterations: {[x['best_iteration_'] for x in outputs]}")
log(f"Folds average num unique values in train: {[x['n_uniq_trn'] for x in outputs]}")
log(f"Folds average num unique values in validation: {[x['n_uniq_val'] for x in outputs]}")
log(f"Folds scores: {[x['best_score_'] for x in outputs]}")
log(f"Folds sharpes: {[x['sharpe']['val'] for x in outputs]}")
log(f'CV score: {cv_score}')
log(f'CV sharpe: {cv_sharpe}')
# Out:
# [2022-06-19 07:59:53] Folds best iterations: [25, 16, 7, 18, 23]
# [2022-06-19 07:59:53] Folds average num unique values in train: [1038.075, 1044.1333333333334, 306.45416666666665, 844.7291666666666, 825.7083333333334]
# [2022-06-19 07:59:53] Folds average num unique values in validation: [1056.7, 1117.1666666666667, 316.8833333333333, 833.35, 864.1]
# [2022-06-19 07:59:53] Folds scores: [0.6925158658046098, 0.6929171972584084, 0.6930311981548629, 0.6928479112442757, 0.6919745035155505]
# [2022-06-19 07:59:53] Folds sharpes: [0.5351524488901799, 0.268895822542659, 0.3033303188794933, 0.24239789626311428, 0.37414070346520567]
# [2022-06-19 07:59:53] CV score: 0.6926573351955415
# [2022-06-19 07:59:53] CV sharpe: 0.34478343800813044

# %%
'''
Signal Analysis
'''
analyze_signal(outputs)
# Out:
# [2022-06-19 07:59:56] Average % in top 200: 0.09739999999999999
# [2022-06-19 07:59:56] Average % in bottom 200: 0.10393333333333328
# [2022-06-19 07:59:57] Mean long returns: 0.15433336755147123
# [2022-06-19 07:59:57] Mean short returns: 0.18455870875346264
# [2022-06-19 07:59:57] Mean net returns: 0.3388920763049339
# [2022-06-19 07:59:57] Sharpe of long: 0.0714489195502813
# [2022-06-19 07:59:57] Sharpe of short: 0.07814254973870888
# [2022-06-19 07:59:57] Sharpe of net: 0.320044380620282

# %% [markdown]
# # Debug
